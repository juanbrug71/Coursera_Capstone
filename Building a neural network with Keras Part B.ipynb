# %% [markdown]
# ## Building a Regression Model using Keras

# %% [markdown]
# ### Table of contents
# 1. Donwnload and clean dataset
# 2. Import Keras
# 3. Build a Neural Network
# 4. Train and Test the Neural Network

# %% [markdown]
# ### Download and Clean Dataset

# %% [markdown]
# We will start by importing the necessary libraries for the project

# %%
import time
import os
import pandas as pd
import numpy as np


from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
conda install -c conda-forge keras
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The dataset that we will use is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used. The ingredients include:
# 1. Cement
# 2. Blast furnace slag
# 3. Fly ash
# 4. Water
# 5. Superplasticizer
# 6. Coarse aggregate
# 7. Fine aggregate

# %% [markdown]
# We will download the data and read it into a pandas daataframe

# %%
concrete_df = pd.read_csv("/Users/juan/Downloads/concrete_data.csv")
concrete_df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# The first sample consists of 540 cubic meters of cement, 0 cubic meters of blast furnace slag and fly ash, 162 cubic meters of water, 2.5 cubic meters of superplasticizer, 1040 cubic meters of fine aggregate, 676 cubic meters of fine aggregate and has a compressive strength of 79.99 MPa at 28 days.

# %% [markdown]
# Check how many data points we have in the data frame

# %%
concrete_df.shape
# Out:
# (1030, 9)

# %% [markdown]
# The next step is to check the dataset for any missing values

# %%
concrete_df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The dataset looks clean so we can proceed to build our model

# %% [markdown]
# #### Split data intro predictors and target

# %%
concrete_df_columns = concrete_df.columns
predictors = concrete_df[concrete_df_columns[concrete_df_columns != "Strength"]] # All columns except Strength
target = concrete_df["Strength"] #Only the column Strength

# %% [markdown]
# Check the first rows for the predictors and target data

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Let's save the number of predictors to n_cols variables, because we will need it when we build our network

# %%
n_cols = predictors.shape[1] #number of predictors

# %% [markdown]
# ### Importing packages from Keras library

# %% [markdown]
# Let's import the packages from the Keras library that we will need to build our regression model

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Part A: Build a baseline model

# %% [markdown]
# Use the Keras library to build a neural network with the following:
#
# One hidden layer of 10 nodes, and a ReLU activation function
#
# Use the adam optimizer and the mean squared error as the loss function.
#
# Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.
#
# Train the model on the training data using 50 epochs.
#
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# Report the mean and the standard deviation of the mean squared errors.

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# Let's create a function that defines our regression model and we can call it to create our model

# %%
#define the regression model with one hidden layer
def regression_model():
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(n_cols,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ####  Train and test the model

# %% [markdown]
# We will create the regression model

# %%
model = regression_model()
# Out:
# WARNING:tensorflow:From /Users/juan/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# Randomly split the data into a training and test sets by holding 30%  of the data for testing. You can use the train_test_split helper function

# %%
X = predictors
y = target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)

# %% [markdown]
# Train the model on the training data using 50 epochs

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# WARNING:tensorflow:From /Users/juan/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 0s - loss: 147687.0670
# Epoch 2/50
#  - 0s - loss: 88079.6639
# Epoch 3/50
#  - 0s - loss: 51429.6772
# Epoch 4/50
#  - 0s - loss: 25998.9317
# Epoch 5/50
#  - 0s - loss: 9984.8584
# Epoch 6/50
#  - 0s - loss: 3074.6764
# Epoch 7/50
#  - 0s - loss: 1320.3720
# Epoch 8/50
#  - 0s - loss: 1078.8339
# Epoch 9/50
#  - 0s - loss: 1031.8237
# Epoch 10/50
#  - 0s - loss: 987.4230
# Epoch 11/50
#  - 0s - loss: 942.8682
# Epoch 12/50
#  - 0s - loss: 902.3165
# Epoch 13/50
#  - 0s - loss: 860.6361
# Epoch 14/50
#  - 0s - loss: 822.1550
# Epoch 15/50
#  - 0s - loss: 785.2765
# Epoch 16/50
#  - 0s - loss: 749.7746
# Epoch 17/50
#  - 0s - loss: 717.2100
# Epoch 18/50
#  - 0s - loss: 687.6735
# Epoch 19/50
#  - 0s - loss: 656.7912
# Epoch 20/50
#  - 0s - loss: 628.9895
# Epoch 21/50
#  - 0s - loss: 602.8013
# Epoch 22/50
#  - 0s - loss: 578.7804
# Epoch 23/50
#  - 0s - loss: 555.5392
# Epoch 24/50
#  - 0s - loss: 534.8057
# Epoch 25/50
#  - 0s - loss: 515.3516
# Epoch 26/50
#  - 0s - loss: 497.1543
# Epoch 27/50
#  - 0s - loss: 479.3742
# Epoch 28/50
#  - 0s - loss: 463.9711
# Epoch 29/50
#  - 0s - loss: 447.4675
# Epoch 30/50
#  - 0s - loss: 433.7993
# Epoch 31/50
#  - 0s - loss: 421.5562
# Epoch 32/50
#  - 0s - loss: 410.8362
# Epoch 33/50
#  - 0s - loss: 398.3253
# Epoch 34/50
#  - 0s - loss: 386.6154
# Epoch 35/50
#  - 0s - loss: 376.5429
# Epoch 36/50
#  - 0s - loss: 366.8661
# Epoch 37/50
#  - 0s - loss: 357.7725
# Epoch 38/50
#  - 0s - loss: 349.9002
# Epoch 39/50
#  - 0s - loss: 342.0370
# Epoch 40/50
#  - 0s - loss: 334.7390
# Epoch 41/50
#  - 0s - loss: 327.9944
# Epoch 42/50
#  - 0s - loss: 323.3291
# Epoch 43/50
#  - 0s - loss: 315.1696
# Epoch 44/50
#  - 0s - loss: 309.9172
# Epoch 45/50
#  - 0s - loss: 303.9565
# Epoch 46/50
#  - 0s - loss: 299.0633
# Epoch 47/50
#  - 0s - loss: 293.9238
# Epoch 48/50
#  - 0s - loss: 289.3402
# Epoch 49/50
#  - 0s - loss: 284.7704
# Epoch 50/50
#  - 0s - loss: 280.5733

# %% [markdown]
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
y_hat = model.predict(X_test)   
mse = mean_squared_error(y_test, y_hat)

# %%
print(mse)
# Out:
# 284.2353282050415

# %% [markdown]
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors

# %% [markdown]
# We will create one function that performs steps 1 to 3 and another function that iterates 50 times and creates the list of 50 mean squared errors

# %%
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """   
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn. 
    X = predictors
    y = target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse

# %%
#Function to round the calculation of the mean and std deviation to 2 decimal places
def get_round(score, num_of_digits=2):
    """Get round with given number of decimal digits 
    """
    return round(score, num_of_digits)

#Function to calculate the mean of the list of mean squared errors
def get_mean(list_of_mse_scores):
    """Get mean
    """
    if list_of_mse_scores:
        return get_round(np.mean(list_of_mse_scores))
    return None

#Function to calculate the standard deviation of the list of mean squared errors
def get_standard_deviation(list_of_mse_scores):
    """Get standard deviation
    """
    if list_of_mse_scores:
        return get_round(np.std(list_of_mse_scores))
    return None




#Function to iterate and calculate the mean squared error
def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
    """Generate the mean and the standard deviation of the mean squared errors 
    """
    # Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.    
    list_of_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        list_of_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))
    # end for

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  list_of_mean_squared_errors))
    
    mean_mse = get_mean(list_of_mean_squared_errors)
    std_mse = get_standard_deviation(list_of_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse

# %%
max_iteration = 50
epochs = 50
verbose = 2

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 3325.9508
# Epoch 2/50
#  - 0s - loss: 1584.1490
# Epoch 3/50
#  - 0s - loss: 1251.4977
# Epoch 4/50
#  - 0s - loss: 1053.0818
# Epoch 5/50
#  - 0s - loss: 895.0838
# Epoch 6/50
#  - 0s - loss: 768.7322
# Epoch 7/50
#  - 0s - loss: 666.6994
# Epoch 8/50
#  - 0s - loss: 590.3865
# Epoch 9/50
#  - 0s - loss: 523.4443
# Epoch 10/50
#  - 0s - loss: 468.7924
# Epoch 11/50
#  - 0s - loss: 426.2245
# Epoch 12/50
#  - 0s - loss: 391.4226
# Epoch 13/50
#  - 0s - loss: 362.8815
# Epoch 14/50
#  - 0s - loss: 337.3791
# Epoch 15/50
#  - 0s - loss: 313.0196
# Epoch 16/50
#  - 0s - loss: 296.8287
# Epoch 17/50
#  - 0s - loss: 273.4657
# Epoch 18/50
#  - 0s - loss: 263.6529
# Epoch 19/50
#  - 0s - loss: 245.2958
# Epoch 20/50
#  - 0s - loss: 232.4135
# Epoch 21/50
#  - 0s - loss: 219.8393
# Epoch 22/50
#  - 0s - loss: 210.6402
# Epoch 23/50
#  - 0s - loss: 200.9771
# Epoch 24/50
#  - 0s - loss: 189.7150
# Epoch 25/50
#  - 0s - loss: 182.9502
# Epoch 26/50
#  - 0s - loss: 174.5668
# Epoch 27/50
#  - 0s - loss: 173.5401
# Epoch 28/50
#  - 0s - loss: 165.5787
# Epoch 29/50
#  - 0s - loss: 157.8165
# Epoch 30/50
#  - 0s - loss: 150.7188
# Epoch 31/50
#  - 0s - loss: 146.4856
# Epoch 32/50
#  - 0s - loss: 142.4047
# Epoch 33/50
#  - 0s - loss: 141.0014
# Epoch 34/50
#  - 0s - loss: 137.1928
# Epoch 35/50
#  - 0s - loss: 134.1842
# Epoch 36/50
#  - 0s - loss: 132.6268
# Epoch 37/50
#  - 0s - loss: 128.0227
# Epoch 38/50
#  - 0s - loss: 129.1394
# Epoch 39/50
#  - 0s - loss: 124.8833
# Epoch 40/50
#  - 0s - loss: 122.8759
# Epoch 41/50
#  - 0s - loss: 121.5429
# Epoch 42/50
#  - 0s - loss: 120.7721
# Epoch 43/50
#  - 0s - loss: 118.8953
# Epoch 44/50
#  - 0s - loss: 119.0220
# Epoch 45/50
#  - 0s - loss: 117.1248
# Epoch 46/50
#  - 0s - loss: 117.0399
# Epoch 47/50
#  - 0s - loss: 115.5079
# Epoch 48/50
#  - 0s - loss: 113.6928
# Epoch 49/50
#  - 0s - loss: 115.5095
# Epoch 50/50
#  - 0s - loss: 116.3679
# Duration (seconds): 2.634979248046875
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 113.4460
# Epoch 2/50
#  - 0s - loss: 111.8800
# Epoch 3/50
#  - 0s - loss: 111.3595
# Epoch 4/50
#  - 0s - loss: 111.0611
# Epoch 5/50
#  - 0s - loss: 116.5003
# Epoch 6/50
#  - 0s - loss: 110.4696
# Epoch 7/50
#  - 0s - loss: 110.6171
# Epoch 8/50
#  - 0s - loss: 110.8319
# Epoch 9/50
#  - 0s - loss: 108.4987
# Epoch 10/50
#  - 0s - loss: 108.3852
# Epoch 11/50
#  - 0s - loss: 108.1914
# Epoch 12/50
#  - 0s - loss: 108.6169
# Epoch 13/50
#  - 0s - loss: 111.6811
# Epoch 14/50
#  - 0s - loss: 109.0123
# Epoch 15/50
#  - 0s - loss: 108.6196
# Epoch 16/50
#  - 0s - loss: 112.5439
# Epoch 17/50
#  - 0s - loss: 108.0254
# Epoch 18/50
#  - 0s - loss: 107.0287
# Epoch 19/50
#  - 0s - loss: 107.4349
# Epoch 20/50
#  - 0s - loss: 110.4408
# Epoch 21/50
#  - 0s - loss: 106.1767
# Epoch 22/50
#  - 0s - loss: 114.1344
# Epoch 23/50
#  - 0s - loss: 107.9600
# Epoch 24/50
#  - 0s - loss: 106.1788
# Epoch 25/50
#  - 0s - loss: 106.3902
# Epoch 26/50
#  - 0s - loss: 107.3663
# Epoch 27/50
#  - 0s - loss: 106.1514
# Epoch 28/50
#  - 0s - loss: 105.9044
# Epoch 29/50
#  - 0s - loss: 110.8764
# Epoch 30/50
#  - 0s - loss: 113.0923
# Epoch 31/50
#  - 0s - loss: 106.1642
# Epoch 32/50
#  - 0s - loss: 111.5292
# Epoch 33/50
#  - 0s - loss: 109.9263
# Epoch 34/50
#  - 0s - loss: 105.9595
# Epoch 35/50
#  - 0s - loss: 110.2075
# Epoch 36/50
#  - 0s - loss: 108.5870
# Epoch 37/50
#  - 0s - loss: 108.0932
# Epoch 38/50
#  - 0s - loss: 106.5773
# Epoch 39/50
#  - 0s - loss: 105.2386
# Epoch 40/50
#  - 0s - loss: 105.8845
# Epoch 41/50
#  - 0s - loss: 105.3143
# Epoch 42/50
#  - 0s - loss: 105.5873
# Epoch 43/50
#  - 0s - loss: 106.1653
# Epoch 44/50
#  - 0s - loss: 105.2151
# Epoch 45/50
#  - 0s - loss: 107.8376
# Epoch 46/50
#  - 0s - loss: 109.8029
# Epoch 47/50
#  - 0s - loss: 110.0069
# Epoch 48/50
#  - 0s - loss: 105.4488
# Epoch 49/50
#  - 0s - loss: 107.2344
# Epoch 50/50
#  - 0s - loss: 109.0251
# Duration (seconds): 2.260143995285034
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 104.9015
# Epoch 2/50
#  - 0s - loss: 105.5174
# Epoch 3/50
#  - 0s - loss: 109.3502
# Epoch 4/50
#  - 0s - loss: 107.3705
# Epoch 5/50
#  - 0s - loss: 106.2415
# Epoch 6/50
#  - 0s - loss: 106.3745
# Epoch 7/50
#  - 0s - loss: 106.8143
# Epoch 8/50
#  - 0s - loss: 108.0229
# Epoch 9/50
#  - 0s - loss: 107.1274
# Epoch 10/50
#  - 0s - loss: 104.3520
# Epoch 11/50
#  - 0s - loss: 109.2974
# Epoch 12/50
#  - 0s - loss: 106.2156
# Epoch 13/50
#  - 0s - loss: 109.1781
# Epoch 14/50
#  - 0s - loss: 107.7314
# Epoch 15/50
#  - 0s - loss: 106.8672
# Epoch 16/50
#  - 0s - loss: 106.2622
# Epoch 17/50
#  - 0s - loss: 107.2071
# Epoch 18/50
#  - 0s - loss: 107.1675
# Epoch 19/50
#  - 0s - loss: 106.4300
# Epoch 20/50
#  - 0s - loss: 104.2813
# Epoch 21/50
#  - 0s - loss: 105.8039
# Epoch 22/50
#  - 0s - loss: 109.2242
# Epoch 23/50
#  - 0s - loss: 107.5125
# Epoch 24/50
#  - 0s - loss: 111.0773
# Epoch 25/50
#  - 0s - loss: 109.2523
# Epoch 26/50
#  - 0s - loss: 105.6761
# Epoch 27/50
#  - 0s - loss: 106.9290
# Epoch 28/50
#  - 0s - loss: 106.2446
# Epoch 29/50
#  - 0s - loss: 107.7901
# Epoch 30/50
#  - 0s - loss: 105.3438
# Epoch 31/50
#  - 0s - loss: 106.8270
# Epoch 32/50
#  - 0s - loss: 106.9492
# Epoch 33/50
#  - 0s - loss: 105.3421
# Epoch 34/50
#  - 0s - loss: 104.3010
# Epoch 35/50
#  - 0s - loss: 105.8832
# Epoch 36/50
#  - 0s - loss: 104.9293
# Epoch 37/50
#  - 0s - loss: 106.2908
# Epoch 38/50
#  - 0s - loss: 106.1114
# Epoch 39/50
#  - 0s - loss: 109.0233
# Epoch 40/50
#  - 0s - loss: 106.5877
# Epoch 41/50
#  - 0s - loss: 109.1702
# Epoch 42/50
#  - 0s - loss: 113.7544
# Epoch 43/50
#  - 0s - loss: 105.3377
# Epoch 44/50
#  - 0s - loss: 104.5197
# Epoch 45/50
#  - 0s - loss: 107.4074
# Epoch 46/50
#  - 0s - loss: 106.4862
# Epoch 47/50
#  - 0s - loss: 104.4239
# Epoch 48/50
#  - 0s - loss: 106.4971
# Epoch 49/50
#  - 0s - loss: 103.2979
# Epoch 50/50
#  - 0s - loss: 104.6971
# Duration (seconds): 2.169996976852417
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 102.2383
# Epoch 2/50
#  - 0s - loss: 104.0673
# Epoch 3/50
#  - 0s - loss: 102.6300
# Epoch 4/50
#  - 0s - loss: 105.1669
# Epoch 5/50
#  - 0s - loss: 101.9537
# Epoch 6/50
#  - 0s - loss: 99.5001
# Epoch 7/50
#  - 0s - loss: 106.1277
# Epoch 8/50
#  - 0s - loss: 101.5310
# Epoch 9/50
#  - 0s - loss: 106.6618
# Epoch 10/50
#  - 0s - loss: 107.2049
# Epoch 11/50
#  - 0s - loss: 101.8056
# Epoch 12/50
#  - 0s - loss: 98.2513
# Epoch 13/50
#  - 0s - loss: 102.5577
# Epoch 14/50
#  - 0s - loss: 102.6151
# Epoch 15/50
#  - 0s - loss: 104.6630
# Epoch 16/50
#  - 0s - loss: 96.5882
# Epoch 17/50
#  - 0s - loss: 97.5002
# Epoch 18/50
#  - 0s - loss: 99.2521
# Epoch 19/50
#  - 0s - loss: 96.5600
# Epoch 20/50
#  - 0s - loss: 99.1333
# Epoch 21/50
#  - 0s - loss: 97.2850
# Epoch 22/50
#  - 0s - loss: 93.2990
# Epoch 23/50
#  - 0s - loss: 93.3900
# Epoch 24/50
#  - 0s - loss: 94.2078
# Epoch 25/50
#  - 0s - loss: 91.7117
# Epoch 26/50
#  - 0s - loss: 92.6772
# Epoch 27/50
#  - 0s - loss: 90.7406
# Epoch 28/50
#  - 0s - loss: 92.9726
# Epoch 29/50
#  - 0s - loss: 94.5978
# Epoch 30/50
#  - 0s - loss: 88.6881
# Epoch 31/50
#  - 0s - loss: 86.3375
# Epoch 32/50
#  - 0s - loss: 85.6086
# Epoch 33/50
#  - 0s - loss: 85.9577
# Epoch 34/50
#  - 0s - loss: 84.5770
# Epoch 35/50
#  - 0s - loss: 86.2564
# Epoch 36/50
#  - 0s - loss: 84.4603
# Epoch 37/50
#  - 0s - loss: 84.1265
# Epoch 38/50
#  - 0s - loss: 82.6684
# Epoch 39/50
#  - 0s - loss: 89.8443
# Epoch 40/50
#  - 0s - loss: 83.5078
# Epoch 41/50
#  - 0s - loss: 81.9116
# Epoch 42/50
#  - 0s - loss: 82.3699
# Epoch 43/50
#  - 0s - loss: 80.3196
# Epoch 44/50
#  - 0s - loss: 82.3737
# Epoch 45/50
#  - 0s - loss: 81.8827
# Epoch 46/50
#  - 0s - loss: 79.1028
# Epoch 47/50
#  - 0s - loss: 81.2779
# Epoch 48/50
#  - 0s - loss: 81.7492
# Epoch 49/50
#  - 0s - loss: 88.4463
# Epoch 50/50
#  - 0s - loss: 80.0049
# Duration (seconds): 2.2478699684143066
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 78.2396
# Epoch 2/50
#  - 0s - loss: 81.0505
# Epoch 3/50
#  - 0s - loss: 77.5545
# Epoch 4/50
#  - 0s - loss: 79.5434
# Epoch 5/50
#  - 0s - loss: 76.9037
# Epoch 6/50
#  - 0s - loss: 77.3295
# Epoch 7/50
#  - 0s - loss: 76.4904
# Epoch 8/50
#  - 0s - loss: 76.5978
# Epoch 9/50
#  - 0s - loss: 79.8146
# Epoch 10/50
#  - 0s - loss: 80.0184
# Epoch 11/50
#  - 0s - loss: 76.2079
# Epoch 12/50
#  - 0s - loss: 77.3326
# Epoch 13/50
#  - 0s - loss: 75.3681
# Epoch 14/50
#  - 0s - loss: 76.3891
# Epoch 15/50
#  - 0s - loss: 75.6678
# Epoch 16/50
#  - 0s - loss: 76.3893
# Epoch 17/50
#  - 0s - loss: 75.5928
# Epoch 18/50
#  - 0s - loss: 74.2074
# Epoch 19/50
#  - 0s - loss: 74.9346
# Epoch 20/50
#  - 0s - loss: 75.3928
# Epoch 21/50
#  - 0s - loss: 76.0487
# Epoch 22/50
#  - 0s - loss: 74.0790
# Epoch 23/50
#  - 0s - loss: 73.3333
# Epoch 24/50
#  - 0s - loss: 74.0190
# Epoch 25/50
#  - 0s - loss: 77.2779
# Epoch 26/50
#  - 0s - loss: 77.1906
# Epoch 27/50
#  - 0s - loss: 74.6332
# Epoch 28/50
#  - 0s - loss: 76.5086
# Epoch 29/50
#  - 0s - loss: 74.6635
# Epoch 30/50
#  - 0s - loss: 77.0892
# Epoch 31/50
#  - 0s - loss: 73.9354
# Epoch 32/50
#  - 0s - loss: 72.6105
# Epoch 33/50
#  - 0s - loss: 77.7118
# Epoch 34/50
#  - 0s - loss: 75.8064
# Epoch 35/50
#  - 0s - loss: 72.9483
# Epoch 36/50
#  - 0s - loss: 73.8364
# Epoch 37/50
#  - 0s - loss: 73.9922
# Epoch 38/50
#  - 0s - loss: 74.0450
# Epoch 39/50
#  - 0s - loss: 73.0911
# Epoch 40/50
#  - 0s - loss: 71.8240
# Epoch 41/50
#  - 0s - loss: 79.1745
# Epoch 42/50
#  - 0s - loss: 71.7843
# Epoch 43/50
#  - 0s - loss: 72.9863
# Epoch 44/50
#  - 0s - loss: 73.3166
# Epoch 45/50
#  - 0s - loss: 71.9555
# Epoch 46/50
#  - 0s - loss: 71.7487
# Epoch 47/50
#  - 0s - loss: 70.9455
# Epoch 48/50
#  - 0s - loss: 71.0226
# Epoch 49/50
#  - 0s - loss: 71.7277
# Epoch 50/50
#  - 0s - loss: 74.2110
# Duration (seconds): 2.161738872528076
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 74.1153
# Epoch 2/50
#  - 0s - loss: 74.7647
# Epoch 3/50
#  - 0s - loss: 70.4586
# Epoch 4/50
#  - 0s - loss: 71.1206
# Epoch 5/50
#  - 0s - loss: 70.1283
# Epoch 6/50
#  - 0s - loss: 70.0993
# Epoch 7/50
#  - 0s - loss: 72.7339
# Epoch 8/50
#  - 0s - loss: 74.5425
# Epoch 9/50
#  - 0s - loss: 72.3849
# Epoch 10/50
#  - 0s - loss: 69.3176
# Epoch 11/50
#  - 0s - loss: 73.2146
# Epoch 12/50
#  - 0s - loss: 70.0814
# Epoch 13/50
#  - 0s - loss: 70.1428
# Epoch 14/50
#  - 0s - loss: 70.0489
# Epoch 15/50
#  - 0s - loss: 69.8005
# Epoch 16/50
#  - 0s - loss: 70.2883
# Epoch 17/50
#  - 0s - loss: 73.1461
# Epoch 18/50
#  - 0s - loss: 73.0147
# Epoch 19/50
#  - 0s - loss: 74.3570
# Epoch 20/50
#  - 0s - loss: 71.9599
# Epoch 21/50
#  - 0s - loss: 71.9930
# Epoch 22/50
#  - 0s - loss: 70.2549
# Epoch 23/50
#  - 0s - loss: 77.2316
# Epoch 24/50
#  - 0s - loss: 73.5883
# Epoch 25/50
#  - 0s - loss: 69.3016
# Epoch 26/50
#  - 0s - loss: 69.4066
# Epoch 27/50
#  - 0s - loss: 69.2151
# Epoch 28/50
#  - 0s - loss: 72.0674
# Epoch 29/50
#  - 0s - loss: 71.8729
# Epoch 30/50
#  - 0s - loss: 74.2614
# Epoch 31/50
#  - 0s - loss: 69.7412
# Epoch 32/50
#  - 0s - loss: 69.3865
# Epoch 33/50
#  - 0s - loss: 72.3987
# Epoch 34/50
#  - 0s - loss: 69.4856
# Epoch 35/50
#  - 0s - loss: 69.0300
# Epoch 36/50
#  - 0s - loss: 67.9735
# Epoch 37/50
#  - 0s - loss: 69.1023
# Epoch 38/50
#  - 0s - loss: 69.3797
# Epoch 39/50
#  - 0s - loss: 70.6937
# Epoch 40/50
#  - 0s - loss: 69.2446
# Epoch 41/50
#  - 0s - loss: 69.7165
# Epoch 42/50
#  - 0s - loss: 68.3361
# Epoch 43/50
#  - 0s - loss: 73.8814
# Epoch 44/50
#  - 0s - loss: 71.3426
# Epoch 45/50
#  - 0s - loss: 74.9065
# Epoch 46/50
#  - 0s - loss: 70.1996
# Epoch 47/50
#  - 0s - loss: 68.8982
# Epoch 48/50
#  - 0s - loss: 68.3824
# Epoch 49/50
#  - 0s - loss: 69.9885
# Epoch 50/50
#  - 0s - loss: 68.2167
# Duration (seconds): 2.2832250595092773
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 69.8081
# Epoch 2/50
#  - 0s - loss: 68.9491
# Epoch 3/50
#  - 0s - loss: 68.2086
# Epoch 4/50
#  - 0s - loss: 67.8824
# Epoch 5/50
#  - 0s - loss: 70.5190
# Epoch 6/50
#  - 0s - loss: 71.2203
# Epoch 7/50
#  - 0s - loss: 74.1450
# Epoch 8/50
#  - 0s - loss: 67.9945
# Epoch 9/50
#  - 0s - loss: 74.7431
# Epoch 10/50
#  - 0s - loss: 68.2631
# Epoch 11/50
#  - 0s - loss: 67.9493
# Epoch 12/50
#  - 0s - loss: 67.3514
# Epoch 13/50
#  - 0s - loss: 66.0793
# Epoch 14/50
#  - 0s - loss: 67.0859
# Epoch 15/50
#  - 0s - loss: 70.2274
# Epoch 16/50
#  - 0s - loss: 72.0921
# Epoch 17/50
#  - 0s - loss: 67.4181
# Epoch 18/50
#  - 0s - loss: 65.7864
# Epoch 19/50
#  - 0s - loss: 67.4637
# Epoch 20/50
#  - 0s - loss: 71.1738
# Epoch 21/50
#  - 0s - loss: 72.3719
# Epoch 22/50
#  - 0s - loss: 71.6126
# Epoch 23/50
#  - 0s - loss: 67.1265
# Epoch 24/50
#  - 0s - loss: 66.2909
# Epoch 25/50
#  - 0s - loss: 66.6565
# Epoch 26/50
#  - 0s - loss: 66.1524
# Epoch 27/50
#  - 0s - loss: 66.2121
# Epoch 28/50
#  - 0s - loss: 66.2271
# Epoch 29/50
#  - 0s - loss: 66.1491
# Epoch 30/50
#  - 0s - loss: 67.6909
# Epoch 31/50
#  - 0s - loss: 65.5642
# Epoch 32/50
#  - 0s - loss: 66.3469
# Epoch 33/50
#  - 0s - loss: 65.2354
# Epoch 34/50
#  - 0s - loss: 64.4932
# Epoch 35/50
#  - 0s - loss: 64.2264
# Epoch 36/50
#  - 0s - loss: 65.0356
# Epoch 37/50
#  - 0s - loss: 65.9779
# Epoch 38/50
#  - 0s - loss: 73.6573
# Epoch 39/50
#  - 0s - loss: 65.2905
# Epoch 40/50
#  - 0s - loss: 63.9094
# Epoch 41/50
#  - 0s - loss: 64.9959
# Epoch 42/50
#  - 0s - loss: 68.2856
# Epoch 43/50
#  - 0s - loss: 65.4168
# Epoch 44/50
#  - 0s - loss: 64.1857
# Epoch 45/50
#  - 0s - loss: 65.3157
# Epoch 46/50
#  - 0s - loss: 64.4674
# Epoch 47/50
#  - 0s - loss: 65.1305
# Epoch 48/50
#  - 0s - loss: 62.9800
# Epoch 49/50
#  - 0s - loss: 62.3575
# Epoch 50/50
#  - 0s - loss: 63.4849
# Duration (seconds): 3.6130831241607666
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 62.9408
# Epoch 2/50
#  - 0s - loss: 63.6927
# Epoch 3/50
#  - 0s - loss: 62.3861
# Epoch 4/50
#  - 0s - loss: 63.6220
# Epoch 5/50
#  - 0s - loss: 62.8001
# Epoch 6/50
#  - 0s - loss: 61.9458
# Epoch 7/50
#  - 0s - loss: 61.7652
# Epoch 8/50
#  - 0s - loss: 61.2173
# Epoch 9/50
#  - 0s - loss: 62.1831
# Epoch 10/50
#  - 0s - loss: 61.4805
# Epoch 11/50
#  - 0s - loss: 63.7173
# Epoch 12/50
#  - 0s - loss: 62.1225
# Epoch 13/50
#  - 0s - loss: 65.6395
# Epoch 14/50
#  - 0s - loss: 61.5539
# Epoch 15/50
#  - 0s - loss: 60.5404
# Epoch 16/50
#  - 0s - loss: 61.5951
# Epoch 17/50
#  - 0s - loss: 62.2073
# Epoch 18/50
#  - 0s - loss: 61.5944
# Epoch 19/50
#  - 0s - loss: 63.4514
# Epoch 20/50
#  - 0s - loss: 63.6214
# Epoch 21/50
#  - 0s - loss: 65.7470
# Epoch 22/50
#  - 0s - loss: 60.8250
# Epoch 23/50
#  - 0s - loss: 61.6917
# Epoch 24/50
#  - 0s - loss: 62.7699
# Epoch 25/50
#  - 0s - loss: 61.2578
# Epoch 26/50
#  - 0s - loss: 60.1806
# Epoch 27/50
#  - 0s - loss: 60.2586
# Epoch 28/50
#  - 0s - loss: 59.7537
# Epoch 29/50
#  - 0s - loss: 63.9737
# Epoch 30/50
#  - 0s - loss: 62.5298
# Epoch 31/50
#  - 0s - loss: 66.6234
# Epoch 32/50
#  - 0s - loss: 61.3951
# Epoch 33/50
#  - 0s - loss: 60.2224
# Epoch 34/50
#  - 0s - loss: 59.2459
# Epoch 35/50
#  - 0s - loss: 58.5232
# Epoch 36/50
#  - 0s - loss: 59.9535
# Epoch 37/50
#  - 0s - loss: 59.5603
# Epoch 38/50
#  - 0s - loss: 58.3726
# Epoch 39/50
#  - 0s - loss: 58.6067
# Epoch 40/50
#  - 0s - loss: 63.1131
# Epoch 41/50
#  - 0s - loss: 64.1580
# Epoch 42/50
#  - 0s - loss: 60.5948
# Epoch 43/50
#  - 0s - loss: 63.0570
# Epoch 44/50
#  - 0s - loss: 63.2374
# Epoch 45/50
#  - 0s - loss: 61.0252
# Epoch 46/50
#  - 0s - loss: 58.1731
# Epoch 47/50
#  - 0s - loss: 58.8292
# Epoch 48/50
#  - 0s - loss: 62.3961
# Epoch 49/50
#  - 0s - loss: 58.6172
# Epoch 50/50
#  - 0s - loss: 58.9164
# Duration (seconds): 2.1503419876098633
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 58.9908
# Epoch 2/50
#  - 0s - loss: 58.5623
# Epoch 3/50
#  - 0s - loss: 59.3663
# Epoch 4/50
#  - 0s - loss: 59.0728
# Epoch 5/50
#  - 0s - loss: 58.6819
# Epoch 6/50
#  - 0s - loss: 65.6086
# Epoch 7/50
#  - 0s - loss: 58.8894
# Epoch 8/50
#  - 0s - loss: 58.7803
# Epoch 9/50
#  - 0s - loss: 69.4912
# Epoch 10/50
#  - 0s - loss: 62.2798
# Epoch 11/50
#  - 0s - loss: 59.0664
# Epoch 12/50
#  - 0s - loss: 58.3873
# Epoch 13/50
#  - 0s - loss: 57.7913
# Epoch 14/50
#  - 0s - loss: 59.5273
# Epoch 15/50
#  - 0s - loss: 57.6319
# Epoch 16/50
#  - 0s - loss: 57.2795
# Epoch 17/50
#  - 0s - loss: 57.6784
# Epoch 18/50
#  - 0s - loss: 57.6973
# Epoch 19/50
#  - 0s - loss: 56.8793
# Epoch 20/50
#  - 0s - loss: 59.2561
# Epoch 21/50
#  - 0s - loss: 58.6792
# Epoch 22/50
#  - 0s - loss: 57.8343
# Epoch 23/50
#  - 0s - loss: 58.1996
# Epoch 24/50
#  - 0s - loss: 56.7387
# Epoch 25/50
#  - 0s - loss: 57.8254
# Epoch 26/50
#  - 0s - loss: 61.2710
# Epoch 27/50
#  - 0s - loss: 60.3798
# Epoch 28/50
#  - 0s - loss: 58.5109
# Epoch 29/50
#  - 0s - loss: 57.5649
# Epoch 30/50
#  - 0s - loss: 56.9222
# Epoch 31/50
#  - 0s - loss: 56.6987
# Epoch 32/50
#  - 0s - loss: 56.0782
# Epoch 33/50
#  - 0s - loss: 59.9972
# Epoch 34/50
#  - 0s - loss: 57.7621
# Epoch 35/50
#  - 0s - loss: 55.8887
# Epoch 36/50
#  - 0s - loss: 60.5227
# Epoch 37/50
#  - 0s - loss: 58.9567
# Epoch 38/50
#  - 0s - loss: 56.0150
# Epoch 39/50
#  - 0s - loss: 59.6635
# Epoch 40/50
#  - 0s - loss: 59.3762
# Epoch 41/50
#  - 0s - loss: 56.6565
# Epoch 42/50
#  - 0s - loss: 56.6752
# Epoch 43/50
#  - 0s - loss: 56.0039
# Epoch 44/50
#  - 0s - loss: 55.5341
# Epoch 45/50
#  - 0s - loss: 56.7367
# Epoch 46/50
#  - 0s - loss: 55.6486
# Epoch 47/50
#  - 0s - loss: 56.5199
# Epoch 48/50
#  - 0s - loss: 57.5210
# Epoch 49/50
#  - 0s - loss: 55.6959
# Epoch 50/50
#  - 0s - loss: 59.8277
# Duration (seconds): 1.7212269306182861
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 57.8628
# Epoch 2/50
#  - 0s - loss: 56.5607
# Epoch 3/50
#  - 0s - loss: 57.6017
# Epoch 4/50
#  - 0s - loss: 55.7961
# Epoch 5/50
#  - 0s - loss: 58.1039
# Epoch 6/50
#  - 0s - loss: 55.0820
# Epoch 7/50
#  - 0s - loss: 55.4161
# Epoch 8/50
#  - 0s - loss: 62.6734
# Epoch 9/50
#  - 0s - loss: 56.5540
# Epoch 10/50
#  - 0s - loss: 55.2204
# Epoch 11/50
#  - 0s - loss: 54.8664
# Epoch 12/50
#  - 0s - loss: 54.4142
# Epoch 13/50
#  - 0s - loss: 56.9607
# Epoch 14/50
#  - 0s - loss: 65.4322
# Epoch 15/50
#  - 0s - loss: 66.4349
# Epoch 16/50
#  - 0s - loss: 57.3978
# Epoch 17/50
#  - 0s - loss: 54.5249
# Epoch 18/50
#  - 0s - loss: 61.4063
# Epoch 19/50
#  - 0s - loss: 60.1167
# Epoch 20/50
#  - 0s - loss: 53.9485
# Epoch 21/50
#  - 0s - loss: 55.7031
# Epoch 22/50
#  - 0s - loss: 58.1793
# Epoch 23/50
#  - 0s - loss: 54.8771
# Epoch 24/50
#  - 0s - loss: 55.0615
# Epoch 25/50
#  - 0s - loss: 53.2694
# Epoch 26/50
#  - 0s - loss: 54.2327
# Epoch 27/50
#  - 0s - loss: 54.1392
# Epoch 28/50
#  - 0s - loss: 54.0485
# Epoch 29/50
#  - 0s - loss: 53.2482
# Epoch 30/50
#  - 0s - loss: 54.2412
# Epoch 31/50
#  - 0s - loss: 54.6015
# Epoch 32/50
#  - 0s - loss: 55.1800
# Epoch 33/50
#  - 0s - loss: 56.0105
# Epoch 34/50
#  - 0s - loss: 53.9857
# Epoch 35/50
#  - 0s - loss: 54.0530
# Epoch 36/50
#  - 0s - loss: 52.9664
# Epoch 37/50
#  - 0s - loss: 56.4563
# Epoch 38/50
#  - 0s - loss: 53.2159
# Epoch 39/50
#  - 0s - loss: 52.9404
# Epoch 40/50
#  - 0s - loss: 53.9262
# Epoch 41/50
#  - 0s - loss: 55.0914
# Epoch 42/50
#  - 0s - loss: 53.2822
# Epoch 43/50
#  - 0s - loss: 53.5685
# Epoch 44/50
#  - 0s - loss: 60.0192
# Epoch 45/50
#  - 0s - loss: 58.9093
# Epoch 46/50
#  - 0s - loss: 53.7766
# Epoch 47/50
#  - 0s - loss: 51.8247
# Epoch 48/50
#  - 0s - loss: 52.7333
# Epoch 49/50
#  - 0s - loss: 52.9864
# Epoch 50/50
#  - 0s - loss: 58.1641
# Duration (seconds): 1.811479091644287
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 53.2420
# Epoch 2/50
#  - 0s - loss: 52.1981
# Epoch 3/50
#  - 0s - loss: 51.7493
# Epoch 4/50
#  - 0s - loss: 51.6682
# Epoch 5/50
#  - 0s - loss: 53.0283
# Epoch 6/50
#  - 0s - loss: 53.9543
# Epoch 7/50
#  - 0s - loss: 54.0522
# Epoch 8/50
#  - 0s - loss: 53.8285
# Epoch 9/50
#  - 0s - loss: 54.6891
# Epoch 10/50
#  - 0s - loss: 52.1130
# Epoch 11/50
#  - 0s - loss: 55.0529
# Epoch 12/50
#  - 0s - loss: 53.0481
# Epoch 13/50
#  - 0s - loss: 52.4373
# Epoch 14/50
#  - 0s - loss: 54.1977
# Epoch 15/50
#  - 0s - loss: 52.9144
# Epoch 16/50
#  - 0s - loss: 54.9076
# Epoch 17/50
#  - 0s - loss: 52.5827
# Epoch 18/50
#  - 0s - loss: 52.6591
# Epoch 19/50
#  - 0s - loss: 53.1488
# Epoch 20/50
#  - 0s - loss: 52.2061
# Epoch 21/50
#  - 0s - loss: 52.7658
# Epoch 22/50
#  - 0s - loss: 54.2457
# Epoch 23/50
#  - 0s - loss: 51.1957
# Epoch 24/50
#  - 0s - loss: 51.2725
# Epoch 25/50
#  - 0s - loss: 54.8192
# Epoch 26/50
#  - 0s - loss: 54.4957
# Epoch 27/50
#  - 0s - loss: 51.4782
# Epoch 28/50
#  - 0s - loss: 51.7622
# Epoch 29/50
#  - 0s - loss: 51.3351
# Epoch 30/50
#  - 0s - loss: 53.0535
# Epoch 31/50
#  - 0s - loss: 51.9639
# Epoch 32/50
#  - 0s - loss: 52.5182
# Epoch 33/50
#  - 0s - loss: 57.1874
# Epoch 34/50
#  - 0s - loss: 51.5949
# Epoch 35/50
#  - 0s - loss: 51.8432
# Epoch 36/50
#  - 0s - loss: 51.4979
# Epoch 37/50
#  - 0s - loss: 53.5560
# Epoch 38/50
#  - 0s - loss: 51.8311
# Epoch 39/50
#  - 0s - loss: 51.6544
# Epoch 40/50
#  - 0s - loss: 53.2245
# Epoch 41/50
#  - 0s - loss: 51.4346
# Epoch 42/50
#  - 0s - loss: 54.8516
# Epoch 43/50
#  - 0s - loss: 50.8514
# Epoch 44/50
#  - 0s - loss: 55.6775
# Epoch 45/50
#  - 0s - loss: 51.6989
# Epoch 46/50
#  - 0s - loss: 51.6350
# Epoch 47/50
#  - 0s - loss: 51.2794
# Epoch 48/50
#  - 0s - loss: 50.7569
# Epoch 49/50
#  - 0s - loss: 51.9782
# Epoch 50/50
#  - 0s - loss: 51.9317
# Duration (seconds): 1.78739595413208
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 54.1867
# Epoch 2/50
#  - 0s - loss: 54.2593
# Epoch 3/50
#  - 0s - loss: 52.3709
# Epoch 4/50
#  - 0s - loss: 57.3682
# Epoch 5/50
#  - 0s - loss: 51.9438
# Epoch 6/50
#  - 0s - loss: 53.5189
# Epoch 7/50
#  - 0s - loss: 53.1584
# Epoch 8/50
#  - 0s - loss: 56.7899
# Epoch 9/50
#  - 0s - loss: 52.1836
# Epoch 10/50
#  - 0s - loss: 50.6931
# Epoch 11/50
#  - 0s - loss: 51.0461
# Epoch 12/50
#  - 0s - loss: 50.4044
# Epoch 13/50
#  - 0s - loss: 51.9753
# Epoch 14/50
#  - 0s - loss: 51.6361
# Epoch 15/50
#  - 0s - loss: 50.7631
# Epoch 16/50
#  - 0s - loss: 50.2657
# Epoch 17/50
#  - 0s - loss: 55.2755
# Epoch 18/50
#  - 0s - loss: 51.5059
# Epoch 19/50
#  - 0s - loss: 51.1491
# Epoch 20/50
#  - 0s - loss: 51.0279
# Epoch 21/50
#  - 0s - loss: 50.6085
# Epoch 22/50
#  - 0s - loss: 51.1367
# Epoch 23/50
#  - 0s - loss: 52.3250
# Epoch 24/50
#  - 0s - loss: 49.9940
# Epoch 25/50
#  - 0s - loss: 50.7614
# Epoch 26/50
#  - 0s - loss: 53.2758
# Epoch 27/50
#  - 0s - loss: 52.0662
# Epoch 28/50
#  - 0s - loss: 50.3591
# Epoch 29/50
#  - 0s - loss: 51.6440
# Epoch 30/50
#  - 0s - loss: 50.9505
# Epoch 31/50
#  - 0s - loss: 53.2276
# Epoch 32/50
#  - 0s - loss: 57.2862
# Epoch 33/50
#  - 0s - loss: 51.4232
# Epoch 34/50
#  - 0s - loss: 52.8991
# Epoch 35/50
#  - 0s - loss: 51.1084
# Epoch 36/50
#  - 0s - loss: 52.0614
# Epoch 37/50
#  - 0s - loss: 51.4047
# Epoch 38/50
#  - 0s - loss: 52.3181
# Epoch 39/50
#  - 0s - loss: 53.4342
# Epoch 40/50
#  - 0s - loss: 53.0429
# Epoch 41/50
#  - 0s - loss: 51.3045
# Epoch 42/50
#  - 0s - loss: 52.1546
# Epoch 43/50
#  - 0s - loss: 54.3805
# Epoch 44/50
#  - 0s - loss: 50.6067
# Epoch 45/50
#  - 0s - loss: 52.3968
# Epoch 46/50
#  - 0s - loss: 54.9480
# Epoch 47/50
#  - 0s - loss: 49.8150
# Epoch 48/50
#  - 0s - loss: 50.5336
# Epoch 49/50
#  - 0s - loss: 50.5247
# Epoch 50/50
#  - 0s - loss: 51.3667
# Duration (seconds): 2.0222790241241455
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 51.5033
# Epoch 2/50
#  - 0s - loss: 57.0095
# Epoch 3/50
#  - 0s - loss: 51.5439
# Epoch 4/50
#  - 0s - loss: 50.4587
# Epoch 5/50
#  - 0s - loss: 52.7118
# Epoch 6/50
#  - 0s - loss: 51.1590
# Epoch 7/50
#  - 0s - loss: 51.1395
# Epoch 8/50
#  - 0s - loss: 50.9781
# Epoch 9/50
#  - 0s - loss: 51.4610
# Epoch 10/50
#  - 0s - loss: 50.2369
# Epoch 11/50
#  - 0s - loss: 49.7365
# Epoch 12/50
#  - 0s - loss: 51.4903
# Epoch 13/50
#  - 0s - loss: 52.2385
# Epoch 14/50
#  - 0s - loss: 51.5426
# Epoch 15/50
#  - 0s - loss: 50.4992
# Epoch 16/50
#  - 0s - loss: 51.5153
# Epoch 17/50
#  - 0s - loss: 50.0173
# Epoch 18/50
#  - 0s - loss: 50.6999
# Epoch 19/50
#  - 0s - loss: 50.8300
# Epoch 20/50
#  - 0s - loss: 53.3941
# Epoch 21/50
#  - 0s - loss: 51.2722
# Epoch 22/50
#  - 0s - loss: 53.0901
# Epoch 23/50
#  - 0s - loss: 53.7379
# Epoch 24/50
#  - 0s - loss: 53.1329
# Epoch 25/50
#  - 0s - loss: 50.5748
# Epoch 26/50
#  - 0s - loss: 52.4688
# Epoch 27/50
#  - 0s - loss: 51.7606
# Epoch 28/50
#  - 0s - loss: 49.8446
# Epoch 29/50
#  - 0s - loss: 50.3608
# Epoch 30/50
#  - 0s - loss: 50.3348
# Epoch 31/50
#  - 0s - loss: 50.0998
# Epoch 32/50
#  - 0s - loss: 50.4309
# Epoch 33/50
#  - 0s - loss: 51.3823
# Epoch 34/50
#  - 0s - loss: 49.4453
# Epoch 35/50
#  - 0s - loss: 50.6882
# Epoch 36/50
#  - 0s - loss: 49.7028
# Epoch 37/50
#  - 0s - loss: 50.4433
# Epoch 38/50
#  - 0s - loss: 51.6171
# Epoch 39/50
#  - 0s - loss: 50.2366
# Epoch 40/50
#  - 0s - loss: 52.0943
# Epoch 41/50
#  - 0s - loss: 50.4287
# Epoch 42/50
#  - 0s - loss: 52.7789
# Epoch 43/50
#  - 0s - loss: 50.9181
# Epoch 44/50
#  - 0s - loss: 49.9402
# Epoch 45/50
#  - 0s - loss: 51.6787
# Epoch 46/50
#  - 0s - loss: 55.4668
# Epoch 47/50
#  - 0s - loss: 56.1392
# Epoch 48/50
#  - 0s - loss: 50.9095
# Epoch 49/50
#  - 0s - loss: 55.8507
# Epoch 50/50
#  - 0s - loss: 54.1959
# Duration (seconds): 1.575707197189331
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 52.9021
# Epoch 2/50
#  - 0s - loss: 49.6732
# Epoch 3/50
#  - 0s - loss: 49.6068
# Epoch 4/50
#  - 0s - loss: 50.3187
# Epoch 5/50
#  - 0s - loss: 54.1124
# Epoch 6/50
#  - 0s - loss: 50.6676
# Epoch 7/50
#  - 0s - loss: 51.9257
# Epoch 8/50
#  - 0s - loss: 48.9456
# Epoch 9/50
#  - 0s - loss: 49.1218
# Epoch 10/50
#  - 0s - loss: 51.3408
# Epoch 11/50
#  - 0s - loss: 51.0201
# Epoch 12/50
#  - 0s - loss: 53.8247
# Epoch 13/50
#  - 0s - loss: 55.3960
# Epoch 14/50
#  - 0s - loss: 49.9603
# Epoch 15/50
#  - 0s - loss: 50.4999
# Epoch 16/50
#  - 0s - loss: 50.0090
# Epoch 17/50
#  - 0s - loss: 50.1213
# Epoch 18/50
#  - 0s - loss: 53.5151
# Epoch 19/50
#  - 0s - loss: 50.1322
# Epoch 20/50
#  - 0s - loss: 50.6803
# Epoch 21/50
#  - 0s - loss: 50.7049
# Epoch 22/50
#  - 0s - loss: 49.4429
# Epoch 23/50
#  - 0s - loss: 50.9270
# Epoch 24/50
#  - 0s - loss: 50.7841
# Epoch 25/50
#  - 0s - loss: 51.9498
# Epoch 26/50
#  - 0s - loss: 50.0817
# Epoch 27/50
#  - 0s - loss: 51.0253
# Epoch 28/50
#  - 0s - loss: 49.4815
# Epoch 29/50
#  - 0s - loss: 50.0354
# Epoch 30/50
#  - 0s - loss: 49.7575
# Epoch 31/50
#  - 0s - loss: 49.7763
# Epoch 32/50
#  - 0s - loss: 49.8754
# Epoch 33/50
#  - 0s - loss: 49.2992
# Epoch 34/50
#  - 0s - loss: 51.5941
# Epoch 35/50
#  - 0s - loss: 49.6475
# Epoch 36/50
#  - 0s - loss: 49.5304
# Epoch 37/50
#  - 0s - loss: 49.6199
# Epoch 38/50
#  - 0s - loss: 49.8175
# Epoch 39/50
#  - 0s - loss: 51.1849
# Epoch 40/50
#  - 0s - loss: 52.0658
# Epoch 41/50
#  - 0s - loss: 52.7275
# Epoch 42/50
#  - 0s - loss: 52.1852
# Epoch 43/50
#  - 0s - loss: 49.7138
# Epoch 44/50
#  - 0s - loss: 50.6563
# Epoch 45/50
#  - 0s - loss: 51.5287
# Epoch 46/50
#  - 0s - loss: 54.8973
# Epoch 47/50
#  - 0s - loss: 55.4348
# Epoch 48/50
#  - 0s - loss: 54.7747
# Epoch 49/50
#  - 0s - loss: 50.1669
# Epoch 50/50
#  - 0s - loss: 50.9531
# Duration (seconds): 1.576775074005127
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 51.0397
# Epoch 2/50
#  - 0s - loss: 49.0683
# Epoch 3/50
#  - 0s - loss: 51.2788
# Epoch 4/50
#  - 0s - loss: 50.0154
# Epoch 5/50
#  - 0s - loss: 52.4905
# Epoch 6/50
#  - 0s - loss: 50.1485
# Epoch 7/50
#  - 0s - loss: 50.6658
# Epoch 8/50
#  - 0s - loss: 51.4074
# Epoch 9/50
#  - 0s - loss: 48.6331
# Epoch 10/50
#  - 0s - loss: 49.6968
# Epoch 11/50
#  - 0s - loss: 51.0881
# Epoch 12/50
#  - 0s - loss: 50.1156
# Epoch 13/50
#  - 0s - loss: 49.8067
# Epoch 14/50
#  - 0s - loss: 50.3216
# Epoch 15/50
#  - 0s - loss: 50.5481
# Epoch 16/50
#  - 0s - loss: 51.1280
# Epoch 17/50
#  - 0s - loss: 50.1010
# Epoch 18/50
#  - 0s - loss: 50.3456
# Epoch 19/50
#  - 0s - loss: 49.8832
# Epoch 20/50
#  - 0s - loss: 51.0203
# Epoch 21/50
#  - 0s - loss: 49.9768
# Epoch 22/50
#  - 0s - loss: 49.2852
# Epoch 23/50
#  - 0s - loss: 49.3982
# Epoch 24/50
#  - 0s - loss: 49.2146
# Epoch 25/50
#  - 0s - loss: 48.5665
# Epoch 26/50
#  - 0s - loss: 49.0413
# Epoch 27/50
#  - 0s - loss: 49.9710
# Epoch 28/50
#  - 0s - loss: 50.3924
# Epoch 29/50
#  - 0s - loss: 51.1667
# Epoch 30/50
#  - 0s - loss: 53.9018
# Epoch 31/50
#  - 0s - loss: 48.9725
# Epoch 32/50
#  - 0s - loss: 49.9085
# Epoch 33/50
#  - 0s - loss: 50.2167
# Epoch 34/50
#  - 0s - loss: 49.5021
# Epoch 35/50
#  - 0s - loss: 49.1127
# Epoch 36/50
#  - 0s - loss: 49.0183
# Epoch 37/50
#  - 0s - loss: 48.6203
# Epoch 38/50
#  - 0s - loss: 55.6394
# Epoch 39/50
#  - 0s - loss: 56.5401
# Epoch 40/50
#  - 0s - loss: 51.9708
# Epoch 41/50
#  - 0s - loss: 49.3061
# Epoch 42/50
#  - 0s - loss: 48.6668
# Epoch 43/50
#  - 0s - loss: 48.6651
# Epoch 44/50
#  - 0s - loss: 51.9801
# Epoch 45/50
#  - 0s - loss: 49.4413
# Epoch 46/50
#  - 0s - loss: 50.2454
# Epoch 47/50
#  - 0s - loss: 51.1366
# Epoch 48/50
#  - 0s - loss: 49.4720
# Epoch 49/50
#  - 0s - loss: 48.8686
# Epoch 50/50
#  - 0s - loss: 49.1482
# Duration (seconds): 1.6828341484069824
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.9483
# Epoch 2/50
#  - 0s - loss: 49.7430
# Epoch 3/50
#  - 0s - loss: 51.1420
# Epoch 4/50
#  - 0s - loss: 51.7571
# Epoch 5/50
#  - 0s - loss: 50.0353
# Epoch 6/50
#  - 0s - loss: 50.0686
# Epoch 7/50
#  - 0s - loss: 53.7739
# Epoch 8/50
#  - 0s - loss: 58.2094
# Epoch 9/50
#  - 0s - loss: 51.7869
# Epoch 10/50
#  - 0s - loss: 51.4234
# Epoch 11/50
#  - 0s - loss: 50.0706
# Epoch 12/50
#  - 0s - loss: 49.4455
# Epoch 13/50
#  - 0s - loss: 50.8276
# Epoch 14/50
#  - 0s - loss: 50.1704
# Epoch 15/50
#  - 0s - loss: 48.6163
# Epoch 16/50
#  - 0s - loss: 49.3218
# Epoch 17/50
#  - 0s - loss: 49.6188
# Epoch 18/50
#  - 0s - loss: 48.2996
# Epoch 19/50
#  - 0s - loss: 50.6560
# Epoch 20/50
#  - 0s - loss: 48.9001
# Epoch 21/50
#  - 0s - loss: 49.0265
# Epoch 22/50
#  - 0s - loss: 49.5027
# Epoch 23/50
#  - 0s - loss: 49.4040
# Epoch 24/50
#  - 0s - loss: 48.8096
# Epoch 25/50
#  - 0s - loss: 50.0041
# Epoch 26/50
#  - 0s - loss: 52.2537
# Epoch 27/50
#  - 0s - loss: 53.4782
# Epoch 28/50
#  - 0s - loss: 48.4789
# Epoch 29/50
#  - 0s - loss: 49.1497
# Epoch 30/50
#  - 0s - loss: 51.5876
# Epoch 31/50
#  - 0s - loss: 51.2267
# Epoch 32/50
#  - 0s - loss: 51.3136
# Epoch 33/50
#  - 0s - loss: 48.2935
# Epoch 34/50
#  - 0s - loss: 48.7251
# Epoch 35/50
#  - 0s - loss: 50.2094
# Epoch 36/50
#  - 0s - loss: 48.6173
# Epoch 37/50
#  - 0s - loss: 49.8874
# Epoch 38/50
#  - 0s - loss: 51.7554
# Epoch 39/50
#  - 0s - loss: 49.8492
# Epoch 40/50
#  - 0s - loss: 49.9676
# Epoch 41/50
#  - 0s - loss: 49.6440
# Epoch 42/50
#  - 0s - loss: 50.4513
# Epoch 43/50
#  - 0s - loss: 49.6147
# Epoch 44/50
#  - 0s - loss: 49.9802
# Epoch 45/50
#  - 0s - loss: 49.3880
# Epoch 46/50
#  - 0s - loss: 49.3339
# Epoch 47/50
#  - 0s - loss: 56.0431
# Epoch 48/50
#  - 0s - loss: 51.6413
# Epoch 49/50
#  - 0s - loss: 49.1091
# Epoch 50/50
#  - 0s - loss: 49.5575
# Duration (seconds): 1.9021639823913574
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 52.4550
# Epoch 2/50
#  - 0s - loss: 50.2206
# Epoch 3/50
#  - 0s - loss: 49.4858
# Epoch 4/50
#  - 0s - loss: 49.0703
# Epoch 5/50
#  - 0s - loss: 48.6055
# Epoch 6/50
#  - 0s - loss: 51.4223
# Epoch 7/50
#  - 0s - loss: 52.1309
# Epoch 8/50
#  - 0s - loss: 50.4906
# Epoch 9/50
#  - 0s - loss: 50.9453
# Epoch 10/50
#  - 0s - loss: 50.0945
# Epoch 11/50
#  - 0s - loss: 52.5730
# Epoch 12/50
#  - 0s - loss: 50.0165
# Epoch 13/50
#  - 0s - loss: 50.0270
# Epoch 14/50
#  - 0s - loss: 49.8801
# Epoch 15/50
#  - 0s - loss: 48.8903
# Epoch 16/50
#  - 0s - loss: 49.3412
# Epoch 17/50
#  - 0s - loss: 54.6856
# Epoch 18/50
#  - 0s - loss: 50.1865
# Epoch 19/50
#  - 0s - loss: 48.9936
# Epoch 20/50
#  - 0s - loss: 50.9299
# Epoch 21/50
#  - 0s - loss: 53.2335
# Epoch 22/50
#  - 0s - loss: 51.8924
# Epoch 23/50
#  - 0s - loss: 49.8875
# Epoch 24/50
#  - 0s - loss: 48.5322
# Epoch 25/50
#  - 1s - loss: 49.5771
# Epoch 26/50
#  - 0s - loss: 49.5742
# Epoch 27/50
#  - 0s - loss: 49.9179
# Epoch 28/50
#  - 0s - loss: 49.1851
# Epoch 29/50
#  - 0s - loss: 50.9588
# Epoch 30/50
#  - 0s - loss: 52.4603
# Epoch 31/50
#  - 0s - loss: 48.8784
# Epoch 32/50
#  - 0s - loss: 49.3523
# Epoch 33/50
#  - 0s - loss: 51.4050
# Epoch 34/50
#  - 0s - loss: 50.0262
# Epoch 35/50
#  - 0s - loss: 49.1086
# Epoch 36/50
#  - 0s - loss: 52.6488
# Epoch 37/50
#  - 0s - loss: 50.3918
# Epoch 38/50
#  - 0s - loss: 49.4688
# Epoch 39/50
#  - 0s - loss: 52.2542
# Epoch 40/50
#  - 0s - loss: 48.5752
# Epoch 41/50
#  - 0s - loss: 51.9288
# Epoch 42/50
#  - 0s - loss: 57.7768
# Epoch 43/50
#  - 0s - loss: 49.9971
# Epoch 44/50
#  - 0s - loss: 49.5550
# Epoch 45/50
#  - 0s - loss: 50.7304
# Epoch 46/50
#  - 0s - loss: 51.4866
# Epoch 47/50
#  - 0s - loss: 50.5925
# Epoch 48/50
#  - 0s - loss: 50.3939
# Epoch 49/50
#  - 0s - loss: 54.9784
# Epoch 50/50
#  - 0s - loss: 52.0686
# Duration (seconds): 3.8401079177856445
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 52.2096
# Epoch 2/50
#  - 0s - loss: 51.3695
# Epoch 3/50
#  - 0s - loss: 49.6310
# Epoch 4/50
#  - 0s - loss: 50.1260
# Epoch 5/50
#  - 0s - loss: 54.1057
# Epoch 6/50
#  - 0s - loss: 49.6888
# Epoch 7/50
#  - 0s - loss: 49.2710
# Epoch 8/50
#  - 0s - loss: 50.2383
# Epoch 9/50
#  - 0s - loss: 49.7508
# Epoch 10/50
#  - 0s - loss: 49.9563
# Epoch 11/50
#  - 0s - loss: 54.3214
# Epoch 12/50
#  - 0s - loss: 52.0346
# Epoch 13/50
#  - 0s - loss: 50.7083
# Epoch 14/50
#  - 0s - loss: 48.6898
# Epoch 15/50
#  - 0s - loss: 48.2759
# Epoch 16/50
#  - 0s - loss: 49.1499
# Epoch 17/50
#  - 0s - loss: 51.5016
# Epoch 18/50
#  - 0s - loss: 53.2676
# Epoch 19/50
#  - 0s - loss: 48.6205
# Epoch 20/50
#  - 0s - loss: 50.0254
# Epoch 21/50
#  - 0s - loss: 49.2861
# Epoch 22/50
#  - 0s - loss: 49.0856
# Epoch 23/50
#  - 0s - loss: 54.2169
# Epoch 24/50
#  - 0s - loss: 52.4699
# Epoch 25/50
#  - 0s - loss: 47.8498
# Epoch 26/50
#  - 0s - loss: 49.1607
# Epoch 27/50
#  - 0s - loss: 51.7713
# Epoch 28/50
#  - 0s - loss: 49.4229
# Epoch 29/50
#  - 0s - loss: 49.2621
# Epoch 30/50
#  - 0s - loss: 50.4913
# Epoch 31/50
#  - 0s - loss: 49.3092
# Epoch 32/50
#  - 0s - loss: 48.9757
# Epoch 33/50
#  - 0s - loss: 50.0857
# Epoch 34/50
#  - 0s - loss: 50.2144
# Epoch 35/50
#  - 0s - loss: 54.9127
# Epoch 36/50
#  - 0s - loss: 49.8087
# Epoch 37/50
#  - 0s - loss: 49.1016
# Epoch 38/50
#  - 0s - loss: 48.7233
# Epoch 39/50
#  - 0s - loss: 49.8125
# Epoch 40/50
#  - 0s - loss: 49.0693
# Epoch 41/50
#  - 0s - loss: 49.2937
# Epoch 42/50
#  - 0s - loss: 48.8621
# Epoch 43/50
#  - 0s - loss: 48.9769
# Epoch 44/50
#  - 0s - loss: 50.7815
# Epoch 45/50
#  - 0s - loss: 50.5439
# Epoch 46/50
#  - 0s - loss: 48.6399
# Epoch 47/50
#  - 0s - loss: 50.4646
# Epoch 48/50
#  - 0s - loss: 49.5806
# Epoch 49/50
#  - 0s - loss: 49.1847
# Epoch 50/50
#  - 0s - loss: 52.3748
# Duration (seconds): 2.6231091022491455
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.6368
# Epoch 2/50
#  - 0s - loss: 48.6873
# Epoch 3/50
#  - 0s - loss: 49.0340
# Epoch 4/50
#  - 0s - loss: 48.4830
# Epoch 5/50
#  - 0s - loss: 49.9880
# Epoch 6/50
#  - 0s - loss: 48.6442
# Epoch 7/50
#  - 0s - loss: 48.8749
# Epoch 8/50
#  - 0s - loss: 49.1694
# Epoch 9/50
#  - 0s - loss: 52.1240
# Epoch 10/50
#  - 0s - loss: 50.2535
# Epoch 11/50
#  - 0s - loss: 49.0396
# Epoch 12/50
#  - 0s - loss: 49.2586
# Epoch 13/50
#  - 0s - loss: 49.6836
# Epoch 14/50
#  - 0s - loss: 49.6376
# Epoch 15/50
#  - 0s - loss: 50.4467
# Epoch 16/50
#  - 0s - loss: 49.7182
# Epoch 17/50
#  - 0s - loss: 52.4921
# Epoch 18/50
#  - 0s - loss: 52.5437
# Epoch 19/50
#  - 0s - loss: 51.4950
# Epoch 20/50
#  - 0s - loss: 54.6314
# Epoch 21/50
#  - 0s - loss: 52.8639
# Epoch 22/50
#  - 0s - loss: 48.9144
# Epoch 23/50
#  - 0s - loss: 49.3173
# Epoch 24/50
#  - 0s - loss: 48.3452
# Epoch 25/50
#  - 0s - loss: 53.6373
# Epoch 26/50
#  - 0s - loss: 50.3209
# Epoch 27/50
#  - 0s - loss: 55.1830
# Epoch 28/50
#  - 0s - loss: 49.3574
# Epoch 29/50
#  - 0s - loss: 50.8875
# Epoch 30/50
#  - 0s - loss: 49.3887
# Epoch 31/50
#  - 0s - loss: 49.4445
# Epoch 32/50
#  - 0s - loss: 49.5286
# Epoch 33/50
#  - 0s - loss: 49.9110
# Epoch 34/50
#  - 0s - loss: 49.3789
# Epoch 35/50
#  - 0s - loss: 48.8697
# Epoch 36/50
#  - 0s - loss: 54.8310
# Epoch 37/50
#  - 0s - loss: 49.6279
# Epoch 38/50
#  - 0s - loss: 49.7893
# Epoch 39/50
#  - 0s - loss: 49.7062
# Epoch 40/50
#  - 0s - loss: 47.8697
# Epoch 41/50
#  - 0s - loss: 48.7175
# Epoch 42/50
#  - 0s - loss: 48.2283
# Epoch 43/50
#  - 0s - loss: 48.1795
# Epoch 44/50
#  - 0s - loss: 48.9418
# Epoch 45/50
#  - 0s - loss: 51.9996
# Epoch 46/50
#  - 0s - loss: 51.4028
# Epoch 47/50
#  - 0s - loss: 50.5766
# Epoch 48/50
#  - 0s - loss: 49.7426
# Epoch 49/50
#  - 0s - loss: 51.5935
# Epoch 50/50
#  - 0s - loss: 49.8742
# Duration (seconds): 1.9045209884643555
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.7273
# Epoch 2/50
#  - 0s - loss: 48.4081
# Epoch 3/50
#  - 0s - loss: 50.7232
# Epoch 4/50
#  - 0s - loss: 50.2409
# Epoch 5/50
#  - 0s - loss: 52.3273
# Epoch 6/50
#  - 0s - loss: 49.6332
# Epoch 7/50
#  - 0s - loss: 48.5218
# Epoch 8/50
#  - 0s - loss: 49.3011
# Epoch 9/50
#  - 0s - loss: 52.5286
# Epoch 10/50
#  - 0s - loss: 53.3515
# Epoch 11/50
#  - 0s - loss: 48.7067
# Epoch 12/50
#  - 0s - loss: 50.9550
# Epoch 13/50
#  - 0s - loss: 50.3115
# Epoch 14/50
#  - 0s - loss: 48.5175
# Epoch 15/50
#  - 0s - loss: 52.4538
# Epoch 16/50
#  - 0s - loss: 51.2287
# Epoch 17/50
#  - 0s - loss: 48.7330
# Epoch 18/50
#  - 0s - loss: 48.5840
# Epoch 19/50
#  - 0s - loss: 50.2618
# Epoch 20/50
#  - 0s - loss: 49.9692
# Epoch 21/50
#  - 0s - loss: 51.8848
# Epoch 22/50
#  - 0s - loss: 54.4405
# Epoch 23/50
#  - 0s - loss: 50.8894
# Epoch 24/50
#  - 0s - loss: 48.0029
# Epoch 25/50
#  - 0s - loss: 49.1053
# Epoch 26/50
#  - 0s - loss: 49.6742
# Epoch 27/50
#  - 0s - loss: 49.0467
# Epoch 28/50
#  - 0s - loss: 49.0805
# Epoch 29/50
#  - 0s - loss: 51.2321
# Epoch 30/50
#  - 0s - loss: 50.2080
# Epoch 31/50
#  - 0s - loss: 48.6143
# Epoch 32/50
#  - 0s - loss: 49.6625
# Epoch 33/50
#  - 0s - loss: 50.2309
# Epoch 34/50
#  - 0s - loss: 50.2801
# Epoch 35/50
#  - 0s - loss: 51.1534
# Epoch 36/50
#  - 0s - loss: 49.4493
# Epoch 37/50
#  - 0s - loss: 48.5596
# Epoch 38/50
#  - 0s - loss: 50.1614
# Epoch 39/50
#  - 0s - loss: 49.4434
# Epoch 40/50
#  - 0s - loss: 49.2287
# Epoch 41/50
#  - 0s - loss: 52.7831
# Epoch 42/50
#  - 0s - loss: 49.7589
# Epoch 43/50
#  - 0s - loss: 49.3616
# Epoch 44/50
#  - 0s - loss: 49.5315
# Epoch 45/50
#  - 0s - loss: 50.5949
# Epoch 46/50
#  - 0s - loss: 50.1712
# Epoch 47/50
#  - 0s - loss: 49.4341
# Epoch 48/50
#  - 0s - loss: 50.8230
# Epoch 49/50
#  - 0s - loss: 52.6404
# Epoch 50/50
#  - 0s - loss: 49.0106
# Duration (seconds): 2.2022929191589355
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.0276
# Epoch 2/50
#  - 0s - loss: 48.2789
# Epoch 3/50
#  - 0s - loss: 48.2058
# Epoch 4/50
#  - 0s - loss: 49.0480
# Epoch 5/50
#  - 0s - loss: 49.8691
# Epoch 6/50
#  - 0s - loss: 53.2996
# Epoch 7/50
#  - 0s - loss: 52.3178
# Epoch 8/50
#  - 0s - loss: 48.5944
# Epoch 9/50
#  - 0s - loss: 50.6468
# Epoch 10/50
#  - 0s - loss: 49.4816
# Epoch 11/50
#  - 0s - loss: 53.4183
# Epoch 12/50
#  - 0s - loss: 51.0746
# Epoch 13/50
#  - 0s - loss: 48.7541
# Epoch 14/50
#  - 0s - loss: 51.2882
# Epoch 15/50
#  - 0s - loss: 49.7898
# Epoch 16/50
#  - 0s - loss: 52.3270
# Epoch 17/50
#  - 0s - loss: 51.5754
# Epoch 18/50
#  - 0s - loss: 49.9146
# Epoch 19/50
#  - 0s - loss: 49.5344
# Epoch 20/50
#  - 0s - loss: 49.2555
# Epoch 21/50
#  - 0s - loss: 50.7026
# Epoch 22/50
#  - 0s - loss: 49.4662
# Epoch 23/50
#  - 0s - loss: 48.3457
# Epoch 24/50
#  - 0s - loss: 49.9703
# Epoch 25/50
#  - 0s - loss: 53.5457
# Epoch 26/50
#  - 0s - loss: 53.8224
# Epoch 27/50
#  - 0s - loss: 48.2013
# Epoch 28/50
#  - 0s - loss: 48.2449
# Epoch 29/50
#  - 0s - loss: 48.0181
# Epoch 30/50
#  - 0s - loss: 52.4816
# Epoch 31/50
#  - 0s - loss: 49.5451
# Epoch 32/50
#  - 0s - loss: 49.4661
# Epoch 33/50
#  - 0s - loss: 49.7085
# Epoch 34/50
#  - 0s - loss: 48.5635
# Epoch 35/50
#  - 0s - loss: 49.4562
# Epoch 36/50
#  - 0s - loss: 48.8235
# Epoch 37/50
#  - 0s - loss: 48.9715
# Epoch 38/50
#  - 0s - loss: 49.8689
# Epoch 39/50
#  - 0s - loss: 48.1808
# Epoch 40/50
#  - 0s - loss: 48.6919
# Epoch 41/50
#  - 0s - loss: 49.7613
# Epoch 42/50
#  - 0s - loss: 50.0245
# Epoch 43/50
#  - 0s - loss: 50.7653
# Epoch 44/50
#  - 0s - loss: 48.5660
# Epoch 45/50
#  - 0s - loss: 50.5324
# Epoch 46/50
#  - 0s - loss: 48.4200
# Epoch 47/50
#  - 0s - loss: 49.5412
# Epoch 48/50
#  - 0s - loss: 49.2719
# Epoch 49/50
#  - 0s - loss: 48.7602
# Epoch 50/50
#  - 0s - loss: 50.3411
# Duration (seconds): 2.196725845336914
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 50.1808
# Epoch 2/50
#  - 0s - loss: 49.1165
# Epoch 3/50
#  - 0s - loss: 48.1203
# Epoch 4/50
#  - 0s - loss: 48.3473
# Epoch 5/50
#  - 0s - loss: 48.8036
# Epoch 6/50
#  - 0s - loss: 50.6397
# Epoch 7/50
#  - 0s - loss: 50.0908
# Epoch 8/50
#  - 0s - loss: 47.8948
# Epoch 9/50
#  - 0s - loss: 49.7685
# Epoch 10/50
#  - 0s - loss: 49.8800
# Epoch 11/50
#  - 0s - loss: 49.8400
# Epoch 12/50
#  - 0s - loss: 49.9201
# Epoch 13/50
#  - 0s - loss: 51.3549
# Epoch 14/50
#  - 0s - loss: 48.9447
# Epoch 15/50
#  - 0s - loss: 50.4708
# Epoch 16/50
#  - 0s - loss: 49.9738
# Epoch 17/50
#  - 0s - loss: 51.1186
# Epoch 18/50
#  - 0s - loss: 49.6117
# Epoch 19/50
#  - 0s - loss: 50.1468
# Epoch 20/50
#  - 0s - loss: 50.7738
# Epoch 21/50
#  - 0s - loss: 48.3998
# Epoch 22/50
#  - 0s - loss: 50.5220
# Epoch 23/50
#  - 0s - loss: 49.3517
# Epoch 24/50
#  - 0s - loss: 49.4725
# Epoch 25/50
#  - 0s - loss: 49.6486
# Epoch 26/50
#  - 0s - loss: 50.3975
# Epoch 27/50
#  - 0s - loss: 48.3727
# Epoch 28/50
#  - 0s - loss: 50.0811
# Epoch 29/50
#  - 0s - loss: 50.6552
# Epoch 30/50
#  - 0s - loss: 52.1420
# Epoch 31/50
#  - 0s - loss: 51.6284
# Epoch 32/50
#  - 0s - loss: 49.0057
# Epoch 33/50
#  - 0s - loss: 50.6050
# Epoch 34/50
#  - 0s - loss: 49.2892
# Epoch 35/50
#  - 0s - loss: 48.9213
# Epoch 36/50
#  - 0s - loss: 48.3319
# Epoch 37/50
#  - 0s - loss: 51.7107
# Epoch 38/50
#  - 0s - loss: 50.1055
# Epoch 39/50
#  - 0s - loss: 48.9104
# Epoch 40/50
#  - 0s - loss: 49.0322
# Epoch 41/50
#  - 0s - loss: 49.5449
# Epoch 42/50
#  - 0s - loss: 48.6845
# Epoch 43/50
#  - 0s - loss: 51.0937
# Epoch 44/50
#  - 0s - loss: 53.6017
# Epoch 45/50
#  - 0s - loss: 50.8812
# Epoch 46/50
#  - 0s - loss: 48.0945
# Epoch 47/50
#  - 0s - loss: 50.0875
# Epoch 48/50
#  - 0s - loss: 50.7126
# Epoch 49/50
#  - 0s - loss: 53.0191
# Epoch 50/50
#  - 0s - loss: 48.9282
# Duration (seconds): 2.247396230697632
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 50.6781
# Epoch 2/50
#  - 0s - loss: 50.2314
# Epoch 3/50
#  - 0s - loss: 49.1636
# Epoch 4/50
#  - 0s - loss: 50.4205
# Epoch 5/50
#  - 0s - loss: 50.0179
# Epoch 6/50
#  - 0s - loss: 48.4831
# Epoch 7/50
#  - 0s - loss: 51.1537
# Epoch 8/50
#  - 0s - loss: 48.7092
# Epoch 9/50
#  - 0s - loss: 48.7253
# Epoch 10/50
#  - 0s - loss: 49.2513
# Epoch 11/50
#  - 0s - loss: 49.1034
# Epoch 12/50
#  - 0s - loss: 48.2529
# Epoch 13/50
#  - 0s - loss: 48.1077
# Epoch 14/50
#  - 0s - loss: 49.6553
# Epoch 15/50
#  - 0s - loss: 49.0874
# Epoch 16/50
#  - 0s - loss: 51.0667
# Epoch 17/50
#  - 0s - loss: 48.4052
# Epoch 18/50
#  - 0s - loss: 49.8891
# Epoch 19/50
#  - 0s - loss: 49.8293
# Epoch 20/50
#  - 0s - loss: 48.5997
# Epoch 21/50
#  - 0s - loss: 53.1367
# Epoch 22/50
#  - 0s - loss: 55.5290
# Epoch 23/50
#  - 0s - loss: 51.0754
# Epoch 24/50
#  - 0s - loss: 50.3956
# Epoch 25/50
#  - 0s - loss: 48.5164
# Epoch 26/50
#  - 0s - loss: 49.5118
# Epoch 27/50
#  - 0s - loss: 52.4232
# Epoch 28/50
#  - 0s - loss: 50.2996
# Epoch 29/50
#  - 0s - loss: 49.7960
# Epoch 30/50
#  - 0s - loss: 52.6161
# Epoch 31/50
#  - 0s - loss: 50.6565
# Epoch 32/50
#  - 0s - loss: 48.0976
# Epoch 33/50
#  - 0s - loss: 50.2132
# Epoch 34/50
#  - 0s - loss: 49.0810
# Epoch 35/50
#  - 0s - loss: 50.8488
# Epoch 36/50
#  - 0s - loss: 50.8415
# Epoch 37/50
#  - 0s - loss: 48.2752
# Epoch 38/50
#  - 0s - loss: 50.3880
# Epoch 39/50
#  - 0s - loss: 48.5857
# Epoch 40/50
#  - 0s - loss: 48.5720
# Epoch 41/50
#  - 0s - loss: 50.1088
# Epoch 42/50
#  - 0s - loss: 48.3677
# Epoch 43/50
#  - 0s - loss: 50.6855
# Epoch 44/50
#  - 0s - loss: 48.4395
# Epoch 45/50
#  - 0s - loss: 52.0226
# Epoch 46/50
#  - 0s - loss: 50.2344
# Epoch 47/50
#  - 0s - loss: 53.5681
# Epoch 48/50
#  - 0s - loss: 49.3944
# Epoch 49/50
#  - 0s - loss: 50.2079
# Epoch 50/50
#  - 0s - loss: 49.2832
# Duration (seconds): 3.0959901809692383
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.6540
# Epoch 2/50
#  - 0s - loss: 51.8577
# Epoch 3/50
#  - 0s - loss: 49.7133
# Epoch 4/50
#  - 0s - loss: 57.7821
# Epoch 5/50
#  - 0s - loss: 48.5849
# Epoch 6/50
#  - 0s - loss: 49.9014
# Epoch 7/50
#  - 0s - loss: 51.0222
# Epoch 8/50
#  - 0s - loss: 51.9452
# Epoch 9/50
#  - 0s - loss: 49.1492
# Epoch 10/50
#  - 0s - loss: 48.8620
# Epoch 11/50
#  - 0s - loss: 51.1140
# Epoch 12/50
#  - 0s - loss: 49.1354
# Epoch 13/50
#  - 0s - loss: 49.6990
# Epoch 14/50
#  - 0s - loss: 49.3721
# Epoch 15/50
#  - 0s - loss: 48.2357
# Epoch 16/50
#  - 0s - loss: 49.2764
# Epoch 17/50
#  - 0s - loss: 50.4259
# Epoch 18/50
#  - 0s - loss: 49.3811
# Epoch 19/50
#  - 0s - loss: 50.6046
# Epoch 20/50
#  - 0s - loss: 49.4409
# Epoch 21/50
#  - 0s - loss: 48.2827
# Epoch 22/50
#  - 0s - loss: 48.9428
# Epoch 23/50
#  - 0s - loss: 49.0330
# Epoch 24/50
#  - 0s - loss: 50.8746
# Epoch 25/50
#  - 0s - loss: 52.0818
# Epoch 26/50
#  - 0s - loss: 51.8349
# Epoch 27/50
#  - 0s - loss: 52.6853
# Epoch 28/50
#  - 0s - loss: 51.3023
# Epoch 29/50
#  - 0s - loss: 48.4626
# Epoch 30/50
#  - 0s - loss: 51.2078
# Epoch 31/50
#  - 0s - loss: 50.7301
# Epoch 32/50
#  - 0s - loss: 50.9033
# Epoch 33/50
#  - 0s - loss: 54.1056
# Epoch 34/50
#  - 0s - loss: 48.7239
# Epoch 35/50
#  - 0s - loss: 50.8762
# Epoch 36/50
#  - 0s - loss: 51.7491
# Epoch 37/50
#  - 0s - loss: 56.5461
# Epoch 38/50
#  - 0s - loss: 50.7944
# Epoch 39/50
#  - 0s - loss: 52.0305
# Epoch 40/50
#  - 0s - loss: 48.6352
# Epoch 41/50
#  - 0s - loss: 51.5886
# Epoch 42/50
#  - 0s - loss: 50.6258
# Epoch 43/50
#  - 0s - loss: 49.1639
# Epoch 44/50
#  - 0s - loss: 50.9896
# Epoch 45/50
#  - 0s - loss: 50.4629
# Epoch 46/50
#  - 0s - loss: 50.6707
# Epoch 47/50
#  - 0s - loss: 48.4192
# Epoch 48/50
#  - 0s - loss: 48.0399
# Epoch 49/50
#  - 0s - loss: 48.9023
# Epoch 50/50
#  - 0s - loss: 57.2534
# Duration (seconds): 2.264482021331787
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.9974
# Epoch 2/50
#  - 0s - loss: 49.9155
# Epoch 3/50
#  - 0s - loss: 48.3555
# Epoch 4/50
#  - 0s - loss: 48.7770
# Epoch 5/50
#  - 0s - loss: 50.0150
# Epoch 6/50
#  - 0s - loss: 49.8441
# Epoch 7/50
#  - 0s - loss: 52.3359
# Epoch 8/50
#  - 0s - loss: 48.2649
# Epoch 9/50
#  - 0s - loss: 47.9604
# Epoch 10/50
#  - 0s - loss: 49.3250
# Epoch 11/50
#  - 0s - loss: 50.9749
# Epoch 12/50
#  - 0s - loss: 49.4163
# Epoch 13/50
#  - 0s - loss: 53.3811
# Epoch 14/50
#  - 0s - loss: 53.2354
# Epoch 15/50
#  - 0s - loss: 52.4578
# Epoch 16/50
#  - 0s - loss: 48.7246
# Epoch 17/50
#  - 0s - loss: 49.6832
# Epoch 18/50
#  - 0s - loss: 50.9023
# Epoch 19/50
#  - 0s - loss: 49.6813
# Epoch 20/50
#  - 0s - loss: 55.4728
# Epoch 21/50
#  - 0s - loss: 50.6978
# Epoch 22/50
#  - 0s - loss: 49.7325
# Epoch 23/50
#  - 0s - loss: 48.1724
# Epoch 24/50
#  - 0s - loss: 51.0664
# Epoch 25/50
#  - 0s - loss: 54.1517
# Epoch 26/50
#  - 0s - loss: 50.7080
# Epoch 27/50
#  - 0s - loss: 48.1059
# Epoch 28/50
#  - 0s - loss: 53.0088
# Epoch 29/50
#  - 0s - loss: 49.1214
# Epoch 30/50
#  - 0s - loss: 48.6916
# Epoch 31/50
#  - 0s - loss: 48.9475
# Epoch 32/50
#  - 0s - loss: 48.8933
# Epoch 33/50
#  - 0s - loss: 50.4752
# Epoch 34/50
#  - 0s - loss: 49.2320
# Epoch 35/50
#  - 0s - loss: 50.4525
# Epoch 36/50
#  - 0s - loss: 50.3710
# Epoch 37/50
#  - 0s - loss: 49.4544
# Epoch 38/50
#  - 0s - loss: 49.5910
# Epoch 39/50
#  - 0s - loss: 50.3860
# Epoch 40/50
#  - 0s - loss: 49.8399
# Epoch 41/50
#  - 0s - loss: 50.1731
# Epoch 42/50
#  - 0s - loss: 48.7634
# Epoch 43/50
#  - 0s - loss: 47.7780
# Epoch 44/50
#  - 0s - loss: 49.9053
# Epoch 45/50
#  - 0s - loss: 52.4587
# Epoch 46/50
#  - 0s - loss: 50.4316
# Epoch 47/50
#  - 0s - loss: 48.9612
# Epoch 48/50
#  - 0s - loss: 49.0894
# Epoch 49/50
#  - 0s - loss: 49.9922
# Epoch 50/50
#  - 0s - loss: 49.1019
# Duration (seconds): 2.777316093444824
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.9194
# Epoch 2/50
#  - 0s - loss: 53.7104
# Epoch 3/50
#  - 0s - loss: 48.0752
# Epoch 4/50
#  - 0s - loss: 51.0479
# Epoch 5/50
#  - 0s - loss: 47.7584
# Epoch 6/50
#  - 0s - loss: 49.6551
# Epoch 7/50
#  - 0s - loss: 50.0127
# Epoch 8/50
#  - 0s - loss: 50.7937
# Epoch 9/50
#  - 0s - loss: 48.3951
# Epoch 10/50
#  - 0s - loss: 48.4166
# Epoch 11/50
#  - 0s - loss: 48.5476
# Epoch 12/50
#  - 0s - loss: 48.3864
# Epoch 13/50
#  - 0s - loss: 50.1986
# Epoch 14/50
#  - 0s - loss: 49.0032
# Epoch 15/50
#  - 0s - loss: 49.7331
# Epoch 16/50
#  - 0s - loss: 50.0677
# Epoch 17/50
#  - 0s - loss: 48.0068
# Epoch 18/50
#  - 0s - loss: 49.6431
# Epoch 19/50
#  - 0s - loss: 47.5885
# Epoch 20/50
#  - 0s - loss: 52.7260
# Epoch 21/50
#  - 0s - loss: 49.2607
# Epoch 22/50
#  - 0s - loss: 52.0021
# Epoch 23/50
#  - 0s - loss: 51.2604
# Epoch 24/50
#  - 0s - loss: 50.1019
# Epoch 25/50
#  - 0s - loss: 50.2309
# Epoch 26/50
#  - 0s - loss: 49.6045
# Epoch 27/50
#  - 0s - loss: 48.5795
# ...
# Epoch 2/50
#  - 0s - loss: 49.2957
# Epoch 3/50
#  - 0s - loss: 48.6202
# Epoch 4/50
#  - 0s - loss: 48.4760
# Epoch 5/50
#  - 0s - loss: 52.1245
# Epoch 6/50
#  - 0s - loss: 52.9399
# Epoch 7/50
#  - 0s - loss: 49.5315
# Epoch 8/50
#  - 0s - loss: 48.8339
# Epoch 9/50
#  - 0s - loss: 48.8684
# Epoch 10/50
#  - 0s - loss: 49.4467
# Epoch 11/50
#  - 0s - loss: 48.3140
# Epoch 12/50
#  - 0s - loss: 48.8126
# Epoch 13/50
#  - 0s - loss: 48.8934
# Epoch 14/50
#  - 0s - loss: 52.3255
# Epoch 15/50
#  - 0s - loss: 48.7046
# Epoch 16/50
#  - 0s - loss: 48.6928
# Epoch 17/50
#  - 0s - loss: 50.4853
# Epoch 18/50
#  - 0s - loss: 47.7410
# Epoch 19/50
#  - 0s - loss: 48.6484
# Epoch 20/50
#  - 0s - loss: 48.9575
# Epoch 21/50
#  - 0s - loss: 48.8653
# Epoch 22/50
#  - 0s - loss: 50.7395
# Epoch 23/50
#  - 0s - loss: 50.9995
# Epoch 24/50
#  - 0s - loss: 49.8435
# Epoch 25/50
#  - 0s - loss: 49.2278
# Epoch 26/50
#  - 0s - loss: 48.8151
# Epoch 27/50
#  - 0s - loss: 49.7255
# Epoch 28/50
#  - 0s - loss: 51.8515
# Epoch 29/50
#  - 0s - loss: 48.5641
# Epoch 30/50
#  - 0s - loss: 48.1919
# Epoch 31/50
#  - 0s - loss: 49.1615
# Epoch 32/50
#  - 0s - loss: 48.0772
# Epoch 33/50
#  - 0s - loss: 48.1811
# Epoch 34/50
#  - 0s - loss: 50.1653
# Epoch 35/50
#  - 0s - loss: 48.3328
# Epoch 36/50
#  - 0s - loss: 50.6191
# Epoch 37/50
#  - 0s - loss: 50.0352
# Epoch 38/50
#  - 0s - loss: 48.1737
# Epoch 39/50
#  - 0s - loss: 48.6692
# Epoch 40/50
#  - 0s - loss: 49.7856
# Epoch 41/50
#  - 0s - loss: 53.0275
# Epoch 42/50
#  - 0s - loss: 54.1750
# Epoch 43/50
#  - 0s - loss: 50.7182
# Epoch 44/50
#  - 0s - loss: 51.5915
# Epoch 45/50
#  - 0s - loss: 51.5777
# Epoch 46/50
#  - 0s - loss: 50.5978
# Epoch 47/50
#  - 0s - loss: 47.9583
# Epoch 48/50
#  - 0s - loss: 51.2279
# Epoch 49/50
#  - 0s - loss: 48.9986
# Epoch 50/50
#  - 0s - loss: 52.5916
# Duration (seconds): 2.3020620346069336
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 51.6558
# Epoch 2/50
#  - 0s - loss: 50.8731
# Epoch 3/50
#  - 0s - loss: 48.9842
# Epoch 4/50
#  - 0s - loss: 48.4507
# Epoch 5/50
#  - 0s - loss: 48.3156
# Epoch 6/50
#  - 0s - loss: 48.4557
# Epoch 7/50
#  - 0s - loss: 48.3073
# Epoch 8/50
#  - 0s - loss: 53.2039
# Epoch 9/50
#  - 0s - loss: 48.9691
# Epoch 10/50
#  - 0s - loss: 51.4218
# Epoch 11/50
#  - 0s - loss: 48.6832
# Epoch 12/50
#  - 0s - loss: 49.1719
# Epoch 13/50
#  - 0s - loss: 50.7567
# Epoch 14/50
#  - 0s - loss: 48.6632
# Epoch 15/50
#  - 0s - loss: 49.9467
# Epoch 16/50
#  - 0s - loss: 49.1292
# Epoch 17/50
#  - 0s - loss: 49.0060
# Epoch 18/50
#  - 0s - loss: 51.7358
# Epoch 19/50
#  - 0s - loss: 51.2093
# Epoch 20/50
#  - 0s - loss: 49.1270
# Epoch 21/50
#  - 0s - loss: 48.8785
# Epoch 22/50
#  - 0s - loss: 49.4808
# Epoch 23/50
#  - 0s - loss: 49.0977
# Epoch 24/50
#  - 0s - loss: 51.2971
# Epoch 25/50
#  - 0s - loss: 50.5964
# Epoch 26/50
#  - 0s - loss: 48.6100
# Epoch 27/50
#  - 0s - loss: 49.2193
# Epoch 28/50
#  - 0s - loss: 50.6337
# Epoch 29/50
#  - 0s - loss: 54.4144
# Epoch 30/50
#  - 0s - loss: 50.0403
# Epoch 31/50
#  - 0s - loss: 48.5600
# Epoch 32/50
#  - 0s - loss: 50.8440
# Epoch 33/50
#  - 0s - loss: 49.2924
# Epoch 34/50
#  - 0s - loss: 49.5314
# Epoch 35/50
#  - 0s - loss: 49.1524
# Epoch 36/50
#  - 0s - loss: 48.7371
# Epoch 37/50
#  - 0s - loss: 48.5694
# Epoch 38/50
#  - 0s - loss: 50.3633
# Epoch 39/50
#  - 0s - loss: 48.0899
# Epoch 40/50
#  - 0s - loss: 51.1197
# Epoch 41/50
#  - 0s - loss: 50.0846
# Epoch 42/50
#  - 0s - loss: 49.9428
# Epoch 43/50
#  - 0s - loss: 49.3286
# Epoch 44/50
#  - 0s - loss: 51.2007
# Epoch 45/50
#  - 0s - loss: 51.7995
# Epoch 46/50
#  - 0s - loss: 48.4109
# Epoch 47/50
#  - 0s - loss: 47.9591
# Epoch 48/50
#  - 0s - loss: 48.7029
# Epoch 49/50
#  - 0s - loss: 48.6170
# Epoch 50/50
#  - 0s - loss: 49.0318
# Duration (seconds): 1.619577169418335
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.6723
# Epoch 2/50
#  - 0s - loss: 49.2771
# Epoch 3/50
#  - 0s - loss: 49.1554
# Epoch 4/50
#  - 0s - loss: 48.8057
# Epoch 5/50
#  - 0s - loss: 53.1431
# Epoch 6/50
#  - 0s - loss: 53.8182
# Epoch 7/50
#  - 0s - loss: 50.6372
# Epoch 8/50
#  - 0s - loss: 49.4241
# Epoch 9/50
#  - 0s - loss: 52.5857
# Epoch 10/50
#  - 0s - loss: 51.2067
# Epoch 11/50
#  - 0s - loss: 49.0743
# Epoch 12/50
#  - 0s - loss: 49.8784
# Epoch 13/50
#  - 0s - loss: 49.7866
# Epoch 14/50
#  - 0s - loss: 52.3975
# Epoch 15/50
#  - 0s - loss: 52.7647
# Epoch 16/50
#  - 0s - loss: 48.9357
# Epoch 17/50
#  - 0s - loss: 48.0882
# Epoch 18/50
#  - 0s - loss: 50.2831
# Epoch 19/50
#  - 0s - loss: 50.6707
# Epoch 20/50
#  - 0s - loss: 49.8205
# Epoch 21/50
#  - 0s - loss: 51.2391
# Epoch 22/50
#  - 0s - loss: 51.7609
# Epoch 23/50
#  - 0s - loss: 50.4871
# Epoch 24/50
#  - 0s - loss: 50.5454
# Epoch 25/50
#  - 0s - loss: 48.6175
# Epoch 26/50
#  - 0s - loss: 49.4162
# Epoch 27/50
#  - 0s - loss: 49.8236
# Epoch 28/50
#  - 0s - loss: 49.1054
# Epoch 29/50
#  - 0s - loss: 48.1668
# Epoch 30/50
#  - 0s - loss: 48.5894
# Epoch 31/50
#  - 0s - loss: 49.7489
# Epoch 32/50
#  - 0s - loss: 48.9110
# Epoch 33/50
#  - 0s - loss: 51.2877
# Epoch 34/50
#  - 0s - loss: 48.3359
# Epoch 35/50
#  - 0s - loss: 48.8693
# Epoch 36/50
#  - 0s - loss: 49.7890
# Epoch 37/50
#  - 0s - loss: 49.7052
# Epoch 38/50
#  - 0s - loss: 50.7045
# Epoch 39/50
#  - 0s - loss: 49.2980
# Epoch 40/50
#  - 0s - loss: 49.5870
# Epoch 41/50
#  - 0s - loss: 48.7513
# Epoch 42/50
#  - 0s - loss: 48.7405
# Epoch 43/50
#  - 0s - loss: 51.6393
# Epoch 44/50
#  - 0s - loss: 48.4716
# Epoch 45/50
#  - 0s - loss: 52.2633
# Epoch 46/50
#  - 0s - loss: 50.0345
# Epoch 47/50
#  - 0s - loss: 49.2620
# Epoch 48/50
#  - 0s - loss: 48.5133
# Epoch 49/50
#  - 0s - loss: 49.1529
# Epoch 50/50
#  - 0s - loss: 47.6305
# Duration (seconds): 1.8553967475891113
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 50.6374
# Epoch 2/50
#  - 0s - loss: 48.7651
# Epoch 3/50
#  - 0s - loss: 50.7528
# Epoch 4/50
#  - 0s - loss: 50.3008
# Epoch 5/50
#  - 0s - loss: 51.4975
# Epoch 6/50
#  - 0s - loss: 48.9307
# Epoch 7/50
#  - 0s - loss: 51.9959
# Epoch 8/50
#  - 0s - loss: 52.2047
# Epoch 9/50
#  - 0s - loss: 51.5084
# Epoch 10/50
#  - 0s - loss: 48.8470
# Epoch 11/50
#  - 0s - loss: 49.2159
# Epoch 12/50
#  - 0s - loss: 48.3060
# Epoch 13/50
#  - 0s - loss: 51.2566
# Epoch 14/50
#  - 0s - loss: 51.0916
# Epoch 15/50
#  - 0s - loss: 52.1125
# Epoch 16/50
#  - 0s - loss: 49.9634
# Epoch 17/50
#  - 0s - loss: 49.0358
# Epoch 18/50
#  - 0s - loss: 49.6183
# Epoch 19/50
#  - 0s - loss: 50.3678
# Epoch 20/50
#  - 0s - loss: 48.3880
# Epoch 21/50
#  - 0s - loss: 49.8511
# Epoch 22/50
#  - 0s - loss: 50.1474
# Epoch 23/50
#  - 0s - loss: 49.9599
# Epoch 24/50
#  - 0s - loss: 50.6576
# Epoch 25/50
#  - 0s - loss: 53.7262
# Epoch 26/50
#  - 0s - loss: 48.2876
# Epoch 27/50
#  - 0s - loss: 48.3438
# Epoch 28/50
#  - 0s - loss: 49.9576
# Epoch 29/50
#  - 0s - loss: 47.9086
# Epoch 30/50
#  - 0s - loss: 50.9648
# Epoch 31/50
#  - 0s - loss: 48.0230
# Epoch 32/50
#  - 0s - loss: 50.2618
# Epoch 33/50
#  - 0s - loss: 48.8492
# Epoch 34/50
#  - 0s - loss: 48.1955
# Epoch 35/50
#  - 0s - loss: 49.0651
# Epoch 36/50
#  - 0s - loss: 48.6304
# Epoch 37/50
#  - 0s - loss: 49.2194
# Epoch 38/50
#  - 0s - loss: 51.1299
# Epoch 39/50
#  - 0s - loss: 50.5525
# Epoch 40/50
#  - 0s - loss: 49.4156
# Epoch 41/50
#  - 0s - loss: 48.3988
# Epoch 42/50
#  - 0s - loss: 51.8697
# Epoch 43/50
#  - 0s - loss: 49.9068
# Epoch 44/50
#  - 0s - loss: 49.1218
# Epoch 45/50
#  - 0s - loss: 47.7425
# Epoch 46/50
#  - 0s - loss: 51.5346
# Epoch 47/50
#  - 0s - loss: 48.3095
# Epoch 48/50
#  - 0s - loss: 49.1636
# Epoch 49/50
#  - 0s - loss: 50.9889
# Epoch 50/50
#  - 0s - loss: 48.4649
# Duration (seconds): 1.9567890167236328
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.2898
# Epoch 2/50
#  - 0s - loss: 48.7019
# Epoch 3/50
#  - 0s - loss: 50.0739
# Epoch 4/50
#  - 0s - loss: 53.5074
# Epoch 5/50
#  - 0s - loss: 55.8378
# Epoch 6/50
#  - 0s - loss: 49.5953
# Epoch 7/50
#  - 0s - loss: 49.8669
# Epoch 8/50
#  - 0s - loss: 48.1832
# Epoch 9/50
#  - 0s - loss: 48.9609
# Epoch 10/50
#  - 0s - loss: 47.9509
# Epoch 11/50
#  - 0s - loss: 49.6319
# Epoch 12/50
#  - 0s - loss: 48.6944
# Epoch 13/50
#  - 0s - loss: 48.6873
# Epoch 14/50
#  - 0s - loss: 48.1132
# Epoch 15/50
#  - 0s - loss: 47.5061
# Epoch 16/50
#  - 0s - loss: 48.8881
# Epoch 17/50
#  - 0s - loss: 48.2837
# Epoch 18/50
#  - 0s - loss: 49.7415
# Epoch 19/50
#  - 0s - loss: 49.4097
# Epoch 20/50
#  - 0s - loss: 49.3744
# Epoch 21/50
#  - 0s - loss: 51.3955
# Epoch 22/50
#  - 0s - loss: 48.4282
# Epoch 23/50
#  - 0s - loss: 51.7445
# Epoch 24/50
#  - 0s - loss: 52.0084
# Epoch 25/50
#  - 0s - loss: 51.0502
# Epoch 26/50
#  - 0s - loss: 49.0093
# Epoch 27/50
#  - 0s - loss: 48.7069
# Epoch 28/50
#  - 0s - loss: 49.2100
# Epoch 29/50
#  - 0s - loss: 48.9760
# Epoch 30/50
#  - 0s - loss: 53.9899
# Epoch 31/50
#  - 0s - loss: 49.3816
# Epoch 32/50
#  - 0s - loss: 50.2981
# Epoch 33/50
#  - 0s - loss: 49.3107
# Epoch 34/50
#  - 0s - loss: 48.3473
# Epoch 35/50
#  - 0s - loss: 47.2157
# Epoch 36/50
#  - 0s - loss: 48.8399
# Epoch 37/50
#  - 0s - loss: 50.6710
# Epoch 38/50
#  - 0s - loss: 51.1025
# Epoch 39/50
#  - 0s - loss: 49.7718
# Epoch 40/50
#  - 0s - loss: 48.9647
# Epoch 41/50
#  - 0s - loss: 49.4329
# Epoch 42/50
#  - 0s - loss: 51.7422
# Epoch 43/50
#  - 0s - loss: 48.6813
# Epoch 44/50
#  - 0s - loss: 48.3941
# Epoch 45/50
#  - 0s - loss: 48.1589
# Epoch 46/50
#  - 0s - loss: 48.4475
# Epoch 47/50
#  - 0s - loss: 50.1424
# Epoch 48/50
#  - 0s - loss: 48.2707
# Epoch 49/50
#  - 0s - loss: 48.7864
# Epoch 50/50
#  - 0s - loss: 50.4138
# Duration (seconds): 2.009471893310547
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 51.5151
# Epoch 2/50
#  - 0s - loss: 48.0509
# Epoch 3/50
#  - 0s - loss: 49.7872
# Epoch 4/50
#  - 0s - loss: 51.7861
# Epoch 5/50
#  - 0s - loss: 50.5868
# Epoch 6/50
#  - 0s - loss: 49.3682
# Epoch 7/50
#  - 0s - loss: 49.0059
# Epoch 8/50
#  - 0s - loss: 57.9394
# Epoch 9/50
#  - 0s - loss: 51.8631
# Epoch 10/50
#  - 0s - loss: 51.2727
# Epoch 11/50
#  - 0s - loss: 48.2248
# Epoch 12/50
#  - 0s - loss: 48.1797
# Epoch 13/50
#  - 0s - loss: 50.9921
# Epoch 14/50
#  - 0s - loss: 56.2101
# Epoch 15/50
#  - 0s - loss: 50.1512
# Epoch 16/50
#  - 0s - loss: 49.8979
# Epoch 17/50
#  - 0s - loss: 51.4890
# Epoch 18/50
#  - 0s - loss: 48.7879
# Epoch 19/50
#  - 0s - loss: 48.1789
# Epoch 20/50
#  - 0s - loss: 50.0346
# Epoch 21/50
#  - 0s - loss: 48.1582
# Epoch 22/50
#  - 0s - loss: 49.2167
# Epoch 23/50
#  - 0s - loss: 50.0853
# Epoch 24/50
#  - 0s - loss: 48.5715
# Epoch 25/50
#  - 0s - loss: 48.5191
# Epoch 26/50
#  - 0s - loss: 52.0244
# Epoch 27/50
#  - 0s - loss: 50.0714
# Epoch 28/50
#  - 0s - loss: 48.4794
# Epoch 29/50
#  - 0s - loss: 48.5372
# Epoch 30/50
#  - 0s - loss: 50.7964
# Epoch 31/50
#  - 0s - loss: 48.6124
# Epoch 32/50
#  - 0s - loss: 51.4374
# Epoch 33/50
#  - 0s - loss: 57.7531
# Epoch 34/50
#  - 0s - loss: 48.9393
# Epoch 35/50
#  - 0s - loss: 48.5506
# Epoch 36/50
#  - 0s - loss: 49.1979
# Epoch 37/50
#  - 0s - loss: 49.2336
# Epoch 38/50
#  - 0s - loss: 50.1972
# Epoch 39/50
#  - 0s - loss: 48.0671
# Epoch 40/50
#  - 0s - loss: 53.0142
# Epoch 41/50
#  - 0s - loss: 51.9239
# Epoch 42/50
#  - 0s - loss: 49.1755
# Epoch 43/50
#  - 0s - loss: 48.4286
# Epoch 44/50
#  - 0s - loss: 50.7954
# Epoch 45/50
#  - 0s - loss: 47.7952
# Epoch 46/50
#  - 0s - loss: 50.5328
# Epoch 47/50
#  - 0s - loss: 48.5639
# Epoch 48/50
#  - 0s - loss: 48.6724
# Epoch 49/50
#  - 0s - loss: 51.1095
# Epoch 50/50
#  - 0s - loss: 48.9210
# Duration (seconds): 1.7609992027282715
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.9592
# Epoch 2/50
#  - 0s - loss: 51.0090
# Epoch 3/50
#  - 0s - loss: 50.1647
# Epoch 4/50
#  - 0s - loss: 49.9861
# Epoch 5/50
#  - 0s - loss: 48.0412
# Epoch 6/50
#  - 0s - loss: 49.0649
# Epoch 7/50
#  - 0s - loss: 50.5920
# Epoch 8/50
#  - 0s - loss: 49.5600
# Epoch 9/50
#  - 0s - loss: 47.8179
# Epoch 10/50
#  - 0s - loss: 55.7422
# Epoch 11/50
#  - 0s - loss: 50.5183
# Epoch 12/50
#  - 0s - loss: 50.2656
# Epoch 13/50
#  - 0s - loss: 52.8867
# Epoch 14/50
#  - 0s - loss: 49.8960
# Epoch 15/50
#  - 0s - loss: 49.2807
# Epoch 16/50
#  - 0s - loss: 51.9867
# Epoch 17/50
#  - 0s - loss: 51.4716
# Epoch 18/50
#  - 0s - loss: 53.2080
# Epoch 19/50
#  - 0s - loss: 49.0550
# Epoch 20/50
#  - 0s - loss: 48.4414
# Epoch 21/50
#  - 0s - loss: 48.8121
# Epoch 22/50
#  - 0s - loss: 49.3969
# Epoch 23/50
#  - 0s - loss: 48.6081
# Epoch 24/50
#  - 0s - loss: 49.3178
# Epoch 25/50
#  - 0s - loss: 49.1273
# Epoch 26/50
#  - 0s - loss: 48.6321
# Epoch 27/50
#  - 0s - loss: 49.1700
# Epoch 28/50
#  - 0s - loss: 48.6452
# Epoch 29/50
#  - 0s - loss: 48.3966
# Epoch 30/50
#  - 0s - loss: 52.8082
# Epoch 31/50
#  - 0s - loss: 51.8172
# Epoch 32/50
#  - 0s - loss: 54.0508
# Epoch 33/50
#  - 0s - loss: 49.6172
# Epoch 34/50
#  - 0s - loss: 48.8026
# Epoch 35/50
#  - 0s - loss: 48.5564
# Epoch 36/50
#  - 0s - loss: 52.0371
# Epoch 37/50
#  - 0s - loss: 52.8806
# Epoch 38/50
#  - 0s - loss: 49.1822
# Epoch 39/50
#  - 0s - loss: 49.3955
# Epoch 40/50
#  - 0s - loss: 54.0151
# Epoch 41/50
#  - 0s - loss: 49.7205
# Epoch 42/50
#  - 0s - loss: 48.5129
# Epoch 43/50
#  - 0s - loss: 49.4390
# Epoch 44/50
#  - 0s - loss: 50.9375
# Epoch 45/50
#  - 0s - loss: 51.9091
# Epoch 46/50
#  - 0s - loss: 48.0725
# Epoch 47/50
#  - 0s - loss: 48.4133
# Epoch 48/50
#  - 0s - loss: 48.6099
# Epoch 49/50
#  - 0s - loss: 48.4211
# Epoch 50/50
#  - 0s - loss: 48.3319
# Duration (seconds): 1.8616151809692383
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.9015
# Epoch 2/50
#  - 0s - loss: 50.1401
# Epoch 3/50
#  - 0s - loss: 48.4085
# Epoch 4/50
#  - 0s - loss: 49.5441
# Epoch 5/50
#  - 0s - loss: 48.9502
# Epoch 6/50
#  - 0s - loss: 50.4198
# Epoch 7/50
#  - 0s - loss: 50.4576
# Epoch 8/50
#  - 0s - loss: 48.4148
# Epoch 9/50
#  - 0s - loss: 51.9373
# Epoch 10/50
#  - 0s - loss: 48.6243
# Epoch 11/50
#  - 0s - loss: 48.2826
# Epoch 12/50
#  - 0s - loss: 48.9847
# Epoch 13/50
#  - 0s - loss: 48.7912
# Epoch 14/50
#  - 0s - loss: 51.9939
# Epoch 15/50
#  - 0s - loss: 50.4040
# Epoch 16/50
#  - 0s - loss: 49.1135
# Epoch 17/50
#  - 0s - loss: 48.4926
# Epoch 18/50
#  - 0s - loss: 48.7737
# Epoch 19/50
#  - 0s - loss: 50.0649
# Epoch 20/50
#  - 0s - loss: 48.7442
# Epoch 21/50
#  - 0s - loss: 49.1726
# Epoch 22/50
#  - 0s - loss: 50.6697
# Epoch 23/50
#  - 0s - loss: 50.1422
# Epoch 24/50
#  - 0s - loss: 48.8196
# Epoch 25/50
#  - 0s - loss: 50.4857
# Epoch 26/50
#  - 0s - loss: 51.4135
# Epoch 27/50
#  - 0s - loss: 51.7179
# Epoch 28/50
#  - 0s - loss: 48.0402
# Epoch 29/50
#  - 0s - loss: 49.1418
# Epoch 30/50
#  - 0s - loss: 50.3883
# Epoch 31/50
#  - 0s - loss: 49.5714
# Epoch 32/50
#  - 0s - loss: 49.3781
# Epoch 33/50
#  - 0s - loss: 49.9754
# Epoch 34/50
#  - 0s - loss: 50.9695
# Epoch 35/50
#  - 0s - loss: 48.5656
# Epoch 36/50
#  - 0s - loss: 48.4549
# Epoch 37/50
#  - 0s - loss: 49.4427
# Epoch 38/50
#  - 0s - loss: 49.7087
# Epoch 39/50
#  - 0s - loss: 50.0521
# Epoch 40/50
#  - 0s - loss: 49.8248
# Epoch 41/50
#  - 0s - loss: 49.4798
# Epoch 42/50
#  - 0s - loss: 49.0060
# Epoch 43/50
#  - 0s - loss: 47.5797
# Epoch 44/50
#  - 0s - loss: 48.1710
# Epoch 45/50
#  - 0s - loss: 48.9363
# Epoch 46/50
#  - 0s - loss: 47.6882
# Epoch 47/50
#  - 0s - loss: 48.8115
# Epoch 48/50
#  - 0s - loss: 49.8525
# Epoch 49/50
#  - 0s - loss: 48.7848
# Epoch 50/50
#  - 0s - loss: 48.4642
# Duration (seconds): 1.716602087020874
# Finished - 50 times.
# And the list of mean squared errors : [115.18102915035738, 107.10157274026368, 94.34312062356966, 78.06215176213338, 66.65942317487716, 62.81128985293042, 58.43432476880878, 52.7247807469296, 53.96078745226556, 50.35243844152994, 53.567849853957995, 52.44889529029417, 48.20562863567655, 49.99301623509975, 48.03034981851431, 51.18940196077829, 48.76829067570568, 54.171622530818865, 50.152544148202466, 49.17575408747368, 58.006110084355484, 48.73287893401875, 48.464074042321606, 49.333415884082825, 49.13399235633032, 53.65860053458069, 55.20918179152516, 50.45876536984886, 49.58879445888733, 49.08435354606231, 49.34065054523152, 48.39448432484072, 52.10942087616029, 49.38235556240083, 51.85213815326994, 48.54906300496077, 51.73244194934997, 48.64766051177515, 48.292405131692256, 49.118382263708995, 48.63965957870873, 53.30072959413295, 57.869609547752795, 48.59008561156648, 50.44259540523432, 48.89883052532959, 50.56885242241915, 56.64148282638893, 50.93486759380735, 49.98786556250496]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 55.41 and 13.89, respectively

# %% [markdown]
# ### Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of not normalized data is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline-not normalized (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline = get_report(name_of_case, mean_mse, std_mse)
df_baseline
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     55.41              13.89

# %% [markdown]
# ## Part B: Normalized data

# %% [markdown]
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
# How does the mean of the mean squared errors compare to that from Step A?

# %% [markdown]
# ### Data before normalization

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %% [markdown]
# ### Data after normalization

# %% [markdown]
# We will normalize the data by substracting the mean and dividing by the standard deviation

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_colsnorm = predictors_norm.shape[1] #number of predictors

# %% [markdown]
# Defining the regression model as above

# %%
#define the regression model with one hidden layer
def regression_model():
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(n_colsnorm,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Creating the regression model

# %%
model = regression_model()

# %% [markdown]
# Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=24)   
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)

# %% [markdown]
# Train the model on the training data using 50 epochs

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
#  - 0s - loss: 1615.0911
# Epoch 2/50
#  - 0s - loss: 1601.5464
# Epoch 3/50
#  - 0s - loss: 1588.7095
# Epoch 4/50
#  - 0s - loss: 1576.3353
# Epoch 5/50
#  - 0s - loss: 1563.9033
# Epoch 6/50
#  - 0s - loss: 1551.2929
# Epoch 7/50
#  - 0s - loss: 1537.9528
# Epoch 8/50
#  - 0s - loss: 1523.9388
# Epoch 9/50
#  - 0s - loss: 1508.6667
# Epoch 10/50
#  - 0s - loss: 1492.2921
# Epoch 11/50
#  - 0s - loss: 1474.5051
# Epoch 12/50
#  - 0s - loss: 1454.9459
# Epoch 13/50
#  - 0s - loss: 1434.1095
# Epoch 14/50
#  - 0s - loss: 1410.9501
# Epoch 15/50
#  - 0s - loss: 1386.9014
# Epoch 16/50
#  - 0s - loss: 1360.5853
# Epoch 17/50
#  - 0s - loss: 1333.2521
# Epoch 18/50
#  - 0s - loss: 1304.6021
# Epoch 19/50
#  - 0s - loss: 1274.8266
# Epoch 20/50
#  - 0s - loss: 1243.6248
# Epoch 21/50
#  - 0s - loss: 1211.5846
# Epoch 22/50
#  - 0s - loss: 1178.4650
# Epoch 23/50
#  - 0s - loss: 1144.4540
# Epoch 24/50
#  - 0s - loss: 1109.9478
# Epoch 25/50
#  - 0s - loss: 1074.7858
# Epoch 26/50
#  - 0s - loss: 1039.1809
# Epoch 27/50
#  - 0s - loss: 1003.1913
# Epoch 28/50
#  - 0s - loss: 966.6377
# Epoch 29/50
#  - 0s - loss: 930.1020
# Epoch 30/50
#  - 0s - loss: 892.7791
# Epoch 31/50
#  - 0s - loss: 855.9839
# Epoch 32/50
#  - 0s - loss: 818.4827
# Epoch 33/50
#  - 0s - loss: 781.5930
# Epoch 34/50
#  - 0s - loss: 745.1268
# Epoch 35/50
#  - 0s - loss: 709.4465
# Epoch 36/50
#  - 0s - loss: 674.6692
# Epoch 37/50
#  - 0s - loss: 640.2671
# Epoch 38/50
#  - 0s - loss: 607.5089
# Epoch 39/50
#  - 0s - loss: 575.7581
# Epoch 40/50
#  - 0s - loss: 545.2237
# Epoch 41/50
#  - 0s - loss: 516.1974
# Epoch 42/50
#  - 0s - loss: 488.6251
# Epoch 43/50
#  - 0s - loss: 462.4684
# Epoch 44/50
#  - 0s - loss: 437.9090
# Epoch 45/50
#  - 0s - loss: 415.3153
# Epoch 46/50
#  - 0s - loss: 393.7769
# Epoch 47/50
#  - 0s - loss: 373.8185
# Epoch 48/50
#  - 0s - loss: 355.5178
# Epoch 49/50
#  - 0s - loss: 338.4282
# Epoch 50/50
#  - 0s - loss: 322.5052

# %% [markdown]
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
y_hat = model.predict(X_test)   
mse = mean_squared_error(y_test, y_hat)

# %%
print(mse)
# Out:
# 296.39646635977283

# %% [markdown]
# For the case of not normalized data that we ran in Part A mse = 284.23, for this case with normalized data mse= 296.39

# %% [markdown]
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors

# %%
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """   
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn. 
    X = predictors_norm
    y = target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse

# %%
#Function to round the calculation of the mean and std deviation to 2 decimal places
def get_round(score, num_of_digits=2):
    """Get round with given number of decimal digits 
    """
    return round(score, num_of_digits)

#Function to calculate the mean of the list of mean squared errors
def get_mean(list_of_mse_scores):
    """Get mean
    """
    if list_of_mse_scores:
        return get_round(np.mean(list_of_mse_scores))
    return None

#Function to calculate the standard deviation of the list of mean squared errors
def get_standard_deviation(list_of_mse_scores):
    """Get standard deviation
    """
    if list_of_mse_scores:
        return get_round(np.std(list_of_mse_scores))
    return None




#Function to iterate and calculate the mean squared error
def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
    """Generate the mean and the standard deviation of the mean squared errors 
    """
    # Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.    
    list_of_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        list_of_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))
    # end for

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  list_of_mean_squared_errors))
    
    mean_mse = get_mean(list_of_mean_squared_errors)
    std_mse = get_standard_deviation(list_of_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse

# %%
max_iteration = 50
epochs = 50
verbose = 2

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors_norm, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 1574.5517
# Epoch 2/50
#  - 0s - loss: 1557.6679
# Epoch 3/50
#  - 0s - loss: 1540.8171
# Epoch 4/50
#  - 0s - loss: 1523.8873
# Epoch 5/50
#  - 0s - loss: 1506.5983
# Epoch 6/50
#  - 0s - loss: 1489.1528
# Epoch 7/50
#  - 0s - loss: 1471.0778
# Epoch 8/50
#  - 0s - loss: 1452.6774
# Epoch 9/50
#  - 0s - loss: 1433.7410
# Epoch 10/50
#  - 0s - loss: 1414.1822
# Epoch 11/50
#  - 0s - loss: 1393.3315
# Epoch 12/50
#  - 0s - loss: 1371.9828
# Epoch 13/50
#  - 0s - loss: 1348.9047
# Epoch 14/50
#  - 0s - loss: 1325.4215
# Epoch 15/50
#  - 0s - loss: 1300.1354
# Epoch 16/50
#  - 0s - loss: 1274.2417
# Epoch 17/50
#  - 0s - loss: 1247.4156
# Epoch 18/50
#  - 0s - loss: 1218.9390
# Epoch 19/50
#  - 0s - loss: 1189.5432
# Epoch 20/50
#  - 0s - loss: 1158.8129
# Epoch 21/50
#  - 0s - loss: 1126.7940
# Epoch 22/50
#  - 0s - loss: 1094.3861
# Epoch 23/50
#  - 0s - loss: 1060.9528
# Epoch 24/50
#  - 0s - loss: 1026.8742
# Epoch 25/50
#  - 0s - loss: 992.5245
# Epoch 26/50
#  - 0s - loss: 957.4635
# Epoch 27/50
#  - 0s - loss: 922.5251
# Epoch 28/50
#  - 0s - loss: 887.7057
# Epoch 29/50
#  - 0s - loss: 853.0985
# Epoch 30/50
#  - 0s - loss: 818.4474
# Epoch 31/50
#  - 0s - loss: 784.1581
# Epoch 32/50
#  - 0s - loss: 750.0654
# Epoch 33/50
#  - 0s - loss: 717.4343
# Epoch 34/50
#  - 0s - loss: 684.4916
# Epoch 35/50
#  - 0s - loss: 653.0353
# Epoch 36/50
#  - 0s - loss: 622.2481
# Epoch 37/50
#  - 0s - loss: 592.7731
# Epoch 38/50
#  - 0s - loss: 564.6304
# Epoch 39/50
#  - 0s - loss: 537.4096
# Epoch 40/50
#  - 0s - loss: 511.2924
# Epoch 41/50
#  - 0s - loss: 486.8244
# Epoch 42/50
#  - 0s - loss: 463.3437
# Epoch 43/50
#  - 0s - loss: 441.1118
# Epoch 44/50
#  - 0s - loss: 420.3343
# Epoch 45/50
#  - 0s - loss: 400.5338
# Epoch 46/50
#  - 0s - loss: 382.6361
# Epoch 47/50
#  - 0s - loss: 365.1906
# Epoch 48/50
#  - 0s - loss: 349.7268
# Epoch 49/50
#  - 0s - loss: 335.1731
# Epoch 50/50
#  - 0s - loss: 321.5715
# Duration (seconds): 3.1487112045288086
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 309.3057
# Epoch 2/50
#  - 0s - loss: 297.7404
# Epoch 3/50
#  - 0s - loss: 287.1657
# Epoch 4/50
#  - 0s - loss: 277.9371
# Epoch 5/50
#  - 0s - loss: 268.9032
# Epoch 6/50
#  - 0s - loss: 261.0471
# Epoch 7/50
#  - 0s - loss: 253.9674
# Epoch 8/50
#  - 0s - loss: 247.1621
# Epoch 9/50
#  - 0s - loss: 241.1753
# Epoch 10/50
#  - 0s - loss: 235.5775
# Epoch 11/50
#  - 0s - loss: 230.5763
# Epoch 12/50
#  - 0s - loss: 225.8944
# Epoch 13/50
#  - 0s - loss: 221.5599
# Epoch 14/50
#  - 0s - loss: 217.6375
# Epoch 15/50
#  - 0s - loss: 213.9966
# Epoch 16/50
#  - 0s - loss: 210.5965
# Epoch 17/50
#  - 0s - loss: 207.4882
# Epoch 18/50
#  - 0s - loss: 204.5269
# Epoch 19/50
#  - 0s - loss: 201.7677
# Epoch 20/50
#  - 0s - loss: 199.1339
# Epoch 21/50
#  - 0s - loss: 196.7729
# Epoch 22/50
#  - 0s - loss: 194.4675
# Epoch 23/50
#  - 0s - loss: 192.3338
# Epoch 24/50
#  - 0s - loss: 190.3026
# Epoch 25/50
#  - 0s - loss: 188.3217
# Epoch 26/50
#  - 0s - loss: 186.6150
# Epoch 27/50
#  - 0s - loss: 184.9247
# Epoch 28/50
#  - 0s - loss: 183.1712
# Epoch 29/50
#  - 0s - loss: 181.7371
# Epoch 30/50
#  - 0s - loss: 180.2357
# Epoch 31/50
#  - 0s - loss: 178.7361
# Epoch 32/50
#  - 0s - loss: 177.3823
# Epoch 33/50
#  - 0s - loss: 176.0469
# Epoch 34/50
#  - 0s - loss: 174.9421
# Epoch 35/50
#  - 0s - loss: 173.6038
# Epoch 36/50
#  - 0s - loss: 172.4919
# Epoch 37/50
#  - 0s - loss: 171.2938
# Epoch 38/50
#  - 0s - loss: 170.2249
# Epoch 39/50
#  - 0s - loss: 169.1714
# Epoch 40/50
#  - 0s - loss: 168.1254
# Epoch 41/50
#  - 0s - loss: 167.1602
# Epoch 42/50
#  - 0s - loss: 166.0486
# Epoch 43/50
#  - 0s - loss: 165.0496
# Epoch 44/50
#  - 0s - loss: 163.9528
# Epoch 45/50
#  - 0s - loss: 162.9659
# Epoch 46/50
#  - 0s - loss: 161.8846
# Epoch 47/50
#  - 0s - loss: 160.9324
# Epoch 48/50
#  - 0s - loss: 159.8660
# Epoch 49/50
#  - 0s - loss: 158.8070
# Epoch 50/50
#  - 0s - loss: 157.8530
# Duration (seconds): 2.0443148612976074
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 156.8077
# Epoch 2/50
#  - 0s - loss: 155.8001
# Epoch 3/50
#  - 0s - loss: 154.8406
# Epoch 4/50
#  - 0s - loss: 153.7980
# Epoch 5/50
#  - 0s - loss: 152.8197
# Epoch 6/50
#  - 0s - loss: 151.8497
# Epoch 7/50
#  - 0s - loss: 150.9906
# Epoch 8/50
#  - 0s - loss: 149.8944
# Epoch 9/50
#  - 0s - loss: 148.9698
# Epoch 10/50
#  - 0s - loss: 148.0783
# Epoch 11/50
#  - 0s - loss: 147.1063
# Epoch 12/50
#  - 0s - loss: 146.2121
# Epoch 13/50
#  - 0s - loss: 145.3861
# Epoch 14/50
#  - 0s - loss: 144.4553
# Epoch 15/50
#  - 0s - loss: 143.5164
# Epoch 16/50
#  - 0s - loss: 142.6313
# Epoch 17/50
#  - 0s - loss: 141.7601
# Epoch 18/50
#  - 0s - loss: 140.8172
# Epoch 19/50
#  - 0s - loss: 139.9389
# Epoch 20/50
#  - 0s - loss: 139.0275
# Epoch 21/50
#  - 0s - loss: 138.2223
# Epoch 22/50
#  - 0s - loss: 137.3071
# Epoch 23/50
#  - 0s - loss: 136.4478
# Epoch 24/50
#  - 0s - loss: 135.6274
# Epoch 25/50
#  - 0s - loss: 134.7682
# Epoch 26/50
#  - 0s - loss: 133.9399
# Epoch 27/50
#  - 0s - loss: 133.0905
# Epoch 28/50
#  - 0s - loss: 132.2878
# Epoch 29/50
#  - 0s - loss: 131.4214
# Epoch 30/50
#  - 0s - loss: 130.6979
# Epoch 31/50
#  - 0s - loss: 129.8496
# Epoch 32/50
#  - 0s - loss: 129.0532
# Epoch 33/50
#  - 0s - loss: 128.1974
# Epoch 34/50
#  - 0s - loss: 127.3616
# Epoch 35/50
#  - 0s - loss: 126.5534
# Epoch 36/50
#  - 0s - loss: 125.8220
# Epoch 37/50
#  - 0s - loss: 125.0574
# Epoch 38/50
#  - 0s - loss: 124.3218
# Epoch 39/50
#  - 0s - loss: 123.5374
# Epoch 40/50
#  - 0s - loss: 122.7651
# Epoch 41/50
#  - 0s - loss: 122.0615
# Epoch 42/50
#  - 0s - loss: 121.3305
# Epoch 43/50
#  - 0s - loss: 120.5216
# Epoch 44/50
#  - 0s - loss: 119.8563
# Epoch 45/50
#  - 0s - loss: 119.1233
# Epoch 46/50
#  - 0s - loss: 118.4136
# Epoch 47/50
#  - 0s - loss: 117.6620
# Epoch 48/50
#  - 0s - loss: 117.0031
# Epoch 49/50
#  - 0s - loss: 116.2843
# Epoch 50/50
#  - 0s - loss: 115.6224
# Duration (seconds): 2.160437822341919
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 114.8775
# Epoch 2/50
#  - 0s - loss: 114.2000
# Epoch 3/50
#  - 0s - loss: 113.4467
# Epoch 4/50
#  - 0s - loss: 112.8129
# Epoch 5/50
#  - 0s - loss: 112.0691
# Epoch 6/50
#  - 0s - loss: 111.5274
# Epoch 7/50
#  - 0s - loss: 110.7487
# Epoch 8/50
#  - 0s - loss: 110.1311
# Epoch 9/50
#  - 0s - loss: 109.4050
# Epoch 10/50
#  - 0s - loss: 108.7433
# Epoch 11/50
#  - 0s - loss: 108.0492
# Epoch 12/50
#  - 0s - loss: 107.4467
# Epoch 13/50
#  - 0s - loss: 106.7581
# Epoch 14/50
#  - 0s - loss: 106.1468
# Epoch 15/50
#  - 0s - loss: 105.4234
# Epoch 16/50
#  - 0s - loss: 104.8269
# Epoch 17/50
#  - 0s - loss: 104.1319
# Epoch 18/50
#  - 0s - loss: 103.5417
# Epoch 19/50
#  - 0s - loss: 102.8841
# Epoch 20/50
#  - 0s - loss: 102.3519
# Epoch 21/50
#  - 0s - loss: 101.7399
# Epoch 22/50
#  - 0s - loss: 101.1446
# Epoch 23/50
#  - 0s - loss: 100.6035
# Epoch 24/50
#  - 0s - loss: 99.9974
# Epoch 25/50
#  - 0s - loss: 99.3625
# Epoch 26/50
#  - 0s - loss: 98.8345
# Epoch 27/50
#  - 0s - loss: 98.2198
# Epoch 28/50
#  - 0s - loss: 97.7465
# Epoch 29/50
#  - 0s - loss: 97.1594
# Epoch 30/50
#  - 0s - loss: 96.5601
# Epoch 31/50
#  - 0s - loss: 95.9891
# Epoch 32/50
#  - 0s - loss: 95.4553
# Epoch 33/50
#  - 0s - loss: 94.9481
# Epoch 34/50
#  - 0s - loss: 94.3262
# Epoch 35/50
#  - 0s - loss: 93.8541
# Epoch 36/50
#  - 0s - loss: 93.2481
# Epoch 37/50
#  - 0s - loss: 92.6989
# Epoch 38/50
#  - 0s - loss: 92.1621
# Epoch 39/50
#  - 0s - loss: 91.6324
# Epoch 40/50
#  - 0s - loss: 91.1762
# Epoch 41/50
#  - 0s - loss: 90.5575
# Epoch 42/50
#  - 0s - loss: 90.0161
# Epoch 43/50
#  - 0s - loss: 89.5057
# Epoch 44/50
#  - 0s - loss: 88.9742
# Epoch 45/50
#  - 0s - loss: 88.4630
# Epoch 46/50
#  - 0s - loss: 87.9215
# Epoch 47/50
#  - 0s - loss: 87.4511
# Epoch 48/50
#  - 0s - loss: 87.0231
# Epoch 49/50
#  - 0s - loss: 86.4776
# Epoch 50/50
#  - 0s - loss: 85.9681
# Duration (seconds): 1.9713590145111084
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 85.5797
# Epoch 2/50
#  - 0s - loss: 85.0129
# Epoch 3/50
#  - 0s - loss: 84.6819
# Epoch 4/50
#  - 0s - loss: 84.1282
# Epoch 5/50
#  - 0s - loss: 83.6645
# Epoch 6/50
#  - 0s - loss: 83.2280
# Epoch 7/50
#  - 0s - loss: 82.7234
# Epoch 8/50
#  - 0s - loss: 82.3565
# Epoch 9/50
#  - 0s - loss: 81.8703
# Epoch 10/50
#  - 0s - loss: 81.3928
# Epoch 11/50
#  - 0s - loss: 80.9398
# Epoch 12/50
#  - 0s - loss: 80.5423
# Epoch 13/50
#  - 0s - loss: 80.1095
# Epoch 14/50
#  - 0s - loss: 79.7943
# Epoch 15/50
#  - 0s - loss: 79.3992
# Epoch 16/50
#  - 0s - loss: 78.9402
# Epoch 17/50
#  - 0s - loss: 78.5493
# Epoch 18/50
#  - 0s - loss: 78.1358
# Epoch 19/50
#  - 0s - loss: 77.7676
# Epoch 20/50
#  - 0s - loss: 77.3737
# Epoch 21/50
#  - 0s - loss: 76.9783
# Epoch 22/50
#  - 0s - loss: 76.6276
# Epoch 23/50
#  - 0s - loss: 76.2172
# Epoch 24/50
#  - 0s - loss: 75.8553
# Epoch 25/50
#  - 0s - loss: 75.5061
# Epoch 26/50
#  - 0s - loss: 75.0811
# Epoch 27/50
#  - 0s - loss: 74.7689
# Epoch 28/50
#  - 0s - loss: 74.3528
# Epoch 29/50
#  - 0s - loss: 74.0290
# Epoch 30/50
#  - 0s - loss: 73.6511
# Epoch 31/50
#  - 0s - loss: 73.2822
# Epoch 32/50
#  - 0s - loss: 72.9577
# Epoch 33/50
#  - 0s - loss: 72.6650
# Epoch 34/50
#  - 0s - loss: 72.3600
# Epoch 35/50
#  - 0s - loss: 71.9797
# Epoch 36/50
#  - 0s - loss: 71.7845
# Epoch 37/50
#  - 0s - loss: 71.4245
# Epoch 38/50
#  - 0s - loss: 71.0887
# Epoch 39/50
#  - 0s - loss: 70.7545
# Epoch 40/50
#  - 0s - loss: 70.4854
# Epoch 41/50
#  - 0s - loss: 70.1926
# Epoch 42/50
#  - 0s - loss: 69.9250
# Epoch 43/50
#  - 0s - loss: 69.6552
# Epoch 44/50
#  - 0s - loss: 69.4077
# Epoch 45/50
#  - 0s - loss: 69.0288
# Epoch 46/50
#  - 0s - loss: 68.8774
# Epoch 47/50
#  - 0s - loss: 68.5138
# Epoch 48/50
#  - 0s - loss: 68.2961
# Epoch 49/50
#  - 0s - loss: 68.0015
# Epoch 50/50
#  - 0s - loss: 67.7598
# Duration (seconds): 2.079355001449585
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.5176
# Epoch 2/50
#  - 0s - loss: 67.2672
# Epoch 3/50
#  - 0s - loss: 67.0856
# Epoch 4/50
#  - 0s - loss: 66.8036
# Epoch 5/50
#  - 0s - loss: 66.5285
# Epoch 6/50
#  - 0s - loss: 66.3171
# Epoch 7/50
#  - 0s - loss: 66.0381
# Epoch 8/50
#  - 0s - loss: 65.7780
# Epoch 9/50
#  - 0s - loss: 65.5674
# Epoch 10/50
#  - 0s - loss: 65.2914
# Epoch 11/50
#  - 0s - loss: 65.1441
# Epoch 12/50
#  - 0s - loss: 64.8213
# Epoch 13/50
#  - 0s - loss: 64.5794
# Epoch 14/50
#  - 0s - loss: 64.4276
# Epoch 15/50
#  - 0s - loss: 64.1725
# Epoch 16/50
#  - 0s - loss: 63.8738
# Epoch 17/50
#  - 0s - loss: 63.6651
# Epoch 18/50
#  - 0s - loss: 63.4187
# Epoch 19/50
#  - 0s - loss: 63.1963
# Epoch 20/50
#  - 0s - loss: 62.9760
# Epoch 21/50
#  - 0s - loss: 62.8176
# Epoch 22/50
#  - 0s - loss: 62.5779
# Epoch 23/50
#  - 0s - loss: 62.4140
# Epoch 24/50
#  - 0s - loss: 62.2430
# Epoch 25/50
#  - 0s - loss: 61.9062
# Epoch 26/50
#  - 0s - loss: 61.7593
# Epoch 27/50
#  - 0s - loss: 61.4775
# Epoch 28/50
#  - 0s - loss: 61.3017
# Epoch 29/50
#  - 0s - loss: 61.1389
# Epoch 30/50
#  - 0s - loss: 60.9090
# Epoch 31/50
#  - 0s - loss: 60.7104
# Epoch 32/50
#  - 0s - loss: 60.5000
# Epoch 33/50
#  - 0s - loss: 60.3443
# Epoch 34/50
#  - 0s - loss: 60.1388
# Epoch 35/50
#  - 0s - loss: 59.9378
# Epoch 36/50
#  - 0s - loss: 59.8162
# Epoch 37/50
#  - 0s - loss: 59.5818
# Epoch 38/50
#  - 0s - loss: 59.4108
# Epoch 39/50
#  - 0s - loss: 59.1449
# Epoch 40/50
#  - 0s - loss: 59.0251
# Epoch 41/50
#  - 0s - loss: 58.8390
# Epoch 42/50
#  - 0s - loss: 58.6797
# Epoch 43/50
#  - 0s - loss: 58.4392
# Epoch 44/50
#  - 0s - loss: 58.2806
# Epoch 45/50
#  - 0s - loss: 58.1005
# Epoch 46/50
#  - 0s - loss: 57.9861
# Epoch 47/50
#  - 0s - loss: 57.8430
# Epoch 48/50
#  - 0s - loss: 57.5488
# Epoch 49/50
#  - 0s - loss: 57.3548
# Epoch 50/50
#  - 0s - loss: 57.1616
# Duration (seconds): 1.90537428855896
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 57.0535
# Epoch 2/50
#  - 0s - loss: 56.8662
# Epoch 3/50
#  - 0s - loss: 56.6454
# Epoch 4/50
#  - 0s - loss: 56.3834
# Epoch 5/50
#  - 0s - loss: 56.1861
# Epoch 6/50
#  - 0s - loss: 55.9665
# Epoch 7/50
#  - 0s - loss: 55.7474
# Epoch 8/50
#  - 0s - loss: 55.5727
# Epoch 9/50
#  - 0s - loss: 55.2571
# Epoch 10/50
#  - 0s - loss: 55.1242
# Epoch 11/50
#  - 0s - loss: 54.8380
# Epoch 12/50
#  - 0s - loss: 54.5963
# Epoch 13/50
#  - 0s - loss: 54.3527
# Epoch 14/50
#  - 0s - loss: 54.1571
# Epoch 15/50
#  - 0s - loss: 53.9543
# Epoch 16/50
#  - 0s - loss: 53.7978
# Epoch 17/50
#  - 0s - loss: 53.5204
# Epoch 18/50
#  - 0s - loss: 53.3722
# Epoch 19/50
#  - 0s - loss: 53.1170
# Epoch 20/50
#  - 0s - loss: 52.9482
# Epoch 21/50
#  - 0s - loss: 52.7373
# Epoch 22/50
#  - 0s - loss: 52.5467
# Epoch 23/50
#  - 0s - loss: 52.3958
# Epoch 24/50
#  - 0s - loss: 52.1735
# Epoch 25/50
#  - 0s - loss: 52.0997
# Epoch 26/50
#  - 0s - loss: 51.8182
# Epoch 27/50
#  - 0s - loss: 51.6314
# Epoch 28/50
#  - 0s - loss: 51.3560
# Epoch 29/50
#  - 0s - loss: 51.2095
# Epoch 30/50
#  - 0s - loss: 50.9735
# Epoch 31/50
#  - 0s - loss: 50.9405
# Epoch 32/50
#  - 0s - loss: 50.6345
# Epoch 33/50
#  - 0s - loss: 50.5222
# Epoch 34/50
#  - 0s - loss: 50.3220
# Epoch 35/50
#  - 0s - loss: 50.1333
# Epoch 36/50
#  - 0s - loss: 49.9927
# Epoch 37/50
#  - 0s - loss: 49.8091
# Epoch 38/50
#  - 0s - loss: 49.7692
# Epoch 39/50
#  - 0s - loss: 49.4611
# Epoch 40/50
#  - 0s - loss: 49.4661
# Epoch 41/50
#  - 0s - loss: 49.1672
# Epoch 42/50
#  - 0s - loss: 49.0655
# Epoch 43/50
#  - 0s - loss: 48.8770
# Epoch 44/50
#  - 0s - loss: 48.7762
# Epoch 45/50
#  - 0s - loss: 48.5802
# Epoch 46/50
#  - 0s - loss: 48.4463
# Epoch 47/50
#  - 0s - loss: 48.2714
# Epoch 48/50
#  - 0s - loss: 48.1645
# Epoch 49/50
#  - 0s - loss: 47.9811
# Epoch 50/50
#  - 0s - loss: 47.8624
# Duration (seconds): 2.0171210765838623
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 47.7906
# Epoch 2/50
#  - 0s - loss: 47.5990
# Epoch 3/50
#  - 0s - loss: 47.5302
# Epoch 4/50
#  - 0s - loss: 47.4900
# Epoch 5/50
#  - 0s - loss: 47.2257
# Epoch 6/50
#  - 0s - loss: 47.1879
# Epoch 7/50
#  - 0s - loss: 47.0283
# Epoch 8/50
#  - 0s - loss: 46.9480
# Epoch 9/50
#  - 0s - loss: 46.8775
# Epoch 10/50
#  - 0s - loss: 46.7048
# Epoch 11/50
#  - 0s - loss: 46.5860
# Epoch 12/50
#  - 0s - loss: 46.5047
# Epoch 13/50
#  - 0s - loss: 46.3902
# Epoch 14/50
#  - 0s - loss: 46.2562
# Epoch 15/50
#  - 0s - loss: 46.2199
# Epoch 16/50
#  - 0s - loss: 46.0761
# Epoch 17/50
#  - 0s - loss: 46.0351
# Epoch 18/50
#  - 0s - loss: 45.8921
# Epoch 19/50
#  - 0s - loss: 45.8292
# Epoch 20/50
#  - 0s - loss: 45.6496
# Epoch 21/50
#  - 0s - loss: 45.6663
# Epoch 22/50
#  - 0s - loss: 45.5791
# Epoch 23/50
#  - 0s - loss: 45.4507
# Epoch 24/50
#  - 0s - loss: 45.3726
# Epoch 25/50
#  - 0s - loss: 45.3403
# Epoch 26/50
#  - 0s - loss: 45.1814
# Epoch 27/50
#  - 0s - loss: 45.0971
# Epoch 28/50
#  - 0s - loss: 45.0550
# Epoch 29/50
#  - 0s - loss: 45.0431
# Epoch 30/50
#  - 0s - loss: 44.8671
# Epoch 31/50
#  - 0s - loss: 44.8013
# Epoch 32/50
#  - 0s - loss: 44.7404
# Epoch 33/50
#  - 0s - loss: 44.7085
# Epoch 34/50
#  - 0s - loss: 44.6453
# Epoch 35/50
#  - 0s - loss: 44.5548
# Epoch 36/50
#  - 0s - loss: 44.4787
# Epoch 37/50
#  - 0s - loss: 44.4227
# Epoch 38/50
#  - 0s - loss: 44.3520
# Epoch 39/50
#  - 0s - loss: 44.3410
# Epoch 40/50
#  - 0s - loss: 44.3065
# Epoch 41/50
#  - 0s - loss: 44.1637
# Epoch 42/50
#  - 0s - loss: 44.0814
# Epoch 43/50
#  - 0s - loss: 44.1163
# Epoch 44/50
#  - 0s - loss: 44.1014
# Epoch 45/50
#  - 0s - loss: 43.9631
# Epoch 46/50
#  - 0s - loss: 43.9151
# Epoch 47/50
#  - 0s - loss: 43.9289
# Epoch 48/50
#  - 0s - loss: 43.8006
# Epoch 49/50
#  - 0s - loss: 43.7595
# Epoch 50/50
#  - 0s - loss: 43.7095
# Duration (seconds): 2.042832851409912
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 43.6470
# Epoch 2/50
#  - 0s - loss: 43.5815
# Epoch 3/50
#  - 0s - loss: 43.5565
# Epoch 4/50
#  - 0s - loss: 43.5201
# Epoch 5/50
#  - 0s - loss: 43.4936
# Epoch 6/50
#  - 0s - loss: 43.6147
# Epoch 7/50
#  - 0s - loss: 43.3756
# Epoch 8/50
#  - 0s - loss: 43.4160
# Epoch 9/50
#  - 0s - loss: 43.2663
# Epoch 10/50
#  - 0s - loss: 43.2031
# Epoch 11/50
#  - 0s - loss: 43.1520
# Epoch 12/50
#  - 0s - loss: 43.1078
# Epoch 13/50
#  - 0s - loss: 43.1684
# Epoch 14/50
#  - 0s - loss: 42.9912
# Epoch 15/50
#  - 0s - loss: 43.0872
# Epoch 16/50
#  - 0s - loss: 42.9623
# Epoch 17/50
#  - 0s - loss: 42.9208
# Epoch 18/50
#  - 0s - loss: 42.8759
# Epoch 19/50
#  - 0s - loss: 43.0201
# Epoch 20/50
#  - 0s - loss: 42.7815
# Epoch 21/50
#  - 0s - loss: 42.8007
# Epoch 22/50
#  - 0s - loss: 42.8133
# Epoch 23/50
#  - 0s - loss: 42.6476
# Epoch 24/50
#  - 0s - loss: 42.6821
# Epoch 25/50
#  - 0s - loss: 42.6990
# Epoch 26/50
#  - 0s - loss: 42.5530
# Epoch 27/50
#  - 0s - loss: 42.5767
# Epoch 28/50
#  - 0s - loss: 42.5081
# Epoch 29/50
#  - 0s - loss: 42.5019
# Epoch 30/50
#  - 0s - loss: 42.4740
# Epoch 31/50
#  - 0s - loss: 42.4483
# Epoch 32/50
#  - 0s - loss: 42.3507
# Epoch 33/50
#  - 0s - loss: 42.2874
# Epoch 34/50
#  - 0s - loss: 42.2529
# Epoch 35/50
#  - 0s - loss: 42.2769
# Epoch 36/50
#  - 0s - loss: 42.2730
# Epoch 37/50
#  - 0s - loss: 42.1602
# Epoch 38/50
#  - 0s - loss: 42.1621
# Epoch 39/50
#  - 0s - loss: 42.1240
# Epoch 40/50
#  - 0s - loss: 42.0452
# Epoch 41/50
#  - 0s - loss: 42.0671
# Epoch 42/50
#  - 0s - loss: 42.0253
# Epoch 43/50
#  - 0s - loss: 41.9660
# Epoch 44/50
#  - 0s - loss: 41.9941
# Epoch 45/50
#  - 0s - loss: 41.8885
# Epoch 46/50
#  - 0s - loss: 41.9295
# Epoch 47/50
#  - 0s - loss: 41.8179
# Epoch 48/50
#  - 0s - loss: 41.7671
# Epoch 49/50
#  - 0s - loss: 41.7683
# Epoch 50/50
#  - 0s - loss: 41.7284
# Duration (seconds): 1.9091227054595947
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 41.6552
# Epoch 2/50
#  - 0s - loss: 41.7363
# Epoch 3/50
#  - 0s - loss: 41.7511
# Epoch 4/50
#  - 0s - loss: 41.6233
# Epoch 5/50
#  - 0s - loss: 41.5881
# Epoch 6/50
#  - 0s - loss: 41.5185
# Epoch 7/50
#  - 0s - loss: 41.5704
# Epoch 8/50
#  - 0s - loss: 41.4929
# Epoch 9/50
#  - 0s - loss: 41.5694
# Epoch 10/50
#  - 0s - loss: 41.4248
# Epoch 11/50
#  - 0s - loss: 41.3392
# Epoch 12/50
#  - 0s - loss: 41.3567
# Epoch 13/50
#  - 0s - loss: 41.3410
# Epoch 14/50
#  - 0s - loss: 41.3479
# Epoch 15/50
#  - 0s - loss: 41.2456
# Epoch 16/50
#  - 0s - loss: 41.2081
# Epoch 17/50
#  - 0s - loss: 41.1709
# Epoch 18/50
#  - 0s - loss: 41.1865
# Epoch 19/50
#  - 0s - loss: 41.1180
# Epoch 20/50
#  - 0s - loss: 41.0847
# Epoch 21/50
#  - 0s - loss: 41.0158
# Epoch 22/50
#  - 0s - loss: 40.9383
# Epoch 23/50
#  - 0s - loss: 40.9444
# Epoch 24/50
#  - 0s - loss: 40.9161
# Epoch 25/50
#  - 0s - loss: 40.8699
# Epoch 26/50
#  - 0s - loss: 40.8577
# Epoch 27/50
#  - 0s - loss: 40.8364
# Epoch 28/50
#  - 0s - loss: 40.7464
# Epoch 29/50
#  - 0s - loss: 40.7345
# Epoch 30/50
#  - 0s - loss: 40.7021
# Epoch 31/50
#  - 0s - loss: 40.7346
# Epoch 32/50
#  - 0s - loss: 40.6266
# Epoch 33/50
#  - 0s - loss: 40.7140
# Epoch 34/50
#  - 0s - loss: 40.6387
# Epoch 35/50
#  - 0s - loss: 40.5426
# Epoch 36/50
#  - 0s - loss: 40.5558
# Epoch 37/50
#  - 0s - loss: 40.5478
# Epoch 38/50
#  - 0s - loss: 40.5336
# Epoch 39/50
#  - 0s - loss: 40.5288
# Epoch 40/50
#  - 0s - loss: 40.4115
# Epoch 41/50
#  - 0s - loss: 40.3848
# Epoch 42/50
#  - 0s - loss: 40.3779
# Epoch 43/50
#  - 0s - loss: 40.3085
# Epoch 44/50
#  - 0s - loss: 40.2699
# Epoch 45/50
#  - 0s - loss: 40.2272
# Epoch 46/50
#  - 0s - loss: 40.2055
# Epoch 47/50
#  - 0s - loss: 40.2984
# Epoch 48/50
#  - 0s - loss: 40.1456
# Epoch 49/50
#  - 0s - loss: 40.1400
# Epoch 50/50
#  - 0s - loss: 40.1318
# Duration (seconds): 2.009500026702881
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 40.1389
# Epoch 2/50
#  - 0s - loss: 40.1507
# Epoch 3/50
#  - 0s - loss: 40.0103
# Epoch 4/50
#  - 0s - loss: 40.0212
# Epoch 5/50
#  - 0s - loss: 40.0331
# Epoch 6/50
#  - 0s - loss: 39.9840
# Epoch 7/50
#  - 0s - loss: 40.0574
# Epoch 8/50
#  - 0s - loss: 39.9059
# Epoch 9/50
#  - 0s - loss: 39.9024
# Epoch 10/50
#  - 0s - loss: 39.8717
# Epoch 11/50
#  - 0s - loss: 39.8549
# Epoch 12/50
#  - 0s - loss: 39.7936
# Epoch 13/50
#  - 0s - loss: 39.7693
# Epoch 14/50
#  - 0s - loss: 39.7831
# Epoch 15/50
#  - 0s - loss: 39.7202
# Epoch 16/50
#  - 0s - loss: 39.6999
# Epoch 17/50
#  - 0s - loss: 39.6538
# Epoch 18/50
#  - 0s - loss: 39.6695
# Epoch 19/50
#  - 0s - loss: 39.6573
# Epoch 20/50
#  - 0s - loss: 39.5911
# Epoch 21/50
#  - 0s - loss: 39.6138
# Epoch 22/50
#  - 0s - loss: 39.5606
# Epoch 23/50
#  - 0s - loss: 39.5169
# Epoch 24/50
#  - 0s - loss: 39.4658
# Epoch 25/50
#  - 0s - loss: 39.4689
# Epoch 26/50
#  - 0s - loss: 39.4294
# Epoch 27/50
#  - 0s - loss: 39.4167
# Epoch 28/50
#  - 0s - loss: 39.3768
# Epoch 29/50
#  - 0s - loss: 39.4613
# Epoch 30/50
#  - 0s - loss: 39.3375
# Epoch 31/50
#  - 0s - loss: 39.2888
# Epoch 32/50
#  - 0s - loss: 39.2622
# Epoch 33/50
#  - 0s - loss: 39.4099
# Epoch 34/50
#  - 0s - loss: 39.1605
# Epoch 35/50
#  - 0s - loss: 39.1363
# Epoch 36/50
#  - 0s - loss: 39.1229
# Epoch 37/50
#  - 0s - loss: 39.1089
# Epoch 38/50
#  - 0s - loss: 39.1253
# Epoch 39/50
#  - 0s - loss: 39.1643
# Epoch 40/50
#  - 0s - loss: 39.0268
# Epoch 41/50
#  - 0s - loss: 39.0854
# Epoch 42/50
#  - 0s - loss: 38.9552
# Epoch 43/50
#  - 0s - loss: 39.0493
# Epoch 44/50
#  - 0s - loss: 38.9658
# Epoch 45/50
#  - 0s - loss: 38.8589
# Epoch 46/50
#  - 0s - loss: 38.8843
# Epoch 47/50
#  - 0s - loss: 38.8632
# Epoch 48/50
#  - 0s - loss: 38.8047
# Epoch 49/50
#  - 0s - loss: 38.8211
# Epoch 50/50
#  - 0s - loss: 38.7192
# Duration (seconds): 2.176068067550659
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 38.7506
# Epoch 2/50
#  - 0s - loss: 38.7082
# Epoch 3/50
#  - 0s - loss: 38.6323
# Epoch 4/50
#  - 0s - loss: 38.6699
# Epoch 5/50
#  - 0s - loss: 38.6351
# Epoch 6/50
#  - 0s - loss: 38.5885
# Epoch 7/50
#  - 0s - loss: 38.5448
# Epoch 8/50
#  - 0s - loss: 38.5114
# Epoch 9/50
#  - 0s - loss: 38.4709
# Epoch 10/50
#  - 0s - loss: 38.4920
# Epoch 11/50
#  - 0s - loss: 38.4234
# Epoch 12/50
#  - 0s - loss: 38.4201
# Epoch 13/50
#  - 0s - loss: 38.4177
# Epoch 14/50
#  - 0s - loss: 38.3689
# Epoch 15/50
#  - 0s - loss: 38.3614
# Epoch 16/50
#  - 0s - loss: 38.3123
# Epoch 17/50
#  - 0s - loss: 38.2757
# Epoch 18/50
#  - 0s - loss: 38.3099
# Epoch 19/50
#  - 0s - loss: 38.2556
# Epoch 20/50
#  - 0s - loss: 38.2332
# Epoch 21/50
#  - 0s - loss: 38.2220
# Epoch 22/50
#  - 0s - loss: 38.1672
# Epoch 23/50
#  - 0s - loss: 38.1398
# Epoch 24/50
#  - 0s - loss: 38.1522
# Epoch 25/50
#  - 0s - loss: 38.1728
# Epoch 26/50
#  - 0s - loss: 38.1242
# Epoch 27/50
#  - 0s - loss: 38.1159
# Epoch 28/50
#  - 0s - loss: 38.0363
# Epoch 29/50
#  - 0s - loss: 38.0346
# Epoch 30/50
#  - 0s - loss: 37.9806
# Epoch 31/50
#  - 0s - loss: 38.0548
# Epoch 32/50
#  - 0s - loss: 38.0413
# Epoch 33/50
#  - 0s - loss: 38.0223
# Epoch 34/50
#  - 0s - loss: 37.9228
# Epoch 35/50
#  - 0s - loss: 37.9072
# Epoch 36/50
#  - 0s - loss: 37.9108
# Epoch 37/50
#  - 0s - loss: 37.8722
# Epoch 38/50
#  - 0s - loss: 37.8426
# Epoch 39/50
#  - 0s - loss: 37.8341
# Epoch 40/50
#  - 0s - loss: 37.9424
# Epoch 41/50
#  - 0s - loss: 37.7708
# Epoch 42/50
#  - 0s - loss: 37.7369
# Epoch 43/50
#  - 0s - loss: 37.7174
# Epoch 44/50
#  - 0s - loss: 37.7198
# Epoch 45/50
#  - 0s - loss: 37.6555
# Epoch 46/50
#  - 0s - loss: 37.6270
# Epoch 47/50
#  - 0s - loss: 37.6042
# Epoch 48/50
#  - 0s - loss: 37.5744
# Epoch 49/50
#  - 0s - loss: 37.7375
# Epoch 50/50
#  - 0s - loss: 37.4992
# Duration (seconds): 1.828578233718872
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 37.5529
# Epoch 2/50
#  - 0s - loss: 37.5819
# Epoch 3/50
#  - 0s - loss: 37.4981
# Epoch 4/50
#  - 0s - loss: 37.4774
# Epoch 5/50
#  - 0s - loss: 37.4224
# Epoch 6/50
#  - 0s - loss: 37.4727
# Epoch 7/50
#  - 0s - loss: 37.4214
# Epoch 8/50
#  - 0s - loss: 37.3650
# Epoch 9/50
#  - 0s - loss: 37.4391
# Epoch 10/50
#  - 0s - loss: 37.3956
# Epoch 11/50
#  - 0s - loss: 37.3317
# Epoch 12/50
#  - 0s - loss: 37.3944
# Epoch 13/50
#  - 0s - loss: 37.4544
# Epoch 14/50
#  - 0s - loss: 37.3424
# Epoch 15/50
#  - 0s - loss: 37.2805
# Epoch 16/50
#  - 0s - loss: 37.3309
# Epoch 17/50
#  - 0s - loss: 37.2045
# Epoch 18/50
#  - 0s - loss: 37.2142
# Epoch 19/50
#  - 0s - loss: 37.1997
# Epoch 20/50
#  - 0s - loss: 37.2061
# Epoch 21/50
#  - 0s - loss: 37.1559
# Epoch 22/50
#  - 0s - loss: 37.1524
# Epoch 23/50
#  - 0s - loss: 37.1108
# Epoch 24/50
#  - 0s - loss: 37.1364
# Epoch 25/50
#  - 0s - loss: 37.1581
# Epoch 26/50
#  - 0s - loss: 37.0475
# Epoch 27/50
#  - 0s - loss: 37.0173
# Epoch 28/50
#  - 0s - loss: 37.0349
# Epoch 29/50
#  - 0s - loss: 37.0083
# Epoch 30/50
#  - 0s - loss: 36.9434
# Epoch 31/50
#  - 0s - loss: 37.0363
# Epoch 32/50
#  - 0s - loss: 36.9062
# Epoch 33/50
#  - 0s - loss: 37.0110
# Epoch 34/50
#  - 0s - loss: 36.8997
# Epoch 35/50
#  - 0s - loss: 36.9249
# Epoch 36/50
#  - 0s - loss: 37.0085
# Epoch 37/50
#  - 0s - loss: 36.9238
# Epoch 38/50
#  - 0s - loss: 36.8594
# Epoch 39/50
#  - 0s - loss: 36.8620
# Epoch 40/50
#  - 0s - loss: 36.8077
# Epoch 41/50
#  - 0s - loss: 36.7809
# Epoch 42/50
#  - 0s - loss: 36.8120
# Epoch 43/50
#  - 0s - loss: 36.7860
# Epoch 44/50
#  - 0s - loss: 36.7730
# Epoch 45/50
#  - 0s - loss: 36.7991
# Epoch 46/50
#  - 0s - loss: 36.7189
# Epoch 47/50
#  - 0s - loss: 36.6979
# Epoch 48/50
#  - 0s - loss: 36.6530
# Epoch 49/50
#  - 0s - loss: 36.6475
# Epoch 50/50
#  - 0s - loss: 36.6382
# Duration (seconds): 1.7189440727233887
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 36.6172
# Epoch 2/50
#  - 0s - loss: 36.6523
# Epoch 3/50
#  - 0s - loss: 36.7291
# Epoch 4/50
#  - 0s - loss: 36.6140
# Epoch 5/50
#  - 0s - loss: 36.5946
# Epoch 6/50
#  - 0s - loss: 36.6131
# Epoch 7/50
#  - 0s - loss: 36.5854
# Epoch 8/50
#  - 0s - loss: 36.5150
# Epoch 9/50
#  - 0s - loss: 36.5575
# Epoch 10/50
#  - 0s - loss: 36.5278
# Epoch 11/50
#  - 0s - loss: 36.4586
# Epoch 12/50
#  - 0s - loss: 36.4579
# Epoch 13/50
#  - 0s - loss: 36.4744
# Epoch 14/50
#  - 0s - loss: 36.4536
# Epoch 15/50
#  - 0s - loss: 36.4957
# Epoch 16/50
#  - 0s - loss: 36.4569
# Epoch 17/50
#  - 0s - loss: 36.3959
# Epoch 18/50
#  - 0s - loss: 36.3907
# Epoch 19/50
#  - 0s - loss: 36.3468
# Epoch 20/50
#  - 0s - loss: 36.3563
# Epoch 21/50
#  - 0s - loss: 36.3793
# Epoch 22/50
#  - 0s - loss: 36.3327
# Epoch 23/50
#  - 0s - loss: 36.3762
# Epoch 24/50
#  - 0s - loss: 36.3229
# Epoch 25/50
#  - 0s - loss: 36.3142
# Epoch 26/50
#  - 0s - loss: 36.3690
# Epoch 27/50
#  - 0s - loss: 36.2935
# Epoch 28/50
#  - 0s - loss: 36.3777
# Epoch 29/50
#  - 0s - loss: 36.2140
# Epoch 30/50
#  - 0s - loss: 36.2562
# Epoch 31/50
#  - 0s - loss: 36.2283
# Epoch 32/50
#  - 0s - loss: 36.2100
# Epoch 33/50
#  - 0s - loss: 36.1863
# Epoch 34/50
#  - 0s - loss: 36.1829
# Epoch 35/50
#  - 0s - loss: 36.1937
# Epoch 36/50
#  - 0s - loss: 36.1553
# Epoch 37/50
#  - 0s - loss: 36.1686
# Epoch 38/50
#  - 0s - loss: 36.1675
# Epoch 39/50
#  - 0s - loss: 36.1077
# Epoch 40/50
#  - 0s - loss: 36.1388
# Epoch 41/50
#  - 0s - loss: 36.1206
# Epoch 42/50
#  - 0s - loss: 36.1370
# Epoch 43/50
#  - 0s - loss: 36.0616
# Epoch 44/50
#  - 0s - loss: 36.0771
# Epoch 45/50
#  - 0s - loss: 36.0824
# Epoch 46/50
#  - 0s - loss: 36.0039
# Epoch 47/50
#  - 0s - loss: 36.0945
# Epoch 48/50
#  - 0s - loss: 36.0733
# Epoch 49/50
#  - 0s - loss: 35.9351
# Epoch 50/50
#  - 0s - loss: 36.1632
# Duration (seconds): 1.9614520072937012
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 36.0582
# Epoch 2/50
#  - 0s - loss: 35.9303
# Epoch 3/50
#  - 0s - loss: 35.9750
# Epoch 4/50
#  - 0s - loss: 35.9549
# Epoch 5/50
#  - 0s - loss: 35.9163
# Epoch 6/50
#  - 0s - loss: 35.9919
# Epoch 7/50
#  - 0s - loss: 35.8911
# Epoch 8/50
#  - 0s - loss: 35.9157
# Epoch 9/50
#  - 0s - loss: 35.9400
# Epoch 10/50
#  - 0s - loss: 35.8981
# Epoch 11/50
#  - 0s - loss: 35.8987
# Epoch 12/50
#  - 0s - loss: 35.8553
# Epoch 13/50
#  - 0s - loss: 35.8679
# Epoch 14/50
#  - 0s - loss: 35.8542
# Epoch 15/50
#  - 0s - loss: 35.8463
# Epoch 16/50
#  - 0s - loss: 35.8012
# Epoch 17/50
#  - 0s - loss: 35.8157
# Epoch 18/50
#  - 0s - loss: 35.8528
# Epoch 19/50
#  - 0s - loss: 35.7951
# Epoch 20/50
#  - 0s - loss: 35.8128
# Epoch 21/50
#  - 0s - loss: 35.7661
# Epoch 22/50
#  - 0s - loss: 35.7629
# Epoch 23/50
#  - 0s - loss: 35.7846
# Epoch 24/50
#  - 0s - loss: 35.7733
# Epoch 25/50
#  - 0s - loss: 35.7238
# Epoch 26/50
#  - 0s - loss: 35.6766
# Epoch 27/50
#  - 0s - loss: 35.7264
# Epoch 28/50
#  - 0s - loss: 35.7463
# Epoch 29/50
#  - 0s - loss: 35.6616
# Epoch 30/50
#  - 0s - loss: 35.6585
# Epoch 31/50
#  - 0s - loss: 35.6772
# Epoch 32/50
#  - 0s - loss: 35.6161
# Epoch 33/50
#  - 0s - loss: 35.6635
# Epoch 34/50
#  - 0s - loss: 35.7810
# Epoch 35/50
#  - 0s - loss: 35.6782
# Epoch 36/50
#  - 0s - loss: 35.6645
# Epoch 37/50
#  - 0s - loss: 35.6232
# Epoch 38/50
#  - 0s - loss: 35.6230
# Epoch 39/50
#  - 0s - loss: 35.5606
# Epoch 40/50
#  - 0s - loss: 35.5694
# Epoch 41/50
#  - 0s - loss: 35.5535
# Epoch 42/50
#  - 0s - loss: 35.5758
# Epoch 43/50
#  - 0s - loss: 35.5168
# Epoch 44/50
#  - 0s - loss: 35.5116
# Epoch 45/50
#  - 0s - loss: 35.5440
# Epoch 46/50
#  - 0s - loss: 35.5019
# Epoch 47/50
#  - 0s - loss: 35.6327
# Epoch 48/50
#  - 0s - loss: 35.4708
# Epoch 49/50
#  - 0s - loss: 35.4750
# Epoch 50/50
#  - 0s - loss: 35.5171
# Duration (seconds): 1.9774608612060547
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 35.4821
# Epoch 2/50
#  - 0s - loss: 35.4775
# Epoch 3/50
#  - 0s - loss: 35.4449
# Epoch 4/50
#  - 0s - loss: 35.4725
# Epoch 5/50
#  - 0s - loss: 35.4787
# Epoch 6/50
#  - 0s - loss: 35.4851
# Epoch 7/50
#  - 0s - loss: 35.4238
# Epoch 8/50
#  - 0s - loss: 35.4548
# Epoch 9/50
#  - 0s - loss: 35.3995
# Epoch 10/50
#  - 0s - loss: 35.4753
# Epoch 11/50
#  - 0s - loss: 35.4619
# Epoch 12/50
#  - 0s - loss: 35.4728
# Epoch 13/50
#  - 0s - loss: 35.3642
# Epoch 14/50
#  - 0s - loss: 35.3452
# Epoch 15/50
#  - 0s - loss: 35.3312
# Epoch 16/50
#  - 0s - loss: 35.3864
# Epoch 17/50
#  - 0s - loss: 35.3724
# Epoch 18/50
#  - 0s - loss: 35.3190
# Epoch 19/50
#  - 0s - loss: 35.3657
# Epoch 20/50
#  - 0s - loss: 35.3062
# Epoch 21/50
#  - 0s - loss: 35.3123
# Epoch 22/50
#  - 0s - loss: 35.2850
# Epoch 23/50
#  - 0s - loss: 35.2209
# Epoch 24/50
#  - 0s - loss: 35.2748
# Epoch 25/50
#  - 0s - loss: 35.3832
# Epoch 26/50
#  - 0s - loss: 35.2408
# Epoch 27/50
#  - 0s - loss: 35.2676
# Epoch 28/50
#  - 0s - loss: 35.1877
# Epoch 29/50
#  - 0s - loss: 35.1873
# Epoch 30/50
#  - 0s - loss: 35.1674
# Epoch 31/50
#  - 0s - loss: 35.1900
# Epoch 32/50
#  - 0s - loss: 35.1381
# Epoch 33/50
#  - 0s - loss: 35.1605
# Epoch 34/50
#  - 0s - loss: 35.1815
# Epoch 35/50
#  - 0s - loss: 35.1516
# Epoch 36/50
#  - 0s - loss: 35.1406
# Epoch 37/50
#  - 0s - loss: 35.1757
# Epoch 38/50
#  - 0s - loss: 35.1686
# Epoch 39/50
#  - 0s - loss: 35.1882
# Epoch 40/50
#  - 0s - loss: 35.1700
# Epoch 41/50
#  - 0s - loss: 35.0990
# Epoch 42/50
#  - 0s - loss: 35.1056
# Epoch 43/50
#  - 0s - loss: 35.0887
# Epoch 44/50
#  - 0s - loss: 35.0742
# Epoch 45/50
#  - 0s - loss: 35.0438
# Epoch 46/50
#  - 0s - loss: 35.0801
# Epoch 47/50
#  - 0s - loss: 35.0312
# Epoch 48/50
#  - 0s - loss: 35.0444
# Epoch 49/50
#  - 0s - loss: 35.0338
# Epoch 50/50
#  - 0s - loss: 35.0261
# Duration (seconds): 1.9476590156555176
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 35.0991
# Epoch 2/50
#  - 0s - loss: 34.9941
# Epoch 3/50
#  - 0s - loss: 35.0041
# Epoch 4/50
#  - 0s - loss: 35.0169
# Epoch 5/50
#  - 0s - loss: 34.9734
# Epoch 6/50
#  - 0s - loss: 34.9894
# Epoch 7/50
#  - 0s - loss: 35.0421
# Epoch 8/50
#  - 0s - loss: 34.9610
# Epoch 9/50
#  - 0s - loss: 34.9543
# Epoch 10/50
#  - 0s - loss: 34.9553
# Epoch 11/50
#  - 0s - loss: 34.9753
# Epoch 12/50
#  - 0s - loss: 34.9291
# Epoch 13/50
#  - 0s - loss: 34.9757
# Epoch 14/50
#  - 0s - loss: 34.9203
# Epoch 15/50
#  - 0s - loss: 34.9541
# Epoch 16/50
#  - 0s - loss: 34.9021
# Epoch 17/50
#  - 0s - loss: 34.9567
# Epoch 18/50
#  - 0s - loss: 34.8836
# Epoch 19/50
#  - 0s - loss: 34.8851
# Epoch 20/50
#  - 0s - loss: 34.9498
# Epoch 21/50
#  - 0s - loss: 34.9056
# Epoch 22/50
#  - 0s - loss: 34.8501
# Epoch 23/50
#  - 0s - loss: 34.8459
# Epoch 24/50
#  - 0s - loss: 34.8530
# Epoch 25/50
#  - 0s - loss: 34.8224
# Epoch 26/50
#  - 0s - loss: 34.8445
# Epoch 27/50
#  - 0s - loss: 34.8403
# Epoch 28/50
#  - 0s - loss: 34.7842
# Epoch 29/50
#  - 0s - loss: 34.7899
# Epoch 30/50
#  - 0s - loss: 34.8547
# Epoch 31/50
#  - 0s - loss: 34.7632
# Epoch 32/50
#  - 0s - loss: 34.7678
# Epoch 33/50
#  - 0s - loss: 34.7682
# Epoch 34/50
#  - 0s - loss: 34.7741
# Epoch 35/50
#  - 0s - loss: 34.7519
# Epoch 36/50
#  - 0s - loss: 34.8699
# Epoch 37/50
#  - 0s - loss: 34.8330
# Epoch 38/50
#  - 0s - loss: 34.7681
# Epoch 39/50
#  - 0s - loss: 34.7407
# Epoch 40/50
#  - 0s - loss: 34.7345
# Epoch 41/50
#  - 0s - loss: 34.7070
# Epoch 42/50
#  - 0s - loss: 34.7285
# Epoch 43/50
#  - 0s - loss: 34.6517
# Epoch 44/50
#  - 0s - loss: 34.8278
# Epoch 45/50
#  - 0s - loss: 34.6905
# Epoch 46/50
#  - 0s - loss: 34.7794
# Epoch 47/50
#  - 0s - loss: 34.6931
# Epoch 48/50
#  - 0s - loss: 34.6923
# Epoch 49/50
#  - 0s - loss: 34.6549
# Epoch 50/50
#  - 0s - loss: 34.6903
# Duration (seconds): 1.9779613018035889
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.6444
# Epoch 2/50
#  - 0s - loss: 34.6729
# Epoch 3/50
#  - 0s - loss: 34.6696
# Epoch 4/50
#  - 0s - loss: 34.6141
# Epoch 5/50
#  - 0s - loss: 34.6259
# Epoch 6/50
#  - 0s - loss: 34.6562
# Epoch 7/50
#  - 0s - loss: 34.7107
# Epoch 8/50
#  - 0s - loss: 34.6466
# Epoch 9/50
#  - 0s - loss: 34.5444
# Epoch 10/50
#  - 0s - loss: 34.5869
# Epoch 11/50
#  - 0s - loss: 34.5536
# Epoch 12/50
#  - 0s - loss: 34.5885
# Epoch 13/50
#  - 0s - loss: 34.5683
# Epoch 14/50
#  - 0s - loss: 34.5846
# Epoch 15/50
#  - 0s - loss: 34.5170
# Epoch 16/50
#  - 0s - loss: 34.5909
# Epoch 17/50
#  - 0s - loss: 34.5979
# Epoch 18/50
#  - 0s - loss: 34.6106
# Epoch 19/50
#  - 0s - loss: 34.5381
# Epoch 20/50
#  - 0s - loss: 34.5240
# Epoch 21/50
#  - 0s - loss: 34.5267
# Epoch 22/50
#  - 0s - loss: 34.4963
# Epoch 23/50
#  - 0s - loss: 34.5251
# Epoch 24/50
#  - 0s - loss: 34.4865
# Epoch 25/50
#  - 0s - loss: 34.5472
# Epoch 26/50
#  - 0s - loss: 34.5178
# Epoch 27/50
#  - 0s - loss: 34.4889
# Epoch 28/50
#  - 0s - loss: 34.4550
# Epoch 29/50
#  - 0s - loss: 34.4633
# Epoch 30/50
#  - 0s - loss: 34.5244
# Epoch 31/50
#  - 0s - loss: 34.4858
# Epoch 32/50
#  - 0s - loss: 34.4940
# Epoch 33/50
#  - 0s - loss: 34.4516
# Epoch 34/50
#  - 0s - loss: 34.4666
# Epoch 35/50
#  - 0s - loss: 34.4726
# Epoch 36/50
#  - 0s - loss: 34.4379
# Epoch 37/50
#  - 0s - loss: 34.4269
# Epoch 38/50
#  - 0s - loss: 34.4116
# Epoch 39/50
#  - 0s - loss: 34.5347
# Epoch 40/50
#  - 0s - loss: 34.4302
# Epoch 41/50
#  - 0s - loss: 34.5449
# Epoch 42/50
#  - 0s - loss: 34.4429
# Epoch 43/50
#  - 0s - loss: 34.4686
# Epoch 44/50
#  - 0s - loss: 34.4635
# Epoch 45/50
#  - 0s - loss: 34.4288
# Epoch 46/50
#  - 0s - loss: 34.4244
# Epoch 47/50
#  - 0s - loss: 34.3951
# Epoch 48/50
#  - 0s - loss: 34.3701
# Epoch 49/50
#  - 0s - loss: 34.3656
# Epoch 50/50
#  - 0s - loss: 34.4501
# Duration (seconds): 2.0529847145080566
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.4549
# Epoch 2/50
#  - 0s - loss: 34.4121
# Epoch 3/50
#  - 0s - loss: 34.3866
# Epoch 4/50
#  - 0s - loss: 34.3894
# Epoch 5/50
#  - 0s - loss: 34.3316
# Epoch 6/50
#  - 0s - loss: 34.3282
# Epoch 7/50
#  - 0s - loss: 34.3180
# Epoch 8/50
#  - 0s - loss: 34.3394
# Epoch 9/50
#  - 0s - loss: 34.3871
# Epoch 10/50
#  - 0s - loss: 34.3240
# Epoch 11/50
#  - 0s - loss: 34.3421
# Epoch 12/50
#  - 0s - loss: 34.2909
# Epoch 13/50
#  - 0s - loss: 34.3126
# Epoch 14/50
#  - 0s - loss: 34.3040
# Epoch 15/50
#  - 0s - loss: 34.2754
# Epoch 16/50
#  - 0s - loss: 34.3105
# Epoch 17/50
#  - 0s - loss: 34.2364
# Epoch 18/50
#  - 0s - loss: 34.2565
# Epoch 19/50
#  - 0s - loss: 34.3385
# Epoch 20/50
#  - 0s - loss: 34.2315
# Epoch 21/50
#  - 0s - loss: 34.2403
# Epoch 22/50
#  - 0s - loss: 34.2255
# Epoch 23/50
#  - 0s - loss: 34.2292
# Epoch 24/50
#  - 0s - loss: 34.2704
# Epoch 25/50
#  - 0s - loss: 34.2570
# Epoch 26/50
#  - 0s - loss: 34.2346
# Epoch 27/50
#  - 0s - loss: 34.2159
# Epoch 28/50
#  - 0s - loss: 34.2107
# Epoch 29/50
#  - 0s - loss: 34.1961
# Epoch 30/50
#  - 0s - loss: 34.1896
# Epoch 31/50
#  - 0s - loss: 34.2173
# Epoch 32/50
#  - 0s - loss: 34.2510
# Epoch 33/50
#  - 0s - loss: 34.1724
# Epoch 34/50
#  - 0s - loss: 34.2391
# Epoch 35/50
#  - 0s - loss: 34.1584
# Epoch 36/50
#  - 0s - loss: 34.1226
# Epoch 37/50
#  - 0s - loss: 34.1816
# Epoch 38/50
#  - 0s - loss: 34.3267
# Epoch 39/50
#  - 0s - loss: 34.1483
# Epoch 40/50
#  - 0s - loss: 34.1497
# Epoch 41/50
#  - 0s - loss: 34.2117
# Epoch 42/50
#  - 0s - loss: 34.1676
# Epoch 43/50
#  - 0s - loss: 34.1589
# Epoch 44/50
#  - 0s - loss: 34.1523
# Epoch 45/50
#  - 0s - loss: 34.1394
# Epoch 46/50
#  - 0s - loss: 34.1418
# Epoch 47/50
#  - 0s - loss: 34.1230
# Epoch 48/50
#  - 0s - loss: 34.0910
# Epoch 49/50
#  - 0s - loss: 34.1484
# Epoch 50/50
#  - 0s - loss: 34.1122
# Duration (seconds): 2.0204977989196777
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.0912
# Epoch 2/50
#  - 0s - loss: 34.1739
# Epoch 3/50
#  - 0s - loss: 34.0718
# Epoch 4/50
#  - 0s - loss: 34.0674
# Epoch 5/50
#  - 0s - loss: 34.1284
# Epoch 6/50
#  - 0s - loss: 34.0541
# Epoch 7/50
#  - 0s - loss: 34.0733
# Epoch 8/50
#  - 0s - loss: 34.1002
# Epoch 9/50
#  - 0s - loss: 34.1935
# Epoch 10/50
#  - 0s - loss: 34.0699
# Epoch 11/50
#  - 0s - loss: 34.1079
# Epoch 12/50
#  - 0s - loss: 34.0297
# Epoch 13/50
#  - 0s - loss: 34.0593
# Epoch 14/50
#  - 0s - loss: 34.0512
# Epoch 15/50
#  - 0s - loss: 34.0641
# Epoch 16/50
#  - 0s - loss: 34.0435
# Epoch 17/50
#  - 0s - loss: 34.0257
# Epoch 18/50
#  - 0s - loss: 33.9925
# Epoch 19/50
#  - 0s - loss: 34.0514
# Epoch 20/50
#  - 0s - loss: 34.0189
# Epoch 21/50
#  - 0s - loss: 33.9668
# Epoch 22/50
#  - 0s - loss: 34.0885
# Epoch 23/50
#  - 0s - loss: 34.0296
# Epoch 24/50
#  - 0s - loss: 34.0165
# Epoch 25/50
#  - 0s - loss: 34.0130
# Epoch 26/50
#  - 0s - loss: 34.0226
# Epoch 27/50
#  - 0s - loss: 33.9799
# Epoch 28/50
#  - 0s - loss: 34.0751
# Epoch 29/50
#  - 0s - loss: 33.9570
# Epoch 30/50
#  - 0s - loss: 34.0351
# Epoch 31/50
#  - 0s - loss: 33.9593
# Epoch 32/50
#  - 0s - loss: 33.9423
# Epoch 33/50
#  - 0s - loss: 33.9897
# Epoch 34/50
#  - 0s - loss: 33.9622
# Epoch 35/50
#  - 0s - loss: 33.9770
# Epoch 36/50
#  - 0s - loss: 33.9262
# Epoch 37/50
#  - 0s - loss: 34.0013
# Epoch 38/50
#  - 0s - loss: 33.9264
# Epoch 39/50
#  - 0s - loss: 33.9562
# Epoch 40/50
#  - 0s - loss: 33.9489
# Epoch 41/50
#  - 0s - loss: 33.9161
# Epoch 42/50
#  - 0s - loss: 33.9534
# Epoch 43/50
#  - 0s - loss: 33.9205
# Epoch 44/50
#  - 0s - loss: 34.0030
# Epoch 45/50
#  - 0s - loss: 33.9068
# Epoch 46/50
#  - 0s - loss: 33.9170
# Epoch 47/50
#  - 0s - loss: 33.9543
# Epoch 48/50
#  - 0s - loss: 33.9184
# Epoch 49/50
#  - 0s - loss: 33.9075
# Epoch 50/50
#  - 0s - loss: 33.9137
# Duration (seconds): 2.089284896850586
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.9070
# Epoch 2/50
#  - 0s - loss: 33.8849
# Epoch 3/50
#  - 0s - loss: 34.0078
# Epoch 4/50
#  - 0s - loss: 33.8688
# Epoch 5/50
#  - 0s - loss: 33.9719
# Epoch 6/50
#  - 0s - loss: 33.8888
# Epoch 7/50
#  - 0s - loss: 33.8643
# Epoch 8/50
#  - 0s - loss: 33.9088
# Epoch 9/50
#  - 0s - loss: 33.8370
# Epoch 10/50
#  - 0s - loss: 33.8840
# Epoch 11/50
#  - 0s - loss: 33.9057
# Epoch 12/50
#  - 0s - loss: 33.8733
# Epoch 13/50
#  - 0s - loss: 33.8380
# Epoch 14/50
#  - 0s - loss: 33.9263
# Epoch 15/50
#  - 0s - loss: 33.8478
# Epoch 16/50
#  - 0s - loss: 33.9143
# Epoch 17/50
#  - 0s - loss: 33.9025
# Epoch 18/50
#  - 0s - loss: 33.8299
# Epoch 19/50
#  - 0s - loss: 33.8536
# Epoch 20/50
#  - 0s - loss: 33.8384
# Epoch 21/50
#  - 0s - loss: 33.8379
# Epoch 22/50
#  - 0s - loss: 33.8882
# Epoch 23/50
#  - 0s - loss: 33.7657
# Epoch 24/50
#  - 0s - loss: 33.8363
# Epoch 25/50
#  - 0s - loss: 33.9524
# Epoch 26/50
#  - 0s - loss: 33.7996
# Epoch 27/50
#  - 0s - loss: 33.8913
# Epoch 28/50
#  - 0s - loss: 33.7771
# Epoch 29/50
#  - 0s - loss: 33.8400
# Epoch 30/50
#  - 0s - loss: 33.7818
# Epoch 31/50
#  - 0s - loss: 33.7974
# Epoch 32/50
#  - 0s - loss: 33.8012
# Epoch 33/50
#  - 0s - loss: 33.8178
# Epoch 34/50
#  - 0s - loss: 33.8469
# Epoch 35/50
#  - 0s - loss: 33.8319
# Epoch 36/50
#  - 0s - loss: 33.7797
# Epoch 37/50
#  - 0s - loss: 33.7556
# Epoch 38/50
#  - 0s - loss: 33.7636
# Epoch 39/50
#  - 0s - loss: 33.7920
# Epoch 40/50
#  - 0s - loss: 33.8214
# Epoch 41/50
#  - 0s - loss: 33.7415
# Epoch 42/50
#  - 0s - loss: 33.7848
# Epoch 43/50
#  - 0s - loss: 33.8246
# Epoch 44/50
#  - 0s - loss: 33.7181
# Epoch 45/50
#  - 0s - loss: 33.8452
# Epoch 46/50
#  - 0s - loss: 33.7462
# Epoch 47/50
#  - 0s - loss: 33.8230
# Epoch 48/50
#  - 0s - loss: 33.7806
# Epoch 49/50
#  - 0s - loss: 33.7876
# Epoch 50/50
#  - 0s - loss: 33.8164
# Duration (seconds): 2.03776216506958
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.7722
# Epoch 2/50
#  - 0s - loss: 33.7695
# Epoch 3/50
#  - 0s - loss: 33.7489
# Epoch 4/50
#  - 0s - loss: 33.7319
# Epoch 5/50
#  - 0s - loss: 33.7380
# Epoch 6/50
#  - 0s - loss: 33.7929
# Epoch 7/50
#  - 0s - loss: 33.6920
# Epoch 8/50
#  - 0s - loss: 33.7227
# Epoch 9/50
#  - 0s - loss: 33.6873
# Epoch 10/50
#  - 0s - loss: 33.7291
# Epoch 11/50
#  - 0s - loss: 33.7303
# Epoch 12/50
#  - 0s - loss: 33.7326
# Epoch 13/50
#  - 0s - loss: 33.6779
# Epoch 14/50
#  - 0s - loss: 33.6861
# Epoch 15/50
#  - 0s - loss: 33.6869
# Epoch 16/50
#  - 0s - loss: 33.7101
# Epoch 17/50
#  - 0s - loss: 33.7444
# Epoch 18/50
#  - 0s - loss: 33.6836
# Epoch 19/50
#  - 0s - loss: 33.6708
# Epoch 20/50
#  - 0s - loss: 33.6783
# Epoch 21/50
#  - 0s - loss: 33.7636
# Epoch 22/50
#  - 0s - loss: 33.6762
# Epoch 23/50
#  - 0s - loss: 33.6658
# Epoch 24/50
#  - 0s - loss: 33.6883
# Epoch 25/50
#  - 0s - loss: 33.6590
# Epoch 26/50
#  - 0s - loss: 33.6162
# Epoch 27/50
#  - 0s - loss: 33.6628
# Epoch 28/50
#  - 0s - loss: 33.6310
# Epoch 29/50
#  - 0s - loss: 33.7445
# Epoch 30/50
#  - 0s - loss: 33.6266
# Epoch 31/50
#  - 0s - loss: 33.6187
# Epoch 32/50
#  - 0s - loss: 33.6183
# Epoch 33/50
#  - 0s - loss: 33.6516
# Epoch 34/50
#  - 0s - loss: 33.6295
# Epoch 35/50
#  - 0s - loss: 33.6015
# Epoch 36/50
#  - 0s - loss: 33.6229
# Epoch 37/50
#  - 0s - loss: 33.6695
# Epoch 38/50
#  - 0s - loss: 33.6792
# Epoch 39/50
#  - 0s - loss: 33.6250
# Epoch 40/50
#  - 0s - loss: 33.6323
# Epoch 41/50
#  - 0s - loss: 33.6298
# Epoch 42/50
#  - 0s - loss: 33.6204
# Epoch 43/50
#  - 0s - loss: 33.6290
# Epoch 44/50
#  - 0s - loss: 33.6857
# Epoch 45/50
#  - 0s - loss: 33.6123
# Epoch 46/50
#  - 0s - loss: 33.6204
# Epoch 47/50
#  - 0s - loss: 33.7140
# Epoch 48/50
#  - 0s - loss: 33.6266
# Epoch 49/50
#  - 0s - loss: 33.6006
# Epoch 50/50
#  - 0s - loss: 33.6019
# Duration (seconds): 2.2019851207733154
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.6316
# Epoch 2/50
#  - 0s - loss: 33.5797
# Epoch 3/50
#  - 0s - loss: 33.6579
# Epoch 4/50
#  - 0s - loss: 33.6604
# Epoch 5/50
#  - 0s - loss: 33.6490
# Epoch 6/50
#  - 0s - loss: 33.5488
# Epoch 7/50
#  - 0s - loss: 33.5647
# Epoch 8/50
#  - 0s - loss: 33.5752
# Epoch 9/50
#  - 0s - loss: 33.5566
# Epoch 10/50
#  - 0s - loss: 33.5835
# Epoch 11/50
#  - 0s - loss: 33.5825
# Epoch 12/50
#  - 0s - loss: 33.5727
# Epoch 13/50
#  - 0s - loss: 33.5534
# Epoch 14/50
#  - 0s - loss: 33.5716
# Epoch 15/50
#  - 0s - loss: 33.5615
# Epoch 16/50
#  - 0s - loss: 33.5676
# Epoch 17/50
#  - 0s - loss: 33.5688
# Epoch 18/50
#  - 0s - loss: 33.5291
# Epoch 19/50
#  - 0s - loss: 33.5052
# Epoch 20/50
#  - 0s - loss: 33.5577
# Epoch 21/50
#  - 0s - loss: 33.5178
# Epoch 22/50
#  - 0s - loss: 33.5120
# Epoch 23/50
#  - 0s - loss: 33.5070
# Epoch 24/50
#  - 0s - loss: 33.5466
# Epoch 25/50
#  - 0s - loss: 33.5853
# Epoch 26/50
#  - 0s - loss: 33.5024
# Epoch 27/50
#  - 0s - loss: 33.4751
# Epoch 28/50
#  - 0s - loss: 33.5351
# Epoch 29/50
#  - 0s - loss: 33.5430
# Epoch 30/50
#  - 0s - loss: 33.5766
# Epoch 31/50
#  - 0s - loss: 33.4891
# Epoch 32/50
#  - 0s - loss: 33.5097
# Epoch 33/50
#  - 0s - loss: 33.4972
# Epoch 34/50
#  - 0s - loss: 33.5294
# Epoch 35/50
#  - 0s - loss: 33.5132
# Epoch 36/50
#  - 0s - loss: 33.4579
# Epoch 37/50
#  - 0s - loss: 33.4538
# Epoch 38/50
#  - 0s - loss: 33.4533
# Epoch 39/50
#  - 0s - loss: 33.5040
# Epoch 40/50
#  - 0s - loss: 33.4117
# Epoch 41/50
#  - 0s - loss: 33.4952
# Epoch 42/50
#  - 0s - loss: 33.4940
# Epoch 43/50
#  - 0s - loss: 33.5060
# Epoch 44/50
#  - 0s - loss: 33.4431
# Epoch 45/50
#  - 0s - loss: 33.5066
# Epoch 46/50
#  - 0s - loss: 33.4774
# Epoch 47/50
#  - 0s - loss: 33.3984
# Epoch 48/50
#  - 0s - loss: 33.4995
# Epoch 49/50
#  - 0s - loss: 33.4728
# Epoch 50/50
#  - 0s - loss: 33.4430
# Duration (seconds): 2.1049327850341797
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.5146
# Epoch 2/50
#  - 0s - loss: 33.4644
# Epoch 3/50
#  - 0s - loss: 33.4241
# Epoch 4/50
#  - 0s - loss: 33.4022
# Epoch 5/50
#  - 0s - loss: 33.4178
# Epoch 6/50
#  - 0s - loss: 33.4977
# Epoch 7/50
#  - 0s - loss: 33.4274
# Epoch 8/50
#  - 0s - loss: 33.3800
# Epoch 9/50
#  - 0s - loss: 33.4528
# Epoch 10/50
#  - 0s - loss: 33.4783
# Epoch 11/50
#  - 0s - loss: 33.4218
# Epoch 12/50
#  - 0s - loss: 33.4262
# Epoch 13/50
#  - 0s - loss: 33.4070
# Epoch 14/50
#  - 0s - loss: 33.3957
# Epoch 15/50
#  - 0s - loss: 33.3559
# Epoch 16/50
#  - 0s - loss: 33.3861
# Epoch 17/50
#  - 0s - loss: 33.4448
# Epoch 18/50
#  - 0s - loss: 33.3374
# Epoch 19/50
#  - 0s - loss: 33.3842
# Epoch 20/50
#  - 0s - loss: 33.4101
# Epoch 21/50
#  - 0s - loss: 33.4982
# Epoch 22/50
#  - 0s - loss: 33.3592
# Epoch 23/50
#  - 0s - loss: 33.3779
# Epoch 24/50
#  - 0s - loss: 33.4288
# Epoch 25/50
#  - 0s - loss: 33.3480
# Epoch 26/50
#  - 0s - loss: 33.3856
# Epoch 27/50
#  - 0s - loss: 33.3598
# Epoch 28/50
#  - 0s - loss: 33.3651
# Epoch 29/50
#  - 0s - loss: 33.3907
# Epoch 30/50
#  - 0s - loss: 33.3432
# Epoch 31/50
#  - 0s - loss: 33.3516
# Epoch 32/50
#  - 0s - loss: 33.4142
# Epoch 33/50
#  - 0s - loss: 33.3249
# Epoch 34/50
#  - 0s - loss: 33.3869
# Epoch 35/50
#  - 0s - loss: 33.3228
# Epoch 36/50
#  - 0s - loss: 33.4293
# Epoch 37/50
#  - 0s - loss: 33.3141
# Epoch 38/50
#  - 0s - loss: 33.3603
# Epoch 39/50
#  - 0s - loss: 33.3236
# Epoch 40/50
#  - 0s - loss: 33.3257
# Epoch 41/50
#  - 0s - loss: 33.3292
# Epoch 42/50
#  - 0s - loss: 33.3678
# Epoch 43/50
#  - 0s - loss: 33.3005
# Epoch 44/50
#  - 0s - loss: 33.2959
# Epoch 45/50
#  - 0s - loss: 33.3417
# Epoch 46/50
#  - 0s - loss: 33.3565
# Epoch 47/50
#  - 0s - loss: 33.3343
# Epoch 48/50
#  - 0s - loss: 33.3211
# Epoch 49/50
#  - 0s - loss: 33.3247
# Epoch 50/50
#  - 0s - loss: 33.3367
# Duration (seconds): 2.0077266693115234
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.3129
# Epoch 2/50
#  - 0s - loss: 33.2811
# Epoch 3/50
#  - 0s - loss: 33.2616
# Epoch 4/50
#  - 0s - loss: 33.3846
# Epoch 5/50
#  - 0s - loss: 33.2672
# Epoch 6/50
#  - 0s - loss: 33.3076
# Epoch 7/50
#  - 0s - loss: 33.2781
# Epoch 8/50
#  - 0s - loss: 33.2540
# Epoch 9/50
#  - 0s - loss: 33.2666
# Epoch 10/50
#  - 0s - loss: 33.2565
# Epoch 11/50
#  - 0s - loss: 33.2132
# Epoch 12/50
#  - 0s - loss: 33.2282
# Epoch 13/50
#  - 0s - loss: 33.2790
# Epoch 14/50
#  - 0s - loss: 33.2531
# Epoch 15/50
#  - 0s - loss: 33.2939
# Epoch 16/50
#  - 0s - loss: 33.2275
# Epoch 17/50
#  - 0s - loss: 33.2144
# Epoch 18/50
#  - 0s - loss: 33.2706
# Epoch 19/50
#  - 0s - loss: 33.2565
# Epoch 20/50
#  - 0s - loss: 33.2149
# Epoch 21/50
#  - 0s - loss: 33.2490
# Epoch 22/50
#  - 0s - loss: 33.1947
# Epoch 23/50
#  - 0s - loss: 33.2616
# Epoch 24/50
#  - 0s - loss: 33.2206
# Epoch 25/50
#  - 0s - loss: 33.2157
# Epoch 26/50
#  - 0s - loss: 33.2708
# Epoch 27/50
#  - 0s - loss: 33.1894
# Epoch 28/50
#  - 0s - loss: 33.3366
# Epoch 29/50
#  - 0s - loss: 33.3364
# Epoch 30/50
#  - 0s - loss: 33.1650
# Epoch 31/50
#  - 0s - loss: 33.1996
# Epoch 32/50
#  - 0s - loss: 33.2665
# Epoch 33/50
#  - 0s - loss: 33.1855
# Epoch 34/50
#  - 0s - loss: 33.1578
# Epoch 35/50
#  - 0s - loss: 33.2045
# Epoch 36/50
#  - 0s - loss: 33.1420
# Epoch 37/50
#  - 0s - loss: 33.2227
# Epoch 38/50
#  - 0s - loss: 33.2271
# Epoch 39/50
#  - 0s - loss: 33.1429
# Epoch 40/50
#  - 0s - loss: 33.1411
# Epoch 41/50
#  - 0s - loss: 33.1546
# Epoch 42/50
#  - 0s - loss: 33.1607
# Epoch 43/50
#  - 0s - loss: 33.1056
# Epoch 44/50
#  - 0s - loss: 33.1942
# Epoch 45/50
#  - 0s - loss: 33.1480
# Epoch 46/50
#  - 0s - loss: 33.1795
# Epoch 47/50
#  - 0s - loss: 33.1663
# Epoch 48/50
#  - 0s - loss: 33.1604
# Epoch 49/50
#  - 0s - loss: 33.1209
# Epoch 50/50
#  - 0s - loss: 33.0983
# Duration (seconds): 2.0723471641540527
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.1084
# Epoch 2/50
#  - 0s - loss: 33.1501
# Epoch 3/50
#  - 0s - loss: 33.1554
# Epoch 4/50
#  - 0s - loss: 33.1774
# Epoch 5/50
#  - 0s - loss: 33.1524
# Epoch 6/50
#  - 0s - loss: 33.1234
# Epoch 7/50
#  - 0s - loss: 33.1069
# Epoch 8/50
#  - 0s - loss: 33.1168
# Epoch 9/50
#  - 0s - loss: 33.1089
# Epoch 10/50
#  - 0s - loss: 33.1336
# Epoch 11/50
#  - 0s - loss: 33.1059
# Epoch 12/50
#  - 0s - loss: 33.0578
# Epoch 13/50
#  - 0s - loss: 33.0990
# Epoch 14/50
#  - 0s - loss: 33.1537
# Epoch 15/50
#  - 0s - loss: 33.1000
# Epoch 16/50
#  - 0s - loss: 33.0897
# Epoch 17/50
#  - 0s - loss: 33.0858
# Epoch 18/50
#  - 0s - loss: 33.1203
# Epoch 19/50
#  - 0s - loss: 33.0502
# Epoch 20/50
#  - 0s - loss: 33.0562
# Epoch 21/50
#  - 0s - loss: 33.0533
# Epoch 22/50
#  - 0s - loss: 33.0768
# Epoch 23/50
#  - 0s - loss: 33.0870
# Epoch 24/50
#  - 0s - loss: 33.0788
# Epoch 25/50
#  - 0s - loss: 33.0391
# Epoch 26/50
#  - 0s - loss: 33.0760
# ...
# Epoch 2/50
#  - 0s - loss: 30.9128
# Epoch 3/50
#  - 0s - loss: 30.9961
# Epoch 4/50
#  - 0s - loss: 30.9080
# Epoch 5/50
#  - 0s - loss: 30.9557
# Epoch 6/50
#  - 0s - loss: 31.0129
# Epoch 7/50
#  - 0s - loss: 30.9449
# Epoch 8/50
#  - 0s - loss: 30.9552
# Epoch 9/50
#  - 0s - loss: 30.9806
# Epoch 10/50
#  - 0s - loss: 30.9451
# Epoch 11/50
#  - 0s - loss: 30.9274
# Epoch 12/50
#  - 0s - loss: 30.9437
# Epoch 13/50
#  - 0s - loss: 30.9210
# Epoch 14/50
#  - 0s - loss: 30.9621
# Epoch 15/50
#  - 0s - loss: 30.9536
# Epoch 16/50
#  - 0s - loss: 30.9304
# Epoch 17/50
#  - 0s - loss: 30.9339
# Epoch 18/50
#  - 0s - loss: 30.9917
# Epoch 19/50
#  - 0s - loss: 30.9741
# Epoch 20/50
#  - 0s - loss: 30.9426
# Epoch 21/50
#  - 0s - loss: 30.9148
# Epoch 22/50
#  - 0s - loss: 30.9513
# Epoch 23/50
#  - 0s - loss: 30.9293
# Epoch 24/50
#  - 0s - loss: 30.9753
# Epoch 25/50
#  - 0s - loss: 30.9519
# Epoch 26/50
#  - 0s - loss: 30.9890
# Epoch 27/50
#  - 0s - loss: 30.9188
# Epoch 28/50
#  - 0s - loss: 30.9216
# Epoch 29/50
#  - 0s - loss: 30.9145
# Epoch 30/50
#  - 0s - loss: 30.9259
# Epoch 31/50
#  - 0s - loss: 30.8945
# Epoch 32/50
#  - 0s - loss: 30.9043
# Epoch 33/50
#  - 0s - loss: 30.9046
# Epoch 34/50
#  - 0s - loss: 30.9029
# Epoch 35/50
#  - 0s - loss: 30.8796
# Epoch 36/50
#  - 0s - loss: 30.8978
# Epoch 37/50
#  - 0s - loss: 30.9396
# Epoch 38/50
#  - 0s - loss: 30.9078
# Epoch 39/50
#  - 0s - loss: 30.9227
# Epoch 40/50
#  - 0s - loss: 30.9248
# Epoch 41/50
#  - 0s - loss: 30.9198
# Epoch 42/50
#  - 0s - loss: 30.9633
# Epoch 43/50
#  - 0s - loss: 30.9018
# Epoch 44/50
#  - 0s - loss: 30.8948
# Epoch 45/50
#  - 0s - loss: 30.9209
# Epoch 46/50
#  - 0s - loss: 30.9271
# Epoch 47/50
#  - 0s - loss: 30.9111
# Epoch 48/50
#  - 0s - loss: 30.9083
# Epoch 49/50
#  - 0s - loss: 30.9213
# Epoch 50/50
#  - 0s - loss: 30.9395
# Duration (seconds): 2.1949169635772705
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.9253
# Epoch 2/50
#  - 0s - loss: 30.9118
# Epoch 3/50
#  - 0s - loss: 30.9128
# Epoch 4/50
#  - 0s - loss: 30.8928
# Epoch 5/50
#  - 0s - loss: 30.8633
# Epoch 6/50
#  - 0s - loss: 30.9040
# Epoch 7/50
#  - 0s - loss: 30.8686
# Epoch 8/50
#  - 0s - loss: 30.8742
# Epoch 9/50
#  - 0s - loss: 30.8940
# Epoch 10/50
#  - 0s - loss: 30.9200
# Epoch 11/50
#  - 0s - loss: 30.9038
# Epoch 12/50
#  - 0s - loss: 30.8919
# Epoch 13/50
#  - 0s - loss: 30.9935
# Epoch 14/50
#  - 0s - loss: 30.8771
# Epoch 15/50
#  - 0s - loss: 30.9401
# Epoch 16/50
#  - 0s - loss: 30.8766
# Epoch 17/50
#  - 0s - loss: 30.9099
# Epoch 18/50
#  - 0s - loss: 30.9080
# Epoch 19/50
#  - 0s - loss: 30.9136
# Epoch 20/50
#  - 0s - loss: 30.8652
# Epoch 21/50
#  - 0s - loss: 30.8486
# Epoch 22/50
#  - 0s - loss: 30.8798
# Epoch 23/50
#  - 0s - loss: 30.8533
# Epoch 24/50
#  - 0s - loss: 30.9048
# Epoch 25/50
#  - 0s - loss: 30.8780
# Epoch 26/50
#  - 0s - loss: 30.9031
# Epoch 27/50
#  - 0s - loss: 30.8709
# Epoch 28/50
#  - 0s - loss: 30.8595
# Epoch 29/50
#  - 0s - loss: 30.8519
# Epoch 30/50
#  - 0s - loss: 30.8566
# Epoch 31/50
#  - 0s - loss: 30.9039
# Epoch 32/50
#  - 0s - loss: 30.8499
# Epoch 33/50
#  - 0s - loss: 30.9174
# Epoch 34/50
#  - 0s - loss: 30.8868
# Epoch 35/50
#  - 0s - loss: 30.9448
# Epoch 36/50
#  - 0s - loss: 30.9129
# Epoch 37/50
#  - 0s - loss: 30.9532
# Epoch 38/50
#  - 0s - loss: 30.8890
# Epoch 39/50
#  - 0s - loss: 30.9161
# Epoch 40/50
#  - 0s - loss: 30.8517
# Epoch 41/50
#  - 0s - loss: 30.8822
# Epoch 42/50
#  - 0s - loss: 30.9257
# Epoch 43/50
#  - 0s - loss: 30.9097
# Epoch 44/50
#  - 0s - loss: 30.8813
# Epoch 45/50
#  - 0s - loss: 30.8463
# Epoch 46/50
#  - 0s - loss: 30.9034
# Epoch 47/50
#  - 0s - loss: 30.8607
# Epoch 48/50
#  - 0s - loss: 30.8673
# Epoch 49/50
#  - 0s - loss: 30.8622
# Epoch 50/50
#  - 0s - loss: 30.9168
# Duration (seconds): 2.152857780456543
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.9376
# Epoch 2/50
#  - 0s - loss: 30.8945
# Epoch 3/50
#  - 0s - loss: 30.8244
# Epoch 4/50
#  - 0s - loss: 30.8434
# Epoch 5/50
#  - 0s - loss: 30.8663
# Epoch 6/50
#  - 0s - loss: 30.9705
# Epoch 7/50
#  - 0s - loss: 30.8481
# Epoch 8/50
#  - 0s - loss: 30.9164
# Epoch 9/50
#  - 0s - loss: 30.8598
# Epoch 10/50
#  - 0s - loss: 30.8848
# Epoch 11/50
#  - 0s - loss: 30.8770
# Epoch 12/50
#  - 0s - loss: 30.8908
# Epoch 13/50
#  - 0s - loss: 30.9697
# Epoch 14/50
#  - 0s - loss: 30.8781
# Epoch 15/50
#  - 0s - loss: 30.8805
# Epoch 16/50
#  - 0s - loss: 30.8342
# Epoch 17/50
#  - 0s - loss: 30.8925
# Epoch 18/50
#  - 0s - loss: 30.8163
# Epoch 19/50
#  - 0s - loss: 30.8985
# Epoch 20/50
#  - 0s - loss: 30.8612
# Epoch 21/50
#  - 0s - loss: 30.8480
# Epoch 22/50
#  - 0s - loss: 30.9910
# Epoch 23/50
#  - 0s - loss: 30.8723
# Epoch 24/50
#  - 0s - loss: 30.8804
# Epoch 25/50
#  - 0s - loss: 30.8806
# Epoch 26/50
#  - 0s - loss: 30.8938
# Epoch 27/50
#  - 0s - loss: 30.8304
# Epoch 28/50
#  - 0s - loss: 30.8257
# Epoch 29/50
#  - 0s - loss: 30.8813
# Epoch 30/50
#  - 0s - loss: 30.8133
# Epoch 31/50
#  - 0s - loss: 30.8420
# Epoch 32/50
#  - 0s - loss: 30.8579
# Epoch 33/50
#  - 0s - loss: 30.9206
# Epoch 34/50
#  - 0s - loss: 30.8188
# Epoch 35/50
#  - 0s - loss: 30.8316
# Epoch 36/50
#  - 0s - loss: 30.8809
# Epoch 37/50
#  - 0s - loss: 30.8829
# Epoch 38/50
#  - 0s - loss: 30.8109
# Epoch 39/50
#  - 0s - loss: 30.8642
# Epoch 40/50
#  - 0s - loss: 30.8567
# Epoch 41/50
#  - 0s - loss: 30.9154
# Epoch 42/50
#  - 0s - loss: 30.8686
# Epoch 43/50
#  - 0s - loss: 30.8840
# Epoch 44/50
#  - 0s - loss: 30.8580
# Epoch 45/50
#  - 0s - loss: 30.8490
# Epoch 46/50
#  - 0s - loss: 30.8376
# Epoch 47/50
#  - 0s - loss: 30.8475
# Epoch 48/50
#  - 0s - loss: 30.8863
# Epoch 49/50
#  - 0s - loss: 30.9163
# Epoch 50/50
#  - 0s - loss: 30.8523
# Duration (seconds): 2.0327749252319336
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.8010
# Epoch 2/50
#  - 0s - loss: 30.8590
# Epoch 3/50
#  - 0s - loss: 30.8200
# Epoch 4/50
#  - 0s - loss: 30.8417
# Epoch 5/50
#  - 0s - loss: 30.7697
# Epoch 6/50
#  - 0s - loss: 30.8273
# Epoch 7/50
#  - 0s - loss: 30.8245
# Epoch 8/50
#  - 0s - loss: 30.8222
# Epoch 9/50
#  - 0s - loss: 30.8294
# Epoch 10/50
#  - 0s - loss: 30.8251
# Epoch 11/50
#  - 0s - loss: 30.8242
# Epoch 12/50
#  - 0s - loss: 30.8364
# Epoch 13/50
#  - 0s - loss: 30.8963
# Epoch 14/50
#  - 0s - loss: 30.7973
# Epoch 15/50
#  - 0s - loss: 30.9057
# Epoch 16/50
#  - 0s - loss: 30.8100
# Epoch 17/50
#  - 0s - loss: 30.8654
# Epoch 18/50
#  - 0s - loss: 30.8047
# Epoch 19/50
#  - 0s - loss: 30.8278
# Epoch 20/50
#  - 0s - loss: 30.7926
# Epoch 21/50
#  - 0s - loss: 30.7932
# Epoch 22/50
#  - 0s - loss: 30.8603
# Epoch 23/50
#  - 0s - loss: 30.8422
# Epoch 24/50
#  - 0s - loss: 30.8154
# Epoch 25/50
#  - 0s - loss: 30.7649
# Epoch 26/50
#  - 0s - loss: 30.8242
# Epoch 27/50
#  - 0s - loss: 30.7936
# Epoch 28/50
#  - 0s - loss: 30.8239
# Epoch 29/50
#  - 0s - loss: 30.8187
# Epoch 30/50
#  - 0s - loss: 30.8190
# Epoch 31/50
#  - 0s - loss: 30.8504
# Epoch 32/50
#  - 0s - loss: 30.7720
# Epoch 33/50
#  - 0s - loss: 30.8027
# Epoch 34/50
#  - 0s - loss: 30.8362
# Epoch 35/50
#  - 0s - loss: 30.8381
# Epoch 36/50
#  - 0s - loss: 30.8692
# Epoch 37/50
#  - 0s - loss: 30.8228
# Epoch 38/50
#  - 0s - loss: 30.8396
# Epoch 39/50
#  - 0s - loss: 30.7849
# Epoch 40/50
#  - 0s - loss: 30.8188
# Epoch 41/50
#  - 0s - loss: 30.8017
# Epoch 42/50
#  - 0s - loss: 30.8005
# Epoch 43/50
#  - 0s - loss: 30.8162
# Epoch 44/50
#  - 0s - loss: 30.8058
# Epoch 45/50
#  - 0s - loss: 30.7892
# Epoch 46/50
#  - 0s - loss: 30.7560
# Epoch 47/50
#  - 0s - loss: 30.8148
# Epoch 48/50
#  - 0s - loss: 30.7856
# Epoch 49/50
#  - 0s - loss: 30.7833
# Epoch 50/50
#  - 0s - loss: 30.7937
# Duration (seconds): 2.0366220474243164
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.7632
# Epoch 2/50
#  - 0s - loss: 30.8382
# Epoch 3/50
#  - 0s - loss: 30.7922
# Epoch 4/50
#  - 0s - loss: 30.7697
# Epoch 5/50
#  - 0s - loss: 30.8194
# Epoch 6/50
#  - 0s - loss: 30.7688
# Epoch 7/50
#  - 0s - loss: 30.7782
# Epoch 8/50
#  - 0s - loss: 30.7619
# Epoch 9/50
#  - 0s - loss: 30.8099
# Epoch 10/50
#  - 0s - loss: 30.8005
# Epoch 11/50
#  - 0s - loss: 30.8500
# Epoch 12/50
#  - 0s - loss: 30.7729
# Epoch 13/50
#  - 0s - loss: 30.8506
# Epoch 14/50
#  - 0s - loss: 30.7706
# Epoch 15/50
#  - 0s - loss: 30.7978
# Epoch 16/50
#  - 0s - loss: 30.7740
# Epoch 17/50
#  - 0s - loss: 30.7978
# Epoch 18/50
#  - 0s - loss: 30.7529
# Epoch 19/50
#  - 0s - loss: 30.8014
# Epoch 20/50
#  - 0s - loss: 30.7794
# Epoch 21/50
#  - 0s - loss: 30.7530
# Epoch 22/50
#  - 0s - loss: 30.7513
# Epoch 23/50
#  - 0s - loss: 30.8125
# Epoch 24/50
#  - 0s - loss: 30.8251
# Epoch 25/50
#  - 0s - loss: 30.7489
# Epoch 26/50
#  - 0s - loss: 30.8197
# Epoch 27/50
#  - 0s - loss: 30.8152
# Epoch 28/50
#  - 0s - loss: 30.7606
# Epoch 29/50
#  - 0s - loss: 30.7671
# Epoch 30/50
#  - 0s - loss: 30.8200
# Epoch 31/50
#  - 0s - loss: 30.7954
# Epoch 32/50
#  - 0s - loss: 30.7797
# Epoch 33/50
#  - 0s - loss: 30.8051
# Epoch 34/50
#  - 0s - loss: 30.7385
# Epoch 35/50
#  - 0s - loss: 30.7633
# Epoch 36/50
#  - 0s - loss: 30.7890
# Epoch 37/50
#  - 0s - loss: 30.7964
# Epoch 38/50
#  - 0s - loss: 30.8556
# Epoch 39/50
#  - 0s - loss: 30.7517
# Epoch 40/50
#  - 0s - loss: 30.7404
# Epoch 41/50
#  - 0s - loss: 30.7379
# Epoch 42/50
#  - 0s - loss: 30.7386
# Epoch 43/50
#  - 0s - loss: 30.7924
# Epoch 44/50
#  - 0s - loss: 30.8055
# Epoch 45/50
#  - 0s - loss: 30.7445
# Epoch 46/50
#  - 0s - loss: 30.8231
# Epoch 47/50
#  - 0s - loss: 30.7197
# Epoch 48/50
#  - 0s - loss: 30.7618
# Epoch 49/50
#  - 0s - loss: 30.7999
# Epoch 50/50
#  - 0s - loss: 30.8297
# Duration (seconds): 2.033752918243408
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.7260
# Epoch 2/50
#  - 0s - loss: 30.7333
# Epoch 3/50
#  - 0s - loss: 30.7648
# Epoch 4/50
#  - 0s - loss: 30.7932
# Epoch 5/50
#  - 0s - loss: 30.8267
# Epoch 6/50
#  - 0s - loss: 30.7298
# Epoch 7/50
#  - 0s - loss: 30.7096
# Epoch 8/50
#  - 0s - loss: 30.8372
# Epoch 9/50
#  - 0s - loss: 30.7620
# Epoch 10/50
#  - 0s - loss: 30.7421
# Epoch 11/50
#  - 0s - loss: 30.7555
# Epoch 12/50
#  - 0s - loss: 30.7160
# Epoch 13/50
#  - 0s - loss: 30.7944
# Epoch 14/50
#  - 0s - loss: 30.7786
# Epoch 15/50
#  - 0s - loss: 30.7665
# Epoch 16/50
#  - 0s - loss: 30.7507
# Epoch 17/50
#  - 0s - loss: 30.7777
# Epoch 18/50
#  - 0s - loss: 30.8021
# Epoch 19/50
#  - 0s - loss: 30.7512
# Epoch 20/50
#  - 0s - loss: 30.8184
# Epoch 21/50
#  - 0s - loss: 30.7480
# Epoch 22/50
#  - 0s - loss: 30.7531
# Epoch 23/50
#  - 0s - loss: 30.7281
# Epoch 24/50
#  - 0s - loss: 30.7325
# Epoch 25/50
#  - 0s - loss: 30.7377
# Epoch 26/50
#  - 0s - loss: 30.8556
# Epoch 27/50
#  - 0s - loss: 30.6902
# Epoch 28/50
#  - 0s - loss: 30.8191
# Epoch 29/50
#  - 0s - loss: 30.7823
# Epoch 30/50
#  - 0s - loss: 30.7657
# Epoch 31/50
#  - 0s - loss: 30.7416
# Epoch 32/50
#  - 0s - loss: 30.7856
# Epoch 33/50
#  - 0s - loss: 30.7600
# Epoch 34/50
#  - 0s - loss: 30.7460
# Epoch 35/50
#  - 0s - loss: 30.7065
# Epoch 36/50
#  - 0s - loss: 30.7775
# Epoch 37/50
#  - 0s - loss: 30.8232
# Epoch 38/50
#  - 0s - loss: 30.7017
# Epoch 39/50
#  - 0s - loss: 30.7129
# Epoch 40/50
#  - 0s - loss: 30.7638
# Epoch 41/50
#  - 0s - loss: 30.7622
# Epoch 42/50
#  - 0s - loss: 30.6852
# Epoch 43/50
#  - 0s - loss: 30.7236
# Epoch 44/50
#  - 0s - loss: 30.7452
# Epoch 45/50
#  - 0s - loss: 30.7536
# Epoch 46/50
#  - 0s - loss: 30.7742
# Epoch 47/50
#  - 0s - loss: 30.7325
# Epoch 48/50
#  - 0s - loss: 30.7576
# Epoch 49/50
#  - 0s - loss: 30.7333
# Epoch 50/50
#  - 0s - loss: 30.7962
# Duration (seconds): 2.2060563564300537
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.7379
# Epoch 2/50
#  - 0s - loss: 30.6905
# Epoch 3/50
#  - 0s - loss: 30.7432
# Epoch 4/50
#  - 0s - loss: 30.7555
# Epoch 5/50
#  - 0s - loss: 30.7125
# Epoch 6/50
#  - 0s - loss: 30.7618
# Epoch 7/50
#  - 0s - loss: 30.7705
# Epoch 8/50
#  - 0s - loss: 30.6774
# Epoch 9/50
#  - 0s - loss: 30.7209
# Epoch 10/50
#  - 0s - loss: 30.7323
# Epoch 11/50
#  - 0s - loss: 30.7004
# Epoch 12/50
#  - 0s - loss: 30.7090
# Epoch 13/50
#  - 0s - loss: 30.7202
# Epoch 14/50
#  - 0s - loss: 30.7291
# Epoch 15/50
#  - 0s - loss: 30.6869
# Epoch 16/50
#  - 0s - loss: 30.6758
# Epoch 17/50
#  - 0s - loss: 30.7043
# Epoch 18/50
#  - 0s - loss: 30.7213
# Epoch 19/50
#  - 0s - loss: 30.7213
# Epoch 20/50
#  - 0s - loss: 30.8281
# Epoch 21/50
#  - 0s - loss: 30.7048
# Epoch 22/50
#  - 0s - loss: 30.7072
# Epoch 23/50
#  - 0s - loss: 30.7474
# Epoch 24/50
#  - 0s - loss: 30.6827
# Epoch 25/50
#  - 0s - loss: 30.7184
# Epoch 26/50
#  - 0s - loss: 30.6586
# Epoch 27/50
#  - 0s - loss: 30.6724
# Epoch 28/50
#  - 0s - loss: 30.6845
# Epoch 29/50
#  - 0s - loss: 30.6819
# Epoch 30/50
#  - 0s - loss: 30.7019
# Epoch 31/50
#  - 0s - loss: 30.7010
# Epoch 32/50
#  - 0s - loss: 30.6680
# Epoch 33/50
#  - 0s - loss: 30.6936
# Epoch 34/50
#  - 0s - loss: 30.7371
# Epoch 35/50
#  - 0s - loss: 30.6757
# Epoch 36/50
#  - 0s - loss: 30.7225
# Epoch 37/50
#  - 0s - loss: 30.6890
# Epoch 38/50
#  - 0s - loss: 30.8170
# Epoch 39/50
#  - 0s - loss: 30.7013
# Epoch 40/50
#  - 0s - loss: 30.7745
# Epoch 41/50
#  - 0s - loss: 30.6625
# Epoch 42/50
#  - 0s - loss: 30.6716
# Epoch 43/50
#  - 0s - loss: 30.7057
# Epoch 44/50
#  - 0s - loss: 30.7318
# Epoch 45/50
#  - 0s - loss: 30.7322
# Epoch 46/50
#  - 0s - loss: 30.7702
# Epoch 47/50
#  - 0s - loss: 30.7418
# Epoch 48/50
#  - 0s - loss: 30.6819
# Epoch 49/50
#  - 0s - loss: 30.6733
# Epoch 50/50
#  - 0s - loss: 30.6984
# Duration (seconds): 2.0632200241088867
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.7270
# Epoch 2/50
#  - 0s - loss: 30.7367
# Epoch 3/50
#  - 0s - loss: 30.7071
# Epoch 4/50
#  - 0s - loss: 30.6510
# Epoch 5/50
#  - 0s - loss: 30.6303
# Epoch 6/50
#  - 0s - loss: 30.6698
# Epoch 7/50
#  - 0s - loss: 30.6981
# Epoch 8/50
#  - 0s - loss: 30.7324
# Epoch 9/50
#  - 0s - loss: 30.8157
# Epoch 10/50
#  - 0s - loss: 30.6742
# Epoch 11/50
#  - 0s - loss: 30.6825
# Epoch 12/50
#  - 0s - loss: 30.7064
# Epoch 13/50
#  - 0s - loss: 30.6491
# Epoch 14/50
#  - 0s - loss: 30.7945
# Epoch 15/50
#  - 0s - loss: 30.6533
# Epoch 16/50
#  - 0s - loss: 30.6682
# Epoch 17/50
#  - 0s - loss: 30.7310
# Epoch 18/50
#  - 0s - loss: 30.7187
# Epoch 19/50
#  - 0s - loss: 30.6832
# Epoch 20/50
#  - 0s - loss: 30.6821
# Epoch 21/50
#  - 0s - loss: 30.6360
# Epoch 22/50
#  - 0s - loss: 30.7250
# Epoch 23/50
#  - 0s - loss: 30.7114
# Epoch 24/50
#  - 0s - loss: 30.6816
# Epoch 25/50
#  - 0s - loss: 30.6823
# Epoch 26/50
#  - 0s - loss: 30.6693
# Epoch 27/50
#  - 0s - loss: 30.6528
# Epoch 28/50
#  - 0s - loss: 30.6573
# Epoch 29/50
#  - 0s - loss: 30.6657
# Epoch 30/50
#  - 0s - loss: 30.7624
# Epoch 31/50
#  - 0s - loss: 30.6614
# Epoch 32/50
#  - 0s - loss: 30.8659
# Epoch 33/50
#  - 0s - loss: 30.6755
# Epoch 34/50
#  - 0s - loss: 30.6859
# Epoch 35/50
#  - 0s - loss: 30.6644
# Epoch 36/50
#  - 0s - loss: 30.7109
# Epoch 37/50
#  - 0s - loss: 30.6464
# Epoch 38/50
#  - 0s - loss: 30.6311
# Epoch 39/50
#  - 0s - loss: 30.7095
# Epoch 40/50
#  - 0s - loss: 30.6622
# Epoch 41/50
#  - 0s - loss: 30.6642
# Epoch 42/50
#  - 0s - loss: 30.6258
# Epoch 43/50
#  - 0s - loss: 30.6500
# Epoch 44/50
#  - 0s - loss: 30.6946
# Epoch 45/50
#  - 0s - loss: 30.6337
# Epoch 46/50
#  - 0s - loss: 30.7228
# Epoch 47/50
#  - 0s - loss: 30.6219
# Epoch 48/50
#  - 0s - loss: 30.6729
# Epoch 49/50
#  - 0s - loss: 30.6672
# Epoch 50/50
#  - 0s - loss: 30.6439
# Duration (seconds): 2.173017740249634
# Finished - 50 times.
# And the list of mean squared errors : [271.0646973534067, 147.04464229323636, 111.50785520777698, 82.17452581707657, 64.2913625692749, 55.07713720152344, 47.88145461099853, 44.62544775281384, 43.3219464436184, 42.31362435058582, 41.44633013721597, 40.85976778601045, 39.930064085236914, 39.43427197133938, 39.14712940095544, 39.022062439744175, 38.89366424925001, 39.097483548269956, 38.92790312802276, 39.06437677243983, 38.96100802067679, 39.07560989265912, 39.18267225368609, 39.28202488190822, 39.31885308205019, 39.38607748458363, 39.597776956865204, 39.604414762705865, 39.513804705996435, 39.41508738803168, 39.316024590530205, 39.14320001021248, 39.02381125858577, 38.87122862035826, 38.81260790001035, 38.58932633236379, 38.47706739266955, 38.36154108521327, 38.21472547375703, 38.02549577188985, 37.9057467042571, 37.90128648388346, 37.7843549462295, 37.72950682322769, 38.01054432468212, 37.81367655726382, 37.79548460153853, 37.814363353496624, 37.73380004407858, 37.721261369870675]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 49.27 and 37.0, respectively

# %% [markdown]
# ###  Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of not normalized data is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline  normalized (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline_norm = get_report(name_of_case, mean_mse, std_mse)
df_baseline_norm
# Out:
#                          Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline  normalized (50 epochs)     49.27               37.0

# %% [markdown]
# Comparing the case of not normalized data with the case of normalized data:

# %%
# Create a data frame with the summary
df_summary = pd.concat([df_baseline, df_baseline_norm], axis=0)

# Review the result dataframe
df_summary.reset_index(drop=True)
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     55.41              13.89
# 1     Baseline  normalized (50 epochs)     49.27              37.00
