# %% [markdown]
# ## Building a Regression Model using Keras

# %% [markdown]
# ### Table of contents
# 1. Donwnload and clean dataset
# 2. Import Keras
# 3. Build a Neural Network
# 4. Train and Test the Neural Network

# %% [markdown]
# ### Download and Clean Dataset

# %% [markdown]
# We will start by importing the necessary libraries for the project

# %%
import time
import os
import pandas as pd
import numpy as np


from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
conda install -c conda-forge keras
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The dataset that we will use is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used. The ingredients include:
# 1. Cement
# 2. Blast furnace slag
# 3. Fly ash
# 4. Water
# 5. Superplasticizer
# 6. Coarse aggregate
# 7. Fine aggregate

# %% [markdown]
# We will download the data and read it into a pandas daataframe

# %%
concrete_df = pd.read_csv("/Users/juan/Downloads/concrete_data.csv")
concrete_df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# The first sample consists of 540 cubic meters of cement, 0 cubic meters of blast furnace slag and fly ash, 162 cubic meters of water, 2.5 cubic meters of superplasticizer, 1040 cubic meters of fine aggregate, 676 cubic meters of fine aggregate and has a compressive strength of 79.99 MPa at 28 days.

# %% [markdown]
# Check how many data points we have in the data frame

# %%
concrete_df.shape
# Out:
# (1030, 9)

# %% [markdown]
# The next step is to check the dataset for any missing values

# %%
concrete_df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The dataset looks clean so we can proceed to build our model

# %% [markdown]
# #### Split data intro predictors and target

# %%
concrete_df_columns = concrete_df.columns
predictors = concrete_df[concrete_df_columns[concrete_df_columns != "Strength"]] # All columns except Strength
target = concrete_df["Strength"] #Only the column Strength

# %% [markdown]
# Check the first rows for the predictors and target data

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Let's save the number of predictors to n_cols variables, because we will need it when we build our network

# %%
n_cols = predictors.shape[1] #number of predictors

# %% [markdown]
# ### Importing packages from Keras library

# %% [markdown]
# Let's import the packages from the Keras library that we will need to build our regression model

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Part A: Build a baseline model

# %% [markdown]
# Use the Keras library to build a neural network with the following:
#
# One hidden layer of 10 nodes, and a ReLU activation function
#
# Use the adam optimizer and the mean squared error as the loss function.
#
# Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.
#
# Train the model on the training data using 50 epochs.
#
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# Report the mean and the standard deviation of the mean squared errors.

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# Let's create a function that defines our regression model and we can call it to create our model

# %%
#define the regression model with one hidden layer
def regression_model():
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(n_cols,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ####  Train and test the model

# %% [markdown]
# We will create the regression model

# %%
model = regression_model()
# Out:
# WARNING:tensorflow:From /Users/juan/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# Randomly split the data into a training and test sets by holding 30%  of the data for testing. You can use the train_test_split helper function

# %%
X = predictors
y = target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)

# %% [markdown]
# Train the model on the training data using 50 epochs

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# WARNING:tensorflow:From /Users/juan/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 0s - loss: 82046.0770
# Epoch 2/50
#  - 0s - loss: 18025.4646
# Epoch 3/50
#  - 0s - loss: 8759.1094
# Epoch 4/50
#  - 0s - loss: 8335.7559
# Epoch 5/50
#  - 0s - loss: 7773.3083
# Epoch 6/50
#  - 0s - loss: 7329.9335
# Epoch 7/50
#  - 0s - loss: 6910.7450
# Epoch 8/50
#  - 0s - loss: 6485.1436
# Epoch 9/50
#  - 0s - loss: 6092.6331
# Epoch 10/50
#  - 0s - loss: 5714.7185
# Epoch 11/50
#  - 0s - loss: 5366.2461
# Epoch 12/50
#  - 0s - loss: 5020.3584
# Epoch 13/50
#  - 0s - loss: 4671.2692
# Epoch 14/50
#  - 0s - loss: 4303.6966
# Epoch 15/50
#  - 0s - loss: 3919.3289
# Epoch 16/50
#  - 0s - loss: 3559.3547
# Epoch 17/50
#  - 0s - loss: 3217.6885
# Epoch 18/50
#  - 0s - loss: 2916.7368
# Epoch 19/50
#  - 0s - loss: 2656.1221
# Epoch 20/50
#  - 0s - loss: 2446.7698
# Epoch 21/50
#  - 0s - loss: 2265.7666
# Epoch 22/50
#  - 0s - loss: 2112.0865
# Epoch 23/50
#  - 0s - loss: 1967.0465
# Epoch 24/50
#  - 0s - loss: 1835.1763
# Epoch 25/50
#  - 0s - loss: 1736.8659
# Epoch 26/50
#  - 0s - loss: 1653.7515
# Epoch 27/50
#  - 0s - loss: 1566.0272
# Epoch 28/50
#  - 0s - loss: 1498.7925
# Epoch 29/50
#  - 0s - loss: 1429.7851
# Epoch 30/50
#  - 0s - loss: 1361.7792
# Epoch 31/50
#  - 0s - loss: 1302.8324
# Epoch 32/50
#  - 0s - loss: 1245.1543
# Epoch 33/50
#  - 0s - loss: 1178.4984
# Epoch 34/50
#  - 0s - loss: 1123.4680
# Epoch 35/50
#  - 0s - loss: 1066.1915
# Epoch 36/50
#  - 0s - loss: 1011.0799
# Epoch 37/50
#  - 0s - loss: 959.0605
# Epoch 38/50
#  - 0s - loss: 910.7249
# Epoch 39/50
#  - 0s - loss: 862.8077
# Epoch 40/50
#  - 0s - loss: 814.4224
# Epoch 41/50
#  - 0s - loss: 765.8996
# Epoch 42/50
#  - 0s - loss: 723.5758
# Epoch 43/50
#  - 0s - loss: 682.4744
# Epoch 44/50
#  - 0s - loss: 642.7288
# Epoch 45/50
#  - 0s - loss: 612.7862
# Epoch 46/50
#  - 0s - loss: 565.7545
# Epoch 47/50
#  - 0s - loss: 528.7583
# Epoch 48/50
#  - 0s - loss: 498.8395
# Epoch 49/50
#  - 0s - loss: 467.4406
# Epoch 50/50
#  - 0s - loss: 432.0988

# %% [markdown]
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
y_hat = model.predict(X_test)   
mse = mean_squared_error(y_test, y_hat)

# %%
print(mse)
# Out:
# 425.5978468613843

# %% [markdown]
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors

# %% [markdown]
# We will create one function that performs steps 1 to 3 and another function that iterates 50 times and creates the list of 50 mean squared errors

# %%
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """   
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn. 
    X = predictors
    y = target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse

# %%
#Function to round the calculation of the mean and std deviation to 2 decimal places
def get_round(score, num_of_digits=2):
    """Get round with given number of decimal digits 
    """
    return round(score, num_of_digits)

#Function to calculate the mean of the list of mean squared errors
def get_mean(list_of_mse_scores):
    """Get mean
    """
    if list_of_mse_scores:
        return get_round(np.mean(list_of_mse_scores))
    return None

#Function to calculate the standard deviation of the list of mean squared errors
def get_standard_deviation(list_of_mse_scores):
    """Get standard deviation
    """
    if list_of_mse_scores:
        return get_round(np.std(list_of_mse_scores))
    return None




#Function to iterate and calculate the mean squared error
def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
    """Generate the mean and the standard deviation of the mean squared errors 
    """
    # Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.    
    list_of_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        list_of_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))
    # end for

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  list_of_mean_squared_errors))
    
    mean_mse = get_mean(list_of_mean_squared_errors)
    std_mse = get_standard_deviation(list_of_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse

# %%
max_iteration = 50
epochs = 50
verbose = 2

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 42431.4934
# Epoch 2/50
#  - 0s - loss: 25715.4288
# Epoch 3/50
#  - 0s - loss: 16453.5699
# Epoch 4/50
#  - 0s - loss: 11494.4647
# Epoch 5/50
#  - 0s - loss: 8518.6648
# Epoch 6/50
#  - 0s - loss: 6386.2868
# Epoch 7/50
#  - 0s - loss: 3597.7111
# Epoch 8/50
#  - 0s - loss: 1373.7471
# Epoch 9/50
#  - 0s - loss: 1059.9671
# Epoch 10/50
#  - 0s - loss: 974.2333
# Epoch 11/50
#  - 0s - loss: 911.4578
# Epoch 12/50
#  - 0s - loss: 856.4017
# Epoch 13/50
#  - 0s - loss: 807.4115
# Epoch 14/50
#  - 0s - loss: 763.6117
# Epoch 15/50
#  - 0s - loss: 725.3675
# Epoch 16/50
#  - 0s - loss: 691.2619
# Epoch 17/50
#  - 0s - loss: 658.5349
# Epoch 18/50
#  - 0s - loss: 630.1255
# Epoch 19/50
#  - 0s - loss: 602.0749
# Epoch 20/50
#  - 0s - loss: 577.2500
# Epoch 21/50
#  - 0s - loss: 552.6402
# Epoch 22/50
#  - 0s - loss: 530.8192
# Epoch 23/50
#  - 0s - loss: 509.8607
# Epoch 24/50
#  - 0s - loss: 489.2211
# Epoch 25/50
#  - 0s - loss: 470.4478
# Epoch 26/50
#  - 0s - loss: 453.7947
# Epoch 27/50
#  - 0s - loss: 438.0117
# Epoch 28/50
#  - 0s - loss: 421.4867
# Epoch 29/50
#  - 0s - loss: 408.1835
# Epoch 30/50
#  - 0s - loss: 395.2251
# Epoch 31/50
#  - 0s - loss: 381.9125
# Epoch 32/50
#  - 0s - loss: 371.0303
# Epoch 33/50
#  - 0s - loss: 361.2502
# Epoch 34/50
#  - 0s - loss: 351.6999
# Epoch 35/50
#  - 0s - loss: 343.5966
# Epoch 36/50
#  - 0s - loss: 334.5995
# Epoch 37/50
#  - 0s - loss: 327.1147
# Epoch 38/50
#  - 0s - loss: 320.2385
# Epoch 39/50
#  - 0s - loss: 313.4991
# Epoch 40/50
#  - 0s - loss: 306.9792
# Epoch 41/50
#  - 0s - loss: 301.6561
# Epoch 42/50
#  - 0s - loss: 296.0070
# Epoch 43/50
#  - 0s - loss: 290.7481
# Epoch 44/50
#  - 0s - loss: 285.7501
# Epoch 45/50
#  - 0s - loss: 280.9295
# Epoch 46/50
#  - 0s - loss: 277.9876
# Epoch 47/50
#  - 0s - loss: 272.4918
# Epoch 48/50
#  - 0s - loss: 269.2946
# Epoch 49/50
#  - 0s - loss: 265.5335
# Epoch 50/50
#  - 0s - loss: 261.5083
# Duration (seconds): 2.2371718883514404
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 257.8284
# Epoch 2/50
#  - 0s - loss: 254.6541
# Epoch 3/50
#  - 0s - loss: 252.1039
# Epoch 4/50
#  - 0s - loss: 249.1908
# Epoch 5/50
#  - 0s - loss: 245.2665
# Epoch 6/50
#  - 0s - loss: 243.2622
# Epoch 7/50
#  - 0s - loss: 240.0424
# Epoch 8/50
#  - 0s - loss: 237.6164
# Epoch 9/50
#  - 0s - loss: 235.1049
# Epoch 10/50
#  - 0s - loss: 231.6893
# Epoch 11/50
#  - 0s - loss: 229.1706
# Epoch 12/50
#  - 0s - loss: 227.1014
# Epoch 13/50
#  - 0s - loss: 224.3192
# Epoch 14/50
#  - 0s - loss: 221.7571
# Epoch 15/50
#  - 0s - loss: 219.5733
# Epoch 16/50
#  - 0s - loss: 217.1398
# Epoch 17/50
#  - 0s - loss: 215.2756
# Epoch 18/50
#  - 0s - loss: 212.5758
# Epoch 19/50
#  - 0s - loss: 210.1245
# Epoch 20/50
#  - 0s - loss: 207.7030
# Epoch 21/50
#  - 0s - loss: 205.4885
# Epoch 22/50
#  - 0s - loss: 203.3356
# Epoch 23/50
#  - 0s - loss: 201.0691
# Epoch 24/50
#  - 0s - loss: 199.0081
# Epoch 25/50
#  - 0s - loss: 196.5311
# Epoch 26/50
#  - 0s - loss: 194.0140
# Epoch 27/50
#  - 0s - loss: 192.6003
# Epoch 28/50
#  - 0s - loss: 189.6350
# Epoch 29/50
#  - 0s - loss: 187.0531
# Epoch 30/50
#  - 0s - loss: 185.1469
# Epoch 31/50
#  - 0s - loss: 183.1230
# Epoch 32/50
#  - 0s - loss: 180.8103
# Epoch 33/50
#  - 0s - loss: 178.9337
# Epoch 34/50
#  - 0s - loss: 176.3505
# Epoch 35/50
#  - 0s - loss: 173.7564
# Epoch 36/50
#  - 0s - loss: 171.1933
# Epoch 37/50
#  - 0s - loss: 169.4765
# Epoch 38/50
#  - 0s - loss: 166.5956
# Epoch 39/50
#  - 0s - loss: 164.9888
# Epoch 40/50
#  - 0s - loss: 162.6929
# Epoch 41/50
#  - 0s - loss: 160.1762
# Epoch 42/50
#  - 0s - loss: 158.3914
# Epoch 43/50
#  - 0s - loss: 155.4739
# Epoch 44/50
#  - 0s - loss: 153.3967
# Epoch 45/50
#  - 0s - loss: 151.7810
# Epoch 46/50
#  - 0s - loss: 149.6526
# Epoch 47/50
#  - 0s - loss: 147.1802
# Epoch 48/50
#  - 0s - loss: 145.6444
# Epoch 49/50
#  - 0s - loss: 143.9298
# Epoch 50/50
#  - 0s - loss: 141.5219
# Duration (seconds): 1.6747691631317139
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 139.5746
# Epoch 2/50
#  - 0s - loss: 137.6992
# Epoch 3/50
#  - 0s - loss: 135.9711
# Epoch 4/50
#  - 0s - loss: 134.1364
# Epoch 5/50
#  - 0s - loss: 132.7398
# Epoch 6/50
#  - 0s - loss: 131.3941
# Epoch 7/50
#  - 0s - loss: 129.4977
# Epoch 8/50
#  - 0s - loss: 128.2159
# Epoch 9/50
#  - 0s - loss: 127.0342
# Epoch 10/50
#  - 0s - loss: 125.8823
# Epoch 11/50
#  - 0s - loss: 123.8163
# Epoch 12/50
#  - 0s - loss: 123.1094
# Epoch 13/50
#  - 0s - loss: 121.5153
# Epoch 14/50
#  - 0s - loss: 120.4634
# Epoch 15/50
#  - 0s - loss: 119.3849
# Epoch 16/50
#  - 0s - loss: 118.3040
# Epoch 17/50
#  - 0s - loss: 117.4737
# Epoch 18/50
#  - 0s - loss: 116.4916
# Epoch 19/50
#  - 0s - loss: 115.5298
# Epoch 20/50
#  - 0s - loss: 115.0291
# Epoch 21/50
#  - 0s - loss: 113.8160
# Epoch 22/50
#  - 0s - loss: 113.5361
# Epoch 23/50
#  - 0s - loss: 113.1075
# Epoch 24/50
#  - 0s - loss: 111.9553
# Epoch 25/50
#  - 0s - loss: 111.0355
# Epoch 26/50
#  - 0s - loss: 110.2430
# Epoch 27/50
#  - 0s - loss: 109.9036
# Epoch 28/50
#  - 0s - loss: 109.3297
# Epoch 29/50
#  - 0s - loss: 109.4880
# Epoch 30/50
#  - 0s - loss: 108.5117
# Epoch 31/50
#  - 0s - loss: 108.3752
# Epoch 32/50
#  - 0s - loss: 107.6503
# Epoch 33/50
#  - 0s - loss: 107.0273
# Epoch 34/50
#  - 0s - loss: 106.6359
# Epoch 35/50
#  - 0s - loss: 106.6763
# Epoch 36/50
#  - 0s - loss: 106.3553
# Epoch 37/50
#  - 0s - loss: 105.3120
# Epoch 38/50
#  - 0s - loss: 104.9706
# Epoch 39/50
#  - 0s - loss: 104.6120
# Epoch 40/50
#  - 0s - loss: 104.7977
# Epoch 41/50
#  - 0s - loss: 104.3591
# Epoch 42/50
#  - 0s - loss: 103.7418
# Epoch 43/50
#  - 0s - loss: 103.3904
# Epoch 44/50
#  - 0s - loss: 104.2432
# Epoch 45/50
#  - 0s - loss: 102.8700
# Epoch 46/50
#  - 0s - loss: 102.7701
# Epoch 47/50
#  - 0s - loss: 103.2451
# Epoch 48/50
#  - 0s - loss: 103.2098
# Epoch 49/50
#  - 0s - loss: 101.8848
# Epoch 50/50
#  - 0s - loss: 102.0901
# Duration (seconds): 1.7404699325561523
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 101.4650
# Epoch 2/50
#  - 0s - loss: 100.9511
# Epoch 3/50
#  - 0s - loss: 101.1627
# Epoch 4/50
#  - 0s - loss: 100.3129
# Epoch 5/50
#  - 0s - loss: 100.7688
# Epoch 6/50
#  - 0s - loss: 99.8396
# Epoch 7/50
#  - 0s - loss: 101.9941
# Epoch 8/50
#  - 0s - loss: 99.8190
# Epoch 9/50
#  - 0s - loss: 99.7802
# Epoch 10/50
#  - 0s - loss: 100.1266
# Epoch 11/50
#  - 0s - loss: 99.1662
# Epoch 12/50
#  - 0s - loss: 98.8231
# Epoch 13/50
#  - 0s - loss: 98.7307
# Epoch 14/50
#  - 0s - loss: 98.6639
# Epoch 15/50
#  - 0s - loss: 98.5608
# Epoch 16/50
#  - 0s - loss: 98.0112
# Epoch 17/50
#  - 0s - loss: 98.1363
# Epoch 18/50
#  - 0s - loss: 98.2249
# Epoch 19/50
#  - 0s - loss: 98.2838
# Epoch 20/50
#  - 0s - loss: 97.3847
# Epoch 21/50
#  - 0s - loss: 97.6179
# Epoch 22/50
#  - 0s - loss: 96.9466
# Epoch 23/50
#  - 0s - loss: 96.7740
# Epoch 24/50
#  - 0s - loss: 96.1949
# Epoch 25/50
#  - 0s - loss: 96.8815
# Epoch 26/50
#  - 0s - loss: 96.8181
# Epoch 27/50
#  - 0s - loss: 95.3917
# Epoch 28/50
#  - 0s - loss: 95.5550
# Epoch 29/50
#  - 0s - loss: 95.7528
# Epoch 30/50
#  - 0s - loss: 95.8752
# Epoch 31/50
#  - 0s - loss: 96.3071
# Epoch 32/50
#  - 0s - loss: 94.7348
# Epoch 33/50
#  - 0s - loss: 94.9795
# Epoch 34/50
#  - 0s - loss: 95.0996
# Epoch 35/50
#  - 0s - loss: 94.2638
# Epoch 36/50
#  - 0s - loss: 94.6812
# Epoch 37/50
#  - 0s - loss: 93.7618
# Epoch 38/50
#  - 0s - loss: 93.5775
# Epoch 39/50
#  - 0s - loss: 93.3088
# Epoch 40/50
#  - 0s - loss: 93.2705
# Epoch 41/50
#  - 0s - loss: 93.0256
# Epoch 42/50
#  - 0s - loss: 93.2579
# Epoch 43/50
#  - 0s - loss: 92.6219
# Epoch 44/50
#  - 0s - loss: 92.4858
# Epoch 45/50
#  - 0s - loss: 92.8237
# Epoch 46/50
#  - 0s - loss: 93.9509
# Epoch 47/50
#  - 0s - loss: 91.9957
# Epoch 48/50
#  - 0s - loss: 92.9048
# Epoch 49/50
#  - 0s - loss: 92.2418
# Epoch 50/50
#  - 0s - loss: 91.8660
# Duration (seconds): 1.6928949356079102
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 91.3877
# Epoch 2/50
#  - 0s - loss: 91.3360
# Epoch 3/50
#  - 0s - loss: 91.2537
# Epoch 4/50
#  - 0s - loss: 90.8987
# Epoch 5/50
#  - 0s - loss: 90.6832
# Epoch 6/50
#  - 0s - loss: 91.5366
# Epoch 7/50
#  - 0s - loss: 90.4922
# Epoch 8/50
#  - 0s - loss: 91.5052
# Epoch 9/50
#  - 0s - loss: 91.2707
# Epoch 10/50
#  - 0s - loss: 90.2728
# Epoch 11/50
#  - 0s - loss: 89.4851
# Epoch 12/50
#  - 0s - loss: 89.6103
# Epoch 13/50
#  - 0s - loss: 89.3124
# Epoch 14/50
#  - 0s - loss: 89.3560
# Epoch 15/50
#  - 0s - loss: 89.0483
# Epoch 16/50
#  - 0s - loss: 90.2376
# Epoch 17/50
#  - 0s - loss: 88.7264
# Epoch 18/50
#  - 0s - loss: 88.4930
# Epoch 19/50
#  - 0s - loss: 88.4704
# Epoch 20/50
#  - 0s - loss: 88.8508
# Epoch 21/50
#  - 0s - loss: 89.6422
# Epoch 22/50
#  - 0s - loss: 87.7375
# Epoch 23/50
#  - 0s - loss: 87.4937
# Epoch 24/50
#  - 0s - loss: 87.0596
# Epoch 25/50
#  - 0s - loss: 87.0574
# Epoch 26/50
#  - 0s - loss: 88.1292
# Epoch 27/50
#  - 0s - loss: 86.5242
# Epoch 28/50
#  - 0s - loss: 86.3246
# Epoch 29/50
#  - 0s - loss: 86.4817
# Epoch 30/50
#  - 0s - loss: 86.6792
# Epoch 31/50
#  - 0s - loss: 86.1519
# Epoch 32/50
#  - 0s - loss: 85.7967
# Epoch 33/50
#  - 0s - loss: 85.7612
# Epoch 34/50
#  - 0s - loss: 85.5794
# Epoch 35/50
#  - 0s - loss: 85.1305
# Epoch 36/50
#  - 0s - loss: 84.4113
# Epoch 37/50
#  - 0s - loss: 84.5172
# Epoch 38/50
#  - 0s - loss: 84.0287
# Epoch 39/50
#  - 0s - loss: 83.5291
# Epoch 40/50
#  - 0s - loss: 83.5327
# Epoch 41/50
#  - 0s - loss: 83.5957
# Epoch 42/50
#  - 0s - loss: 83.2345
# Epoch 43/50
#  - 0s - loss: 82.4063
# Epoch 44/50
#  - 0s - loss: 82.1641
# Epoch 45/50
#  - 0s - loss: 82.0510
# Epoch 46/50
#  - 0s - loss: 81.7583
# Epoch 47/50
#  - 0s - loss: 81.9865
# Epoch 48/50
#  - 0s - loss: 81.3475
# Epoch 49/50
#  - 0s - loss: 80.8472
# Epoch 50/50
#  - 0s - loss: 81.9694
# Duration (seconds): 1.6724071502685547
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 80.5216
# Epoch 2/50
#  - 0s - loss: 80.4716
# Epoch 3/50
#  - 0s - loss: 80.1121
# Epoch 4/50
#  - 0s - loss: 79.9432
# Epoch 5/50
#  - 0s - loss: 79.5218
# Epoch 6/50
#  - 0s - loss: 79.3144
# Epoch 7/50
#  - 0s - loss: 78.9614
# Epoch 8/50
#  - 0s - loss: 79.6711
# Epoch 9/50
#  - 0s - loss: 78.7735
# Epoch 10/50
#  - 0s - loss: 78.6480
# Epoch 11/50
#  - 0s - loss: 78.5851
# Epoch 12/50
#  - 0s - loss: 78.4496
# Epoch 13/50
#  - 0s - loss: 78.5688
# Epoch 14/50
#  - 0s - loss: 79.5197
# Epoch 15/50
#  - 0s - loss: 77.4640
# Epoch 16/50
#  - 0s - loss: 77.8987
# Epoch 17/50
#  - 0s - loss: 77.4185
# Epoch 18/50
#  - 0s - loss: 78.4658
# Epoch 19/50
#  - 0s - loss: 77.4090
# Epoch 20/50
#  - 0s - loss: 78.3428
# Epoch 21/50
#  - 0s - loss: 77.0727
# Epoch 22/50
#  - 0s - loss: 76.8334
# Epoch 23/50
#  - 0s - loss: 76.3240
# Epoch 24/50
#  - 0s - loss: 76.0054
# Epoch 25/50
#  - 0s - loss: 76.4614
# Epoch 26/50
#  - 0s - loss: 76.1167
# Epoch 27/50
#  - 0s - loss: 76.2686
# Epoch 28/50
#  - 0s - loss: 75.9660
# Epoch 29/50
#  - 0s - loss: 76.1010
# Epoch 30/50
#  - 0s - loss: 75.5899
# Epoch 31/50
#  - 0s - loss: 75.6949
# Epoch 32/50
#  - 0s - loss: 75.0277
# Epoch 33/50
#  - 0s - loss: 75.2154
# Epoch 34/50
#  - 0s - loss: 76.7850
# Epoch 35/50
#  - 0s - loss: 76.9550
# Epoch 36/50
#  - 0s - loss: 75.1477
# Epoch 37/50
#  - 0s - loss: 74.6488
# Epoch 38/50
#  - 0s - loss: 74.2867
# Epoch 39/50
#  - 0s - loss: 74.1397
# Epoch 40/50
#  - 0s - loss: 75.1444
# Epoch 41/50
#  - 0s - loss: 75.5324
# Epoch 42/50
#  - 0s - loss: 74.3345
# Epoch 43/50
#  - 0s - loss: 73.8403
# Epoch 44/50
#  - 0s - loss: 73.9221
# Epoch 45/50
#  - 0s - loss: 73.8243
# Epoch 46/50
#  - 0s - loss: 74.3348
# Epoch 47/50
#  - 0s - loss: 73.7944
# Epoch 48/50
#  - 0s - loss: 73.3544
# Epoch 49/50
#  - 0s - loss: 73.9636
# Epoch 50/50
#  - 0s - loss: 74.1755
# Duration (seconds): 1.72548508644104
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 73.6530
# Epoch 2/50
#  - 0s - loss: 73.1432
# Epoch 3/50
#  - 0s - loss: 73.7306
# Epoch 4/50
#  - 0s - loss: 73.0893
# Epoch 5/50
#  - 0s - loss: 73.4355
# Epoch 6/50
#  - 0s - loss: 72.7638
# Epoch 7/50
#  - 0s - loss: 73.3158
# Epoch 8/50
#  - 0s - loss: 72.9601
# Epoch 9/50
#  - 0s - loss: 73.8847
# Epoch 10/50
#  - 0s - loss: 73.4686
# Epoch 11/50
#  - 0s - loss: 72.7729
# Epoch 12/50
#  - 0s - loss: 72.7779
# Epoch 13/50
#  - 0s - loss: 72.5875
# Epoch 14/50
#  - 0s - loss: 72.1883
# Epoch 15/50
#  - 0s - loss: 72.5259
# Epoch 16/50
#  - 0s - loss: 72.2234
# Epoch 17/50
#  - 0s - loss: 72.7126
# Epoch 18/50
#  - 0s - loss: 72.6437
# Epoch 19/50
#  - 0s - loss: 72.3882
# Epoch 20/50
#  - 0s - loss: 72.5055
# Epoch 21/50
#  - 0s - loss: 72.5160
# Epoch 22/50
#  - 0s - loss: 71.7747
# Epoch 23/50
#  - 0s - loss: 72.7532
# Epoch 24/50
#  - 0s - loss: 72.4339
# Epoch 25/50
#  - 0s - loss: 71.7519
# Epoch 26/50
#  - 0s - loss: 73.6908
# Epoch 27/50
#  - 0s - loss: 72.3117
# Epoch 28/50
#  - 0s - loss: 72.0693
# Epoch 29/50
#  - 0s - loss: 72.1457
# Epoch 30/50
#  - 0s - loss: 72.7572
# Epoch 31/50
#  - 0s - loss: 72.8276
# Epoch 32/50
#  - 0s - loss: 72.2176
# Epoch 33/50
#  - 0s - loss: 71.6262
# Epoch 34/50
#  - 0s - loss: 73.3456
# Epoch 35/50
#  - 0s - loss: 71.7601
# Epoch 36/50
#  - 0s - loss: 71.9465
# Epoch 37/50
#  - 0s - loss: 71.9828
# Epoch 38/50
#  - 0s - loss: 71.6317
# Epoch 39/50
#  - 0s - loss: 71.7704
# Epoch 40/50
#  - 0s - loss: 73.5442
# Epoch 41/50
#  - 0s - loss: 72.6767
# Epoch 42/50
#  - 0s - loss: 71.2201
# Epoch 43/50
#  - 0s - loss: 71.0492
# Epoch 44/50
#  - 0s - loss: 71.3442
# Epoch 45/50
#  - 0s - loss: 71.1058
# Epoch 46/50
#  - 0s - loss: 71.8610
# Epoch 47/50
#  - 0s - loss: 71.2411
# Epoch 48/50
#  - 0s - loss: 71.4071
# Epoch 49/50
#  - 0s - loss: 71.0908
# Epoch 50/50
#  - 0s - loss: 72.5859
# Duration (seconds): 1.7307491302490234
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 70.7522
# Epoch 2/50
#  - 0s - loss: 70.9683
# Epoch 3/50
#  - 0s - loss: 71.6473
# Epoch 4/50
#  - 0s - loss: 71.6691
# Epoch 5/50
#  - 0s - loss: 71.6211
# Epoch 6/50
#  - 0s - loss: 71.8338
# Epoch 7/50
#  - 0s - loss: 70.5288
# Epoch 8/50
#  - 0s - loss: 70.9981
# Epoch 9/50
#  - 0s - loss: 71.1054
# Epoch 10/50
#  - 0s - loss: 71.4988
# Epoch 11/50
#  - 0s - loss: 70.5596
# Epoch 12/50
#  - 0s - loss: 71.5503
# Epoch 13/50
#  - 0s - loss: 71.1810
# Epoch 14/50
#  - 0s - loss: 70.8033
# Epoch 15/50
#  - 0s - loss: 70.7509
# Epoch 16/50
#  - 0s - loss: 71.3635
# Epoch 17/50
#  - 0s - loss: 71.7098
# Epoch 18/50
#  - 0s - loss: 70.8657
# Epoch 19/50
#  - 0s - loss: 70.6260
# Epoch 20/50
#  - 0s - loss: 70.7115
# Epoch 21/50
#  - 0s - loss: 70.5347
# Epoch 22/50
#  - 0s - loss: 70.6437
# Epoch 23/50
#  - 0s - loss: 70.7912
# Epoch 24/50
#  - 0s - loss: 70.2846
# Epoch 25/50
#  - 0s - loss: 71.8128
# Epoch 26/50
#  - 0s - loss: 70.3815
# Epoch 27/50
#  - 0s - loss: 70.2594
# Epoch 28/50
#  - 0s - loss: 70.5067
# Epoch 29/50
#  - 0s - loss: 70.7407
# Epoch 30/50
#  - 0s - loss: 71.1389
# Epoch 31/50
#  - 0s - loss: 71.0184
# Epoch 32/50
#  - 0s - loss: 70.1951
# Epoch 33/50
#  - 0s - loss: 70.8370
# Epoch 34/50
#  - 0s - loss: 70.0780
# Epoch 35/50
#  - 0s - loss: 70.4433
# Epoch 36/50
#  - 0s - loss: 70.9066
# Epoch 37/50
#  - 0s - loss: 70.5038
# Epoch 38/50
#  - 0s - loss: 69.8522
# Epoch 39/50
#  - 0s - loss: 69.9521
# Epoch 40/50
#  - 0s - loss: 70.1238
# Epoch 41/50
#  - 0s - loss: 69.9063
# Epoch 42/50
#  - 0s - loss: 69.9769
# Epoch 43/50
#  - 0s - loss: 70.1126
# Epoch 44/50
#  - 0s - loss: 71.6180
# Epoch 45/50
#  - 0s - loss: 72.1483
# Epoch 46/50
#  - 0s - loss: 69.8155
# Epoch 47/50
#  - 0s - loss: 70.4809
# Epoch 48/50
#  - 0s - loss: 71.0648
# Epoch 49/50
#  - 0s - loss: 70.4366
# Epoch 50/50
#  - 0s - loss: 69.8122
# Duration (seconds): 1.7760450839996338
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 70.2362
# Epoch 2/50
#  - 0s - loss: 70.1670
# Epoch 3/50
#  - 0s - loss: 69.8773
# Epoch 4/50
#  - 0s - loss: 69.4271
# Epoch 5/50
#  - 0s - loss: 70.7774
# Epoch 6/50
#  - 0s - loss: 70.3599
# Epoch 7/50
#  - 0s - loss: 70.1584
# Epoch 8/50
#  - 0s - loss: 69.9091
# Epoch 9/50
#  - 0s - loss: 71.1090
# Epoch 10/50
#  - 0s - loss: 69.7348
# Epoch 11/50
#  - 0s - loss: 70.0816
# Epoch 12/50
#  - 0s - loss: 69.4403
# Epoch 13/50
#  - 0s - loss: 70.6246
# Epoch 14/50
#  - 0s - loss: 69.8305
# Epoch 15/50
#  - 0s - loss: 70.6361
# Epoch 16/50
#  - 0s - loss: 70.3974
# Epoch 17/50
#  - 0s - loss: 69.6898
# Epoch 18/50
#  - 0s - loss: 69.5634
# Epoch 19/50
#  - 0s - loss: 69.5106
# Epoch 20/50
#  - 0s - loss: 69.8938
# Epoch 21/50
#  - 0s - loss: 69.0899
# Epoch 22/50
#  - 0s - loss: 69.6521
# Epoch 23/50
#  - 0s - loss: 71.1816
# Epoch 24/50
#  - 0s - loss: 69.3530
# Epoch 25/50
#  - 0s - loss: 70.7556
# Epoch 26/50
#  - 0s - loss: 69.4945
# Epoch 27/50
#  - 0s - loss: 70.2727
# Epoch 28/50
#  - 0s - loss: 69.9310
# Epoch 29/50
#  - 0s - loss: 70.0325
# Epoch 30/50
#  - 0s - loss: 69.4289
# Epoch 31/50
#  - 0s - loss: 69.1373
# Epoch 32/50
#  - 0s - loss: 69.2953
# Epoch 33/50
#  - 0s - loss: 69.4858
# Epoch 34/50
#  - 0s - loss: 69.3785
# Epoch 35/50
#  - 0s - loss: 69.7117
# Epoch 36/50
#  - 0s - loss: 69.1281
# Epoch 37/50
#  - 0s - loss: 69.0826
# Epoch 38/50
#  - 0s - loss: 69.7645
# Epoch 39/50
#  - 0s - loss: 69.2106
# Epoch 40/50
#  - 0s - loss: 68.8816
# Epoch 41/50
#  - 0s - loss: 69.8945
# Epoch 42/50
#  - 0s - loss: 69.0548
# Epoch 43/50
#  - 0s - loss: 69.2661
# Epoch 44/50
#  - 0s - loss: 68.7834
# Epoch 45/50
#  - 0s - loss: 69.3240
# Epoch 46/50
#  - 0s - loss: 70.2071
# Epoch 47/50
#  - 0s - loss: 69.1089
# Epoch 48/50
#  - 0s - loss: 69.0659
# Epoch 49/50
#  - 0s - loss: 68.9025
# Epoch 50/50
#  - 0s - loss: 69.4551
# Duration (seconds): 2.1742162704467773
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 69.7935
# Epoch 2/50
#  - 0s - loss: 69.8944
# Epoch 3/50
#  - 0s - loss: 68.8736
# Epoch 4/50
#  - 0s - loss: 69.0506
# Epoch 5/50
#  - 0s - loss: 68.8025
# Epoch 6/50
#  - 0s - loss: 68.5716
# Epoch 7/50
#  - 0s - loss: 69.3626
# Epoch 8/50
#  - 0s - loss: 68.9409
# Epoch 9/50
#  - 0s - loss: 69.3843
# Epoch 10/50
#  - 0s - loss: 68.7999
# Epoch 11/50
#  - 0s - loss: 68.7794
# Epoch 12/50
#  - 0s - loss: 68.9780
# Epoch 13/50
#  - 0s - loss: 70.3448
# Epoch 14/50
#  - 0s - loss: 68.4783
# Epoch 15/50
#  - 0s - loss: 68.8718
# Epoch 16/50
#  - 0s - loss: 70.0247
# Epoch 17/50
#  - 0s - loss: 69.5853
# Epoch 18/50
#  - 0s - loss: 68.6223
# Epoch 19/50
#  - 0s - loss: 69.6275
# Epoch 20/50
#  - 0s - loss: 68.0988
# Epoch 21/50
#  - 0s - loss: 69.2885
# Epoch 22/50
#  - 0s - loss: 69.1124
# Epoch 23/50
#  - 0s - loss: 68.7820
# Epoch 24/50
#  - 0s - loss: 68.2684
# Epoch 25/50
#  - 0s - loss: 68.9448
# Epoch 26/50
#  - 0s - loss: 68.9842
# Epoch 27/50
#  - 0s - loss: 68.6091
# Epoch 28/50
#  - 0s - loss: 68.9171
# Epoch 29/50
#  - 0s - loss: 68.2771
# Epoch 30/50
#  - 0s - loss: 68.3665
# Epoch 31/50
#  - 0s - loss: 68.4497
# Epoch 32/50
#  - 0s - loss: 69.8310
# Epoch 33/50
#  - 0s - loss: 68.9605
# Epoch 34/50
#  - 0s - loss: 68.8801
# Epoch 35/50
#  - 0s - loss: 68.7442
# Epoch 36/50
#  - 0s - loss: 68.2673
# Epoch 37/50
#  - 0s - loss: 68.1435
# Epoch 38/50
#  - 0s - loss: 69.0510
# Epoch 39/50
#  - 0s - loss: 68.5726
# Epoch 40/50
#  - 0s - loss: 68.2008
# Epoch 41/50
#  - 0s - loss: 68.5989
# Epoch 42/50
#  - 0s - loss: 68.4622
# Epoch 43/50
#  - 0s - loss: 68.0436
# Epoch 44/50
#  - 0s - loss: 68.4637
# Epoch 45/50
#  - 0s - loss: 68.5931
# Epoch 46/50
#  - 0s - loss: 68.3515
# Epoch 47/50
#  - 0s - loss: 68.0740
# Epoch 48/50
#  - 0s - loss: 69.1015
# Epoch 49/50
#  - 0s - loss: 68.4891
# Epoch 50/50
#  - 0s - loss: 69.2609
# Duration (seconds): 1.9611048698425293
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 68.9145
# Epoch 2/50
#  - 0s - loss: 68.0156
# Epoch 3/50
#  - 0s - loss: 68.2499
# Epoch 4/50
#  - 0s - loss: 68.7839
# Epoch 5/50
#  - 0s - loss: 70.1196
# Epoch 6/50
#  - 0s - loss: 68.4052
# Epoch 7/50
#  - 0s - loss: 68.9603
# Epoch 8/50
#  - 0s - loss: 69.6996
# Epoch 9/50
#  - 0s - loss: 68.1705
# Epoch 10/50
#  - 0s - loss: 68.2005
# Epoch 11/50
#  - 0s - loss: 68.1556
# Epoch 12/50
#  - 0s - loss: 68.4772
# Epoch 13/50
#  - 0s - loss: 70.0470
# Epoch 14/50
#  - 0s - loss: 67.7793
# Epoch 15/50
#  - 0s - loss: 68.2996
# Epoch 16/50
#  - 0s - loss: 68.1282
# Epoch 17/50
#  - 0s - loss: 68.2335
# Epoch 18/50
#  - 0s - loss: 67.9274
# Epoch 19/50
#  - 0s - loss: 68.1462
# Epoch 20/50
#  - 0s - loss: 68.0361
# Epoch 21/50
#  - 0s - loss: 68.8993
# Epoch 22/50
#  - 0s - loss: 68.0377
# Epoch 23/50
#  - 0s - loss: 67.9951
# Epoch 24/50
#  - 0s - loss: 69.0273
# Epoch 25/50
#  - 0s - loss: 68.4789
# Epoch 26/50
#  - 0s - loss: 68.2183
# Epoch 27/50
#  - 0s - loss: 67.7916
# Epoch 28/50
#  - 0s - loss: 68.4374
# Epoch 29/50
#  - 0s - loss: 67.7059
# Epoch 30/50
#  - 0s - loss: 68.0841
# Epoch 31/50
#  - 0s - loss: 68.5280
# Epoch 32/50
#  - 0s - loss: 68.1657
# Epoch 33/50
#  - 0s - loss: 69.1161
# Epoch 34/50
#  - 0s - loss: 68.1390
# Epoch 35/50
#  - 0s - loss: 67.8515
# Epoch 36/50
#  - 0s - loss: 68.2005
# Epoch 37/50
#  - 0s - loss: 67.5646
# Epoch 38/50
#  - 0s - loss: 67.8446
# Epoch 39/50
#  - 0s - loss: 67.6282
# Epoch 40/50
#  - 0s - loss: 68.0704
# Epoch 41/50
#  - 0s - loss: 68.5883
# Epoch 42/50
#  - 0s - loss: 69.7770
# Epoch 43/50
#  - 0s - loss: 68.3286
# Epoch 44/50
#  - 0s - loss: 67.9097
# Epoch 45/50
#  - 0s - loss: 67.9926
# Epoch 46/50
#  - 0s - loss: 68.5228
# Epoch 47/50
#  - 0s - loss: 67.6129
# Epoch 48/50
#  - 0s - loss: 68.3690
# Epoch 49/50
#  - 0s - loss: 69.1760
# Epoch 50/50
#  - 0s - loss: 68.6164
# Duration (seconds): 1.648108959197998
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.6678
# Epoch 2/50
#  - 0s - loss: 67.6640
# Epoch 3/50
#  - 0s - loss: 69.4579
# Epoch 4/50
#  - 0s - loss: 69.1010
# Epoch 5/50
#  - 0s - loss: 69.1306
# Epoch 6/50
#  - 0s - loss: 67.7271
# Epoch 7/50
#  - 0s - loss: 68.0274
# Epoch 8/50
#  - 0s - loss: 67.4855
# Epoch 9/50
#  - 0s - loss: 68.6434
# Epoch 10/50
#  - 0s - loss: 67.3307
# Epoch 11/50
#  - 0s - loss: 68.8280
# Epoch 12/50
#  - 0s - loss: 67.5995
# Epoch 13/50
#  - 0s - loss: 69.0180
# Epoch 14/50
#  - 0s - loss: 67.6216
# Epoch 15/50
#  - 0s - loss: 67.8847
# Epoch 16/50
#  - 0s - loss: 67.3651
# Epoch 17/50
#  - 0s - loss: 67.4370
# Epoch 18/50
#  - 0s - loss: 68.1023
# Epoch 19/50
#  - 0s - loss: 67.3767
# Epoch 20/50
#  - 0s - loss: 67.3046
# Epoch 21/50
#  - 0s - loss: 67.3117
# Epoch 22/50
#  - 0s - loss: 68.4958
# Epoch 23/50
#  - 0s - loss: 68.3727
# Epoch 24/50
#  - 0s - loss: 66.7477
# Epoch 25/50
#  - 0s - loss: 67.9726
# Epoch 26/50
#  - 0s - loss: 67.3059
# Epoch 27/50
#  - 0s - loss: 67.7613
# Epoch 28/50
#  - 0s - loss: 67.9114
# Epoch 29/50
#  - 0s - loss: 67.2035
# Epoch 30/50
#  - 0s - loss: 67.3883
# Epoch 31/50
#  - 0s - loss: 67.1117
# Epoch 32/50
#  - 0s - loss: 67.0681
# Epoch 33/50
#  - 0s - loss: 67.8376
# Epoch 34/50
#  - 0s - loss: 67.6125
# Epoch 35/50
#  - 0s - loss: 67.5872
# Epoch 36/50
#  - 0s - loss: 66.9472
# Epoch 37/50
#  - 0s - loss: 67.4513
# Epoch 38/50
#  - 0s - loss: 66.9764
# Epoch 39/50
#  - 0s - loss: 67.5849
# Epoch 40/50
#  - 0s - loss: 68.8620
# Epoch 41/50
#  - 0s - loss: 67.5114
# Epoch 42/50
#  - 0s - loss: 67.7599
# Epoch 43/50
#  - 0s - loss: 67.0544
# Epoch 44/50
#  - 0s - loss: 67.3908
# Epoch 45/50
#  - 0s - loss: 67.3259
# Epoch 46/50
#  - 0s - loss: 67.2243
# Epoch 47/50
#  - 0s - loss: 67.2160
# Epoch 48/50
#  - 0s - loss: 67.1137
# Epoch 49/50
#  - 0s - loss: 67.2300
# Epoch 50/50
#  - 0s - loss: 67.4444
# Duration (seconds): 1.906677007675171
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.9687
# Epoch 2/50
#  - 0s - loss: 69.1981
# Epoch 3/50
#  - 0s - loss: 68.0027
# Epoch 4/50
#  - 0s - loss: 67.9143
# Epoch 5/50
#  - 0s - loss: 68.0276
# Epoch 6/50
#  - 0s - loss: 67.8993
# Epoch 7/50
#  - 0s - loss: 67.4231
# Epoch 8/50
#  - 0s - loss: 67.2835
# Epoch 9/50
#  - 0s - loss: 67.1044
# Epoch 10/50
#  - 0s - loss: 67.0322
# Epoch 11/50
#  - 0s - loss: 68.1430
# Epoch 12/50
#  - 0s - loss: 68.1599
# Epoch 13/50
#  - 0s - loss: 67.5852
# Epoch 14/50
#  - 0s - loss: 67.1851
# Epoch 15/50
#  - 0s - loss: 67.1897
# Epoch 16/50
#  - 0s - loss: 67.5658
# Epoch 17/50
#  - 0s - loss: 67.4624
# Epoch 18/50
#  - 0s - loss: 67.0904
# Epoch 19/50
#  - 0s - loss: 67.3608
# Epoch 20/50
#  - 0s - loss: 67.2321
# Epoch 21/50
#  - 0s - loss: 67.0316
# Epoch 22/50
#  - 0s - loss: 67.3762
# Epoch 23/50
#  - 0s - loss: 67.0747
# Epoch 24/50
#  - 0s - loss: 67.1384
# Epoch 25/50
#  - 0s - loss: 67.9506
# Epoch 26/50
#  - 0s - loss: 67.4002
# Epoch 27/50
#  - 0s - loss: 68.6567
# Epoch 28/50
#  - 0s - loss: 67.7110
# Epoch 29/50
#  - 0s - loss: 68.0494
# Epoch 30/50
#  - 0s - loss: 68.3876
# Epoch 31/50
#  - 0s - loss: 67.3205
# Epoch 32/50
#  - 0s - loss: 67.6330
# Epoch 33/50
#  - 0s - loss: 68.5507
# Epoch 34/50
#  - 0s - loss: 68.2271
# Epoch 35/50
#  - 0s - loss: 67.1964
# Epoch 36/50
#  - 0s - loss: 67.3853
# Epoch 37/50
#  - 0s - loss: 67.2076
# Epoch 38/50
#  - 0s - loss: 67.3450
# Epoch 39/50
#  - 0s - loss: 66.3688
# Epoch 40/50
#  - 0s - loss: 69.7699
# Epoch 41/50
#  - 0s - loss: 68.0318
# Epoch 42/50
#  - 0s - loss: 67.0819
# Epoch 43/50
#  - 0s - loss: 66.7358
# Epoch 44/50
#  - 0s - loss: 68.7031
# Epoch 45/50
#  - 0s - loss: 68.8756
# Epoch 46/50
#  - 0s - loss: 67.7406
# Epoch 47/50
#  - 0s - loss: 66.8458
# Epoch 48/50
#  - 0s - loss: 67.6309
# Epoch 49/50
#  - 0s - loss: 66.5417
# Epoch 50/50
#  - 0s - loss: 68.2500
# Duration (seconds): 1.7748279571533203
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.5539
# Epoch 2/50
#  - 0s - loss: 67.0633
# Epoch 3/50
#  - 0s - loss: 66.5449
# Epoch 4/50
#  - 0s - loss: 67.0467
# Epoch 5/50
#  - 0s - loss: 67.7387
# Epoch 6/50
#  - 0s - loss: 67.0094
# Epoch 7/50
#  - 0s - loss: 67.1103
# Epoch 8/50
#  - 0s - loss: 67.4072
# Epoch 9/50
#  - 0s - loss: 68.0666
# Epoch 10/50
#  - 0s - loss: 66.7621
# Epoch 11/50
#  - 0s - loss: 67.0064
# Epoch 12/50
#  - 0s - loss: 67.4519
# Epoch 13/50
#  - 0s - loss: 67.0285
# Epoch 14/50
#  - 0s - loss: 67.8287
# Epoch 15/50
#  - 0s - loss: 68.1633
# Epoch 16/50
#  - 0s - loss: 66.8208
# Epoch 17/50
#  - 0s - loss: 67.2762
# Epoch 18/50
#  - 0s - loss: 66.8770
# Epoch 19/50
#  - 0s - loss: 67.7493
# Epoch 20/50
#  - 0s - loss: 68.0300
# Epoch 21/50
#  - 0s - loss: 66.4192
# Epoch 22/50
#  - 0s - loss: 68.1760
# Epoch 23/50
#  - 0s - loss: 66.8212
# Epoch 24/50
#  - 0s - loss: 66.5692
# Epoch 25/50
#  - 0s - loss: 66.9349
# Epoch 26/50
#  - 0s - loss: 66.5673
# Epoch 27/50
#  - 0s - loss: 66.8447
# Epoch 28/50
#  - 0s - loss: 67.5122
# Epoch 29/50
#  - 0s - loss: 66.8556
# Epoch 30/50
#  - 0s - loss: 66.5550
# Epoch 31/50
#  - 0s - loss: 66.9501
# Epoch 32/50
#  - 0s - loss: 66.8219
# Epoch 33/50
#  - 0s - loss: 66.7513
# Epoch 34/50
#  - 0s - loss: 66.5852
# Epoch 35/50
#  - 0s - loss: 67.4158
# Epoch 36/50
#  - 0s - loss: 67.8710
# Epoch 37/50
#  - 0s - loss: 66.6096
# Epoch 38/50
#  - 0s - loss: 66.8093
# Epoch 39/50
#  - 0s - loss: 67.0378
# Epoch 40/50
#  - 0s - loss: 66.7323
# Epoch 41/50
#  - 0s - loss: 66.5526
# Epoch 42/50
#  - 0s - loss: 66.6629
# Epoch 43/50
#  - 0s - loss: 67.2642
# Epoch 44/50
#  - 0s - loss: 66.6353
# Epoch 45/50
#  - 0s - loss: 67.4331
# Epoch 46/50
#  - 0s - loss: 67.3156
# Epoch 47/50
#  - 0s - loss: 66.7554
# Epoch 48/50
#  - 0s - loss: 66.4092
# Epoch 49/50
#  - 0s - loss: 66.9529
# Epoch 50/50
#  - 0s - loss: 67.4789
# Duration (seconds): 1.7890291213989258
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.6870
# Epoch 2/50
#  - 0s - loss: 67.0133
# Epoch 3/50
#  - 0s - loss: 66.9081
# Epoch 4/50
#  - 0s - loss: 66.9459
# Epoch 5/50
#  - 0s - loss: 67.5785
# Epoch 6/50
#  - 0s - loss: 66.6676
# Epoch 7/50
#  - 0s - loss: 67.2203
# Epoch 8/50
#  - 0s - loss: 66.3904
# Epoch 9/50
#  - 0s - loss: 66.8055
# Epoch 10/50
#  - 0s - loss: 66.5017
# Epoch 11/50
#  - 0s - loss: 66.2577
# Epoch 12/50
#  - 0s - loss: 67.3233
# Epoch 13/50
#  - 0s - loss: 66.9187
# Epoch 14/50
#  - 0s - loss: 67.5463
# Epoch 15/50
#  - 0s - loss: 68.1487
# Epoch 16/50
#  - 0s - loss: 66.7987
# Epoch 17/50
#  - 0s - loss: 66.7335
# Epoch 18/50
#  - 0s - loss: 66.4407
# Epoch 19/50
#  - 0s - loss: 66.5231
# Epoch 20/50
#  - 0s - loss: 66.4810
# Epoch 21/50
#  - 0s - loss: 66.6718
# Epoch 22/50
#  - 0s - loss: 67.6715
# Epoch 23/50
#  - 0s - loss: 66.4075
# Epoch 24/50
#  - 0s - loss: 66.9835
# Epoch 25/50
#  - 0s - loss: 66.8049
# Epoch 26/50
#  - 0s - loss: 67.0234
# Epoch 27/50
#  - 0s - loss: 66.6595
# Epoch 28/50
#  - 0s - loss: 67.0178
# Epoch 29/50
#  - 0s - loss: 68.4179
# Epoch 30/50
#  - 0s - loss: 67.2543
# Epoch 31/50
#  - 0s - loss: 66.8814
# Epoch 32/50
#  - 0s - loss: 66.8119
# Epoch 33/50
#  - 0s - loss: 67.7539
# Epoch 34/50
#  - 0s - loss: 67.0543
# Epoch 35/50
#  - 0s - loss: 66.5529
# Epoch 36/50
#  - 0s - loss: 67.0749
# Epoch 37/50
#  - 0s - loss: 67.3739
# Epoch 38/50
#  - 0s - loss: 67.1737
# Epoch 39/50
#  - 0s - loss: 66.5151
# Epoch 40/50
#  - 0s - loss: 66.9528
# Epoch 41/50
#  - 0s - loss: 66.6617
# Epoch 42/50
#  - 0s - loss: 66.9483
# Epoch 43/50
#  - 0s - loss: 67.1525
# Epoch 44/50
#  - 0s - loss: 67.4297
# Epoch 45/50
#  - 0s - loss: 66.3705
# Epoch 46/50
#  - 0s - loss: 67.3610
# Epoch 47/50
#  - 0s - loss: 66.8864
# Epoch 48/50
#  - 0s - loss: 66.8370
# Epoch 49/50
#  - 0s - loss: 66.6123
# Epoch 50/50
#  - 0s - loss: 67.3806
# Duration (seconds): 1.755094051361084
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.1546
# Epoch 2/50
#  - 0s - loss: 67.1054
# Epoch 3/50
#  - 0s - loss: 67.2271
# Epoch 4/50
#  - 0s - loss: 67.6400
# Epoch 5/50
#  - 0s - loss: 66.9187
# Epoch 6/50
#  - 0s - loss: 67.3914
# Epoch 7/50
#  - 0s - loss: 67.3153
# Epoch 8/50
#  - 0s - loss: 66.7774
# Epoch 9/50
#  - 0s - loss: 67.0163
# Epoch 10/50
#  - 0s - loss: 66.9302
# Epoch 11/50
#  - 0s - loss: 66.8814
# Epoch 12/50
#  - 0s - loss: 66.6897
# Epoch 13/50
#  - 0s - loss: 66.8531
# Epoch 14/50
#  - 0s - loss: 67.5853
# Epoch 15/50
#  - 0s - loss: 68.6948
# Epoch 16/50
#  - 0s - loss: 67.4016
# Epoch 17/50
#  - 0s - loss: 67.5611
# Epoch 18/50
#  - 0s - loss: 67.1244
# Epoch 19/50
#  - 0s - loss: 67.2818
# Epoch 20/50
#  - 0s - loss: 66.9445
# Epoch 21/50
#  - 0s - loss: 66.7823
# Epoch 22/50
#  - 0s - loss: 67.2985
# Epoch 23/50
#  - 0s - loss: 66.9614
# Epoch 24/50
#  - 0s - loss: 67.6206
# Epoch 25/50
#  - 0s - loss: 66.6954
# Epoch 26/50
#  - 0s - loss: 67.0774
# Epoch 27/50
#  - 0s - loss: 66.5638
# Epoch 28/50
#  - 0s - loss: 67.8805
# Epoch 29/50
#  - 0s - loss: 67.0743
# Epoch 30/50
#  - 0s - loss: 66.5857
# Epoch 31/50
#  - 0s - loss: 66.8899
# Epoch 32/50
#  - 0s - loss: 66.4739
# Epoch 33/50
#  - 0s - loss: 68.6205
# Epoch 34/50
#  - 0s - loss: 67.2557
# Epoch 35/50
#  - 0s - loss: 66.9083
# Epoch 36/50
#  - 0s - loss: 66.5271
# Epoch 37/50
#  - 0s - loss: 67.0532
# Epoch 38/50
#  - 0s - loss: 67.1255
# Epoch 39/50
#  - 0s - loss: 68.1427
# Epoch 40/50
#  - 0s - loss: 67.3587
# Epoch 41/50
#  - 0s - loss: 67.4430
# Epoch 42/50
#  - 0s - loss: 67.0496
# Epoch 43/50
#  - 0s - loss: 66.8882
# Epoch 44/50
#  - 0s - loss: 66.6050
# Epoch 45/50
#  - 0s - loss: 67.2559
# Epoch 46/50
#  - 0s - loss: 67.5516
# Epoch 47/50
#  - 0s - loss: 68.2403
# Epoch 48/50
#  - 0s - loss: 67.5333
# Epoch 49/50
#  - 0s - loss: 67.2892
# Epoch 50/50
#  - 0s - loss: 67.0643
# Duration (seconds): 1.7794177532196045
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.0585
# Epoch 2/50
#  - 0s - loss: 67.6203
# Epoch 3/50
#  - 0s - loss: 67.4458
# Epoch 4/50
#  - 0s - loss: 66.9781
# Epoch 5/50
#  - 0s - loss: 66.5269
# Epoch 6/50
#  - 0s - loss: 66.7936
# Epoch 7/50
#  - 0s - loss: 67.6014
# Epoch 8/50
#  - 0s - loss: 66.6505
# Epoch 9/50
#  - 0s - loss: 66.6500
# Epoch 10/50
#  - 0s - loss: 66.5166
# Epoch 11/50
#  - 0s - loss: 66.5908
# Epoch 12/50
#  - 0s - loss: 66.6599
# Epoch 13/50
#  - 0s - loss: 66.6865
# Epoch 14/50
#  - 0s - loss: 66.9545
# Epoch 15/50
#  - 0s - loss: 67.0857
# Epoch 16/50
#  - 0s - loss: 67.1342
# Epoch 17/50
#  - 0s - loss: 67.1820
# Epoch 18/50
#  - 0s - loss: 69.3976
# Epoch 19/50
#  - 0s - loss: 66.9370
# Epoch 20/50
#  - 0s - loss: 66.7699
# Epoch 21/50
#  - 0s - loss: 66.6373
# Epoch 22/50
#  - 0s - loss: 67.9013
# Epoch 23/50
#  - 0s - loss: 66.7172
# Epoch 24/50
#  - 0s - loss: 66.6681
# Epoch 25/50
#  - 0s - loss: 66.4217
# Epoch 26/50
#  - 0s - loss: 66.5328
# Epoch 27/50
#  - 0s - loss: 68.2033
# Epoch 28/50
#  - 0s - loss: 66.9900
# Epoch 29/50
#  - 0s - loss: 66.8281
# Epoch 30/50
#  - 0s - loss: 66.4914
# Epoch 31/50
#  - 0s - loss: 67.4373
# Epoch 32/50
#  - 0s - loss: 67.7585
# Epoch 33/50
#  - 0s - loss: 66.7887
# Epoch 34/50
#  - 0s - loss: 67.7940
# Epoch 35/50
#  - 0s - loss: 67.2034
# Epoch 36/50
#  - 0s - loss: 66.6762
# Epoch 37/50
#  - 0s - loss: 66.7321
# Epoch 38/50
#  - 0s - loss: 66.4806
# Epoch 39/50
#  - 0s - loss: 66.5719
# Epoch 40/50
#  - 0s - loss: 66.7798
# Epoch 41/50
#  - 0s - loss: 67.1171
# Epoch 42/50
#  - 0s - loss: 67.9955
# Epoch 43/50
#  - 0s - loss: 67.3371
# Epoch 44/50
#  - 0s - loss: 66.5089
# Epoch 45/50
#  - 0s - loss: 66.5641
# Epoch 46/50
#  - 0s - loss: 66.8571
# Epoch 47/50
#  - 0s - loss: 66.7516
# Epoch 48/50
#  - 0s - loss: 66.7871
# Epoch 49/50
#  - 0s - loss: 68.1996
# Epoch 50/50
#  - 0s - loss: 67.0027
# Duration (seconds): 1.6384339332580566
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 70.0933
# Epoch 2/50
#  - 0s - loss: 66.8622
# Epoch 3/50
#  - 0s - loss: 66.8038
# Epoch 4/50
#  - 0s - loss: 66.6011
# Epoch 5/50
#  - 0s - loss: 67.0094
# Epoch 6/50
#  - 0s - loss: 66.8022
# Epoch 7/50
#  - 0s - loss: 66.5612
# Epoch 8/50
#  - 0s - loss: 67.1992
# Epoch 9/50
#  - 0s - loss: 66.9271
# Epoch 10/50
#  - 0s - loss: 66.6166
# Epoch 11/50
#  - 0s - loss: 66.4201
# Epoch 12/50
#  - 0s - loss: 66.6486
# Epoch 13/50
#  - 0s - loss: 66.9117
# Epoch 14/50
#  - 0s - loss: 66.8255
# Epoch 15/50
#  - 0s - loss: 66.8803
# Epoch 16/50
#  - 0s - loss: 66.4933
# Epoch 17/50
#  - 0s - loss: 66.3232
# Epoch 18/50
#  - 0s - loss: 67.1390
# Epoch 19/50
#  - 0s - loss: 66.7958
# Epoch 20/50
#  - 0s - loss: 66.4563
# Epoch 21/50
#  - 0s - loss: 66.4811
# Epoch 22/50
#  - 0s - loss: 66.5470
# Epoch 23/50
#  - 0s - loss: 66.5230
# Epoch 24/50
#  - 0s - loss: 66.2492
# Epoch 25/50
#  - 0s - loss: 66.7285
# Epoch 26/50
#  - 0s - loss: 66.1159
# Epoch 27/50
#  - 0s - loss: 66.0471
# Epoch 28/50
#  - 0s - loss: 66.1249
# Epoch 29/50
#  - 0s - loss: 66.5728
# Epoch 30/50
#  - 0s - loss: 65.9960
# Epoch 31/50
#  - 0s - loss: 66.1347
# Epoch 32/50
#  - 0s - loss: 66.0033
# Epoch 33/50
#  - 0s - loss: 66.1968
# Epoch 34/50
#  - 0s - loss: 65.8235
# Epoch 35/50
#  - 0s - loss: 65.8536
# Epoch 36/50
#  - 0s - loss: 65.5922
# Epoch 37/50
#  - 0s - loss: 65.4461
# Epoch 38/50
#  - 0s - loss: 65.3039
# Epoch 39/50
#  - 0s - loss: 66.5809
# Epoch 40/50
#  - 0s - loss: 65.8101
# Epoch 41/50
#  - 0s - loss: 65.2963
# Epoch 42/50
#  - 0s - loss: 65.2333
# Epoch 43/50
#  - 0s - loss: 66.7063
# Epoch 44/50
#  - 0s - loss: 66.5937
# Epoch 45/50
#  - 0s - loss: 65.8374
# Epoch 46/50
#  - 0s - loss: 66.7092
# Epoch 47/50
#  - 0s - loss: 65.1005
# Epoch 48/50
#  - 0s - loss: 66.8392
# Epoch 49/50
#  - 0s - loss: 65.5766
# Epoch 50/50
#  - 0s - loss: 64.8768
# Duration (seconds): 1.6447951793670654
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.9953
# Epoch 2/50
#  - 0s - loss: 65.8589
# Epoch 3/50
#  - 0s - loss: 65.1558
# Epoch 4/50
#  - 0s - loss: 64.7574
# Epoch 5/50
#  - 0s - loss: 64.8613
# Epoch 6/50
#  - 0s - loss: 64.7216
# Epoch 7/50
#  - 0s - loss: 64.7660
# Epoch 8/50
#  - 0s - loss: 64.6924
# Epoch 9/50
#  - 0s - loss: 64.4699
# Epoch 10/50
#  - 0s - loss: 64.8449
# Epoch 11/50
#  - 0s - loss: 64.8242
# Epoch 12/50
#  - 0s - loss: 64.8784
# Epoch 13/50
#  - 0s - loss: 65.1670
# Epoch 14/50
#  - 0s - loss: 65.2856
# Epoch 15/50
#  - 0s - loss: 65.2602
# Epoch 16/50
#  - 0s - loss: 64.5358
# Epoch 17/50
#  - 0s - loss: 64.8940
# Epoch 18/50
#  - 0s - loss: 65.3402
# Epoch 19/50
#  - 0s - loss: 64.6210
# Epoch 20/50
#  - 0s - loss: 65.2860
# Epoch 21/50
#  - 0s - loss: 65.8048
# Epoch 22/50
#  - 0s - loss: 65.6774
# Epoch 23/50
#  - 0s - loss: 65.3062
# Epoch 24/50
#  - 0s - loss: 65.6296
# Epoch 25/50
#  - 0s - loss: 64.7439
# Epoch 26/50
#  - 0s - loss: 64.5236
# Epoch 27/50
#  - 0s - loss: 65.4117
# Epoch 28/50
#  - 0s - loss: 64.9889
# Epoch 29/50
#  - 0s - loss: 64.7909
# Epoch 30/50
#  - 0s - loss: 64.5474
# Epoch 31/50
#  - 0s - loss: 64.6933
# Epoch 32/50
#  - 0s - loss: 64.4617
# Epoch 33/50
#  - 0s - loss: 64.5250
# Epoch 34/50
#  - 0s - loss: 64.8122
# Epoch 35/50
#  - 0s - loss: 64.3123
# Epoch 36/50
#  - 0s - loss: 64.4669
# Epoch 37/50
#  - 0s - loss: 64.5232
# Epoch 38/50
#  - 0s - loss: 65.3850
# Epoch 39/50
#  - 0s - loss: 65.1190
# Epoch 40/50
#  - 0s - loss: 65.5568
# Epoch 41/50
#  - 0s - loss: 64.2267
# Epoch 42/50
#  - 0s - loss: 65.1854
# Epoch 43/50
#  - 0s - loss: 64.6154
# Epoch 44/50
#  - 0s - loss: 64.3676
# Epoch 45/50
#  - 0s - loss: 64.5398
# Epoch 46/50
#  - 0s - loss: 64.3914
# Epoch 47/50
#  - 0s - loss: 64.6710
# Epoch 48/50
#  - 0s - loss: 64.4732
# Epoch 49/50
#  - 0s - loss: 64.8167
# Epoch 50/50
#  - 0s - loss: 64.0381
# Duration (seconds): 1.6506576538085938
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 65.0654
# Epoch 2/50
#  - 0s - loss: 66.6122
# Epoch 3/50
#  - 0s - loss: 64.2345
# Epoch 4/50
#  - 0s - loss: 64.7813
# Epoch 5/50
#  - 0s - loss: 64.6537
# Epoch 6/50
#  - 0s - loss: 64.4633
# Epoch 7/50
#  - 0s - loss: 65.8616
# Epoch 8/50
#  - 0s - loss: 64.7850
# Epoch 9/50
#  - 0s - loss: 65.7537
# Epoch 10/50
#  - 0s - loss: 65.2379
# Epoch 11/50
#  - 0s - loss: 65.0900
# Epoch 12/50
#  - 0s - loss: 64.7328
# Epoch 13/50
#  - 0s - loss: 64.0992
# Epoch 14/50
#  - 0s - loss: 64.0935
# Epoch 15/50
#  - 0s - loss: 64.1340
# Epoch 16/50
#  - 0s - loss: 64.4218
# Epoch 17/50
#  - 0s - loss: 64.6217
# Epoch 18/50
#  - 0s - loss: 65.1318
# Epoch 19/50
#  - 0s - loss: 64.0504
# Epoch 20/50
#  - 0s - loss: 64.7034
# Epoch 21/50
#  - 0s - loss: 65.0201
# Epoch 22/50
#  - 0s - loss: 64.1110
# Epoch 23/50
#  - 0s - loss: 64.6701
# Epoch 24/50
#  - 0s - loss: 64.6571
# Epoch 25/50
#  - 0s - loss: 64.1202
# Epoch 26/50
#  - 0s - loss: 64.0716
# Epoch 27/50
#  - 0s - loss: 64.2993
# Epoch 28/50
#  - 0s - loss: 64.5626
# Epoch 29/50
#  - 0s - loss: 64.2350
# Epoch 30/50
#  - 0s - loss: 64.8577
# Epoch 31/50
#  - 0s - loss: 64.4450
# Epoch 32/50
#  - 0s - loss: 65.2708
# Epoch 33/50
#  - 0s - loss: 63.8942
# Epoch 34/50
#  - 0s - loss: 64.0006
# Epoch 35/50
#  - 0s - loss: 64.5865
# Epoch 36/50
#  - 0s - loss: 64.9856
# Epoch 37/50
#  - 0s - loss: 65.0367
# Epoch 38/50
#  - 0s - loss: 64.1680
# Epoch 39/50
#  - 0s - loss: 63.6626
# Epoch 40/50
#  - 0s - loss: 65.6381
# Epoch 41/50
#  - 0s - loss: 63.8664
# Epoch 42/50
#  - 0s - loss: 64.2670
# Epoch 43/50
#  - 0s - loss: 64.3519
# Epoch 44/50
#  - 0s - loss: 65.1039
# Epoch 45/50
#  - 0s - loss: 64.0452
# Epoch 46/50
#  - 0s - loss: 64.1326
# Epoch 47/50
#  - 0s - loss: 64.2177
# Epoch 48/50
#  - 0s - loss: 65.2556
# Epoch 49/50
#  - 0s - loss: 64.9574
# Epoch 50/50
#  - 0s - loss: 64.2156
# Duration (seconds): 1.7143430709838867
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 63.8067
# Epoch 2/50
#  - 0s - loss: 64.0386
# Epoch 3/50
#  - 0s - loss: 64.2079
# Epoch 4/50
#  - 0s - loss: 64.2917
# Epoch 5/50
#  - 0s - loss: 63.9684
# Epoch 6/50
#  - 0s - loss: 65.0095
# Epoch 7/50
#  - 0s - loss: 64.4094
# Epoch 8/50
#  - 0s - loss: 64.5653
# Epoch 9/50
#  - 0s - loss: 65.0584
# Epoch 10/50
#  - 0s - loss: 65.6500
# Epoch 11/50
#  - 0s - loss: 64.4438
# Epoch 12/50
#  - 0s - loss: 64.2526
# Epoch 13/50
#  - 0s - loss: 64.0304
# Epoch 14/50
#  - 0s - loss: 64.0277
# Epoch 15/50
#  - 0s - loss: 64.3682
# Epoch 16/50
#  - 0s - loss: 64.2300
# Epoch 17/50
#  - 0s - loss: 64.4909
# Epoch 18/50
#  - 0s - loss: 65.6203
# Epoch 19/50
#  - 0s - loss: 64.6544
# Epoch 20/50
#  - 0s - loss: 64.4480
# Epoch 21/50
#  - 0s - loss: 64.1365
# Epoch 22/50
#  - 0s - loss: 63.8176
# Epoch 23/50
#  - 0s - loss: 64.2913
# Epoch 24/50
#  - 0s - loss: 63.9605
# Epoch 25/50
#  - 0s - loss: 64.4370
# Epoch 26/50
#  - 0s - loss: 64.2665
# Epoch 27/50
#  - 0s - loss: 64.4493
# Epoch 28/50
#  - 0s - loss: 65.0489
# Epoch 29/50
#  - 0s - loss: 64.7261
# Epoch 30/50
#  - 0s - loss: 64.4364
# Epoch 31/50
#  - 0s - loss: 64.0215
# Epoch 32/50
#  - 0s - loss: 64.9490
# Epoch 33/50
#  - 0s - loss: 64.9043
# Epoch 34/50
#  - 0s - loss: 64.1897
# Epoch 35/50
#  - 0s - loss: 65.4009
# Epoch 36/50
#  - 0s - loss: 65.7473
# Epoch 37/50
#  - 0s - loss: 64.2217
# Epoch 38/50
#  - 0s - loss: 64.6150
# Epoch 39/50
#  - 0s - loss: 64.5005
# Epoch 40/50
#  - 0s - loss: 63.9950
# Epoch 41/50
#  - 0s - loss: 64.4482
# Epoch 42/50
#  - 0s - loss: 64.9829
# Epoch 43/50
#  - 0s - loss: 63.8200
# Epoch 44/50
#  - 0s - loss: 64.4813
# Epoch 45/50
#  - 0s - loss: 64.1469
# Epoch 46/50
#  - 0s - loss: 64.1829
# Epoch 47/50
#  - 0s - loss: 64.1923
# Epoch 48/50
#  - 0s - loss: 63.8651
# Epoch 49/50
#  - 0s - loss: 64.1012
# Epoch 50/50
#  - 0s - loss: 63.9373
# Duration (seconds): 1.7032508850097656
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.0880
# Epoch 2/50
#  - 0s - loss: 64.0442
# Epoch 3/50
#  - 0s - loss: 63.9871
# Epoch 4/50
#  - 0s - loss: 64.9804
# Epoch 5/50
#  - 0s - loss: 65.0049
# Epoch 6/50
#  - 0s - loss: 63.9680
# Epoch 7/50
#  - 0s - loss: 64.5945
# Epoch 8/50
#  - 0s - loss: 64.1764
# Epoch 9/50
#  - 0s - loss: 64.0471
# Epoch 10/50
#  - 0s - loss: 65.3165
# Epoch 11/50
#  - 0s - loss: 64.1221
# Epoch 12/50
#  - 0s - loss: 64.4130
# Epoch 13/50
#  - 0s - loss: 64.2574
# Epoch 14/50
#  - 0s - loss: 64.0152
# Epoch 15/50
#  - 0s - loss: 63.9396
# Epoch 16/50
#  - 0s - loss: 64.5149
# Epoch 17/50
#  - 0s - loss: 64.2568
# Epoch 18/50
#  - 0s - loss: 63.9625
# Epoch 19/50
#  - 0s - loss: 64.6811
# Epoch 20/50
#  - 0s - loss: 66.8756
# Epoch 21/50
#  - 0s - loss: 66.0836
# Epoch 22/50
#  - 0s - loss: 64.1039
# Epoch 23/50
#  - 0s - loss: 66.1011
# Epoch 24/50
#  - 0s - loss: 65.7309
# Epoch 25/50
#  - 0s - loss: 64.4412
# Epoch 26/50
#  - 0s - loss: 63.9942
# Epoch 27/50
#  - 0s - loss: 63.7332
# Epoch 28/50
#  - 0s - loss: 64.4616
# Epoch 29/50
#  - 0s - loss: 63.9617
# Epoch 30/50
#  - 0s - loss: 63.9387
# Epoch 31/50
#  - 0s - loss: 64.4906
# Epoch 32/50
#  - 0s - loss: 64.7592
# Epoch 33/50
#  - 0s - loss: 64.0859
# Epoch 34/50
#  - 0s - loss: 64.0892
# Epoch 35/50
#  - 0s - loss: 64.5445
# Epoch 36/50
#  - 0s - loss: 65.7447
# Epoch 37/50
#  - 0s - loss: 64.5575
# Epoch 38/50
#  - 0s - loss: 64.3304
# Epoch 39/50
#  - 0s - loss: 63.9714
# Epoch 40/50
#  - 0s - loss: 64.1779
# Epoch 41/50
#  - 0s - loss: 64.0590
# Epoch 42/50
#  - 0s - loss: 64.0159
# Epoch 43/50
#  - 0s - loss: 64.8962
# Epoch 44/50
#  - 0s - loss: 66.4995
# Epoch 45/50
#  - 0s - loss: 64.1010
# Epoch 46/50
#  - 0s - loss: 64.2972
# Epoch 47/50
#  - 0s - loss: 64.1653
# Epoch 48/50
#  - 0s - loss: 63.9275
# Epoch 49/50
#  - 0s - loss: 64.1537
# Epoch 50/50
#  - 0s - loss: 64.2316
# Duration (seconds): 1.684067726135254
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.3123
# Epoch 2/50
#  - 0s - loss: 64.0555
# Epoch 3/50
#  - 0s - loss: 63.9746
# Epoch 4/50
#  - 0s - loss: 63.8470
# Epoch 5/50
#  - 0s - loss: 64.1317
# Epoch 6/50
#  - 0s - loss: 63.8852
# Epoch 7/50
#  - 0s - loss: 64.1802
# Epoch 8/50
#  - 0s - loss: 64.7696
# Epoch 9/50
#  - 0s - loss: 64.0048
# Epoch 10/50
#  - 0s - loss: 64.5708
# Epoch 11/50
#  - 0s - loss: 64.3738
# Epoch 12/50
#  - 0s - loss: 64.1555
# Epoch 13/50
#  - 0s - loss: 64.2053
# Epoch 14/50
#  - 0s - loss: 64.0362
# Epoch 15/50
#  - 0s - loss: 64.5336
# Epoch 16/50
#  - 0s - loss: 64.2989
# Epoch 17/50
#  - 0s - loss: 64.1427
# Epoch 18/50
#  - 0s - loss: 64.6647
# Epoch 19/50
#  - 0s - loss: 64.0247
# Epoch 20/50
#  - 0s - loss: 64.4069
# Epoch 21/50
#  - 0s - loss: 63.8540
# Epoch 22/50
#  - 0s - loss: 65.8239
# Epoch 23/50
#  - 0s - loss: 64.6869
# Epoch 24/50
#  - 0s - loss: 63.9381
# Epoch 25/50
#  - 0s - loss: 64.2052
# Epoch 26/50
#  - 0s - loss: 64.0599
# Epoch 27/50
#  - 0s - loss: 63.9240
# Epoch 28/50
#  - 0s - loss: 65.3283
# Epoch 29/50
#  - 0s - loss: 63.7709
# Epoch 30/50
#  - 0s - loss: 64.0234
# Epoch 31/50
#  - 0s - loss: 64.8762
# Epoch 32/50
#  - 0s - loss: 64.0971
# Epoch 33/50
#  - 0s - loss: 63.9021
# Epoch 34/50
#  - 0s - loss: 63.9962
# Epoch 35/50
#  - 0s - loss: 63.6860
# Epoch 36/50
#  - 0s - loss: 64.4475
# Epoch 37/50
#  - 0s - loss: 64.5714
# Epoch 38/50
#  - 0s - loss: 64.3454
# Epoch 39/50
#  - 0s - loss: 65.1300
# Epoch 40/50
#  - 0s - loss: 65.9610
# Epoch 41/50
#  - 0s - loss: 63.8637
# Epoch 42/50
#  - 0s - loss: 64.4283
# Epoch 43/50
#  - 0s - loss: 64.0270
# Epoch 44/50
#  - 0s - loss: 63.9126
# Epoch 45/50
#  - 0s - loss: 65.6065
# Epoch 46/50
#  - 0s - loss: 64.4189
# Epoch 47/50
#  - 0s - loss: 64.9204
# Epoch 48/50
#  - 0s - loss: 64.2319
# Epoch 49/50
#  - 0s - loss: 64.4440
# Epoch 50/50
#  - 0s - loss: 64.2783
# Duration (seconds): 1.6576001644134521
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.2666
# Epoch 2/50
#  - 0s - loss: 64.0880
# Epoch 3/50
#  - 0s - loss: 63.9842
# Epoch 4/50
#  - 0s - loss: 64.0808
# Epoch 5/50
#  - 0s - loss: 64.1231
# Epoch 6/50
#  - 0s - loss: 64.6878
# Epoch 7/50
#  - 0s - loss: 66.0671
# Epoch 8/50
#  - 0s - loss: 64.1578
# Epoch 9/50
#  - 0s - loss: 64.2450
# Epoch 10/50
#  - 0s - loss: 64.2025
# Epoch 11/50
#  - 0s - loss: 63.9819
# Epoch 12/50
#  - 0s - loss: 64.6323
# Epoch 13/50
#  - 0s - loss: 64.4151
# Epoch 14/50
#  - 0s - loss: 64.1726
# Epoch 15/50
#  - 0s - loss: 64.2379
# Epoch 16/50
#  - 0s - loss: 65.0468
# Epoch 17/50
#  - 0s - loss: 64.1151
# Epoch 18/50
#  - 0s - loss: 64.7944
# Epoch 19/50
#  - 0s - loss: 63.8430
# Epoch 20/50
#  - 0s - loss: 63.6130
# Epoch 21/50
#  - 0s - loss: 63.9864
# Epoch 22/50
#  - 0s - loss: 64.0716
# Epoch 23/50
#  - 0s - loss: 64.1023
# Epoch 24/50
#  - 0s - loss: 64.4654
# Epoch 25/50
#  - 0s - loss: 64.5427
# Epoch 26/50
#  - 0s - loss: 64.0478
# Epoch 27/50
#  - 0s - loss: 64.7766
# Epoch 28/50
#  - 0s - loss: 64.4282
# Epoch 29/50
#  - 0s - loss: 65.7074
# Epoch 30/50
#  - 0s - loss: 64.4728
# Epoch 31/50
#  - 0s - loss: 64.8500
# Epoch 32/50
#  - 0s - loss: 64.1263
# Epoch 33/50
#  - 0s - loss: 64.3979
# Epoch 34/50
#  - 0s - loss: 64.0666
# Epoch 35/50
#  - 0s - loss: 63.9034
# Epoch 36/50
#  - 0s - loss: 63.8451
# Epoch 37/50
#  - 0s - loss: 63.9825
# Epoch 38/50
#  - 0s - loss: 64.1541
# Epoch 39/50
#  - 0s - loss: 63.7243
# Epoch 40/50
#  - 0s - loss: 63.9455
# Epoch 41/50
#  - 0s - loss: 64.1680
# Epoch 42/50
#  - 0s - loss: 64.0526
# Epoch 43/50
#  - 0s - loss: 63.9385
# Epoch 44/50
#  - 0s - loss: 63.9996
# Epoch 45/50
#  - 0s - loss: 64.7146
# Epoch 46/50
#  - 0s - loss: 64.0425
# Epoch 47/50
#  - 0s - loss: 63.9341
# Epoch 48/50
#  - 0s - loss: 64.3694
# Epoch 49/50
#  - 0s - loss: 65.2559
# Epoch 50/50
#  - 0s - loss: 64.2804
# Duration (seconds): 1.708225965499878
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.3502
# Epoch 2/50
#  - 0s - loss: 63.8393
# Epoch 3/50
#  - 0s - loss: 65.0039
# Epoch 4/50
#  - 0s - loss: 64.0931
# Epoch 5/50
#  - 0s - loss: 63.7434
# Epoch 6/50
#  - 0s - loss: 64.1268
# Epoch 7/50
#  - 0s - loss: 63.9165
# Epoch 8/50
#  - 0s - loss: 64.5347
# Epoch 9/50
#  - 0s - loss: 64.3081
# Epoch 10/50
#  - 0s - loss: 64.4462
# Epoch 11/50
#  - 0s - loss: 64.2540
# Epoch 12/50
#  - 0s - loss: 63.5737
# Epoch 13/50
#  - 0s - loss: 64.2086
# Epoch 14/50
#  - 0s - loss: 64.1323
# Epoch 15/50
#  - 0s - loss: 63.8235
# Epoch 16/50
#  - 0s - loss: 64.0136
# Epoch 17/50
#  - 0s - loss: 65.0322
# Epoch 18/50
#  - 0s - loss: 63.8843
# Epoch 19/50
#  - 0s - loss: 64.1142
# Epoch 20/50
#  - 0s - loss: 64.1833
# Epoch 21/50
#  - 0s - loss: 63.8816
# Epoch 22/50
#  - 0s - loss: 64.5208
# Epoch 23/50
#  - 0s - loss: 67.1651
# Epoch 24/50
#  - 0s - loss: 65.1215
# Epoch 25/50
#  - 0s - loss: 64.1473
# Epoch 26/50
#  - 0s - loss: 64.5794
# Epoch 27/50
#  - 0s - loss: 64.7123
# Epoch 28/50
#  - 0s - loss: 64.0126
# Epoch 29/50
#  - 0s - loss: 64.1245
# Epoch 30/50
#  - 0s - loss: 63.6445
# Epoch 31/50
#  - 0s - loss: 63.8463
# Epoch 32/50
#  - 0s - loss: 63.7232
# Epoch 33/50
#  - 0s - loss: 64.2026
# Epoch 34/50
#  - 0s - loss: 64.6168
# Epoch 35/50
#  - 0s - loss: 64.0490
# Epoch 36/50
#  - 0s - loss: 63.7236
# Epoch 37/50
#  - 0s - loss: 64.1777
# Epoch 38/50
#  - 0s - loss: 64.2343
# Epoch 39/50
#  - 0s - loss: 64.1566
# Epoch 40/50
#  - 0s - loss: 64.1497
# Epoch 41/50
#  - 0s - loss: 63.8353
# Epoch 42/50
#  - 0s - loss: 64.3163
# Epoch 43/50
#  - 0s - loss: 64.4649
# Epoch 44/50
#  - 0s - loss: 64.1215
# Epoch 45/50
#  - 0s - loss: 63.9892
# Epoch 46/50
#  - 0s - loss: 64.5498
# Epoch 47/50
#  - 0s - loss: 66.2890
# Epoch 48/50
#  - 0s - loss: 63.9828
# Epoch 49/50
#  - 0s - loss: 64.3102
# Epoch 50/50
#  - 0s - loss: 63.7505
# Duration (seconds): 1.6473758220672607
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.0565
# Epoch 2/50
#  - 0s - loss: 64.7897
# Epoch 3/50
#  - 0s - loss: 64.9633
# Epoch 4/50
#  - 0s - loss: 65.6139
# Epoch 5/50
#  - 0s - loss: 64.1669
# Epoch 6/50
#  - 0s - loss: 63.7266
# Epoch 7/50
#  - 0s - loss: 65.3687
# Epoch 8/50
#  - 0s - loss: 64.0069
# Epoch 9/50
#  - 0s - loss: 64.0429
# Epoch 10/50
#  - 0s - loss: 63.9486
# Epoch 11/50
#  - 0s - loss: 64.9741
# Epoch 12/50
#  - 0s - loss: 64.6129
# Epoch 13/50
#  - 0s - loss: 64.7714
# Epoch 14/50
#  - 0s - loss: 64.0136
# Epoch 15/50
#  - 0s - loss: 64.5091
# Epoch 16/50
#  - 0s - loss: 63.8867
# Epoch 17/50
#  - 0s - loss: 64.2920
# Epoch 18/50
#  - 0s - loss: 64.1894
# Epoch 19/50
#  - 0s - loss: 64.9987
# Epoch 20/50
#  - 0s - loss: 64.1733
# Epoch 21/50
#  - 0s - loss: 64.0755
# Epoch 22/50
#  - 0s - loss: 63.8242
# Epoch 23/50
#  - 0s - loss: 64.1781
# Epoch 24/50
#  - 0s - loss: 64.0959
# Epoch 25/50
#  - 0s - loss: 64.1340
# Epoch 26/50
#  - 0s - loss: 64.2627
# Epoch 27/50
# ...
# Epoch 2/50
#  - 0s - loss: 64.6887
# Epoch 3/50
#  - 0s - loss: 64.6464
# Epoch 4/50
#  - 0s - loss: 66.7328
# Epoch 5/50
#  - 0s - loss: 65.7926
# Epoch 6/50
#  - 0s - loss: 64.4342
# Epoch 7/50
#  - 0s - loss: 64.2439
# Epoch 8/50
#  - 0s - loss: 63.8925
# Epoch 9/50
#  - 0s - loss: 64.7482
# Epoch 10/50
#  - 0s - loss: 64.0084
# Epoch 11/50
#  - 0s - loss: 64.3551
# Epoch 12/50
#  - 0s - loss: 63.8291
# Epoch 13/50
#  - 0s - loss: 63.8294
# Epoch 14/50
#  - 0s - loss: 64.3176
# Epoch 15/50
#  - 0s - loss: 64.0011
# Epoch 16/50
#  - 0s - loss: 65.2911
# Epoch 17/50
#  - 0s - loss: 63.9288
# Epoch 18/50
#  - 0s - loss: 64.2463
# Epoch 19/50
#  - 0s - loss: 63.8108
# Epoch 20/50
#  - 0s - loss: 64.2286
# Epoch 21/50
#  - 0s - loss: 63.7548
# Epoch 22/50
#  - 0s - loss: 64.3668
# Epoch 23/50
#  - 0s - loss: 63.6498
# Epoch 24/50
#  - 0s - loss: 64.0419
# Epoch 25/50
#  - 0s - loss: 63.9230
# Epoch 26/50
#  - 0s - loss: 65.0356
# Epoch 27/50
#  - 0s - loss: 64.4870
# Epoch 28/50
#  - 0s - loss: 63.6852
# Epoch 29/50
#  - 0s - loss: 64.4166
# Epoch 30/50
#  - 0s - loss: 64.0259
# Epoch 31/50
#  - 0s - loss: 64.9079
# Epoch 32/50
#  - 0s - loss: 64.1295
# Epoch 33/50
#  - 0s - loss: 63.9876
# Epoch 34/50
#  - 0s - loss: 63.8941
# Epoch 35/50
#  - 0s - loss: 64.3241
# Epoch 36/50
#  - 0s - loss: 64.9604
# Epoch 37/50
#  - 0s - loss: 64.0147
# Epoch 38/50
#  - 0s - loss: 64.5808
# Epoch 39/50
#  - 0s - loss: 63.8638
# Epoch 40/50
#  - 0s - loss: 63.8689
# Epoch 41/50
#  - 0s - loss: 64.0810
# Epoch 42/50
#  - 0s - loss: 63.6457
# Epoch 43/50
#  - 0s - loss: 63.6431
# Epoch 44/50
#  - 0s - loss: 64.1329
# Epoch 45/50
#  - 0s - loss: 63.8100
# Epoch 46/50
#  - 0s - loss: 63.7170
# Epoch 47/50
#  - 0s - loss: 64.1845
# Epoch 48/50
#  - 0s - loss: 63.6743
# Epoch 49/50
#  - 0s - loss: 63.9665
# Epoch 50/50
#  - 0s - loss: 64.3188
# Duration (seconds): 2.0116028785705566
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 63.5141
# Epoch 2/50
#  - 0s - loss: 64.1342
# Epoch 3/50
#  - 0s - loss: 64.5905
# Epoch 4/50
#  - 0s - loss: 64.1424
# Epoch 5/50
#  - 0s - loss: 63.9763
# Epoch 6/50
#  - 0s - loss: 64.0566
# Epoch 7/50
#  - 0s - loss: 64.9276
# Epoch 8/50
#  - 0s - loss: 63.5528
# Epoch 9/50
#  - 0s - loss: 63.9075
# Epoch 10/50
#  - 0s - loss: 64.5735
# Epoch 11/50
#  - 0s - loss: 63.8476
# Epoch 12/50
#  - 0s - loss: 64.1723
# Epoch 13/50
#  - 0s - loss: 64.6639
# Epoch 14/50
#  - 0s - loss: 64.7563
# Epoch 15/50
#  - 0s - loss: 63.9378
# Epoch 16/50
#  - 0s - loss: 64.8550
# Epoch 17/50
#  - 0s - loss: 64.1681
# Epoch 18/50
#  - 0s - loss: 63.8282
# Epoch 19/50
#  - 0s - loss: 64.6682
# Epoch 20/50
#  - 0s - loss: 64.0351
# Epoch 21/50
#  - 0s - loss: 63.7352
# Epoch 22/50
#  - 0s - loss: 64.0205
# Epoch 23/50
#  - 0s - loss: 63.7954
# Epoch 24/50
#  - 0s - loss: 64.9191
# Epoch 25/50
#  - 0s - loss: 63.9542
# Epoch 26/50
#  - 0s - loss: 64.6906
# Epoch 27/50
#  - 0s - loss: 64.7730
# Epoch 28/50
#  - 0s - loss: 63.6909
# Epoch 29/50
#  - 0s - loss: 64.6983
# Epoch 30/50
#  - 0s - loss: 63.7009
# Epoch 31/50
#  - 0s - loss: 64.4437
# Epoch 32/50
#  - 0s - loss: 64.1120
# Epoch 33/50
#  - 0s - loss: 63.6053
# Epoch 34/50
#  - 0s - loss: 64.1071
# Epoch 35/50
#  - 0s - loss: 64.4928
# Epoch 36/50
#  - 0s - loss: 63.9453
# Epoch 37/50
#  - 0s - loss: 64.3432
# Epoch 38/50
#  - 0s - loss: 64.1180
# Epoch 39/50
#  - 0s - loss: 64.2063
# Epoch 40/50
#  - 0s - loss: 64.4608
# Epoch 41/50
#  - 0s - loss: 64.6987
# Epoch 42/50
#  - 0s - loss: 64.5447
# Epoch 43/50
#  - 0s - loss: 63.7726
# Epoch 44/50
#  - 0s - loss: 64.0161
# Epoch 45/50
#  - 0s - loss: 64.2003
# Epoch 46/50
#  - 0s - loss: 64.4749
# Epoch 47/50
#  - 0s - loss: 64.6550
# Epoch 48/50
#  - 0s - loss: 63.8569
# Epoch 49/50
#  - 0s - loss: 64.2355
# Epoch 50/50
#  - 0s - loss: 63.6637
# Duration (seconds): 1.7853989601135254
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 63.8198
# Epoch 2/50
#  - 0s - loss: 63.9249
# Epoch 3/50
#  - 0s - loss: 64.4957
# Epoch 4/50
#  - 0s - loss: 63.8442
# Epoch 5/50
#  - 0s - loss: 64.0322
# Epoch 6/50
#  - 0s - loss: 64.4745
# Epoch 7/50
#  - 0s - loss: 64.0277
# Epoch 8/50
#  - 0s - loss: 64.1449
# Epoch 9/50
#  - 0s - loss: 63.7143
# Epoch 10/50
#  - 0s - loss: 64.2716
# Epoch 11/50
#  - 0s - loss: 64.3287
# Epoch 12/50
#  - 0s - loss: 63.7605
# Epoch 13/50
#  - 0s - loss: 64.7780
# Epoch 14/50
#  - 0s - loss: 63.7704
# Epoch 15/50
#  - 0s - loss: 64.5321
# Epoch 16/50
#  - 0s - loss: 65.4672
# Epoch 17/50
#  - 0s - loss: 64.6949
# Epoch 18/50
#  - 0s - loss: 64.0591
# Epoch 19/50
#  - 0s - loss: 64.1213
# Epoch 20/50
#  - 0s - loss: 63.8595
# Epoch 21/50
#  - 0s - loss: 63.5771
# Epoch 22/50
#  - 0s - loss: 63.7781
# Epoch 23/50
#  - 0s - loss: 65.0232
# Epoch 24/50
#  - 0s - loss: 64.0707
# Epoch 25/50
#  - 0s - loss: 64.1439
# Epoch 26/50
#  - 0s - loss: 64.0699
# Epoch 27/50
#  - 0s - loss: 64.0537
# Epoch 28/50
#  - 0s - loss: 63.9657
# Epoch 29/50
#  - 0s - loss: 63.8922
# Epoch 30/50
#  - 0s - loss: 64.4540
# Epoch 31/50
#  - 0s - loss: 63.7602
# Epoch 32/50
#  - 0s - loss: 65.5762
# Epoch 33/50
#  - 0s - loss: 63.9313
# Epoch 34/50
#  - 0s - loss: 64.3432
# Epoch 35/50
#  - 0s - loss: 64.1033
# Epoch 36/50
#  - 0s - loss: 63.8512
# Epoch 37/50
#  - 0s - loss: 64.0929
# Epoch 38/50
#  - 0s - loss: 63.8989
# Epoch 39/50
#  - 0s - loss: 63.6018
# Epoch 40/50
#  - 0s - loss: 63.5923
# Epoch 41/50
#  - 0s - loss: 64.5283
# Epoch 42/50
#  - 0s - loss: 64.9558
# Epoch 43/50
#  - 0s - loss: 63.9412
# Epoch 44/50
#  - 0s - loss: 63.7627
# Epoch 45/50
#  - 0s - loss: 63.8230
# Epoch 46/50
#  - 0s - loss: 63.8501
# Epoch 47/50
#  - 0s - loss: 63.7727
# Epoch 48/50
#  - 0s - loss: 64.8839
# Epoch 49/50
#  - 0s - loss: 63.8822
# Epoch 50/50
#  - 0s - loss: 64.0462
# Duration (seconds): 1.8403480052947998
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.8016
# Epoch 2/50
#  - 0s - loss: 63.8138
# Epoch 3/50
#  - 0s - loss: 64.2605
# Epoch 4/50
#  - 0s - loss: 63.9300
# Epoch 5/50
#  - 0s - loss: 64.3662
# Epoch 6/50
#  - 0s - loss: 64.4204
# Epoch 7/50
#  - 0s - loss: 64.1153
# Epoch 8/50
#  - 0s - loss: 63.7299
# Epoch 9/50
#  - 0s - loss: 63.7335
# Epoch 10/50
#  - 0s - loss: 63.7947
# Epoch 11/50
#  - 0s - loss: 64.4382
# Epoch 12/50
#  - 0s - loss: 65.4216
# Epoch 13/50
#  - 0s - loss: 65.8207
# Epoch 14/50
#  - 0s - loss: 64.2204
# Epoch 15/50
#  - 0s - loss: 63.9536
# Epoch 16/50
#  - 0s - loss: 63.7026
# Epoch 17/50
#  - 0s - loss: 63.7793
# Epoch 18/50
#  - 0s - loss: 63.6317
# Epoch 19/50
#  - 0s - loss: 63.9887
# Epoch 20/50
#  - 0s - loss: 64.2492
# Epoch 21/50
#  - 0s - loss: 64.3206
# Epoch 22/50
#  - 0s - loss: 63.9753
# Epoch 23/50
#  - 0s - loss: 64.9418
# Epoch 24/50
#  - 0s - loss: 64.7323
# Epoch 25/50
#  - 0s - loss: 65.6760
# Epoch 26/50
#  - 0s - loss: 64.3205
# Epoch 27/50
#  - 0s - loss: 64.1268
# Epoch 28/50
#  - 0s - loss: 64.1211
# Epoch 29/50
#  - 0s - loss: 64.2482
# Epoch 30/50
#  - 0s - loss: 64.1205
# Epoch 31/50
#  - 0s - loss: 64.4912
# Epoch 32/50
#  - 0s - loss: 64.8004
# Epoch 33/50
#  - 0s - loss: 63.7081
# Epoch 34/50
#  - 0s - loss: 63.7120
# Epoch 35/50
#  - 0s - loss: 64.3916
# Epoch 36/50
#  - 0s - loss: 65.4264
# Epoch 37/50
#  - 0s - loss: 65.5492
# Epoch 38/50
#  - 0s - loss: 63.8555
# Epoch 39/50
#  - 0s - loss: 63.7961
# Epoch 40/50
#  - 0s - loss: 64.5410
# Epoch 41/50
#  - 0s - loss: 64.2101
# Epoch 42/50
#  - 0s - loss: 64.3155
# Epoch 43/50
#  - 0s - loss: 64.3683
# Epoch 44/50
#  - 0s - loss: 64.0353
# Epoch 45/50
#  - 0s - loss: 64.1076
# Epoch 46/50
#  - 0s - loss: 63.7657
# Epoch 47/50
#  - 0s - loss: 63.6733
# Epoch 48/50
#  - 0s - loss: 64.1157
# Epoch 49/50
#  - 0s - loss: 65.2038
# Epoch 50/50
#  - 0s - loss: 66.5499
# Duration (seconds): 1.6935200691223145
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.6765
# Epoch 2/50
#  - 0s - loss: 64.1452
# Epoch 3/50
#  - 0s - loss: 63.6337
# Epoch 4/50
#  - 0s - loss: 64.6106
# Epoch 5/50
#  - 0s - loss: 63.7473
# Epoch 6/50
#  - 0s - loss: 64.8363
# Epoch 7/50
#  - 0s - loss: 63.9723
# Epoch 8/50
#  - 0s - loss: 64.0430
# Epoch 9/50
#  - 0s - loss: 64.8470
# Epoch 10/50
#  - 0s - loss: 63.7047
# Epoch 11/50
#  - 0s - loss: 64.4829
# Epoch 12/50
#  - 0s - loss: 64.9725
# Epoch 13/50
#  - 0s - loss: 64.1208
# Epoch 14/50
#  - 0s - loss: 64.1307
# Epoch 15/50
#  - 0s - loss: 63.7398
# Epoch 16/50
#  - 0s - loss: 66.1352
# Epoch 17/50
#  - 0s - loss: 64.3189
# Epoch 18/50
#  - 0s - loss: 63.8348
# Epoch 19/50
#  - 0s - loss: 63.9921
# Epoch 20/50
#  - 0s - loss: 64.4075
# Epoch 21/50
#  - 0s - loss: 64.3372
# Epoch 22/50
#  - 0s - loss: 63.9910
# Epoch 23/50
#  - 0s - loss: 64.0948
# Epoch 24/50
#  - 0s - loss: 63.9818
# Epoch 25/50
#  - 0s - loss: 63.8244
# Epoch 26/50
#  - 0s - loss: 63.7173
# Epoch 27/50
#  - 0s - loss: 64.0010
# Epoch 28/50
#  - 0s - loss: 63.8631
# Epoch 29/50
#  - 0s - loss: 65.5420
# Epoch 30/50
#  - 0s - loss: 63.9607
# Epoch 31/50
#  - 0s - loss: 63.6831
# Epoch 32/50
#  - 0s - loss: 64.5203
# Epoch 33/50
#  - 0s - loss: 64.5311
# Epoch 34/50
#  - 0s - loss: 63.7892
# Epoch 35/50
#  - 0s - loss: 63.8419
# Epoch 36/50
#  - 0s - loss: 63.8789
# Epoch 37/50
#  - 0s - loss: 64.1601
# Epoch 38/50
#  - 0s - loss: 64.7041
# Epoch 39/50
#  - 0s - loss: 63.7676
# Epoch 40/50
#  - 0s - loss: 63.9912
# Epoch 41/50
#  - 0s - loss: 64.4212
# Epoch 42/50
#  - 0s - loss: 63.8860
# Epoch 43/50
#  - 0s - loss: 64.6024
# Epoch 44/50
#  - 0s - loss: 64.0915
# Epoch 45/50
#  - 0s - loss: 64.3173
# Epoch 46/50
#  - 0s - loss: 63.7960
# Epoch 47/50
#  - 0s - loss: 64.1440
# Epoch 48/50
#  - 0s - loss: 65.0218
# Epoch 49/50
#  - 0s - loss: 64.1151
# Epoch 50/50
#  - 0s - loss: 68.0033
# Duration (seconds): 1.8035218715667725
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.4994
# Epoch 2/50
#  - 0s - loss: 66.2451
# Epoch 3/50
#  - 0s - loss: 64.8609
# Epoch 4/50
#  - 0s - loss: 64.6206
# Epoch 5/50
#  - 0s - loss: 64.2223
# Epoch 6/50
#  - 0s - loss: 63.8308
# Epoch 7/50
#  - 0s - loss: 63.8452
# Epoch 8/50
#  - 0s - loss: 64.0841
# Epoch 9/50
#  - 0s - loss: 64.3255
# Epoch 10/50
#  - 0s - loss: 64.7718
# Epoch 11/50
#  - 0s - loss: 64.9056
# Epoch 12/50
#  - 0s - loss: 63.8327
# Epoch 13/50
#  - 0s - loss: 63.7394
# Epoch 14/50
#  - 0s - loss: 63.8063
# Epoch 15/50
#  - 0s - loss: 64.0369
# Epoch 16/50
#  - 0s - loss: 64.5547
# Epoch 17/50
#  - 0s - loss: 63.7471
# Epoch 18/50
#  - 0s - loss: 64.6349
# Epoch 19/50
#  - 0s - loss: 64.4068
# Epoch 20/50
#  - 0s - loss: 63.8083
# Epoch 21/50
#  - 0s - loss: 63.9076
# Epoch 22/50
#  - 0s - loss: 64.1426
# Epoch 23/50
#  - 0s - loss: 63.9734
# Epoch 24/50
#  - 0s - loss: 64.1405
# Epoch 25/50
#  - 0s - loss: 64.0695
# Epoch 26/50
#  - 0s - loss: 63.6161
# Epoch 27/50
#  - 0s - loss: 64.3994
# Epoch 28/50
#  - 0s - loss: 63.8156
# Epoch 29/50
#  - 0s - loss: 64.1506
# Epoch 30/50
#  - 0s - loss: 64.0747
# Epoch 31/50
#  - 0s - loss: 63.9823
# Epoch 32/50
#  - 0s - loss: 63.8723
# Epoch 33/50
#  - 0s - loss: 63.8074
# Epoch 34/50
#  - 0s - loss: 64.4638
# Epoch 35/50
#  - 0s - loss: 63.9829
# Epoch 36/50
#  - 0s - loss: 65.4043
# Epoch 37/50
#  - 0s - loss: 64.0311
# Epoch 38/50
#  - 0s - loss: 64.1409
# Epoch 39/50
#  - 0s - loss: 63.7964
# Epoch 40/50
#  - 0s - loss: 64.6687
# Epoch 41/50
#  - 0s - loss: 63.7817
# Epoch 42/50
#  - 0s - loss: 63.6248
# Epoch 43/50
#  - 0s - loss: 63.7745
# Epoch 44/50
#  - 0s - loss: 63.7632
# Epoch 45/50
#  - 0s - loss: 64.4785
# Epoch 46/50
#  - 0s - loss: 63.7048
# Epoch 47/50
#  - 0s - loss: 63.8565
# Epoch 48/50
#  - 0s - loss: 64.5118
# Epoch 49/50
#  - 0s - loss: 64.3816
# Epoch 50/50
#  - 0s - loss: 64.5187
# Duration (seconds): 1.433332920074463
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 66.6658
# Epoch 2/50
#  - 0s - loss: 63.9114
# Epoch 3/50
#  - 0s - loss: 64.2731
# Epoch 4/50
#  - 0s - loss: 64.8013
# Epoch 5/50
#  - 0s - loss: 63.8711
# Epoch 6/50
#  - 0s - loss: 64.2525
# Epoch 7/50
#  - 0s - loss: 64.4971
# Epoch 8/50
#  - 0s - loss: 64.7204
# Epoch 9/50
#  - 0s - loss: 64.1309
# Epoch 10/50
#  - 0s - loss: 64.3290
# Epoch 11/50
#  - 0s - loss: 64.6345
# Epoch 12/50
#  - 0s - loss: 63.6952
# Epoch 13/50
#  - 0s - loss: 63.9711
# Epoch 14/50
#  - 0s - loss: 63.6268
# Epoch 15/50
#  - 0s - loss: 63.6069
# Epoch 16/50
#  - 0s - loss: 63.9121
# Epoch 17/50
#  - 0s - loss: 65.3167
# Epoch 18/50
#  - 0s - loss: 64.0729
# Epoch 19/50
#  - 0s - loss: 63.6928
# Epoch 20/50
#  - 0s - loss: 63.9536
# Epoch 21/50
#  - 0s - loss: 64.1461
# Epoch 22/50
#  - 0s - loss: 64.2878
# Epoch 23/50
#  - 0s - loss: 63.6806
# Epoch 24/50
#  - 0s - loss: 64.4855
# Epoch 25/50
#  - 0s - loss: 64.3529
# Epoch 26/50
#  - 0s - loss: 64.0144
# Epoch 27/50
#  - 0s - loss: 63.6981
# Epoch 28/50
#  - 0s - loss: 63.7987
# Epoch 29/50
#  - 0s - loss: 64.2639
# Epoch 30/50
#  - 0s - loss: 64.0965
# Epoch 31/50
#  - 0s - loss: 64.3973
# Epoch 32/50
#  - 0s - loss: 64.5385
# Epoch 33/50
#  - 0s - loss: 64.2664
# Epoch 34/50
#  - 0s - loss: 63.8690
# Epoch 35/50
#  - 0s - loss: 63.8699
# Epoch 36/50
#  - 0s - loss: 64.3855
# Epoch 37/50
#  - 0s - loss: 64.6385
# Epoch 38/50
#  - 0s - loss: 64.0806
# Epoch 39/50
#  - 0s - loss: 64.6981
# Epoch 40/50
#  - 0s - loss: 63.6500
# Epoch 41/50
#  - 0s - loss: 63.9631
# Epoch 42/50
#  - 0s - loss: 64.0666
# Epoch 43/50
#  - 0s - loss: 64.1920
# Epoch 44/50
#  - 0s - loss: 63.8026
# Epoch 45/50
#  - 0s - loss: 64.1704
# Epoch 46/50
#  - 0s - loss: 63.7178
# Epoch 47/50
#  - 0s - loss: 63.9201
# Epoch 48/50
#  - 0s - loss: 63.8021
# Epoch 49/50
#  - 0s - loss: 64.4480
# Epoch 50/50
#  - 0s - loss: 64.4064
# Duration (seconds): 1.6892149448394775
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 64.6281
# Epoch 2/50
#  - 0s - loss: 64.1166
# Epoch 3/50
#  - 0s - loss: 63.7845
# Epoch 4/50
#  - 0s - loss: 64.0893
# Epoch 5/50
#  - 0s - loss: 63.7924
# Epoch 6/50
#  - 0s - loss: 63.9863
# Epoch 7/50
#  - 0s - loss: 64.5898
# Epoch 8/50
#  - 0s - loss: 64.6485
# Epoch 9/50
#  - 0s - loss: 63.9046
# Epoch 10/50
#  - 0s - loss: 64.2232
# Epoch 11/50
#  - 0s - loss: 64.1113
# Epoch 12/50
#  - 0s - loss: 63.8006
# Epoch 13/50
#  - 0s - loss: 63.9347
# Epoch 14/50
#  - 0s - loss: 63.6513
# Epoch 15/50
#  - 0s - loss: 63.7658
# Epoch 16/50
#  - 0s - loss: 64.6160
# Epoch 17/50
#  - 0s - loss: 64.2415
# Epoch 18/50
#  - 0s - loss: 63.7613
# Epoch 19/50
#  - 0s - loss: 63.8826
# Epoch 20/50
#  - 0s - loss: 63.9123
# Epoch 21/50
#  - 0s - loss: 63.8632
# Epoch 22/50
#  - 0s - loss: 63.7877
# Epoch 23/50
#  - 0s - loss: 65.3623
# Epoch 24/50
#  - 0s - loss: 65.8910
# Epoch 25/50
#  - 0s - loss: 64.2893
# Epoch 26/50
#  - 0s - loss: 64.8100
# Epoch 27/50
#  - 0s - loss: 63.7930
# Epoch 28/50
#  - 0s - loss: 64.2177
# Epoch 29/50
#  - 0s - loss: 64.6964
# Epoch 30/50
#  - 0s - loss: 63.6166
# Epoch 31/50
#  - 0s - loss: 64.2516
# Epoch 32/50
#  - 0s - loss: 64.0566
# Epoch 33/50
#  - 0s - loss: 63.9254
# Epoch 34/50
#  - 0s - loss: 64.2486
# Epoch 35/50
#  - 0s - loss: 65.0047
# Epoch 36/50
#  - 0s - loss: 64.0033
# Epoch 37/50
#  - 0s - loss: 63.8271
# Epoch 38/50
#  - 0s - loss: 64.5878
# Epoch 39/50
#  - 0s - loss: 65.2223
# Epoch 40/50
#  - 0s - loss: 63.5331
# Epoch 41/50
#  - 0s - loss: 63.9381
# Epoch 42/50
#  - 0s - loss: 64.3713
# Epoch 43/50
#  - 0s - loss: 63.5683
# Epoch 44/50
#  - 0s - loss: 64.4980
# Epoch 45/50
#  - 0s - loss: 63.4272
# Epoch 46/50
#  - 0s - loss: 64.0178
# Epoch 47/50
#  - 0s - loss: 63.9267
# Epoch 48/50
#  - 0s - loss: 63.7658
# Epoch 49/50
#  - 0s - loss: 63.9958
# Epoch 50/50
#  - 0s - loss: 64.6441
# Duration (seconds): 1.6843681335449219
# Finished - 50 times.
# And the list of mean squared errors : [248.76616595796298, 134.13344300396318, 94.94006573746817, 85.5210736172868, 77.31046563250098, 71.86630396374898, 70.37635063141533, 64.2973270467106, 63.97501624508346, 65.27528008189218, 63.55280222145062, 62.332000037498155, 61.961894716015856, 63.00399941392259, 62.551235380326844, 62.18275193588221, 62.47077582764886, 60.70527506768146, 60.69964008752018, 60.92253029658082, 61.12486718143477, 60.318723514413655, 60.475388919594366, 60.62466362361406, 60.344483481476075, 60.347857615544044, 61.35599796149987, 60.1154413273966, 60.01217847373633, 61.09360944087985, 60.54731263321179, 60.15694398664075, 60.33737922396463, 60.636243519097796, 60.391495583086346, 59.99676340699423, 60.05941431912476, 61.043479113621785, 60.46493157980935, 59.99326437267558, 61.283290800759666, 61.26318954525544, 61.517716909120985, 60.61766703686159, 60.77553520538325, 62.14768923106299, 63.25916840823728, 62.648210899409605, 61.36028702741649, 59.96637688003812]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 68.42 and 28.34, respectively

# %% [markdown]
# ### Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of not normalized data is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline-not normalized (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline = get_report(name_of_case, mean_mse, std_mse)
df_baseline
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     68.42              28.34

# %% [markdown]
# ## Part B: Normalized data

# %% [markdown]
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
# How does the mean of the mean squared errors compare to that from Step A?

# %% [markdown]
# ### Data before normalization

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %% [markdown]
# ### Data after normalization

# %% [markdown]
# We will normalize the data by substracting the mean and dividing by the standard deviation

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_colsnorm = predictors_norm.shape[1] #number of predictors

# %% [markdown]
# Defining the regression model as above

# %%
#define the regression model with one hidden layer
def regression_model():
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(n_colsnorm,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Creating the regression model

# %%
model = regression_model()

# %% [markdown]
# Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=24)   
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)

# %% [markdown]
# Train the model on the training data using 50 epochs

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
#  - 0s - loss: 1580.2936
# Epoch 2/50
#  - 0s - loss: 1565.4569
# Epoch 3/50
#  - 0s - loss: 1550.2420
# Epoch 4/50
#  - 0s - loss: 1534.3472
# Epoch 5/50
#  - 0s - loss: 1517.6791
# Epoch 6/50
#  - 0s - loss: 1500.3521
# Epoch 7/50
#  - 0s - loss: 1482.0560
# Epoch 8/50
#  - 0s - loss: 1462.7950
# Epoch 9/50
#  - 0s - loss: 1442.5782
# Epoch 10/50
#  - 0s - loss: 1420.9095
# Epoch 11/50
#  - 0s - loss: 1398.4737
# Epoch 12/50
#  - 0s - loss: 1374.6691
# Epoch 13/50
#  - 0s - loss: 1349.8286
# Epoch 14/50
#  - 0s - loss: 1324.1022
# Epoch 15/50
#  - 0s - loss: 1297.1598
# Epoch 16/50
#  - 0s - loss: 1269.1467
# Epoch 17/50
#  - 0s - loss: 1240.6282
# Epoch 18/50
#  - 0s - loss: 1210.9761
# Epoch 19/50
#  - 0s - loss: 1180.7707
# Epoch 20/50
#  - 0s - loss: 1149.7748
# Epoch 21/50
#  - 0s - loss: 1118.2775
# Epoch 22/50
#  - 0s - loss: 1086.0821
# Epoch 23/50
#  - 0s - loss: 1053.1280
# Epoch 24/50
#  - 0s - loss: 1019.8849
# Epoch 25/50
#  - 0s - loss: 986.3940
# Epoch 26/50
#  - 0s - loss: 952.3473
# Epoch 27/50
#  - 0s - loss: 917.8836
# Epoch 28/50
#  - 0s - loss: 884.1236
# Epoch 29/50
#  - 0s - loss: 850.5115
# Epoch 30/50
#  - 0s - loss: 817.1543
# Epoch 31/50
#  - 0s - loss: 784.4119
# Epoch 32/50
#  - 0s - loss: 751.8798
# Epoch 33/50
#  - 0s - loss: 720.4175
# Epoch 34/50
#  - 0s - loss: 689.3981
# Epoch 35/50
#  - 0s - loss: 659.4818
# Epoch 36/50
#  - 0s - loss: 630.1766
# Epoch 37/50
#  - 0s - loss: 602.5707
# Epoch 38/50
#  - 0s - loss: 575.3997
# Epoch 39/50
#  - 0s - loss: 549.3891
# Epoch 40/50
#  - 0s - loss: 524.8227
# Epoch 41/50
#  - 0s - loss: 500.8982
# Epoch 42/50
#  - 0s - loss: 478.0918
# Epoch 43/50
#  - 0s - loss: 456.6713
# Epoch 44/50
#  - 0s - loss: 436.0980
# Epoch 45/50
#  - 0s - loss: 416.7909
# Epoch 46/50
#  - 0s - loss: 398.3341
# Epoch 47/50
#  - 0s - loss: 380.7258
# Epoch 48/50
#  - 0s - loss: 364.6730
# Epoch 49/50
#  - 0s - loss: 349.0310
# Epoch 50/50
#  - 0s - loss: 334.7044

# %% [markdown]
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
y_hat = model.predict(X_test)   
mse = mean_squared_error(y_test, y_hat)

# %%
print(mse)
# Out:
# 281.52303027541734

# %% [markdown]
# For the case of not normalized data that we ran in Part A mse = 425.59, for this case with normalized data mse=281.52

# %% [markdown]
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors

# %%
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """   
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn. 
    X = predictors_norm
    y = target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse

# %%
#Function to round the calculation of the mean and std deviation to 2 decimal places
def get_round(score, num_of_digits=2):
    """Get round with given number of decimal digits 
    """
    return round(score, num_of_digits)

#Function to calculate the mean of the list of mean squared errors
def get_mean(list_of_mse_scores):
    """Get mean
    """
    if list_of_mse_scores:
        return get_round(np.mean(list_of_mse_scores))
    return None

#Function to calculate the standard deviation of the list of mean squared errors
def get_standard_deviation(list_of_mse_scores):
    """Get standard deviation
    """
    if list_of_mse_scores:
        return get_round(np.std(list_of_mse_scores))
    return None




#Function to iterate and calculate the mean squared error
def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
    """Generate the mean and the standard deviation of the mean squared errors 
    """
    # Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.    
    list_of_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        list_of_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))
    # end for

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  list_of_mean_squared_errors))
    
    mean_mse = get_mean(list_of_mean_squared_errors)
    std_mse = get_standard_deviation(list_of_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse

# %%
max_iteration = 50
epochs = 50
verbose = 2

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors_norm, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 1548.6876
# Epoch 2/50
#  - 0s - loss: 1529.2276
# Epoch 3/50
#  - 0s - loss: 1509.7447
# Epoch 4/50
#  - 0s - loss: 1489.1789
# Epoch 5/50
#  - 0s - loss: 1468.6996
# Epoch 6/50
#  - 0s - loss: 1447.3221
# Epoch 7/50
#  - 0s - loss: 1424.8728
# Epoch 8/50
#  - 0s - loss: 1401.4830
# Epoch 9/50
#  - 0s - loss: 1377.4726
# Epoch 10/50
#  - 0s - loss: 1352.0345
# Epoch 11/50
#  - 0s - loss: 1325.3782
# Epoch 12/50
#  - 0s - loss: 1297.8572
# Epoch 13/50
#  - 0s - loss: 1269.2500
# Epoch 14/50
#  - 0s - loss: 1239.3789
# Epoch 15/50
#  - 0s - loss: 1208.5932
# Epoch 16/50
#  - 0s - loss: 1177.1423
# Epoch 17/50
#  - 0s - loss: 1144.4714
# Epoch 18/50
#  - 0s - loss: 1111.5249
# Epoch 19/50
#  - 0s - loss: 1078.0212
# Epoch 20/50
#  - 0s - loss: 1043.2538
# Epoch 21/50
#  - 0s - loss: 1008.7613
# Epoch 22/50
#  - 0s - loss: 973.9042
# Epoch 23/50
#  - 0s - loss: 938.6763
# Epoch 24/50
#  - 0s - loss: 903.7288
# Epoch 25/50
#  - 0s - loss: 868.6808
# Epoch 26/50
#  - 0s - loss: 833.9111
# Epoch 27/50
#  - 0s - loss: 799.3184
# Epoch 28/50
#  - 0s - loss: 765.5056
# Epoch 29/50
#  - 0s - loss: 732.0258
# Epoch 30/50
#  - 0s - loss: 698.9078
# Epoch 31/50
#  - 0s - loss: 667.2045
# Epoch 32/50
#  - 0s - loss: 636.0109
# Epoch 33/50
#  - 0s - loss: 606.3381
# Epoch 34/50
#  - 0s - loss: 577.4477
# Epoch 35/50
#  - 0s - loss: 549.7736
# Epoch 36/50
#  - 0s - loss: 523.4186
# Epoch 37/50
#  - 0s - loss: 498.4229
# Epoch 38/50
#  - 0s - loss: 474.1810
# Epoch 39/50
#  - 0s - loss: 451.2080
# Epoch 40/50
#  - 0s - loss: 429.7003
# Epoch 41/50
#  - 0s - loss: 409.1949
# Epoch 42/50
#  - 0s - loss: 390.0108
# Epoch 43/50
#  - 0s - loss: 371.6809
# Epoch 44/50
#  - 0s - loss: 354.8059
# Epoch 45/50
#  - 0s - loss: 339.0281
# Epoch 46/50
#  - 0s - loss: 324.3092
# Epoch 47/50
#  - 0s - loss: 310.6814
# Epoch 48/50
#  - 0s - loss: 298.0813
# Epoch 49/50
#  - 0s - loss: 286.3013
# Epoch 50/50
#  - 0s - loss: 275.6730
# Duration (seconds): 2.354387044906616
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 265.6135
# Epoch 2/50
#  - 0s - loss: 256.5711
# Epoch 3/50
#  - 0s - loss: 248.0276
# Epoch 4/50
#  - 0s - loss: 240.3512
# Epoch 5/50
#  - 0s - loss: 233.3232
# Epoch 6/50
#  - 0s - loss: 226.8536
# Epoch 7/50
#  - 0s - loss: 220.9938
# Epoch 8/50
#  - 0s - loss: 215.7078
# Epoch 9/50
#  - 0s - loss: 210.8400
# Epoch 10/50
#  - 0s - loss: 206.4636
# Epoch 11/50
#  - 0s - loss: 202.4712
# Epoch 12/50
#  - 0s - loss: 198.6605
# Epoch 13/50
#  - 0s - loss: 195.3533
# Epoch 14/50
#  - 0s - loss: 192.2555
# Epoch 15/50
#  - 0s - loss: 189.4046
# Epoch 16/50
#  - 0s - loss: 186.6671
# Epoch 17/50
#  - 0s - loss: 184.2516
# Epoch 18/50
#  - 0s - loss: 182.0160
# Epoch 19/50
#  - 0s - loss: 179.9018
# Epoch 20/50
#  - 0s - loss: 177.8719
# Epoch 21/50
#  - 0s - loss: 176.0074
# Epoch 22/50
#  - 0s - loss: 174.1941
# Epoch 23/50
#  - 0s - loss: 172.5308
# Epoch 24/50
#  - 0s - loss: 170.8904
# Epoch 25/50
#  - 0s - loss: 169.3223
# Epoch 26/50
#  - 0s - loss: 167.8842
# Epoch 27/50
#  - 0s - loss: 166.4312
# Epoch 28/50
#  - 0s - loss: 165.0320
# Epoch 29/50
#  - 0s - loss: 163.7890
# Epoch 30/50
#  - 0s - loss: 162.5094
# Epoch 31/50
#  - 0s - loss: 161.2305
# Epoch 32/50
#  - 0s - loss: 160.0637
# Epoch 33/50
#  - 0s - loss: 158.8925
# Epoch 34/50
#  - 0s - loss: 157.7428
# Epoch 35/50
#  - 0s - loss: 156.6260
# Epoch 36/50
#  - 0s - loss: 155.5960
# Epoch 37/50
#  - 0s - loss: 154.5692
# Epoch 38/50
#  - 0s - loss: 153.4971
# Epoch 39/50
#  - 0s - loss: 152.5227
# Epoch 40/50
#  - 0s - loss: 151.6165
# Epoch 41/50
#  - 0s - loss: 150.7383
# Epoch 42/50
#  - 0s - loss: 149.7156
# Epoch 43/50
#  - 0s - loss: 148.8368
# Epoch 44/50
#  - 0s - loss: 147.9097
# Epoch 45/50
#  - 0s - loss: 147.0806
# Epoch 46/50
#  - 0s - loss: 146.2064
# Epoch 47/50
#  - 0s - loss: 145.3427
# Epoch 48/50
#  - 0s - loss: 144.5442
# Epoch 49/50
#  - 0s - loss: 143.6738
# Epoch 50/50
#  - 0s - loss: 142.8477
# Duration (seconds): 1.7000360488891602
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 142.1119
# Epoch 2/50
#  - 0s - loss: 141.2175
# Epoch 3/50
#  - 0s - loss: 140.4378
# Epoch 4/50
#  - 0s - loss: 139.5891
# Epoch 5/50
#  - 0s - loss: 138.8335
# Epoch 6/50
#  - 0s - loss: 138.0569
# Epoch 7/50
#  - 0s - loss: 137.2940
# Epoch 8/50
#  - 0s - loss: 136.6494
# Epoch 9/50
#  - 0s - loss: 135.8984
# Epoch 10/50
#  - 0s - loss: 135.1488
# Epoch 11/50
#  - 0s - loss: 134.4393
# Epoch 12/50
#  - 0s - loss: 133.7674
# Epoch 13/50
#  - 0s - loss: 133.1506
# Epoch 14/50
#  - 0s - loss: 132.5417
# Epoch 15/50
#  - 0s - loss: 131.8760
# Epoch 16/50
#  - 0s - loss: 131.2795
# Epoch 17/50
#  - 0s - loss: 130.7199
# Epoch 18/50
#  - 0s - loss: 129.9739
# Epoch 19/50
#  - 0s - loss: 129.4203
# Epoch 20/50
#  - 0s - loss: 128.8887
# Epoch 21/50
#  - 0s - loss: 128.3284
# Epoch 22/50
#  - 0s - loss: 127.6778
# Epoch 23/50
#  - 0s - loss: 127.1268
# Epoch 24/50
#  - 0s - loss: 126.5375
# Epoch 25/50
#  - 0s - loss: 125.9879
# Epoch 26/50
#  - 0s - loss: 125.4388
# Epoch 27/50
#  - 0s - loss: 124.8747
# Epoch 28/50
#  - 0s - loss: 124.3845
# Epoch 29/50
#  - 0s - loss: 123.7788
# Epoch 30/50
#  - 0s - loss: 123.2752
# Epoch 31/50
#  - 0s - loss: 122.7163
# Epoch 32/50
#  - 0s - loss: 122.1903
# Epoch 33/50
#  - 0s - loss: 121.6747
# Epoch 34/50
#  - 0s - loss: 121.0895
# Epoch 35/50
#  - 0s - loss: 120.5775
# Epoch 36/50
#  - 0s - loss: 119.9833
# Epoch 37/50
#  - 0s - loss: 119.5350
# Epoch 38/50
#  - 0s - loss: 118.9987
# Epoch 39/50
#  - 0s - loss: 118.4187
# Epoch 40/50
#  - 0s - loss: 117.9273
# Epoch 41/50
#  - 0s - loss: 117.4357
# Epoch 42/50
#  - 0s - loss: 116.8637
# Epoch 43/50
#  - 0s - loss: 116.3752
# Epoch 44/50
#  - 0s - loss: 115.8569
# Epoch 45/50
#  - 0s - loss: 115.3156
# Epoch 46/50
#  - 0s - loss: 114.7876
# Epoch 47/50
#  - 0s - loss: 114.3159
# Epoch 48/50
#  - 0s - loss: 113.7970
# Epoch 49/50
#  - 0s - loss: 113.2505
# Epoch 50/50
#  - 0s - loss: 112.6813
# Duration (seconds): 1.7586500644683838
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 112.1334
# Epoch 2/50
#  - 0s - loss: 111.6634
# Epoch 3/50
#  - 0s - loss: 111.0830
# Epoch 4/50
#  - 0s - loss: 110.5503
# Epoch 5/50
#  - 0s - loss: 109.9708
# Epoch 6/50
#  - 0s - loss: 109.3902
# Epoch 7/50
#  - 0s - loss: 108.8316
# Epoch 8/50
#  - 0s - loss: 108.4429
# Epoch 9/50
#  - 0s - loss: 107.7543
# Epoch 10/50
#  - 0s - loss: 107.2016
# Epoch 11/50
#  - 0s - loss: 106.6094
# Epoch 12/50
#  - 0s - loss: 106.0604
# Epoch 13/50
#  - 0s - loss: 105.4790
# Epoch 14/50
#  - 0s - loss: 104.9551
# Epoch 15/50
#  - 0s - loss: 104.3422
# Epoch 16/50
#  - 0s - loss: 103.7110
# Epoch 17/50
#  - 0s - loss: 103.0686
# Epoch 18/50
#  - 0s - loss: 102.5108
# Epoch 19/50
#  - 0s - loss: 101.9117
# Epoch 20/50
#  - 0s - loss: 101.2929
# Epoch 21/50
#  - 0s - loss: 100.7113
# Epoch 22/50
#  - 0s - loss: 100.1098
# Epoch 23/50
#  - 0s - loss: 99.4716
# Epoch 24/50
#  - 0s - loss: 98.8102
# Epoch 25/50
#  - 0s - loss: 98.1980
# Epoch 26/50
#  - 0s - loss: 97.6220
# Epoch 27/50
#  - 0s - loss: 97.0005
# Epoch 28/50
#  - 0s - loss: 96.3826
# Epoch 29/50
#  - 0s - loss: 95.7541
# Epoch 30/50
#  - 0s - loss: 95.1542
# Epoch 31/50
#  - 0s - loss: 94.6411
# Epoch 32/50
#  - 0s - loss: 93.9290
# Epoch 33/50
#  - 0s - loss: 93.3268
# Epoch 34/50
#  - 0s - loss: 92.7550
# Epoch 35/50
#  - 0s - loss: 92.1974
# Epoch 36/50
#  - 0s - loss: 91.6106
# Epoch 37/50
#  - 0s - loss: 91.1328
# Epoch 38/50
#  - 0s - loss: 90.4310
# Epoch 39/50
#  - 0s - loss: 89.9094
# Epoch 40/50
#  - 0s - loss: 89.4132
# Epoch 41/50
#  - 0s - loss: 88.8023
# Epoch 42/50
#  - 0s - loss: 88.3338
# Epoch 43/50
#  - 0s - loss: 87.6972
# Epoch 44/50
#  - 0s - loss: 87.1125
# Epoch 45/50
#  - 0s - loss: 86.6206
# Epoch 46/50
#  - 0s - loss: 86.0741
# Epoch 47/50
#  - 0s - loss: 85.5559
# Epoch 48/50
#  - 0s - loss: 85.1152
# Epoch 49/50
#  - 0s - loss: 84.6197
# Epoch 50/50
#  - 0s - loss: 84.0497
# Duration (seconds): 1.710202693939209
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 83.5592
# Epoch 2/50
#  - 0s - loss: 83.0741
# Epoch 3/50
#  - 0s - loss: 82.5591
# Epoch 4/50
#  - 0s - loss: 82.0377
# Epoch 5/50
#  - 0s - loss: 81.5471
# Epoch 6/50
#  - 0s - loss: 81.1126
# Epoch 7/50
#  - 0s - loss: 80.6343
# Epoch 8/50
#  - 0s - loss: 80.0773
# Epoch 9/50
#  - 0s - loss: 79.6638
# Epoch 10/50
#  - 0s - loss: 79.1954
# Epoch 11/50
#  - 0s - loss: 78.7268
# Epoch 12/50
#  - 0s - loss: 78.2836
# Epoch 13/50
#  - 0s - loss: 77.7368
# Epoch 14/50
#  - 0s - loss: 77.3082
# Epoch 15/50
#  - 0s - loss: 76.9153
# Epoch 16/50
#  - 0s - loss: 76.4226
# Epoch 17/50
#  - 0s - loss: 75.9490
# Epoch 18/50
#  - 0s - loss: 75.4848
# Epoch 19/50
#  - 0s - loss: 75.0627
# Epoch 20/50
#  - 0s - loss: 74.6306
# Epoch 21/50
#  - 0s - loss: 74.1700
# Epoch 22/50
#  - 0s - loss: 73.7859
# Epoch 23/50
#  - 0s - loss: 73.3433
# Epoch 24/50
#  - 0s - loss: 72.9934
# Epoch 25/50
#  - 0s - loss: 72.5391
# Epoch 26/50
#  - 0s - loss: 72.1216
# Epoch 27/50
#  - 0s - loss: 71.7264
# Epoch 28/50
#  - 0s - loss: 71.3782
# Epoch 29/50
#  - 0s - loss: 70.9469
# Epoch 30/50
#  - 0s - loss: 70.5715
# Epoch 31/50
#  - 0s - loss: 70.1979
# Epoch 32/50
#  - 0s - loss: 69.9048
# Epoch 33/50
#  - 0s - loss: 69.4624
# Epoch 34/50
#  - 0s - loss: 69.0714
# Epoch 35/50
#  - 0s - loss: 68.6911
# Epoch 36/50
#  - 0s - loss: 68.3375
# Epoch 37/50
#  - 0s - loss: 67.9425
# Epoch 38/50
#  - 0s - loss: 67.6139
# Epoch 39/50
#  - 0s - loss: 67.3017
# Epoch 40/50
#  - 0s - loss: 66.9716
# Epoch 41/50
#  - 0s - loss: 66.6157
# Epoch 42/50
#  - 0s - loss: 66.2513
# Epoch 43/50
#  - 0s - loss: 65.9943
# Epoch 44/50
#  - 0s - loss: 65.6479
# Epoch 45/50
#  - 0s - loss: 65.3440
# Epoch 46/50
#  - 0s - loss: 65.0261
# Epoch 47/50
#  - 0s - loss: 64.6970
# Epoch 48/50
#  - 0s - loss: 64.3761
# Epoch 49/50
#  - 0s - loss: 64.1183
# Epoch 50/50
#  - 0s - loss: 63.8272
# Duration (seconds): 1.6553001403808594
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 63.4995
# Epoch 2/50
#  - 0s - loss: 63.2443
# Epoch 3/50
#  - 0s - loss: 62.9501
# Epoch 4/50
#  - 0s - loss: 62.6594
# Epoch 5/50
#  - 0s - loss: 62.3527
# Epoch 6/50
#  - 0s - loss: 62.0903
# Epoch 7/50
#  - 0s - loss: 61.8432
# Epoch 8/50
#  - 0s - loss: 61.5702
# Epoch 9/50
#  - 0s - loss: 61.2488
# Epoch 10/50
#  - 0s - loss: 61.0012
# Epoch 11/50
#  - 0s - loss: 60.7805
# Epoch 12/50
#  - 0s - loss: 60.4808
# Epoch 13/50
#  - 0s - loss: 60.2809
# Epoch 14/50
#  - 0s - loss: 59.9685
# Epoch 15/50
#  - 0s - loss: 59.7807
# Epoch 16/50
#  - 0s - loss: 59.4691
# Epoch 17/50
#  - 0s - loss: 59.2438
# Epoch 18/50
#  - 0s - loss: 58.9761
# Epoch 19/50
#  - 0s - loss: 58.7628
# Epoch 20/50
#  - 0s - loss: 58.4410
# Epoch 21/50
#  - 0s - loss: 58.3044
# Epoch 22/50
#  - 0s - loss: 58.0584
# Epoch 23/50
#  - 0s - loss: 57.8866
# Epoch 24/50
#  - 0s - loss: 57.6156
# Epoch 25/50
#  - 0s - loss: 57.3798
# Epoch 26/50
#  - 0s - loss: 57.1535
# Epoch 27/50
#  - 0s - loss: 56.9190
# Epoch 28/50
#  - 0s - loss: 56.6690
# Epoch 29/50
#  - 0s - loss: 56.5332
# Epoch 30/50
#  - 0s - loss: 56.2947
# Epoch 31/50
#  - 0s - loss: 56.1150
# Epoch 32/50
#  - 0s - loss: 55.9222
# Epoch 33/50
#  - 0s - loss: 55.7082
# Epoch 34/50
#  - 0s - loss: 55.4884
# Epoch 35/50
#  - 0s - loss: 55.2803
# Epoch 36/50
#  - 0s - loss: 55.2366
# Epoch 37/50
#  - 0s - loss: 54.9450
# Epoch 38/50
#  - 0s - loss: 54.7329
# Epoch 39/50
#  - 0s - loss: 54.5325
# Epoch 40/50
#  - 0s - loss: 54.3134
# Epoch 41/50
#  - 0s - loss: 54.1835
# Epoch 42/50
#  - 0s - loss: 54.0030
# Epoch 43/50
#  - 0s - loss: 53.8351
# Epoch 44/50
#  - 0s - loss: 53.6631
# Epoch 45/50
#  - 0s - loss: 53.4265
# Epoch 46/50
#  - 0s - loss: 53.2468
# Epoch 47/50
#  - 0s - loss: 53.1063
# Epoch 48/50
#  - 0s - loss: 52.9370
# Epoch 49/50
#  - 0s - loss: 52.7449
# Epoch 50/50
#  - 0s - loss: 52.5696
# Duration (seconds): 1.629361867904663
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 52.4537
# Epoch 2/50
#  - 0s - loss: 52.2488
# Epoch 3/50
#  - 0s - loss: 52.0720
# Epoch 4/50
#  - 0s - loss: 51.9814
# Epoch 5/50
#  - 0s - loss: 51.7751
# Epoch 6/50
#  - 0s - loss: 51.6775
# Epoch 7/50
#  - 0s - loss: 51.5109
# Epoch 8/50
#  - 0s - loss: 51.3640
# Epoch 9/50
#  - 0s - loss: 51.2361
# Epoch 10/50
#  - 0s - loss: 51.2151
# Epoch 11/50
#  - 0s - loss: 50.9503
# Epoch 12/50
#  - 0s - loss: 50.8155
# Epoch 13/50
#  - 0s - loss: 50.6455
# Epoch 14/50
#  - 0s - loss: 50.5555
# Epoch 15/50
#  - 0s - loss: 50.3883
# Epoch 16/50
#  - 0s - loss: 50.3164
# Epoch 17/50
#  - 0s - loss: 50.1543
# Epoch 18/50
#  - 0s - loss: 50.0346
# Epoch 19/50
#  - 0s - loss: 49.9091
# Epoch 20/50
#  - 0s - loss: 49.7975
# Epoch 21/50
#  - 0s - loss: 49.6508
# Epoch 22/50
#  - 0s - loss: 49.5914
# Epoch 23/50
#  - 0s - loss: 49.3967
# Epoch 24/50
#  - 0s - loss: 49.3381
# Epoch 25/50
#  - 0s - loss: 49.2727
# Epoch 26/50
#  - 0s - loss: 49.0353
# Epoch 27/50
#  - 0s - loss: 48.9466
# Epoch 28/50
#  - 0s - loss: 48.8203
# Epoch 29/50
#  - 0s - loss: 48.7248
# Epoch 30/50
#  - 0s - loss: 48.6576
# Epoch 31/50
#  - 0s - loss: 48.4961
# Epoch 32/50
#  - 0s - loss: 48.4496
# Epoch 33/50
#  - 0s - loss: 48.3463
# Epoch 34/50
#  - 0s - loss: 48.2420
# Epoch 35/50
#  - 0s - loss: 48.1175
# Epoch 36/50
#  - 0s - loss: 48.0279
# Epoch 37/50
#  - 0s - loss: 47.8627
# Epoch 38/50
#  - 0s - loss: 47.7968
# Epoch 39/50
#  - 0s - loss: 47.6937
# Epoch 40/50
#  - 0s - loss: 47.6072
# Epoch 41/50
#  - 0s - loss: 47.4896
# Epoch 42/50
#  - 0s - loss: 47.4119
# Epoch 43/50
#  - 0s - loss: 47.2835
# Epoch 44/50
#  - 0s - loss: 47.1634
# Epoch 45/50
#  - 0s - loss: 47.0929
# Epoch 46/50
#  - 0s - loss: 47.0085
# Epoch 47/50
#  - 0s - loss: 46.8978
# Epoch 48/50
#  - 0s - loss: 46.7892
# Epoch 49/50
#  - 0s - loss: 46.7037
# Epoch 50/50
#  - 0s - loss: 46.5933
# Duration (seconds): 1.7191448211669922
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 46.5309
# Epoch 2/50
#  - 0s - loss: 46.4085
# Epoch 3/50
#  - 0s - loss: 46.2856
# Epoch 4/50
#  - 0s - loss: 46.2408
# Epoch 5/50
#  - 0s - loss: 46.1470
# Epoch 6/50
#  - 0s - loss: 46.0729
# Epoch 7/50
#  - 0s - loss: 45.9538
# Epoch 8/50
#  - 0s - loss: 45.9180
# Epoch 9/50
#  - 0s - loss: 45.7435
# Epoch 10/50
#  - 0s - loss: 45.7213
# Epoch 11/50
#  - 0s - loss: 45.6259
# Epoch 12/50
#  - 0s - loss: 45.5239
# Epoch 13/50
#  - 0s - loss: 45.4641
# Epoch 14/50
#  - 0s - loss: 45.4374
# Epoch 15/50
#  - 0s - loss: 45.3044
# Epoch 16/50
#  - 0s - loss: 45.2371
# Epoch 17/50
#  - 0s - loss: 45.1769
# Epoch 18/50
#  - 0s - loss: 45.0654
# Epoch 19/50
#  - 0s - loss: 44.9885
# Epoch 20/50
#  - 0s - loss: 44.9012
# Epoch 21/50
#  - 0s - loss: 44.8405
# Epoch 22/50
#  - 0s - loss: 44.8011
# Epoch 23/50
#  - 0s - loss: 44.6572
# Epoch 24/50
#  - 0s - loss: 44.5990
# Epoch 25/50
#  - 0s - loss: 44.5265
# Epoch 26/50
#  - 0s - loss: 44.4302
# Epoch 27/50
#  - 0s - loss: 44.4078
# Epoch 28/50
#  - 0s - loss: 44.3689
# Epoch 29/50
#  - 0s - loss: 44.2712
# Epoch 30/50
#  - 0s - loss: 44.2432
# Epoch 31/50
#  - 0s - loss: 44.1483
# Epoch 32/50
#  - 0s - loss: 44.0966
# Epoch 33/50
#  - 0s - loss: 44.0396
# Epoch 34/50
#  - 0s - loss: 43.9830
# Epoch 35/50
#  - 0s - loss: 43.8627
# Epoch 36/50
#  - 0s - loss: 43.8262
# Epoch 37/50
#  - 0s - loss: 43.8111
# Epoch 38/50
#  - 0s - loss: 43.7473
# Epoch 39/50
#  - 0s - loss: 43.7327
# Epoch 40/50
#  - 0s - loss: 43.5538
# Epoch 41/50
#  - 0s - loss: 43.5277
# Epoch 42/50
#  - 0s - loss: 43.4632
# Epoch 43/50
#  - 0s - loss: 43.4802
# Epoch 44/50
#  - 0s - loss: 43.2964
# Epoch 45/50
#  - 0s - loss: 43.3107
# Epoch 46/50
#  - 0s - loss: 43.2934
# Epoch 47/50
#  - 0s - loss: 43.1896
# Epoch 48/50
#  - 0s - loss: 43.1093
# Epoch 49/50
#  - 0s - loss: 43.1727
# Epoch 50/50
#  - 0s - loss: 42.9913
# Duration (seconds): 1.7133350372314453
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 42.9875
# Epoch 2/50
#  - 0s - loss: 42.9271
# Epoch 3/50
#  - 0s - loss: 42.8403
# Epoch 4/50
#  - 0s - loss: 42.9061
# Epoch 5/50
#  - 0s - loss: 42.7547
# Epoch 6/50
#  - 0s - loss: 42.6854
# Epoch 7/50
#  - 0s - loss: 42.6905
# Epoch 8/50
#  - 0s - loss: 42.5998
# Epoch 9/50
#  - 0s - loss: 42.5833
# Epoch 10/50
#  - 0s - loss: 42.5063
# Epoch 11/50
#  - 0s - loss: 42.4417
# Epoch 12/50
#  - 0s - loss: 42.3974
# Epoch 13/50
#  - 0s - loss: 42.4197
# Epoch 14/50
#  - 0s - loss: 42.3563
# Epoch 15/50
#  - 0s - loss: 42.2757
# Epoch 16/50
#  - 0s - loss: 42.2126
# Epoch 17/50
#  - 0s - loss: 42.1583
# Epoch 18/50
#  - 0s - loss: 42.1348
# Epoch 19/50
#  - 0s - loss: 42.1605
# Epoch 20/50
#  - 0s - loss: 42.0196
# Epoch 21/50
#  - 0s - loss: 41.9591
# Epoch 22/50
#  - 0s - loss: 41.9226
# Epoch 23/50
#  - 0s - loss: 41.8847
# Epoch 24/50
#  - 0s - loss: 41.8429
# Epoch 25/50
#  - 0s - loss: 41.8062
# Epoch 26/50
#  - 0s - loss: 41.8008
# Epoch 27/50
#  - 0s - loss: 41.7187
# Epoch 28/50
#  - 0s - loss: 41.6920
# Epoch 29/50
#  - 0s - loss: 41.6359
# Epoch 30/50
#  - 0s - loss: 41.5284
# Epoch 31/50
#  - 0s - loss: 41.5085
# Epoch 32/50
#  - 0s - loss: 41.4629
# Epoch 33/50
#  - 0s - loss: 41.4175
# Epoch 34/50
#  - 0s - loss: 41.3748
# Epoch 35/50
#  - 0s - loss: 41.3225
# Epoch 36/50
#  - 0s - loss: 41.3247
# Epoch 37/50
#  - 0s - loss: 41.2721
# Epoch 38/50
#  - 0s - loss: 41.2567
# Epoch 39/50
#  - 0s - loss: 41.1689
# Epoch 40/50
#  - 0s - loss: 41.1074
# Epoch 41/50
#  - 0s - loss: 41.0653
# Epoch 42/50
#  - 0s - loss: 41.0287
# Epoch 43/50
#  - 0s - loss: 41.0436
# Epoch 44/50
#  - 0s - loss: 40.9678
# Epoch 45/50
#  - 0s - loss: 40.9225
# Epoch 46/50
#  - 0s - loss: 40.8729
# Epoch 47/50
#  - 0s - loss: 40.8143
# Epoch 48/50
#  - 0s - loss: 40.7628
# Epoch 49/50
#  - 0s - loss: 40.7870
# Epoch 50/50
#  - 0s - loss: 40.7477
# Duration (seconds): 1.7370939254760742
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 40.6794
# Epoch 2/50
#  - 0s - loss: 40.6639
# Epoch 3/50
#  - 0s - loss: 40.5637
# Epoch 4/50
#  - 0s - loss: 40.5679
# Epoch 5/50
#  - 0s - loss: 40.5536
# Epoch 6/50
#  - 0s - loss: 40.5192
# Epoch 7/50
#  - 0s - loss: 40.4470
# Epoch 8/50
#  - 0s - loss: 40.4139
# Epoch 9/50
#  - 0s - loss: 40.4148
# Epoch 10/50
#  - 0s - loss: 40.3398
# Epoch 11/50
#  - 0s - loss: 40.2673
# Epoch 12/50
#  - 0s - loss: 40.2513
# Epoch 13/50
#  - 0s - loss: 40.2074
# Epoch 14/50
#  - 0s - loss: 40.1692
# Epoch 15/50
#  - 0s - loss: 40.1204
# Epoch 16/50
#  - 0s - loss: 40.1807
# Epoch 17/50
#  - 0s - loss: 40.1145
# Epoch 18/50
#  - 0s - loss: 40.0541
# Epoch 19/50
#  - 0s - loss: 40.0706
# Epoch 20/50
#  - 0s - loss: 40.0245
# Epoch 21/50
#  - 0s - loss: 39.9752
# Epoch 22/50
#  - 0s - loss: 39.9363
# Epoch 23/50
#  - 0s - loss: 39.8914
# Epoch 24/50
#  - 0s - loss: 39.8838
# Epoch 25/50
#  - 0s - loss: 39.8839
# Epoch 26/50
#  - 0s - loss: 39.7575
# Epoch 27/50
#  - 0s - loss: 39.8636
# Epoch 28/50
#  - 0s - loss: 39.7149
# Epoch 29/50
#  - 0s - loss: 39.6765
# Epoch 30/50
#  - 0s - loss: 39.6463
# Epoch 31/50
#  - 0s - loss: 39.6426
# Epoch 32/50
#  - 0s - loss: 39.6166
# Epoch 33/50
#  - 0s - loss: 39.6553
# Epoch 34/50
#  - 0s - loss: 39.4916
# Epoch 35/50
#  - 0s - loss: 39.5149
# Epoch 36/50
#  - 0s - loss: 39.5000
# Epoch 37/50
#  - 0s - loss: 39.5201
# Epoch 38/50
#  - 0s - loss: 39.4322
# Epoch 39/50
#  - 0s - loss: 39.3702
# Epoch 40/50
#  - 0s - loss: 39.3729
# Epoch 41/50
#  - 0s - loss: 39.3282
# Epoch 42/50
#  - 0s - loss: 39.4100
# Epoch 43/50
#  - 0s - loss: 39.2729
# Epoch 44/50
#  - 0s - loss: 39.3431
# Epoch 45/50
#  - 0s - loss: 39.2318
# Epoch 46/50
#  - 0s - loss: 39.2239
# Epoch 47/50
#  - 0s - loss: 39.1676
# Epoch 48/50
#  - 0s - loss: 39.1548
# Epoch 49/50
#  - 0s - loss: 39.1351
# Epoch 50/50
#  - 0s - loss: 39.0785
# Duration (seconds): 1.6398959159851074
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 39.1759
# Epoch 2/50
#  - 0s - loss: 39.0095
# Epoch 3/50
#  - 0s - loss: 38.9999
# Epoch 4/50
#  - 0s - loss: 39.0170
# Epoch 5/50
#  - 0s - loss: 38.9711
# Epoch 6/50
#  - 0s - loss: 38.9517
# Epoch 7/50
#  - 0s - loss: 38.9301
# Epoch 8/50
#  - 0s - loss: 38.8883
# Epoch 9/50
#  - 0s - loss: 38.8476
# Epoch 10/50
#  - 0s - loss: 38.8326
# Epoch 11/50
#  - 0s - loss: 38.8370
# Epoch 12/50
#  - 0s - loss: 38.7467
# Epoch 13/50
#  - 0s - loss: 38.7647
# Epoch 14/50
#  - 0s - loss: 38.7214
# Epoch 15/50
#  - 0s - loss: 38.7515
# Epoch 16/50
#  - 0s - loss: 38.6852
# Epoch 17/50
#  - 0s - loss: 38.6915
# Epoch 18/50
#  - 0s - loss: 38.5824
# Epoch 19/50
#  - 0s - loss: 38.5591
# Epoch 20/50
#  - 0s - loss: 38.5828
# Epoch 21/50
#  - 0s - loss: 38.6241
# Epoch 22/50
#  - 0s - loss: 38.5409
# Epoch 23/50
#  - 0s - loss: 38.4830
# Epoch 24/50
#  - 0s - loss: 38.4755
# Epoch 25/50
#  - 0s - loss: 38.4431
# Epoch 26/50
#  - 0s - loss: 38.5144
# Epoch 27/50
#  - 0s - loss: 38.3994
# Epoch 28/50
#  - 0s - loss: 38.4457
# Epoch 29/50
#  - 0s - loss: 38.3519
# Epoch 30/50
#  - 0s - loss: 38.3794
# Epoch 31/50
#  - 0s - loss: 38.3460
# Epoch 32/50
#  - 0s - loss: 38.3492
# Epoch 33/50
#  - 0s - loss: 38.2951
# Epoch 34/50
#  - 0s - loss: 38.2693
# Epoch 35/50
#  - 0s - loss: 38.2205
# Epoch 36/50
#  - 0s - loss: 38.2214
# Epoch 37/50
#  - 0s - loss: 38.1811
# Epoch 38/50
#  - 0s - loss: 38.1616
# Epoch 39/50
#  - 0s - loss: 38.1765
# Epoch 40/50
#  - 0s - loss: 38.1449
# Epoch 41/50
#  - 0s - loss: 38.1735
# Epoch 42/50
#  - 0s - loss: 38.0849
# Epoch 43/50
#  - 0s - loss: 38.0302
# Epoch 44/50
#  - 0s - loss: 38.0769
# Epoch 45/50
#  - 0s - loss: 38.0669
# Epoch 46/50
#  - 0s - loss: 38.0503
# Epoch 47/50
#  - 0s - loss: 37.9776
# Epoch 48/50
#  - 0s - loss: 38.0425
# Epoch 49/50
#  - 0s - loss: 37.9503
# Epoch 50/50
#  - 0s - loss: 37.9160
# Duration (seconds): 1.6396229267120361
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 37.9346
# Epoch 2/50
#  - 0s - loss: 37.9355
# Epoch 3/50
#  - 0s - loss: 37.8698
# Epoch 4/50
#  - 0s - loss: 37.8511
# Epoch 5/50
#  - 0s - loss: 37.8021
# Epoch 6/50
#  - 0s - loss: 37.7968
# Epoch 7/50
#  - 0s - loss: 37.7827
# Epoch 8/50
#  - 0s - loss: 37.7975
# Epoch 9/50
#  - 0s - loss: 37.7620
# Epoch 10/50
#  - 0s - loss: 37.8149
# Epoch 11/50
#  - 0s - loss: 37.7199
# Epoch 12/50
#  - 0s - loss: 37.7608
# Epoch 13/50
#  - 0s - loss: 37.6766
# Epoch 14/50
#  - 0s - loss: 37.6495
# Epoch 15/50
#  - 0s - loss: 37.6968
# Epoch 16/50
#  - 0s - loss: 37.5990
# Epoch 17/50
#  - 0s - loss: 37.6050
# Epoch 18/50
#  - 0s - loss: 37.6030
# Epoch 19/50
#  - 0s - loss: 37.6801
# Epoch 20/50
#  - 0s - loss: 37.5527
# Epoch 21/50
#  - 0s - loss: 37.5691
# Epoch 22/50
#  - 0s - loss: 37.5170
# Epoch 23/50
#  - 0s - loss: 37.4975
# Epoch 24/50
#  - 0s - loss: 37.5031
# Epoch 25/50
#  - 0s - loss: 37.4336
# Epoch 26/50
#  - 0s - loss: 37.4837
# Epoch 27/50
#  - 0s - loss: 37.4545
# Epoch 28/50
#  - 0s - loss: 37.4242
# Epoch 29/50
#  - 0s - loss: 37.4025
# Epoch 30/50
#  - 0s - loss: 37.4622
# Epoch 31/50
#  - 0s - loss: 37.4168
# Epoch 32/50
#  - 0s - loss: 37.3428
# Epoch 33/50
#  - 0s - loss: 37.3231
# Epoch 34/50
#  - 0s - loss: 37.3357
# Epoch 35/50
#  - 0s - loss: 37.3784
# Epoch 36/50
#  - 0s - loss: 37.2856
# Epoch 37/50
#  - 0s - loss: 37.3499
# Epoch 38/50
#  - 0s - loss: 37.2159
# Epoch 39/50
#  - 0s - loss: 37.2439
# Epoch 40/50
#  - 0s - loss: 37.2233
# Epoch 41/50
#  - 0s - loss: 37.1722
# Epoch 42/50
#  - 0s - loss: 37.2457
# Epoch 43/50
#  - 0s - loss: 37.1827
# Epoch 44/50
#  - 0s - loss: 37.1675
# Epoch 45/50
#  - 0s - loss: 37.1408
# Epoch 46/50
#  - 0s - loss: 37.1236
# Epoch 47/50
#  - 0s - loss: 37.2643
# Epoch 48/50
#  - 0s - loss: 37.0808
# Epoch 49/50
#  - 0s - loss: 37.1685
# Epoch 50/50
#  - 0s - loss: 37.1230
# Duration (seconds): 1.6965420246124268
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 37.0680
# Epoch 2/50
#  - 0s - loss: 37.0397
# Epoch 3/50
#  - 0s - loss: 37.0712
# Epoch 4/50
#  - 0s - loss: 37.0545
# Epoch 5/50
#  - 0s - loss: 36.9923
# Epoch 6/50
#  - 0s - loss: 37.0163
# Epoch 7/50
#  - 0s - loss: 36.9700
# Epoch 8/50
#  - 0s - loss: 36.9624
# Epoch 9/50
#  - 0s - loss: 36.9663
# Epoch 10/50
#  - 0s - loss: 36.9705
# Epoch 11/50
#  - 0s - loss: 36.9018
# Epoch 12/50
#  - 0s - loss: 36.9041
# Epoch 13/50
#  - 0s - loss: 36.9174
# Epoch 14/50
#  - 0s - loss: 36.9041
# Epoch 15/50
#  - 0s - loss: 36.9102
# Epoch 16/50
#  - 0s - loss: 36.8639
# Epoch 17/50
#  - 0s - loss: 36.8951
# Epoch 18/50
#  - 0s - loss: 36.8351
# Epoch 19/50
#  - 0s - loss: 36.8412
# Epoch 20/50
#  - 0s - loss: 36.8710
# Epoch 21/50
#  - 0s - loss: 36.7552
# Epoch 22/50
#  - 0s - loss: 36.7927
# Epoch 23/50
#  - 0s - loss: 36.7524
# Epoch 24/50
#  - 0s - loss: 36.7356
# Epoch 25/50
#  - 0s - loss: 36.7732
# Epoch 26/50
#  - 0s - loss: 36.7155
# Epoch 27/50
#  - 0s - loss: 36.7107
# Epoch 28/50
#  - 0s - loss: 36.7258
# Epoch 29/50
#  - 0s - loss: 36.6667
# Epoch 30/50
#  - 0s - loss: 36.6444
# Epoch 31/50
#  - 0s - loss: 36.6276
# Epoch 32/50
#  - 0s - loss: 36.6116
# Epoch 33/50
#  - 0s - loss: 36.6754
# Epoch 34/50
#  - 0s - loss: 36.6037
# Epoch 35/50
#  - 0s - loss: 36.6179
# Epoch 36/50
#  - 0s - loss: 36.5759
# Epoch 37/50
#  - 0s - loss: 36.5776
# Epoch 38/50
#  - 0s - loss: 36.5367
# Epoch 39/50
#  - 0s - loss: 36.5460
# Epoch 40/50
#  - 0s - loss: 36.5529
# Epoch 41/50
#  - 0s - loss: 36.5407
# Epoch 42/50
#  - 0s - loss: 36.5113
# Epoch 43/50
#  - 0s - loss: 36.4837
# Epoch 44/50
#  - 0s - loss: 36.5205
# Epoch 45/50
#  - 0s - loss: 36.4406
# Epoch 46/50
#  - 0s - loss: 36.4366
# Epoch 47/50
#  - 0s - loss: 36.4652
# Epoch 48/50
#  - 0s - loss: 36.4539
# Epoch 49/50
#  - 0s - loss: 36.4850
# Epoch 50/50
#  - 0s - loss: 36.4065
# Duration (seconds): 1.7111780643463135
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 36.3925
# Epoch 2/50
#  - 0s - loss: 36.4262
# Epoch 3/50
#  - 0s - loss: 36.4317
# Epoch 4/50
#  - 0s - loss: 36.3327
# Epoch 5/50
#  - 0s - loss: 36.3553
# Epoch 6/50
#  - 0s - loss: 36.3593
# Epoch 7/50
#  - 0s - loss: 36.2972
# Epoch 8/50
#  - 0s - loss: 36.3031
# Epoch 9/50
#  - 0s - loss: 36.2999
# Epoch 10/50
#  - 0s - loss: 36.3507
# Epoch 11/50
#  - 0s - loss: 36.2922
# Epoch 12/50
#  - 0s - loss: 36.2569
# Epoch 13/50
#  - 0s - loss: 36.3356
# Epoch 14/50
#  - 0s - loss: 36.2507
# Epoch 15/50
#  - 0s - loss: 36.2834
# Epoch 16/50
#  - 0s - loss: 36.2350
# Epoch 17/50
#  - 0s - loss: 36.2100
# Epoch 18/50
#  - 0s - loss: 36.2558
# Epoch 19/50
#  - 0s - loss: 36.2373
# Epoch 20/50
#  - 0s - loss: 36.1775
# Epoch 21/50
#  - 0s - loss: 36.1815
# Epoch 22/50
#  - 0s - loss: 36.2125
# Epoch 23/50
#  - 0s - loss: 36.1620
# Epoch 24/50
#  - 0s - loss: 36.1310
# Epoch 25/50
#  - 0s - loss: 36.1538
# Epoch 26/50
#  - 0s - loss: 36.1082
# Epoch 27/50
#  - 0s - loss: 36.1356
# Epoch 28/50
#  - 0s - loss: 36.1361
# Epoch 29/50
#  - 0s - loss: 36.1027
# Epoch 30/50
#  - 0s - loss: 36.0850
# Epoch 31/50
#  - 0s - loss: 36.1218
# Epoch 32/50
#  - 0s - loss: 36.0625
# Epoch 33/50
#  - 0s - loss: 36.0766
# Epoch 34/50
#  - 0s - loss: 36.0547
# Epoch 35/50
#  - 0s - loss: 36.0676
# Epoch 36/50
#  - 0s - loss: 36.1168
# Epoch 37/50
#  - 0s - loss: 35.9749
# Epoch 38/50
#  - 0s - loss: 36.0736
# Epoch 39/50
#  - 0s - loss: 35.9830
# Epoch 40/50
#  - 0s - loss: 35.9567
# Epoch 41/50
#  - 0s - loss: 36.0031
# Epoch 42/50
#  - 0s - loss: 35.9579
# Epoch 43/50
#  - 0s - loss: 35.9756
# Epoch 44/50
#  - 0s - loss: 35.9698
# Epoch 45/50
#  - 0s - loss: 35.9018
# Epoch 46/50
#  - 0s - loss: 35.9028
# Epoch 47/50
#  - 0s - loss: 35.8804
# Epoch 48/50
#  - 0s - loss: 35.8833
# Epoch 49/50
#  - 0s - loss: 35.8893
# Epoch 50/50
#  - 0s - loss: 35.8541
# Duration (seconds): 1.7062599658966064
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 35.8592
# Epoch 2/50
#  - 0s - loss: 35.8606
# Epoch 3/50
#  - 0s - loss: 35.8465
# Epoch 4/50
#  - 0s - loss: 35.8178
# Epoch 5/50
#  - 0s - loss: 35.8318
# Epoch 6/50
#  - 0s - loss: 35.8344
# Epoch 7/50
#  - 0s - loss: 35.7694
# Epoch 8/50
#  - 0s - loss: 35.7851
# Epoch 9/50
#  - 0s - loss: 35.7601
# Epoch 10/50
#  - 0s - loss: 35.7378
# Epoch 11/50
#  - 0s - loss: 35.8348
# Epoch 12/50
#  - 0s - loss: 35.7414
# Epoch 13/50
#  - 0s - loss: 35.6938
# Epoch 14/50
#  - 0s - loss: 35.7105
# Epoch 15/50
#  - 0s - loss: 35.7664
# Epoch 16/50
#  - 0s - loss: 35.6714
# Epoch 17/50
#  - 0s - loss: 35.7046
# Epoch 18/50
#  - 0s - loss: 35.6657
# Epoch 19/50
#  - 0s - loss: 35.6767
# Epoch 20/50
#  - 0s - loss: 35.6302
# Epoch 21/50
#  - 0s - loss: 35.6288
# Epoch 22/50
#  - 0s - loss: 35.6193
# Epoch 23/50
#  - 0s - loss: 35.6086
# Epoch 24/50
#  - 0s - loss: 35.6251
# Epoch 25/50
#  - 0s - loss: 35.5778
# Epoch 26/50
#  - 0s - loss: 35.5864
# Epoch 27/50
#  - 0s - loss: 35.6105
# Epoch 28/50
#  - 0s - loss: 35.5656
# Epoch 29/50
#  - 0s - loss: 35.5156
# Epoch 30/50
#  - 0s - loss: 35.6014
# Epoch 31/50
#  - 0s - loss: 35.5900
# Epoch 32/50
#  - 0s - loss: 35.5320
# Epoch 33/50
#  - 0s - loss: 35.5167
# Epoch 34/50
#  - 0s - loss: 35.5595
# Epoch 35/50
#  - 0s - loss: 35.4940
# Epoch 36/50
#  - 0s - loss: 35.4731
# Epoch 37/50
#  - 0s - loss: 35.5379
# Epoch 38/50
#  - 0s - loss: 35.4555
# Epoch 39/50
#  - 0s - loss: 35.4627
# Epoch 40/50
#  - 0s - loss: 35.4435
# Epoch 41/50
#  - 0s - loss: 35.4555
# Epoch 42/50
#  - 0s - loss: 35.5703
# Epoch 43/50
#  - 0s - loss: 35.3899
# Epoch 44/50
#  - 0s - loss: 35.4018
# Epoch 45/50
#  - 0s - loss: 35.4127
# Epoch 46/50
#  - 0s - loss: 35.4227
# Epoch 47/50
#  - 0s - loss: 35.3590
# Epoch 48/50
#  - 0s - loss: 35.3883
# Epoch 49/50
#  - 0s - loss: 35.3952
# Epoch 50/50
#  - 0s - loss: 35.3729
# Duration (seconds): 1.6649219989776611
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 35.3296
# Epoch 2/50
#  - 0s - loss: 35.3898
# Epoch 3/50
#  - 0s - loss: 35.3282
# Epoch 4/50
#  - 0s - loss: 35.3545
# Epoch 5/50
#  - 0s - loss: 35.3217
# Epoch 6/50
#  - 0s - loss: 35.3889
# Epoch 7/50
#  - 0s - loss: 35.3490
# Epoch 8/50
#  - 0s - loss: 35.2994
# Epoch 9/50
#  - 0s - loss: 35.2865
# Epoch 10/50
#  - 0s - loss: 35.2392
# Epoch 11/50
#  - 0s - loss: 35.2803
# Epoch 12/50
#  - 0s - loss: 35.3017
# Epoch 13/50
#  - 0s - loss: 35.2408
# Epoch 14/50
#  - 0s - loss: 35.2674
# Epoch 15/50
#  - 0s - loss: 35.2709
# Epoch 16/50
#  - 0s - loss: 35.2706
# Epoch 17/50
#  - 0s - loss: 35.3198
# Epoch 18/50
#  - 0s - loss: 35.2461
# Epoch 19/50
#  - 0s - loss: 35.1801
# Epoch 20/50
#  - 0s - loss: 35.2111
# Epoch 21/50
#  - 0s - loss: 35.2063
# Epoch 22/50
#  - 0s - loss: 35.2172
# Epoch 23/50
#  - 0s - loss: 35.1914
# Epoch 24/50
#  - 0s - loss: 35.1724
# Epoch 25/50
#  - 0s - loss: 35.1899
# Epoch 26/50
#  - 0s - loss: 35.1433
# Epoch 27/50
#  - 0s - loss: 35.1478
# Epoch 28/50
#  - 0s - loss: 35.2310
# Epoch 29/50
#  - 0s - loss: 35.1271
# Epoch 30/50
#  - 0s - loss: 35.1633
# Epoch 31/50
#  - 0s - loss: 35.1923
# Epoch 32/50
#  - 0s - loss: 35.1453
# Epoch 33/50
#  - 0s - loss: 35.1427
# Epoch 34/50
#  - 0s - loss: 35.1600
# Epoch 35/50
#  - 0s - loss: 35.1525
# Epoch 36/50
#  - 0s - loss: 35.0679
# Epoch 37/50
#  - 0s - loss: 35.1008
# Epoch 38/50
#  - 0s - loss: 35.0830
# Epoch 39/50
#  - 0s - loss: 35.1019
# Epoch 40/50
#  - 0s - loss: 35.0913
# Epoch 41/50
#  - 0s - loss: 35.1194
# Epoch 42/50
#  - 0s - loss: 35.1427
# Epoch 43/50
#  - 0s - loss: 35.0340
# Epoch 44/50
#  - 0s - loss: 35.1735
# Epoch 45/50
#  - 0s - loss: 35.3050
# Epoch 46/50
#  - 0s - loss: 35.1357
# Epoch 47/50
#  - 0s - loss: 35.0253
# Epoch 48/50
#  - 0s - loss: 35.0793
# Epoch 49/50
#  - 0s - loss: 35.0742
# Epoch 50/50
#  - 0s - loss: 35.0501
# Duration (seconds): 1.7859890460968018
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 35.0292
# Epoch 2/50
#  - 0s - loss: 35.0578
# Epoch 3/50
#  - 0s - loss: 35.0177
# Epoch 4/50
#  - 0s - loss: 35.0353
# Epoch 5/50
#  - 0s - loss: 35.0561
# Epoch 6/50
#  - 0s - loss: 35.0285
# Epoch 7/50
#  - 0s - loss: 34.9743
# Epoch 8/50
#  - 0s - loss: 34.9936
# Epoch 9/50
#  - 0s - loss: 34.9803
# Epoch 10/50
#  - 0s - loss: 34.9834
# Epoch 11/50
#  - 0s - loss: 35.0247
# Epoch 12/50
#  - 0s - loss: 34.9397
# Epoch 13/50
#  - 0s - loss: 34.9524
# Epoch 14/50
#  - 0s - loss: 34.9650
# Epoch 15/50
#  - 0s - loss: 34.9596
# Epoch 16/50
#  - 0s - loss: 34.9201
# Epoch 17/50
#  - 0s - loss: 34.9496
# Epoch 18/50
#  - 0s - loss: 34.9126
# Epoch 19/50
#  - 0s - loss: 34.9182
# Epoch 20/50
#  - 0s - loss: 34.8953
# Epoch 21/50
#  - 0s - loss: 34.9252
# Epoch 22/50
#  - 0s - loss: 34.8849
# Epoch 23/50
#  - 0s - loss: 34.9341
# Epoch 24/50
#  - 0s - loss: 34.9404
# Epoch 25/50
#  - 0s - loss: 34.9077
# Epoch 26/50
#  - 0s - loss: 34.8946
# Epoch 27/50
#  - 0s - loss: 34.9212
# Epoch 28/50
#  - 0s - loss: 34.9097
# Epoch 29/50
#  - 0s - loss: 34.8308
# Epoch 30/50
#  - 0s - loss: 34.9535
# Epoch 31/50
#  - 0s - loss: 34.9103
# Epoch 32/50
#  - 0s - loss: 34.8474
# Epoch 33/50
#  - 0s - loss: 34.8618
# Epoch 34/50
#  - 0s - loss: 34.8450
# Epoch 35/50
#  - 0s - loss: 34.8360
# Epoch 36/50
#  - 0s - loss: 34.8605
# Epoch 37/50
#  - 0s - loss: 34.8007
# Epoch 38/50
#  - 0s - loss: 34.8765
# Epoch 39/50
#  - 0s - loss: 34.8264
# Epoch 40/50
#  - 0s - loss: 34.8208
# Epoch 41/50
#  - 0s - loss: 34.7721
# Epoch 42/50
#  - 0s - loss: 34.8126
# Epoch 43/50
#  - 0s - loss: 34.7949
# Epoch 44/50
#  - 0s - loss: 34.7780
# Epoch 45/50
#  - 0s - loss: 34.7927
# Epoch 46/50
#  - 0s - loss: 34.8104
# Epoch 47/50
#  - 0s - loss: 34.8142
# Epoch 48/50
#  - 0s - loss: 34.7467
# Epoch 49/50
#  - 0s - loss: 34.7790
# Epoch 50/50
#  - 0s - loss: 34.8349
# Duration (seconds): 1.6304168701171875
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.8329
# Epoch 2/50
#  - 0s - loss: 34.7665
# Epoch 3/50
#  - 0s - loss: 34.7499
# Epoch 4/50
#  - 0s - loss: 34.7553
# Epoch 5/50
#  - 0s - loss: 34.7569
# Epoch 6/50
#  - 0s - loss: 34.7512
# Epoch 7/50
#  - 0s - loss: 34.6871
# Epoch 8/50
#  - 0s - loss: 34.7772
# Epoch 9/50
#  - 0s - loss: 34.6939
# Epoch 10/50
#  - 0s - loss: 34.7261
# Epoch 11/50
#  - 0s - loss: 34.6795
# Epoch 12/50
#  - 0s - loss: 34.7481
# Epoch 13/50
#  - 0s - loss: 34.7117
# Epoch 14/50
#  - 0s - loss: 34.6622
# Epoch 15/50
#  - 0s - loss: 34.6790
# Epoch 16/50
#  - 0s - loss: 34.6596
# Epoch 17/50
#  - 0s - loss: 34.6257
# Epoch 18/50
#  - 0s - loss: 34.6961
# Epoch 19/50
#  - 0s - loss: 34.6369
# Epoch 20/50
#  - 0s - loss: 34.6336
# Epoch 21/50
#  - 0s - loss: 34.6269
# Epoch 22/50
#  - 0s - loss: 34.6514
# Epoch 23/50
#  - 0s - loss: 34.6117
# Epoch 24/50
#  - 0s - loss: 34.7729
# Epoch 25/50
#  - 0s - loss: 34.6703
# Epoch 26/50
#  - 0s - loss: 34.6586
# Epoch 27/50
#  - 0s - loss: 34.6088
# Epoch 28/50
#  - 0s - loss: 34.5869
# Epoch 29/50
#  - 0s - loss: 34.6056
# Epoch 30/50
#  - 0s - loss: 34.5957
# Epoch 31/50
#  - 0s - loss: 34.6270
# Epoch 32/50
#  - 0s - loss: 34.6660
# Epoch 33/50
#  - 0s - loss: 34.5472
# Epoch 34/50
#  - 0s - loss: 34.6533
# Epoch 35/50
#  - 0s - loss: 34.6061
# Epoch 36/50
#  - 0s - loss: 34.6119
# Epoch 37/50
#  - 0s - loss: 34.5391
# Epoch 38/50
#  - 0s - loss: 34.5197
# Epoch 39/50
#  - 0s - loss: 34.5351
# Epoch 40/50
#  - 0s - loss: 34.5461
# Epoch 41/50
#  - 0s - loss: 34.5693
# Epoch 42/50
#  - 0s - loss: 34.5457
# Epoch 43/50
#  - 0s - loss: 34.5778
# Epoch 44/50
#  - 0s - loss: 34.5331
# Epoch 45/50
#  - 0s - loss: 34.5266
# Epoch 46/50
#  - 0s - loss: 34.5694
# Epoch 47/50
#  - 0s - loss: 34.5207
# Epoch 48/50
#  - 0s - loss: 34.5492
# Epoch 49/50
#  - 0s - loss: 34.5536
# Epoch 50/50
#  - 0s - loss: 34.5456
# Duration (seconds): 1.6231911182403564
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.5441
# Epoch 2/50
#  - 0s - loss: 34.5062
# Epoch 3/50
#  - 0s - loss: 34.5560
# Epoch 4/50
#  - 0s - loss: 34.4685
# Epoch 5/50
#  - 0s - loss: 34.4869
# Epoch 6/50
#  - 0s - loss: 34.5661
# Epoch 7/50
#  - 0s - loss: 34.4549
# Epoch 8/50
#  - 0s - loss: 34.4497
# Epoch 9/50
#  - 0s - loss: 34.4966
# Epoch 10/50
#  - 0s - loss: 34.4992
# Epoch 11/50
#  - 0s - loss: 34.4456
# Epoch 12/50
#  - 0s - loss: 34.4359
# Epoch 13/50
#  - 0s - loss: 34.4654
# Epoch 14/50
#  - 0s - loss: 34.4515
# Epoch 15/50
#  - 0s - loss: 34.4211
# Epoch 16/50
#  - 0s - loss: 34.3968
# Epoch 17/50
#  - 0s - loss: 34.4630
# Epoch 18/50
#  - 0s - loss: 34.4376
# Epoch 19/50
#  - 0s - loss: 34.4204
# Epoch 20/50
#  - 0s - loss: 34.4159
# Epoch 21/50
#  - 0s - loss: 34.4289
# Epoch 22/50
#  - 0s - loss: 34.4081
# Epoch 23/50
#  - 0s - loss: 34.3780
# Epoch 24/50
#  - 0s - loss: 34.4192
# Epoch 25/50
#  - 0s - loss: 34.3898
# Epoch 26/50
#  - 0s - loss: 34.4260
# Epoch 27/50
#  - 0s - loss: 34.3838
# Epoch 28/50
#  - 0s - loss: 34.3406
# Epoch 29/50
#  - 0s - loss: 34.4125
# Epoch 30/50
#  - 0s - loss: 34.4478
# Epoch 31/50
#  - 0s - loss: 34.3445
# Epoch 32/50
#  - 0s - loss: 34.3889
# Epoch 33/50
#  - 0s - loss: 34.3429
# Epoch 34/50
#  - 0s - loss: 34.4178
# Epoch 35/50
#  - 0s - loss: 34.3351
# Epoch 36/50
#  - 0s - loss: 34.3167
# Epoch 37/50
#  - 0s - loss: 34.3436
# Epoch 38/50
#  - 0s - loss: 34.3088
# Epoch 39/50
#  - 0s - loss: 34.2871
# Epoch 40/50
#  - 0s - loss: 34.3273
# Epoch 41/50
#  - 0s - loss: 34.3456
# Epoch 42/50
#  - 0s - loss: 34.3331
# Epoch 43/50
#  - 0s - loss: 34.3093
# Epoch 44/50
#  - 0s - loss: 34.2765
# Epoch 45/50
#  - 0s - loss: 34.2810
# Epoch 46/50
#  - 0s - loss: 34.2470
# Epoch 47/50
#  - 0s - loss: 34.2707
# Epoch 48/50
#  - 0s - loss: 34.2709
# Epoch 49/50
#  - 0s - loss: 34.2633
# Epoch 50/50
#  - 0s - loss: 34.2216
# Duration (seconds): 1.5990688800811768
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.2404
# Epoch 2/50
#  - 0s - loss: 34.2083
# Epoch 3/50
#  - 0s - loss: 34.3150
# Epoch 4/50
#  - 0s - loss: 34.2365
# Epoch 5/50
#  - 0s - loss: 34.2234
# Epoch 6/50
#  - 0s - loss: 34.2201
# Epoch 7/50
#  - 0s - loss: 34.2300
# Epoch 8/50
#  - 0s - loss: 34.1993
# Epoch 9/50
#  - 0s - loss: 34.2452
# Epoch 10/50
#  - 0s - loss: 34.2513
# Epoch 11/50
#  - 0s - loss: 34.2030
# Epoch 12/50
#  - 0s - loss: 34.2599
# Epoch 13/50
#  - 0s - loss: 34.1885
# Epoch 14/50
#  - 0s - loss: 34.2033
# Epoch 15/50
#  - 0s - loss: 34.1818
# Epoch 16/50
#  - 0s - loss: 34.1786
# Epoch 17/50
#  - 0s - loss: 34.1771
# Epoch 18/50
#  - 0s - loss: 34.1967
# Epoch 19/50
#  - 0s - loss: 34.1953
# Epoch 20/50
#  - 0s - loss: 34.2100
# Epoch 21/50
#  - 0s - loss: 34.1841
# Epoch 22/50
#  - 0s - loss: 34.1551
# Epoch 23/50
#  - 0s - loss: 34.1676
# Epoch 24/50
#  - 0s - loss: 34.1753
# Epoch 25/50
#  - 0s - loss: 34.1399
# Epoch 26/50
#  - 0s - loss: 34.1799
# Epoch 27/50
#  - 0s - loss: 34.1568
# Epoch 28/50
#  - 0s - loss: 34.1681
# Epoch 29/50
#  - 0s - loss: 34.1497
# Epoch 30/50
#  - 0s - loss: 34.1699
# Epoch 31/50
#  - 0s - loss: 34.1168
# Epoch 32/50
#  - 0s - loss: 34.1544
# Epoch 33/50
#  - 0s - loss: 34.1212
# Epoch 34/50
#  - 0s - loss: 34.1575
# Epoch 35/50
#  - 0s - loss: 34.1263
# Epoch 36/50
#  - 0s - loss: 34.1312
# Epoch 37/50
#  - 0s - loss: 34.1798
# Epoch 38/50
#  - 0s - loss: 34.1325
# Epoch 39/50
#  - 0s - loss: 34.0789
# Epoch 40/50
#  - 0s - loss: 34.0971
# Epoch 41/50
#  - 0s - loss: 34.1222
# Epoch 42/50
#  - 0s - loss: 34.0693
# Epoch 43/50
#  - 0s - loss: 34.0841
# Epoch 44/50
#  - 0s - loss: 34.0814
# Epoch 45/50
#  - 0s - loss: 34.1202
# Epoch 46/50
#  - 0s - loss: 34.0375
# Epoch 47/50
#  - 0s - loss: 34.0547
# Epoch 48/50
#  - 0s - loss: 34.0762
# Epoch 49/50
#  - 0s - loss: 34.0692
# Epoch 50/50
#  - 0s - loss: 34.0393
# Duration (seconds): 1.6286969184875488
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.0172
# Epoch 2/50
#  - 0s - loss: 34.0875
# Epoch 3/50
#  - 0s - loss: 34.1222
# Epoch 4/50
#  - 0s - loss: 34.1101
# Epoch 5/50
#  - 0s - loss: 34.0510
# Epoch 6/50
#  - 0s - loss: 33.9810
# Epoch 7/50
#  - 0s - loss: 34.0302
# Epoch 8/50
#  - 0s - loss: 34.0299
# Epoch 9/50
#  - 0s - loss: 34.0418
# Epoch 10/50
#  - 0s - loss: 34.0038
# Epoch 11/50
#  - 0s - loss: 34.0897
# Epoch 12/50
#  - 0s - loss: 34.0422
# Epoch 13/50
#  - 0s - loss: 33.9987
# Epoch 14/50
#  - 0s - loss: 33.9760
# Epoch 15/50
#  - 0s - loss: 33.9850
# Epoch 16/50
#  - 0s - loss: 34.0292
# Epoch 17/50
#  - 0s - loss: 33.9593
# Epoch 18/50
#  - 0s - loss: 33.9465
# Epoch 19/50
#  - 0s - loss: 33.9452
# Epoch 20/50
#  - 0s - loss: 33.9337
# Epoch 21/50
#  - 0s - loss: 33.9344
# Epoch 22/50
#  - 0s - loss: 33.9824
# Epoch 23/50
#  - 0s - loss: 33.9221
# Epoch 24/50
#  - 0s - loss: 33.9364
# Epoch 25/50
#  - 0s - loss: 33.9186
# Epoch 26/50
#  - 0s - loss: 33.9212
# Epoch 27/50
#  - 0s - loss: 33.9429
# Epoch 28/50
#  - 0s - loss: 33.9686
# Epoch 29/50
#  - 0s - loss: 33.9239
# Epoch 30/50
#  - 0s - loss: 33.9337
# Epoch 31/50
#  - 0s - loss: 33.8705
# Epoch 32/50
#  - 0s - loss: 33.8598
# Epoch 33/50
#  - 0s - loss: 33.9003
# Epoch 34/50
#  - 0s - loss: 33.9532
# Epoch 35/50
#  - 0s - loss: 33.9334
# Epoch 36/50
#  - 0s - loss: 33.9109
# Epoch 37/50
#  - 0s - loss: 33.8833
# Epoch 38/50
#  - 0s - loss: 33.8828
# Epoch 39/50
#  - 0s - loss: 33.8659
# Epoch 40/50
#  - 0s - loss: 33.8142
# Epoch 41/50
#  - 0s - loss: 33.8371
# Epoch 42/50
#  - 0s - loss: 33.8628
# Epoch 43/50
#  - 0s - loss: 33.9897
# Epoch 44/50
#  - 0s - loss: 33.8689
# Epoch 45/50
#  - 0s - loss: 33.8420
# Epoch 46/50
#  - 0s - loss: 33.9170
# Epoch 47/50
#  - 0s - loss: 33.8538
# Epoch 48/50
#  - 0s - loss: 33.8488
# Epoch 49/50
#  - 0s - loss: 33.8392
# Epoch 50/50
#  - 0s - loss: 33.8410
# Duration (seconds): 1.657707929611206
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.8044
# Epoch 2/50
#  - 0s - loss: 33.7774
# Epoch 3/50
#  - 0s - loss: 33.7828
# Epoch 4/50
#  - 0s - loss: 33.7845
# Epoch 5/50
#  - 0s - loss: 33.8042
# Epoch 6/50
#  - 0s - loss: 33.7747
# Epoch 7/50
#  - 0s - loss: 33.7754
# Epoch 8/50
#  - 0s - loss: 33.8078
# Epoch 9/50
#  - 0s - loss: 33.7750
# Epoch 10/50
#  - 0s - loss: 33.8176
# Epoch 11/50
#  - 0s - loss: 33.7963
# Epoch 12/50
#  - 0s - loss: 33.7857
# Epoch 13/50
#  - 0s - loss: 33.7560
# Epoch 14/50
#  - 0s - loss: 33.7679
# Epoch 15/50
#  - 0s - loss: 33.7705
# Epoch 16/50
#  - 0s - loss: 33.7449
# Epoch 17/50
#  - 0s - loss: 33.7383
# Epoch 18/50
#  - 0s - loss: 33.7673
# Epoch 19/50
#  - 0s - loss: 33.7413
# Epoch 20/50
#  - 0s - loss: 33.7541
# Epoch 21/50
#  - 0s - loss: 33.7215
# Epoch 22/50
#  - 0s - loss: 33.7189
# Epoch 23/50
#  - 0s - loss: 33.7007
# Epoch 24/50
#  - 0s - loss: 33.7040
# Epoch 25/50
#  - 0s - loss: 33.7500
# Epoch 26/50
#  - 0s - loss: 33.7060
# Epoch 27/50
#  - 0s - loss: 33.6836
# Epoch 28/50
#  - 0s - loss: 33.7114
# Epoch 29/50
#  - 0s - loss: 33.7347
# Epoch 30/50
#  - 0s - loss: 33.7039
# Epoch 31/50
#  - 0s - loss: 33.6545
# Epoch 32/50
#  - 0s - loss: 33.7147
# Epoch 33/50
#  - 0s - loss: 33.7196
# Epoch 34/50
#  - 0s - loss: 33.6761
# Epoch 35/50
#  - 0s - loss: 33.6464
# Epoch 36/50
#  - 0s - loss: 33.6439
# Epoch 37/50
#  - 0s - loss: 33.6777
# Epoch 38/50
#  - 0s - loss: 33.6348
# Epoch 39/50
#  - 0s - loss: 33.6406
# Epoch 40/50
#  - 0s - loss: 33.6710
# Epoch 41/50
#  - 0s - loss: 33.6468
# Epoch 42/50
#  - 0s - loss: 33.7189
# Epoch 43/50
#  - 0s - loss: 33.6050
# Epoch 44/50
#  - 0s - loss: 33.6382
# Epoch 45/50
#  - 0s - loss: 33.6295
# Epoch 46/50
#  - 0s - loss: 33.6699
# Epoch 47/50
#  - 0s - loss: 33.6774
# Epoch 48/50
#  - 0s - loss: 33.5608
# Epoch 49/50
#  - 0s - loss: 33.5820
# Epoch 50/50
#  - 0s - loss: 33.6667
# Duration (seconds): 1.6380500793457031
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.6125
# Epoch 2/50
#  - 0s - loss: 33.6217
# Epoch 3/50
#  - 0s - loss: 33.6839
# Epoch 4/50
#  - 0s - loss: 33.6523
# Epoch 5/50
#  - 0s - loss: 33.5887
# Epoch 6/50
#  - 0s - loss: 33.6046
# Epoch 7/50
#  - 0s - loss: 33.5847
# Epoch 8/50
#  - 0s - loss: 33.6125
# Epoch 9/50
#  - 0s - loss: 33.6098
# Epoch 10/50
#  - 0s - loss: 33.5633
# Epoch 11/50
#  - 0s - loss: 33.6333
# Epoch 12/50
#  - 0s - loss: 33.6125
# Epoch 13/50
#  - 0s - loss: 33.5698
# Epoch 14/50
#  - 0s - loss: 33.6213
# Epoch 15/50
#  - 0s - loss: 33.6140
# Epoch 16/50
#  - 0s - loss: 33.5966
# Epoch 17/50
#  - 0s - loss: 33.6259
# Epoch 18/50
#  - 0s - loss: 33.5480
# Epoch 19/50
#  - 0s - loss: 33.5542
# Epoch 20/50
#  - 0s - loss: 33.5370
# Epoch 21/50
#  - 0s - loss: 33.5478
# Epoch 22/50
#  - 0s - loss: 33.5332
# Epoch 23/50
#  - 0s - loss: 33.5297
# Epoch 24/50
#  - 0s - loss: 33.5273
# Epoch 25/50
#  - 0s - loss: 33.5164
# Epoch 26/50
#  - 0s - loss: 33.5088
# Epoch 27/50
#  - 0s - loss: 33.5322
# Epoch 28/50
#  - 0s - loss: 33.4766
# Epoch 29/50
#  - 0s - loss: 33.4534
# Epoch 30/50
#  - 0s - loss: 33.4848
# Epoch 31/50
#  - 0s - loss: 33.4868
# Epoch 32/50
#  - 0s - loss: 33.5414
# Epoch 33/50
#  - 0s - loss: 33.4704
# Epoch 34/50
#  - 0s - loss: 33.4811
# Epoch 35/50
#  - 0s - loss: 33.4531
# Epoch 36/50
#  - 0s - loss: 33.4748
# Epoch 37/50
#  - 0s - loss: 33.4747
# Epoch 38/50
#  - 0s - loss: 33.4176
# Epoch 39/50
#  - 0s - loss: 33.4570
# Epoch 40/50
#  - 0s - loss: 33.4026
# Epoch 41/50
#  - 0s - loss: 33.4894
# Epoch 42/50
#  - 0s - loss: 33.4305
# Epoch 43/50
#  - 0s - loss: 33.5469
# Epoch 44/50
#  - 0s - loss: 33.5035
# Epoch 45/50
#  - 0s - loss: 33.4014
# Epoch 46/50
#  - 0s - loss: 33.4411
# Epoch 47/50
#  - 0s - loss: 33.4165
# Epoch 48/50
#  - 0s - loss: 33.3742
# Epoch 49/50
#  - 0s - loss: 33.3810
# Epoch 50/50
#  - 0s - loss: 33.3826
# Duration (seconds): 1.6377899646759033
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.4066
# Epoch 2/50
#  - 0s - loss: 33.3897
# Epoch 3/50
#  - 0s - loss: 33.3839
# Epoch 4/50
#  - 0s - loss: 33.3852
# Epoch 5/50
#  - 0s - loss: 33.4000
# Epoch 6/50
#  - 0s - loss: 33.4350
# Epoch 7/50
#  - 0s - loss: 33.3836
# Epoch 8/50
#  - 0s - loss: 33.3300
# Epoch 9/50
#  - 0s - loss: 33.3184
# Epoch 10/50
#  - 0s - loss: 33.3622
# Epoch 11/50
#  - 0s - loss: 33.4142
# Epoch 12/50
#  - 0s - loss: 33.3739
# Epoch 13/50
#  - 0s - loss: 33.3787
# Epoch 14/50
#  - 0s - loss: 33.3937
# Epoch 15/50
#  - 0s - loss: 33.3531
# Epoch 16/50
#  - 0s - loss: 33.4520
# Epoch 17/50
#  - 0s - loss: 33.3375
# Epoch 18/50
#  - 0s - loss: 33.4531
# Epoch 19/50
#  - 0s - loss: 33.3518
# Epoch 20/50
#  - 0s - loss: 33.3245
# Epoch 21/50
#  - 0s - loss: 33.2965
# Epoch 22/50
#  - 0s - loss: 33.3075
# Epoch 23/50
#  - 0s - loss: 33.3381
# Epoch 24/50
#  - 0s - loss: 33.3597
# Epoch 25/50
#  - 0s - loss: 33.2688
# Epoch 26/50
#  - 0s - loss: 33.3524
# Epoch 27/50
#  - 0s - loss: 33.2939
# Epoch 28/50
#  - 0s - loss: 33.3285
# Epoch 29/50
#  - 0s - loss: 33.3015
# Epoch 30/50
#  - 0s - loss: 33.2537
# Epoch 31/50
#  - 0s - loss: 33.2646
# Epoch 32/50
#  - 0s - loss: 33.2397
# Epoch 33/50
#  - 0s - loss: 33.2532
# Epoch 34/50
#  - 0s - loss: 33.3122
# Epoch 35/50
#  - 0s - loss: 33.2607
# Epoch 36/50
#  - 0s - loss: 33.2518
# Epoch 37/50
#  - 0s - loss: 33.2437
# Epoch 38/50
#  - 0s - loss: 33.2494
# Epoch 39/50
#  - 0s - loss: 33.2307
# Epoch 40/50
#  - 0s - loss: 33.2572
# Epoch 41/50
#  - 0s - loss: 33.2512
# Epoch 42/50
#  - 0s - loss: 33.2369
# Epoch 43/50
#  - 0s - loss: 33.2053
# Epoch 44/50
#  - 0s - loss: 33.2153
# Epoch 45/50
#  - 0s - loss: 33.2528
# Epoch 46/50
#  - 0s - loss: 33.2392
# Epoch 47/50
#  - 0s - loss: 33.2161
# Epoch 48/50
#  - 0s - loss: 33.2898
# Epoch 49/50
#  - 0s - loss: 33.2039
# Epoch 50/50
#  - 0s - loss: 33.1687
# Duration (seconds): 1.659703016281128
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 33.1578
# Epoch 2/50
#  - 0s - loss: 33.1563
# Epoch 3/50
#  - 0s - loss: 33.1670
# Epoch 4/50
#  - 0s - loss: 33.1721
# Epoch 5/50
#  - 0s - loss: 33.1569
# Epoch 6/50
#  - 0s - loss: 33.1611
# Epoch 7/50
#  - 0s - loss: 33.1538
# Epoch 8/50
#  - 0s - loss: 33.1560
# Epoch 9/50
#  - 0s - loss: 33.1915
# Epoch 10/50
#  - 0s - loss: 33.1249
# Epoch 11/50
#  - 0s - loss: 33.1805
# Epoch 12/50
#  - 0s - loss: 33.1241
# Epoch 13/50
#  - 0s - loss: 33.1325
# Epoch 14/50
#  - 0s - loss: 33.0972
# Epoch 15/50
#  - 0s - loss: 33.1121
# Epoch 16/50
#  - 0s - loss: 33.1445
# Epoch 17/50
#  - 0s - loss: 33.1642
# Epoch 18/50
#  - 0s - loss: 33.0838
# Epoch 19/50
#  - 0s - loss: 33.1335
# Epoch 20/50
#  - 0s - loss: 33.1253
# Epoch 21/50
#  - 0s - loss: 33.0514
# Epoch 22/50
#  - 0s - loss: 33.0307
# Epoch 23/50
#  - 0s - loss: 33.1046
# Epoch 24/50
#  - 0s - loss: 33.0706
# Epoch 25/50
#  - 0s - loss: 33.0360
# Epoch 26/50
#  - 0s - loss: 33.0415
# Epoch 27/50
#  - 0s - loss: 33.0527
# Epoch 28/50
#  - 0s - loss: 33.1069
# Epoch 29/50
#  - 0s - loss: 33.0105
# Epoch 30/50
#  - 0s - loss: 33.0064
# Epoch 31/50
#  - 0s - loss: 33.0564
# Epoch 32/50
#  - 0s - loss: 33.0380
# Epoch 33/50
#  - 0s - loss: 32.9831
# Epoch 34/50
#  - 0s - loss: 33.0102
# Epoch 35/50
#  - 0s - loss: 33.0015
# Epoch 36/50
#  - 0s - loss: 32.9972
# Epoch 37/50
#  - 0s - loss: 33.0470
# Epoch 38/50
#  - 0s - loss: 33.1123
# Epoch 39/50
#  - 0s - loss: 33.0150
# Epoch 40/50
#  - 0s - loss: 33.0287
# Epoch 41/50
#  - 0s - loss: 33.0145
# Epoch 42/50
#  - 0s - loss: 32.9469
# Epoch 43/50
#  - 0s - loss: 32.9391
# Epoch 44/50
#  - 0s - loss: 32.9568
# Epoch 45/50
#  - 0s - loss: 32.9707
# Epoch 46/50
#  - 0s - loss: 32.9226
# Epoch 47/50
#  - 0s - loss: 32.9128
# Epoch 48/50
#  - 0s - loss: 32.9749
# Epoch 49/50
#  - 0s - loss: 32.9406
# Epoch 50/50
#  - 0s - loss: 32.9068
# Duration (seconds): 1.6076951026916504
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 32.9412
# Epoch 2/50
#  - 0s - loss: 32.9493
# Epoch 3/50
#  - 0s - loss: 32.9461
# Epoch 4/50
#  - 0s - loss: 32.8864
# Epoch 5/50
#  - 0s - loss: 32.8943
# Epoch 6/50
#  - 0s - loss: 32.9485
# Epoch 7/50
#  - 0s - loss: 32.8865
# Epoch 8/50
#  - 0s - loss: 32.8742
# Epoch 9/50
#  - 0s - loss: 32.8980
# Epoch 10/50
#  - 0s - loss: 32.9541
# Epoch 11/50
#  - 0s - loss: 32.8874
# Epoch 12/50
#  - 0s - loss: 32.8309
# Epoch 13/50
#  - 0s - loss: 32.8815
# Epoch 14/50
#  - 0s - loss: 32.8364
# Epoch 15/50
#  - 0s - loss: 32.8614
# Epoch 16/50
#  - 0s - loss: 32.8700
# Epoch 17/50
#  - 0s - loss: 32.8713
# Epoch 18/50
#  - 0s - loss: 32.8196
# Epoch 19/50
#  - 0s - loss: 32.9352
# Epoch 20/50
#  - 0s - loss: 32.8376
# Epoch 21/50
#  - 0s - loss: 32.8328
# Epoch 22/50
#  - 0s - loss: 32.8390
# Epoch 23/50
#  - 0s - loss: 32.8417
# Epoch 24/50
#  - 0s - loss: 32.7948
# Epoch 25/50
#  - 0s - loss: 32.8068
# Epoch 26/50
#  - 0s - loss: 32.7895
# ...
# Epoch 2/50
#  - 0s - loss: 31.6992
# Epoch 3/50
#  - 0s - loss: 31.7096
# Epoch 4/50
#  - 0s - loss: 31.6943
# Epoch 5/50
#  - 0s - loss: 31.6523
# Epoch 6/50
#  - 0s - loss: 31.6943
# Epoch 7/50
#  - 0s - loss: 31.7544
# Epoch 8/50
#  - 0s - loss: 31.7188
# Epoch 9/50
#  - 0s - loss: 31.6915
# Epoch 10/50
#  - 0s - loss: 31.7767
# Epoch 11/50
#  - 0s - loss: 31.6703
# Epoch 12/50
#  - 0s - loss: 31.6532
# Epoch 13/50
#  - 0s - loss: 31.6689
# Epoch 14/50
#  - 0s - loss: 31.6753
# Epoch 15/50
#  - 0s - loss: 31.6427
# Epoch 16/50
#  - 0s - loss: 31.6366
# Epoch 17/50
#  - 0s - loss: 31.6370
# Epoch 18/50
#  - 0s - loss: 31.6626
# Epoch 19/50
#  - 0s - loss: 31.6235
# Epoch 20/50
#  - 0s - loss: 31.6397
# Epoch 21/50
#  - 0s - loss: 31.6667
# Epoch 22/50
#  - 0s - loss: 31.6709
# Epoch 23/50
#  - 0s - loss: 31.6988
# Epoch 24/50
#  - 0s - loss: 31.6855
# Epoch 25/50
#  - 0s - loss: 31.6482
# Epoch 26/50
#  - 0s - loss: 31.6881
# Epoch 27/50
#  - 0s - loss: 31.6885
# Epoch 28/50
#  - 0s - loss: 31.6617
# Epoch 29/50
#  - 0s - loss: 31.7839
# Epoch 30/50
#  - 0s - loss: 31.6405
# Epoch 31/50
#  - 0s - loss: 31.8460
# Epoch 32/50
#  - 0s - loss: 31.6195
# Epoch 33/50
#  - 0s - loss: 31.7097
# Epoch 34/50
#  - 0s - loss: 31.6018
# Epoch 35/50
#  - 0s - loss: 31.6183
# Epoch 36/50
#  - 0s - loss: 31.6703
# Epoch 37/50
#  - 0s - loss: 31.6442
# Epoch 38/50
#  - 0s - loss: 31.6546
# Epoch 39/50
#  - 0s - loss: 31.7035
# Epoch 40/50
#  - 0s - loss: 31.6404
# Epoch 41/50
#  - 0s - loss: 31.6511
# Epoch 42/50
#  - 0s - loss: 31.6828
# Epoch 43/50
#  - 0s - loss: 31.6639
# Epoch 44/50
#  - 0s - loss: 31.6433
# Epoch 45/50
#  - 0s - loss: 31.6597
# Epoch 46/50
#  - 0s - loss: 31.6866
# Epoch 47/50
#  - 0s - loss: 31.6724
# Epoch 48/50
#  - 0s - loss: 31.7142
# Epoch 49/50
#  - 0s - loss: 31.6491
# Epoch 50/50
#  - 0s - loss: 31.6544
# Duration (seconds): 1.668661117553711
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.6605
# Epoch 2/50
#  - 0s - loss: 31.6517
# Epoch 3/50
#  - 0s - loss: 31.6190
# Epoch 4/50
#  - 0s - loss: 31.6103
# Epoch 5/50
#  - 0s - loss: 31.6477
# Epoch 6/50
#  - 0s - loss: 31.6486
# Epoch 7/50
#  - 0s - loss: 31.6272
# Epoch 8/50
#  - 0s - loss: 31.6432
# Epoch 9/50
#  - 0s - loss: 31.6830
# Epoch 10/50
#  - 0s - loss: 31.6342
# Epoch 11/50
#  - 0s - loss: 31.6374
# Epoch 12/50
#  - 0s - loss: 31.6620
# Epoch 13/50
#  - 0s - loss: 31.6087
# Epoch 14/50
#  - 0s - loss: 31.6671
# Epoch 15/50
#  - 0s - loss: 31.6775
# Epoch 16/50
#  - 0s - loss: 31.6315
# Epoch 17/50
#  - 0s - loss: 31.6473
# Epoch 18/50
#  - 0s - loss: 31.6154
# Epoch 19/50
#  - 0s - loss: 31.6398
# Epoch 20/50
#  - 0s - loss: 31.6311
# Epoch 21/50
#  - 0s - loss: 31.6671
# Epoch 22/50
#  - 0s - loss: 31.7383
# Epoch 23/50
#  - 0s - loss: 31.6936
# Epoch 24/50
#  - 0s - loss: 31.7229
# Epoch 25/50
#  - 0s - loss: 31.5817
# Epoch 26/50
#  - 0s - loss: 31.6308
# Epoch 27/50
#  - 0s - loss: 31.6354
# Epoch 28/50
#  - 0s - loss: 31.6748
# Epoch 29/50
#  - 0s - loss: 31.6357
# Epoch 30/50
#  - 0s - loss: 31.5995
# Epoch 31/50
#  - 0s - loss: 31.6254
# Epoch 32/50
#  - 0s - loss: 31.6757
# Epoch 33/50
#  - 0s - loss: 31.6447
# Epoch 34/50
#  - 0s - loss: 31.6902
# Epoch 35/50
#  - 0s - loss: 31.6062
# Epoch 36/50
#  - 0s - loss: 31.6415
# Epoch 37/50
#  - 0s - loss: 31.6681
# Epoch 38/50
#  - 0s - loss: 31.5906
# Epoch 39/50
#  - 0s - loss: 31.6311
# Epoch 40/50
#  - 0s - loss: 31.6287
# Epoch 41/50
#  - 0s - loss: 31.6699
# Epoch 42/50
#  - 0s - loss: 31.6506
# Epoch 43/50
#  - 0s - loss: 31.6164
# Epoch 44/50
#  - 0s - loss: 31.6123
# Epoch 45/50
#  - 0s - loss: 31.6286
# Epoch 46/50
#  - 0s - loss: 31.6347
# Epoch 47/50
#  - 0s - loss: 31.6252
# Epoch 48/50
#  - 0s - loss: 31.6127
# Epoch 49/50
#  - 0s - loss: 31.6223
# Epoch 50/50
#  - 0s - loss: 31.6914
# Duration (seconds): 1.669640302658081
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.6613
# Epoch 2/50
#  - 0s - loss: 31.5971
# Epoch 3/50
#  - 0s - loss: 31.6164
# Epoch 4/50
#  - 0s - loss: 31.6388
# Epoch 5/50
#  - 0s - loss: 31.6355
# Epoch 6/50
#  - 0s - loss: 31.5959
# Epoch 7/50
#  - 0s - loss: 31.6220
# Epoch 8/50
#  - 0s - loss: 31.6718
# Epoch 9/50
#  - 0s - loss: 31.6420
# Epoch 10/50
#  - 0s - loss: 31.5880
# Epoch 11/50
#  - 0s - loss: 31.6223
# Epoch 12/50
#  - 0s - loss: 31.5919
# Epoch 13/50
#  - 0s - loss: 31.6652
# Epoch 14/50
#  - 0s - loss: 31.7212
# Epoch 15/50
#  - 0s - loss: 31.6615
# Epoch 16/50
#  - 0s - loss: 31.6014
# Epoch 17/50
#  - 0s - loss: 31.6178
# Epoch 18/50
#  - 0s - loss: 31.5926
# Epoch 19/50
#  - 0s - loss: 31.6455
# Epoch 20/50
#  - 0s - loss: 31.6056
# Epoch 21/50
#  - 0s - loss: 31.5915
# Epoch 22/50
#  - 0s - loss: 31.6093
# Epoch 23/50
#  - 0s - loss: 31.6297
# Epoch 24/50
#  - 0s - loss: 31.6888
# Epoch 25/50
#  - 0s - loss: 31.6493
# Epoch 26/50
#  - 0s - loss: 31.5962
# Epoch 27/50
#  - 0s - loss: 31.6427
# Epoch 28/50
#  - 0s - loss: 31.5715
# Epoch 29/50
#  - 0s - loss: 31.5908
# Epoch 30/50
#  - 0s - loss: 31.6369
# Epoch 31/50
#  - 0s - loss: 31.5970
# Epoch 32/50
#  - 0s - loss: 31.6741
# Epoch 33/50
#  - 0s - loss: 31.6443
# Epoch 34/50
#  - 0s - loss: 31.6246
# Epoch 35/50
#  - 0s - loss: 31.6285
# Epoch 36/50
#  - 0s - loss: 31.6100
# Epoch 37/50
#  - 0s - loss: 31.6183
# Epoch 38/50
#  - 0s - loss: 31.5839
# Epoch 39/50
#  - 0s - loss: 31.6133
# Epoch 40/50
#  - 0s - loss: 31.5903
# Epoch 41/50
#  - 0s - loss: 31.6788
# Epoch 42/50
#  - 0s - loss: 31.6441
# Epoch 43/50
#  - 0s - loss: 31.6644
# Epoch 44/50
#  - 0s - loss: 31.5817
# Epoch 45/50
#  - 0s - loss: 31.6090
# Epoch 46/50
#  - 0s - loss: 31.6000
# Epoch 47/50
#  - 0s - loss: 31.5732
# Epoch 48/50
#  - 0s - loss: 31.7373
# Epoch 49/50
#  - 0s - loss: 31.6791
# Epoch 50/50
#  - 0s - loss: 31.5697
# Duration (seconds): 1.7574520111083984
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.6338
# Epoch 2/50
#  - 0s - loss: 31.6153
# Epoch 3/50
#  - 0s - loss: 31.5764
# Epoch 4/50
#  - 0s - loss: 31.5395
# Epoch 5/50
#  - 0s - loss: 31.6323
# Epoch 6/50
#  - 0s - loss: 31.5662
# Epoch 7/50
#  - 0s - loss: 31.6331
# Epoch 8/50
#  - 0s - loss: 31.6092
# Epoch 9/50
#  - 0s - loss: 31.5975
# Epoch 10/50
#  - 0s - loss: 31.5677
# Epoch 11/50
#  - 0s - loss: 31.6069
# Epoch 12/50
#  - 0s - loss: 31.5959
# Epoch 13/50
#  - 0s - loss: 31.5593
# Epoch 14/50
#  - 0s - loss: 31.5560
# Epoch 15/50
#  - 0s - loss: 31.6190
# Epoch 16/50
#  - 0s - loss: 31.6185
# Epoch 17/50
#  - 0s - loss: 31.5955
# Epoch 18/50
#  - 0s - loss: 31.6493
# Epoch 19/50
#  - 0s - loss: 31.6001
# Epoch 20/50
#  - 0s - loss: 31.6811
# Epoch 21/50
#  - 0s - loss: 31.6297
# Epoch 22/50
#  - 0s - loss: 31.5605
# Epoch 23/50
#  - 0s - loss: 31.5794
# Epoch 24/50
#  - 0s - loss: 31.5754
# Epoch 25/50
#  - 0s - loss: 31.5854
# Epoch 26/50
#  - 0s - loss: 31.5612
# Epoch 27/50
#  - 0s - loss: 31.5785
# Epoch 28/50
#  - 0s - loss: 31.5594
# Epoch 29/50
#  - 0s - loss: 31.5456
# Epoch 30/50
#  - 0s - loss: 31.6288
# Epoch 31/50
#  - 0s - loss: 31.6136
# Epoch 32/50
#  - 0s - loss: 31.5828
# Epoch 33/50
#  - 0s - loss: 31.5701
# Epoch 34/50
#  - 0s - loss: 31.5867
# Epoch 35/50
#  - 0s - loss: 31.5552
# Epoch 36/50
#  - 0s - loss: 31.5815
# Epoch 37/50
#  - 0s - loss: 31.5588
# Epoch 38/50
#  - 0s - loss: 31.5937
# Epoch 39/50
#  - 0s - loss: 31.5580
# Epoch 40/50
#  - 0s - loss: 31.6177
# Epoch 41/50
#  - 0s - loss: 31.5798
# Epoch 42/50
#  - 0s - loss: 31.5485
# Epoch 43/50
#  - 0s - loss: 31.5949
# Epoch 44/50
#  - 0s - loss: 31.5987
# Epoch 45/50
#  - 0s - loss: 31.5338
# Epoch 46/50
#  - 0s - loss: 31.5982
# Epoch 47/50
#  - 0s - loss: 31.6621
# Epoch 48/50
#  - 0s - loss: 31.5720
# Epoch 49/50
#  - 0s - loss: 31.6080
# Epoch 50/50
#  - 0s - loss: 31.5606
# Duration (seconds): 1.9743800163269043
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.5645
# Epoch 2/50
#  - 0s - loss: 31.5674
# Epoch 3/50
#  - 0s - loss: 31.5738
# Epoch 4/50
#  - 0s - loss: 31.5646
# Epoch 5/50
#  - 0s - loss: 31.6634
# Epoch 6/50
#  - 0s - loss: 31.5370
# Epoch 7/50
#  - 0s - loss: 31.5520
# Epoch 8/50
#  - 0s - loss: 31.5545
# Epoch 9/50
#  - 0s - loss: 31.5554
# Epoch 10/50
#  - 0s - loss: 31.5602
# Epoch 11/50
#  - 0s - loss: 31.6406
# Epoch 12/50
#  - 0s - loss: 31.5696
# Epoch 13/50
#  - 0s - loss: 31.5786
# Epoch 14/50
#  - 0s - loss: 31.7017
# Epoch 15/50
#  - 0s - loss: 31.5774
# Epoch 16/50
#  - 0s - loss: 31.5937
# Epoch 17/50
#  - 0s - loss: 31.6636
# Epoch 18/50
#  - 0s - loss: 31.5342
# Epoch 19/50
#  - 0s - loss: 31.5373
# Epoch 20/50
#  - 0s - loss: 31.5948
# Epoch 21/50
#  - 0s - loss: 31.5496
# Epoch 22/50
#  - 0s - loss: 31.5759
# Epoch 23/50
#  - 0s - loss: 31.5684
# Epoch 24/50
#  - 0s - loss: 31.5997
# Epoch 25/50
#  - 0s - loss: 31.6332
# Epoch 26/50
#  - 0s - loss: 31.6046
# Epoch 27/50
#  - 0s - loss: 31.6287
# Epoch 28/50
#  - 0s - loss: 31.6128
# Epoch 29/50
#  - 0s - loss: 31.5538
# Epoch 30/50
#  - 0s - loss: 31.5642
# Epoch 31/50
#  - 0s - loss: 31.5952
# Epoch 32/50
#  - 0s - loss: 31.5407
# Epoch 33/50
#  - 0s - loss: 31.5569
# Epoch 34/50
#  - 0s - loss: 31.5101
# Epoch 35/50
#  - 0s - loss: 31.6441
# Epoch 36/50
#  - 0s - loss: 31.5902
# Epoch 37/50
#  - 0s - loss: 31.5754
# Epoch 38/50
#  - 0s - loss: 31.6175
# Epoch 39/50
#  - 0s - loss: 31.5751
# Epoch 40/50
#  - 0s - loss: 31.5862
# Epoch 41/50
#  - 0s - loss: 31.5579
# Epoch 42/50
#  - 0s - loss: 31.6252
# Epoch 43/50
#  - 0s - loss: 31.5282
# Epoch 44/50
#  - 0s - loss: 31.6217
# Epoch 45/50
#  - 0s - loss: 31.6100
# Epoch 46/50
#  - 0s - loss: 31.5605
# Epoch 47/50
#  - 0s - loss: 31.5793
# Epoch 48/50
#  - 0s - loss: 31.5401
# Epoch 49/50
#  - 0s - loss: 31.5672
# Epoch 50/50
#  - 0s - loss: 31.5682
# Duration (seconds): 2.1858317852020264
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.5133
# Epoch 2/50
#  - 0s - loss: 31.5294
# Epoch 3/50
#  - 0s - loss: 31.5560
# Epoch 4/50
#  - 0s - loss: 31.5801
# Epoch 5/50
#  - 0s - loss: 31.5205
# Epoch 6/50
#  - 0s - loss: 31.5900
# Epoch 7/50
#  - 0s - loss: 31.5013
# Epoch 8/50
#  - 0s - loss: 31.6205
# Epoch 9/50
#  - 0s - loss: 31.6347
# Epoch 10/50
#  - 0s - loss: 31.5969
# Epoch 11/50
#  - 0s - loss: 31.5132
# Epoch 12/50
#  - 0s - loss: 31.5978
# Epoch 13/50
#  - 0s - loss: 31.5664
# Epoch 14/50
#  - 0s - loss: 31.5065
# Epoch 15/50
#  - 0s - loss: 31.5287
# Epoch 16/50
#  - 0s - loss: 31.6000
# Epoch 17/50
#  - 0s - loss: 31.5228
# Epoch 18/50
#  - 0s - loss: 31.5343
# Epoch 19/50
#  - 0s - loss: 31.5650
# Epoch 20/50
#  - 0s - loss: 31.5801
# Epoch 21/50
#  - 0s - loss: 31.5304
# Epoch 22/50
#  - 0s - loss: 31.5376
# Epoch 23/50
#  - 0s - loss: 31.5554
# Epoch 24/50
#  - 0s - loss: 31.5104
# Epoch 25/50
#  - 0s - loss: 31.5643
# Epoch 26/50
#  - 0s - loss: 31.5230
# Epoch 27/50
#  - 0s - loss: 31.5580
# Epoch 28/50
#  - 0s - loss: 31.5486
# Epoch 29/50
#  - 0s - loss: 31.5354
# Epoch 30/50
#  - 0s - loss: 31.5258
# Epoch 31/50
#  - 0s - loss: 31.5214
# Epoch 32/50
#  - 0s - loss: 31.5560
# Epoch 33/50
#  - 0s - loss: 31.5822
# Epoch 34/50
#  - 0s - loss: 31.5771
# Epoch 35/50
#  - 0s - loss: 31.5826
# Epoch 36/50
#  - 0s - loss: 31.5199
# Epoch 37/50
#  - 0s - loss: 31.5370
# Epoch 38/50
#  - 0s - loss: 31.5674
# Epoch 39/50
#  - 0s - loss: 31.5295
# Epoch 40/50
#  - 0s - loss: 31.5452
# Epoch 41/50
#  - 0s - loss: 31.5586
# Epoch 42/50
#  - 0s - loss: 31.5140
# Epoch 43/50
#  - 0s - loss: 31.5081
# Epoch 44/50
#  - 0s - loss: 31.5625
# Epoch 45/50
#  - 0s - loss: 31.5564
# Epoch 46/50
#  - 0s - loss: 31.5876
# Epoch 47/50
#  - 0s - loss: 31.5493
# Epoch 48/50
#  - 0s - loss: 31.4865
# Epoch 49/50
#  - 0s - loss: 31.5109
# Epoch 50/50
#  - 0s - loss: 31.5767
# Duration (seconds): 1.8113200664520264
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.5614
# Epoch 2/50
#  - 0s - loss: 31.5278
# Epoch 3/50
#  - 0s - loss: 31.5388
# Epoch 4/50
#  - 0s - loss: 31.5023
# Epoch 5/50
#  - 0s - loss: 31.5404
# Epoch 6/50
#  - 0s - loss: 31.4925
# Epoch 7/50
#  - 0s - loss: 31.5262
# Epoch 8/50
#  - 0s - loss: 31.5182
# Epoch 9/50
#  - 0s - loss: 31.5042
# Epoch 10/50
#  - 0s - loss: 31.4949
# Epoch 11/50
#  - 0s - loss: 31.5329
# Epoch 12/50
#  - 0s - loss: 31.5353
# Epoch 13/50
#  - 0s - loss: 31.5248
# Epoch 14/50
#  - 0s - loss: 31.5004
# Epoch 15/50
#  - 0s - loss: 31.4817
# Epoch 16/50
#  - 0s - loss: 31.5395
# Epoch 17/50
#  - 0s - loss: 31.5305
# Epoch 18/50
#  - 0s - loss: 31.5373
# Epoch 19/50
#  - 0s - loss: 31.5424
# Epoch 20/50
#  - 0s - loss: 31.5182
# Epoch 21/50
#  - 0s - loss: 31.5618
# Epoch 22/50
#  - 0s - loss: 31.5464
# Epoch 23/50
#  - 0s - loss: 31.5549
# Epoch 24/50
#  - 0s - loss: 31.5205
# Epoch 25/50
#  - 0s - loss: 31.5667
# Epoch 26/50
#  - 0s - loss: 31.5199
# Epoch 27/50
#  - 0s - loss: 31.4907
# Epoch 28/50
#  - 0s - loss: 31.4882
# Epoch 29/50
#  - 0s - loss: 31.5340
# Epoch 30/50
#  - 0s - loss: 31.5815
# Epoch 31/50
#  - 0s - loss: 31.4952
# Epoch 32/50
#  - 0s - loss: 31.4718
# Epoch 33/50
#  - 0s - loss: 31.5343
# Epoch 34/50
#  - 0s - loss: 31.6057
# Epoch 35/50
#  - 0s - loss: 31.5185
# Epoch 36/50
#  - 0s - loss: 31.4885
# Epoch 37/50
#  - 0s - loss: 31.5103
# Epoch 38/50
#  - 0s - loss: 31.5098
# Epoch 39/50
#  - 0s - loss: 31.5221
# Epoch 40/50
#  - 0s - loss: 31.5114
# Epoch 41/50
#  - 0s - loss: 31.5014
# Epoch 42/50
#  - 0s - loss: 31.5503
# Epoch 43/50
#  - 0s - loss: 31.4570
# Epoch 44/50
#  - 0s - loss: 31.5512
# Epoch 45/50
#  - 0s - loss: 31.5045
# Epoch 46/50
#  - 0s - loss: 31.5358
# Epoch 47/50
#  - 0s - loss: 31.4990
# Epoch 48/50
#  - 0s - loss: 31.5288
# Epoch 49/50
#  - 0s - loss: 31.4737
# Epoch 50/50
#  - 0s - loss: 31.4899
# Duration (seconds): 1.6945810317993164
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.5267
# Epoch 2/50
#  - 0s - loss: 31.4896
# Epoch 3/50
#  - 0s - loss: 31.5104
# Epoch 4/50
#  - 0s - loss: 31.4807
# Epoch 5/50
#  - 0s - loss: 31.4999
# Epoch 6/50
#  - 0s - loss: 31.4783
# Epoch 7/50
#  - 0s - loss: 31.5009
# Epoch 8/50
#  - 0s - loss: 31.4965
# Epoch 9/50
#  - 0s - loss: 31.4989
# Epoch 10/50
#  - 0s - loss: 31.5080
# Epoch 11/50
#  - 0s - loss: 31.5390
# Epoch 12/50
#  - 0s - loss: 31.5367
# Epoch 13/50
#  - 0s - loss: 31.4603
# Epoch 14/50
#  - 0s - loss: 31.5268
# Epoch 15/50
#  - 0s - loss: 31.4948
# Epoch 16/50
#  - 0s - loss: 31.4975
# Epoch 17/50
#  - 0s - loss: 31.5664
# Epoch 18/50
#  - 0s - loss: 31.4988
# Epoch 19/50
#  - 0s - loss: 31.4857
# Epoch 20/50
#  - 0s - loss: 31.4482
# Epoch 21/50
#  - 0s - loss: 31.6134
# Epoch 22/50
#  - 0s - loss: 31.4782
# Epoch 23/50
#  - 0s - loss: 31.4875
# Epoch 24/50
#  - 0s - loss: 31.4994
# Epoch 25/50
#  - 0s - loss: 31.5403
# Epoch 26/50
#  - 0s - loss: 31.5098
# Epoch 27/50
#  - 0s - loss: 31.4736
# Epoch 28/50
#  - 0s - loss: 31.5219
# Epoch 29/50
#  - 0s - loss: 31.5271
# Epoch 30/50
#  - 0s - loss: 31.4916
# Epoch 31/50
#  - 0s - loss: 31.4749
# Epoch 32/50
#  - 0s - loss: 31.4700
# Epoch 33/50
#  - 0s - loss: 31.5132
# Epoch 34/50
#  - 0s - loss: 31.5020
# Epoch 35/50
#  - 0s - loss: 31.4562
# Epoch 36/50
#  - 0s - loss: 31.5016
# Epoch 37/50
#  - 0s - loss: 31.4612
# Epoch 38/50
#  - 0s - loss: 31.4908
# Epoch 39/50
#  - 0s - loss: 31.4973
# Epoch 40/50
#  - 0s - loss: 31.4690
# Epoch 41/50
#  - 0s - loss: 31.5019
# Epoch 42/50
#  - 0s - loss: 31.5443
# Epoch 43/50
#  - 0s - loss: 31.4799
# Epoch 44/50
#  - 0s - loss: 31.5424
# Epoch 45/50
#  - 0s - loss: 31.4516
# Epoch 46/50
#  - 0s - loss: 31.5433
# Epoch 47/50
#  - 0s - loss: 31.4807
# Epoch 48/50
#  - 0s - loss: 31.5024
# Epoch 49/50
#  - 0s - loss: 31.4772
# Epoch 50/50
#  - 0s - loss: 31.4697
# Duration (seconds): 3.1181609630584717
# Finished - 50 times.
# And the list of mean squared errors : [257.91019067311646, 139.75947685727914, 115.8268901956153, 89.27991728016384, 68.60270377861178, 56.47903016502931, 50.180042747134294, 47.0759317404381, 45.16890694584364, 43.65338293983685, 42.558462975495914, 41.8734927518714, 41.25039189038488, 40.65689640915801, 40.06856529546394, 39.8867164372205, 39.56149439613335, 39.460702720357304, 39.4972211313019, 39.542664713294926, 39.45881703945728, 39.51523424329795, 39.41061337096152, 39.367964961949916, 39.50722204689464, 39.256786327663185, 39.228412466302245, 39.18133376684367, 39.17880781598449, 39.207775305359924, 39.23075535649387, 39.2677197562715, 39.14571027463182, 39.17742722689151, 39.13056643559805, 39.241840660429155, 39.15990843962851, 39.14971497176471, 39.099326383288115, 39.08855108262433, 39.16186161352693, 39.231910898189, 39.04084816063947, 39.036575524152745, 39.06356075194954, 38.90164207885294, 38.90366594300933, 38.87286527553512, 38.77401416003163, 38.83940591822867]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 49.86 and 35.23, respectively

# %% [markdown]
# ###  Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of not normalized data is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline  normalized (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline_norm = get_report(name_of_case, mean_mse, std_mse)
df_baseline_norm
# Out:
#                          Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline  normalized (50 epochs)     49.86              35.23

# %% [markdown]
# Comparing the case of not normalized data with the case of normalized data:

# %%
# Create a data frame with the summary
df_summary = pd.concat([df_baseline, df_baseline_norm], axis=0)

# Review the result dataframe
df_summary.reset_index(drop=True)
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     68.42              28.34
# 1     Baseline  normalized (50 epochs)     49.86              35.23

# %% [markdown]
# ### Part C: Normalized data with 100 epochs

# %% [markdown]
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# #### Building the model with normalized data and increasing to 100 epochs

# %%
max_iteration = 50
epochs = 100
verbose = 0

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors_norm, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 4.3207032680511475
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.371795892715454
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.5873563289642334
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 4.480020046234131
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.949136257171631
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.9860382080078125
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.7247979640960693
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.908574342727661
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.012000799179077
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.858659029006958
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.635478973388672
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.280419111251831
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.2085511684417725
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.2441980838775635
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.499807119369507
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4696412086486816
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.800136089324951
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4955668449401855
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.7776761054992676
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.59940505027771
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.7334799766540527
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.465791940689087
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.8652312755584717
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.148855686187744
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.66805100440979
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.3999929428100586
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4304659366607666
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.450967788696289
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4130420684814453
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.389112710952759
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4261980056762695
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.400970220565796
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4006049633026123
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.3882946968078613
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4494271278381348
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.6311380863189697
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.555586099624634
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4138989448547363
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.0537350177764893
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.5862510204315186
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.431885004043579
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.471548080444336
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.464931011199951
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.5820438861846924
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.539923906326294
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.520310878753662
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.489349842071533
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.43218994140625
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4730403423309326
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.5772078037261963
# Finished - 50 times.
# And the list of mean squared errors : [148.55955584310627, 84.96118269533798, 52.99957040438355, 44.56484574066699, 41.9178338082171, 40.836028541159735, 40.232537876653716, 39.81080398986626, 39.70338416521696, 39.700490905115736, 39.5625332507642, 39.339457340172046, 39.44687599294375, 39.344223075040496, 39.414852080080976, 39.49393448360867, 39.7562682860654, 39.68999271615738, 39.417029845931566, 39.43230600337048, 39.24805543940592, 39.14393558549388, 39.11280754107269, 39.12912107036367, 39.01160975481083, 39.008861701599606, 39.07096919419982, 38.96115697166274, 38.948417900710275, 38.95028266210124, 38.977829650293934, 38.896697854157196, 38.720221864955775, 38.565231388359194, 38.48655093471779, 38.53763840448198, 38.617609645136106, 38.599652004249606, 38.47313623950049, 38.489427334191596, 38.35525241762405, 38.48521270630916, 38.36428237449447, 38.46275066264364, 38.416339819858365, 38.37079664884361, 38.25870917322873, 38.36204255294914, 38.333783923226, 38.30143146284237]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 42.58 and 16.57, respectively

# %% [markdown]
# ### Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of normalized data running 100 epochs is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline  normalized (100 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline_norm100 = get_report(name_of_case, mean_mse, std_mse)
df_baseline_norm100
# Out:
#                           Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline  normalized (100 epochs)     42.58              16.57

# %% [markdown]
# Comparing the normalized cases ran with 50 epochs and 100 epochs

# %%
# Create a data frame with the summary
df_summary = pd.concat([df_baseline, df_baseline_norm, df_baseline_norm100], axis=0)

# Review the result dataframe
df_summary.reset_index(drop=True)
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     68.42              28.34
# 1     Baseline  normalized (50 epochs)     49.86              35.23
# 2    Baseline  normalized (100 epochs)     42.58              16.57

# %% [markdown]
# We can see from the result, that both the Mean of the  MSE (mean squared error) and the Std Deviation  of the MSE reduced when the number of epochs was increased from 50 to 100
