# %% [markdown]
# ## Building a Regression Model using Keras

# %% [markdown]
# ### Table of contents
# 1. Donwnload and clean dataset
# 2. Import Keras
# 3. Build a Neural Network
# 4. Train and Test the Neural Network

# %% [markdown]
# ### Download and Clean Dataset

# %% [markdown]
# We will start by importing the necessary libraries for the project

# %%
import time
import os
import pandas as pd
import numpy as np


from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
conda install -c conda-forge keras
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The dataset that we will use is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used. The ingredients include:
# 1. Cement
# 2. Blast furnace slag
# 3. Fly ash
# 4. Water
# 5. Superplasticizer
# 6. Coarse aggregate
# 7. Fine aggregate

# %% [markdown]
# We will download the data and read it into a pandas daataframe

# %%
concrete_df = pd.read_csv("/Users/juan/Downloads/concrete_data.csv")
concrete_df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# The first sample consists of 540 cubic meters of cement, 0 cubic meters of blast furnace slag and fly ash, 162 cubic meters of water, 2.5 cubic meters of superplasticizer, 1040 cubic meters of fine aggregate, 676 cubic meters of fine aggregate and has a compressive strength of 79.99 MPa at 28 days.

# %% [markdown]
# Check how many data points we have in the data frame

# %%
concrete_df.shape
# Out:
# (1030, 9)

# %% [markdown]
# The next step is to check the dataset for any missing values

# %%
concrete_df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The dataset looks clean so we can proceed to build our model

# %% [markdown]
# #### Split data intro predictors and target

# %%
concrete_df_columns = concrete_df.columns
predictors = concrete_df[concrete_df_columns[concrete_df_columns != "Strength"]] # All columns except Strength
target = concrete_df["Strength"] #Only the column Strength

# %% [markdown]
# Check the first rows for the predictors and target data

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Let's save the number of predictors to n_cols variables, because we will need it when we build our network

# %%
n_cols = predictors.shape[1] #number of predictors

# %% [markdown]
# ### Importing packages from Keras library

# %% [markdown]
# Let's import the packages from the Keras library that we will need to build our regression model

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Part A: Build a baseline model

# %% [markdown]
# Use the Keras library to build a neural network with the following:
#
# One hidden layer of 10 nodes, and a ReLU activation function
#
# Use the adam optimizer and the mean squared error as the loss function.
#
# Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.
#
# Train the model on the training data using 50 epochs.
#
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# Report the mean and the standard deviation of the mean squared errors.

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# Let's create a function that defines our regression model and we can call it to create our model

# %%
#define the regression model with one hidden layer
def regression_model():
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(n_cols,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ####  Train and test the model

# %% [markdown]
# We will create the regression model

# %%
model = regression_model()
# Out:
# WARNING:tensorflow:From /Users/juan/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# Randomly split the data into a training and test sets by holding 30%  of the data for testing. You can use the train_test_split helper function

# %%
X = predictors
y = target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)

# %% [markdown]
# Train the model on the training data using 50 epochs

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# WARNING:tensorflow:From /Users/juan/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 0s - loss: 180527.1437
# Epoch 2/50
#  - 0s - loss: 73816.3552
# Epoch 3/50
#  - 0s - loss: 24301.4264
# Epoch 4/50
#  - 0s - loss: 9429.0605
# Epoch 5/50
#  - 0s - loss: 6735.8674
# Epoch 6/50
#  - 0s - loss: 6215.4641
# Epoch 7/50
#  - 0s - loss: 5925.8628
# Epoch 8/50
#  - 0s - loss: 5623.9222
# Epoch 9/50
#  - 0s - loss: 5337.4198
# Epoch 10/50
#  - 0s - loss: 5047.6248
# Epoch 11/50
#  - 0s - loss: 4774.2336
# Epoch 12/50
#  - 0s - loss: 4507.4581
# Epoch 13/50
#  - 0s - loss: 4256.2851
# Epoch 14/50
#  - 0s - loss: 4008.5407
# Epoch 15/50
#  - 0s - loss: 3782.1135
# Epoch 16/50
#  - 0s - loss: 3562.5313
# Epoch 17/50
#  - 0s - loss: 3354.1346
# Epoch 18/50
#  - 0s - loss: 3162.2124
# Epoch 19/50
#  - 0s - loss: 2972.0130
# Epoch 20/50
#  - 0s - loss: 2795.3107
# Epoch 21/50
#  - 0s - loss: 2636.3989
# Epoch 22/50
#  - 0s - loss: 2478.9551
# Epoch 23/50
#  - 0s - loss: 2335.0443
# Epoch 24/50
#  - 0s - loss: 2198.9506
# Epoch 25/50
#  - 0s - loss: 2076.0854
# Epoch 26/50
#  - 0s - loss: 1960.8697
# Epoch 27/50
#  - 0s - loss: 1850.9651
# Epoch 28/50
#  - 0s - loss: 1752.0061
# Epoch 29/50
#  - 0s - loss: 1658.0867
# Epoch 30/50
#  - 0s - loss: 1570.3309
# Epoch 31/50
#  - 0s - loss: 1492.4591
# Epoch 32/50
#  - 0s - loss: 1415.0668
# Epoch 33/50
#  - 0s - loss: 1342.7992
# Epoch 34/50
#  - 0s - loss: 1274.8581
# Epoch 35/50
#  - 0s - loss: 1215.3113
# Epoch 36/50
#  - 0s - loss: 1157.2364
# Epoch 37/50
#  - 0s - loss: 1102.8009
# Epoch 38/50
#  - 0s - loss: 1052.2301
# Epoch 39/50
#  - 0s - loss: 1006.2093
# Epoch 40/50
#  - 0s - loss: 959.6432
# Epoch 41/50
#  - 0s - loss: 918.0097
# Epoch 42/50
#  - 0s - loss: 878.1788
# Epoch 43/50
#  - 0s - loss: 841.1184
# Epoch 44/50
#  - 0s - loss: 806.1098
# Epoch 45/50
#  - 0s - loss: 777.8710
# Epoch 46/50
#  - 0s - loss: 744.0238
# Epoch 47/50
#  - 0s - loss: 712.7572
# Epoch 48/50
#  - 0s - loss: 682.7574
# Epoch 49/50
#  - 0s - loss: 658.1099
# Epoch 50/50
#  - 0s - loss: 635.0090

# %% [markdown]
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
y_hat = model.predict(X_test)   
mse = mean_squared_error(y_test, y_hat)

# %%
print(mse)
# Out:
# 605.8291324037887

# %% [markdown]
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors

# %% [markdown]
# We will create one function that performs steps 1 to 3 and another function that iterates 50 times and creates the list of 50 mean squared errors

# %%
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """   
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn. 
    X = predictors
    y = target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse

# %%
#Function to round the calculation of the mean and std deviation to 2 decimal places
def get_round(score, num_of_digits=2):
    """Get round with given number of decimal digits 
    """
    return round(score, num_of_digits)

#Function to calculate the mean of the list of mean squared errors
def get_mean(list_of_mse_scores):
    """Get mean
    """
    if list_of_mse_scores:
        return get_round(np.mean(list_of_mse_scores))
    return None

#Function to calculate the standard deviation of the list of mean squared errors
def get_standard_deviation(list_of_mse_scores):
    """Get standard deviation
    """
    if list_of_mse_scores:
        return get_round(np.std(list_of_mse_scores))
    return None




#Function to iterate and calculate the mean squared error
def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
    """Generate the mean and the standard deviation of the mean squared errors 
    """
    # Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.    
    list_of_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        list_of_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))
    # end for

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  list_of_mean_squared_errors))
    
    mean_mse = get_mean(list_of_mean_squared_errors)
    std_mse = get_standard_deviation(list_of_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse

# %%
max_iteration = 50
epochs = 50
verbose = 2

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 119351.8213
# Epoch 2/50
#  - 0s - loss: 44068.6167
# Epoch 3/50
#  - 0s - loss: 11587.9586
# Epoch 4/50
#  - 0s - loss: 3815.3857
# Epoch 5/50
#  - 0s - loss: 3047.8626
# Epoch 6/50
#  - 0s - loss: 2971.1660
# Epoch 7/50
#  - 0s - loss: 2878.7121
# Epoch 8/50
#  - 0s - loss: 2793.7753
# Epoch 9/50
#  - 0s - loss: 2701.1468
# Epoch 10/50
#  - 0s - loss: 2610.0612
# Epoch 11/50
#  - 0s - loss: 2522.3222
# Epoch 12/50
#  - 0s - loss: 2437.0822
# Epoch 13/50
#  - 0s - loss: 2351.9643
# Epoch 14/50
#  - 0s - loss: 2267.0414
# Epoch 15/50
#  - 0s - loss: 2188.4220
# Epoch 16/50
#  - 0s - loss: 2110.2339
# Epoch 17/50
#  - 0s - loss: 2034.0986
# Epoch 18/50
#  - 0s - loss: 1960.7441
# Epoch 19/50
#  - 0s - loss: 1890.8609
# Epoch 20/50
#  - 0s - loss: 1826.7647
# Epoch 21/50
#  - 0s - loss: 1757.2713
# Epoch 22/50
#  - 0s - loss: 1695.7342
# Epoch 23/50
#  - 0s - loss: 1638.9417
# Epoch 24/50
#  - 0s - loss: 1581.0371
# Epoch 25/50
#  - 0s - loss: 1526.6497
# Epoch 26/50
#  - 0s - loss: 1473.0517
# Epoch 27/50
#  - 0s - loss: 1421.9072
# Epoch 28/50
#  - 0s - loss: 1371.5596
# Epoch 29/50
#  - 0s - loss: 1332.4682
# Epoch 30/50
#  - 0s - loss: 1280.6147
# Epoch 31/50
#  - 0s - loss: 1237.3554
# Epoch 32/50
#  - 0s - loss: 1197.7636
# Epoch 33/50
#  - 0s - loss: 1157.5911
# Epoch 34/50
#  - 0s - loss: 1118.8222
# Epoch 35/50
#  - 0s - loss: 1083.0155
# Epoch 36/50
#  - 0s - loss: 1050.5173
# Epoch 37/50
#  - 0s - loss: 1017.5957
# Epoch 38/50
#  - 0s - loss: 979.9804
# Epoch 39/50
#  - 0s - loss: 949.0821
# Epoch 40/50
#  - 0s - loss: 919.8825
# Epoch 41/50
#  - 0s - loss: 888.9914
# Epoch 42/50
#  - 0s - loss: 865.0552
# Epoch 43/50
#  - 0s - loss: 835.3493
# Epoch 44/50
#  - 0s - loss: 807.5523
# Epoch 45/50
#  - 0s - loss: 783.2453
# Epoch 46/50
#  - 0s - loss: 759.8505
# Epoch 47/50
#  - 0s - loss: 735.7915
# Epoch 48/50
#  - 0s - loss: 713.5324
# Epoch 49/50
#  - 0s - loss: 691.8973
# Epoch 50/50
#  - 0s - loss: 673.1022
# Duration (seconds): 2.202594041824341
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 651.5459
# Epoch 2/50
#  - 0s - loss: 635.5862
# Epoch 3/50
#  - 0s - loss: 613.8321
# Epoch 4/50
#  - 0s - loss: 597.7674
# Epoch 5/50
#  - 0s - loss: 580.2898
# Epoch 6/50
#  - 0s - loss: 563.1197
# Epoch 7/50
#  - 0s - loss: 548.5233
# Epoch 8/50
#  - 0s - loss: 532.5541
# Epoch 9/50
#  - 0s - loss: 518.5948
# Epoch 10/50
#  - 0s - loss: 502.7929
# Epoch 11/50
#  - 0s - loss: 490.4791
# Epoch 12/50
#  - 0s - loss: 477.9026
# Epoch 13/50
#  - 0s - loss: 464.1755
# Epoch 14/50
#  - 0s - loss: 452.4858
# Epoch 15/50
#  - 0s - loss: 441.2222
# Epoch 16/50
#  - 0s - loss: 430.9242
# Epoch 17/50
#  - 0s - loss: 420.0395
# Epoch 18/50
#  - 0s - loss: 409.5886
# Epoch 19/50
#  - 0s - loss: 399.8538
# Epoch 20/50
#  - 0s - loss: 390.4771
# Epoch 21/50
#  - 0s - loss: 380.9305
# Epoch 22/50
#  - 0s - loss: 371.4148
# Epoch 23/50
#  - 0s - loss: 364.6385
# Epoch 24/50
#  - 0s - loss: 355.2943
# Epoch 25/50
#  - 0s - loss: 348.6085
# Epoch 26/50
#  - 0s - loss: 342.5056
# Epoch 27/50
#  - 0s - loss: 331.5738
# Epoch 28/50
#  - 0s - loss: 326.3894
# Epoch 29/50
#  - 0s - loss: 323.2790
# Epoch 30/50
#  - 0s - loss: 313.7973
# Epoch 31/50
#  - 0s - loss: 305.6704
# Epoch 32/50
#  - 0s - loss: 300.0624
# Epoch 33/50
#  - 0s - loss: 297.0489
# Epoch 34/50
#  - 0s - loss: 289.6242
# Epoch 35/50
#  - 0s - loss: 283.6880
# Epoch 36/50
#  - 0s - loss: 279.1336
# Epoch 37/50
#  - 0s - loss: 273.6982
# Epoch 38/50
#  - 0s - loss: 268.6361
# Epoch 39/50
#  - 0s - loss: 264.5960
# Epoch 40/50
#  - 0s - loss: 260.3086
# Epoch 41/50
#  - 0s - loss: 257.5156
# Epoch 42/50
#  - 0s - loss: 251.7028
# Epoch 43/50
#  - 0s - loss: 247.8220
# Epoch 44/50
#  - 0s - loss: 244.2755
# Epoch 45/50
#  - 0s - loss: 240.6241
# Epoch 46/50
#  - 0s - loss: 236.7893
# Epoch 47/50
#  - 0s - loss: 233.9144
# Epoch 48/50
#  - 0s - loss: 230.4933
# Epoch 49/50
#  - 0s - loss: 227.1546
# Epoch 50/50
#  - 0s - loss: 224.4372
# Duration (seconds): 1.5903208255767822
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 221.4305
# Epoch 2/50
#  - 0s - loss: 219.7293
# Epoch 3/50
#  - 0s - loss: 216.6761
# Epoch 4/50
#  - 0s - loss: 213.4713
# Epoch 5/50
#  - 0s - loss: 210.9495
# Epoch 6/50
#  - 0s - loss: 209.0660
# Epoch 7/50
#  - 0s - loss: 208.5826
# Epoch 8/50
#  - 0s - loss: 204.5616
# Epoch 9/50
#  - 0s - loss: 203.2557
# Epoch 10/50
#  - 0s - loss: 199.3394
# Epoch 11/50
#  - 0s - loss: 199.4718
# Epoch 12/50
#  - 0s - loss: 198.2825
# Epoch 13/50
#  - 0s - loss: 194.0886
# Epoch 14/50
#  - 0s - loss: 191.6429
# Epoch 15/50
#  - 0s - loss: 190.8742
# Epoch 16/50
#  - 0s - loss: 190.6218
# Epoch 17/50
#  - 0s - loss: 186.3752
# Epoch 18/50
#  - 0s - loss: 185.2895
# Epoch 19/50
#  - 0s - loss: 182.7166
# Epoch 20/50
#  - 0s - loss: 181.0959
# Epoch 21/50
#  - 0s - loss: 179.6019
# Epoch 22/50
#  - 0s - loss: 178.0307
# Epoch 23/50
#  - 0s - loss: 177.9229
# Epoch 24/50
#  - 0s - loss: 176.7702
# Epoch 25/50
#  - 0s - loss: 174.4711
# Epoch 26/50
#  - 0s - loss: 173.9271
# Epoch 27/50
#  - 0s - loss: 172.1459
# Epoch 28/50
#  - 0s - loss: 169.8696
# Epoch 29/50
#  - 0s - loss: 168.5938
# Epoch 30/50
#  - 0s - loss: 168.1550
# Epoch 31/50
#  - 0s - loss: 167.8790
# Epoch 32/50
#  - 0s - loss: 165.7045
# Epoch 33/50
#  - 0s - loss: 163.4858
# Epoch 34/50
#  - 0s - loss: 164.9882
# Epoch 35/50
#  - 0s - loss: 164.0539
# Epoch 36/50
#  - 0s - loss: 163.7439
# Epoch 37/50
#  - 0s - loss: 163.0755
# Epoch 38/50
#  - 0s - loss: 159.6896
# Epoch 39/50
#  - 0s - loss: 157.3888
# Epoch 40/50
#  - 0s - loss: 157.0591
# Epoch 41/50
#  - 0s - loss: 155.4002
# Epoch 42/50
#  - 0s - loss: 154.7421
# Epoch 43/50
#  - 0s - loss: 153.1592
# Epoch 44/50
#  - 0s - loss: 153.7308
# Epoch 45/50
#  - 0s - loss: 151.1898
# Epoch 46/50
#  - 0s - loss: 151.9659
# Epoch 47/50
#  - 0s - loss: 149.8352
# Epoch 48/50
#  - 0s - loss: 151.4439
# Epoch 49/50
#  - 0s - loss: 149.5972
# Epoch 50/50
#  - 0s - loss: 147.7613
# Duration (seconds): 1.5968787670135498
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 146.9062
# Epoch 2/50
#  - 0s - loss: 145.7700
# Epoch 3/50
#  - 0s - loss: 144.4273
# Epoch 4/50
#  - 0s - loss: 144.9122
# Epoch 5/50
#  - 0s - loss: 144.7870
# Epoch 6/50
#  - 0s - loss: 141.6040
# Epoch 7/50
#  - 0s - loss: 142.4226
# Epoch 8/50
#  - 0s - loss: 140.4344
# Epoch 9/50
#  - 0s - loss: 141.4880
# Epoch 10/50
#  - 0s - loss: 139.4228
# Epoch 11/50
#  - 0s - loss: 138.3010
# Epoch 12/50
#  - 0s - loss: 137.6991
# Epoch 13/50
#  - 0s - loss: 139.1217
# Epoch 14/50
#  - 0s - loss: 138.9901
# Epoch 15/50
#  - 0s - loss: 136.0963
# Epoch 16/50
#  - 0s - loss: 136.9012
# Epoch 17/50
#  - 0s - loss: 135.4426
# Epoch 18/50
#  - 0s - loss: 133.8100
# Epoch 19/50
#  - 0s - loss: 132.8328
# Epoch 20/50
#  - 0s - loss: 135.3473
# Epoch 21/50
#  - 0s - loss: 133.2805
# Epoch 22/50
#  - 0s - loss: 131.1919
# Epoch 23/50
#  - 0s - loss: 131.6226
# Epoch 24/50
#  - 0s - loss: 130.3912
# Epoch 25/50
#  - 0s - loss: 130.3274
# Epoch 26/50
#  - 0s - loss: 129.1935
# Epoch 27/50
#  - 0s - loss: 129.4114
# Epoch 28/50
#  - 0s - loss: 130.0341
# Epoch 29/50
#  - 0s - loss: 128.8992
# Epoch 30/50
#  - 0s - loss: 127.2322
# Epoch 31/50
#  - 0s - loss: 126.6681
# Epoch 32/50
#  - 0s - loss: 125.9479
# Epoch 33/50
#  - 0s - loss: 125.7897
# Epoch 34/50
#  - 0s - loss: 126.6862
# Epoch 35/50
#  - 0s - loss: 125.4601
# Epoch 36/50
#  - 0s - loss: 124.3301
# Epoch 37/50
#  - 0s - loss: 123.8034
# Epoch 38/50
#  - 0s - loss: 125.2783
# Epoch 39/50
#  - 0s - loss: 122.4192
# Epoch 40/50
#  - 0s - loss: 123.0518
# Epoch 41/50
#  - 0s - loss: 122.0209
# Epoch 42/50
#  - 0s - loss: 121.8573
# Epoch 43/50
#  - 0s - loss: 122.5664
# Epoch 44/50
#  - 0s - loss: 120.7156
# Epoch 45/50
#  - 0s - loss: 123.2213
# Epoch 46/50
#  - 0s - loss: 123.4399
# Epoch 47/50
#  - 0s - loss: 121.3325
# Epoch 48/50
#  - 0s - loss: 119.7669
# Epoch 49/50
#  - 0s - loss: 119.9211
# Epoch 50/50
#  - 0s - loss: 118.6837
# Duration (seconds): 1.6041736602783203
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 118.1702
# Epoch 2/50
#  - 0s - loss: 122.0537
# Epoch 3/50
#  - 0s - loss: 117.3903
# Epoch 4/50
#  - 0s - loss: 119.1446
# Epoch 5/50
#  - 0s - loss: 116.8885
# Epoch 6/50
#  - 0s - loss: 117.1750
# Epoch 7/50
#  - 0s - loss: 116.5089
# Epoch 8/50
#  - 0s - loss: 116.2622
# Epoch 9/50
#  - 0s - loss: 119.4986
# Epoch 10/50
#  - 0s - loss: 121.3106
# Epoch 11/50
#  - 0s - loss: 118.5375
# Epoch 12/50
#  - 0s - loss: 114.8348
# Epoch 13/50
#  - 0s - loss: 116.9044
# Epoch 14/50
#  - 0s - loss: 115.1019
# Epoch 15/50
#  - 0s - loss: 115.1515
# Epoch 16/50
#  - 0s - loss: 114.8311
# Epoch 17/50
#  - 0s - loss: 116.1888
# Epoch 18/50
#  - 0s - loss: 114.3757
# Epoch 19/50
#  - 0s - loss: 114.5324
# Epoch 20/50
#  - 0s - loss: 113.6011
# Epoch 21/50
#  - 0s - loss: 113.8618
# Epoch 22/50
#  - 0s - loss: 115.1044
# Epoch 23/50
#  - 0s - loss: 114.9299
# Epoch 24/50
#  - 0s - loss: 114.8413
# Epoch 25/50
#  - 0s - loss: 113.3982
# Epoch 26/50
#  - 0s - loss: 112.4151
# Epoch 27/50
#  - 0s - loss: 113.3654
# Epoch 28/50
#  - 0s - loss: 113.7679
# Epoch 29/50
#  - 0s - loss: 115.4232
# Epoch 30/50
#  - 0s - loss: 114.4394
# Epoch 31/50
#  - 0s - loss: 112.5570
# Epoch 32/50
#  - 0s - loss: 111.3377
# Epoch 33/50
#  - 0s - loss: 111.6659
# Epoch 34/50
#  - 0s - loss: 111.5528
# Epoch 35/50
#  - 0s - loss: 112.7256
# Epoch 36/50
#  - 0s - loss: 112.1523
# Epoch 37/50
#  - 0s - loss: 111.9268
# Epoch 38/50
#  - 0s - loss: 111.5143
# Epoch 39/50
#  - 0s - loss: 109.9495
# Epoch 40/50
#  - 0s - loss: 113.0982
# Epoch 41/50
#  - 0s - loss: 114.8532
# Epoch 42/50
#  - 0s - loss: 111.5504
# Epoch 43/50
#  - 0s - loss: 110.7824
# Epoch 44/50
#  - 0s - loss: 109.8766
# Epoch 45/50
#  - 0s - loss: 109.7822
# Epoch 46/50
#  - 0s - loss: 110.5408
# Epoch 47/50
#  - 0s - loss: 111.9544
# Epoch 48/50
#  - 0s - loss: 111.0190
# Epoch 49/50
#  - 0s - loss: 110.1372
# Epoch 50/50
#  - 0s - loss: 110.2997
# Duration (seconds): 1.5861351490020752
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 110.5275
# Epoch 2/50
#  - 0s - loss: 110.5941
# Epoch 3/50
#  - 0s - loss: 109.8900
# Epoch 4/50
#  - 0s - loss: 110.9630
# Epoch 5/50
#  - 0s - loss: 110.8451
# Epoch 6/50
#  - 0s - loss: 113.0605
# Epoch 7/50
#  - 0s - loss: 111.4115
# Epoch 8/50
#  - 0s - loss: 111.4121
# Epoch 9/50
#  - 0s - loss: 109.9275
# Epoch 10/50
#  - 0s - loss: 110.1481
# Epoch 11/50
#  - 0s - loss: 109.9975
# Epoch 12/50
#  - 0s - loss: 109.1031
# Epoch 13/50
#  - 0s - loss: 109.2379
# Epoch 14/50
#  - 0s - loss: 109.6503
# Epoch 15/50
#  - 0s - loss: 109.8192
# Epoch 16/50
#  - 0s - loss: 111.4060
# Epoch 17/50
#  - 0s - loss: 112.3298
# Epoch 18/50
#  - 0s - loss: 109.3523
# Epoch 19/50
#  - 0s - loss: 110.4743
# Epoch 20/50
#  - 0s - loss: 110.0698
# Epoch 21/50
#  - 0s - loss: 108.6501
# Epoch 22/50
#  - 0s - loss: 109.2710
# Epoch 23/50
#  - 0s - loss: 108.0474
# Epoch 24/50
#  - 0s - loss: 109.1269
# Epoch 25/50
#  - 0s - loss: 112.3574
# Epoch 26/50
#  - 0s - loss: 109.7769
# Epoch 27/50
#  - 0s - loss: 110.7157
# Epoch 28/50
#  - 0s - loss: 112.3020
# Epoch 29/50
#  - 0s - loss: 111.8142
# Epoch 30/50
#  - 0s - loss: 109.1224
# Epoch 31/50
#  - 0s - loss: 109.3076
# Epoch 32/50
#  - 0s - loss: 109.3411
# Epoch 33/50
#  - 0s - loss: 110.0945
# Epoch 34/50
#  - 0s - loss: 111.3947
# Epoch 35/50
#  - 0s - loss: 116.1456
# Epoch 36/50
#  - 0s - loss: 115.7160
# Epoch 37/50
#  - 0s - loss: 112.9506
# Epoch 38/50
#  - 0s - loss: 109.4879
# Epoch 39/50
#  - 0s - loss: 108.5190
# Epoch 40/50
#  - 0s - loss: 108.6484
# Epoch 41/50
#  - 0s - loss: 108.4527
# Epoch 42/50
#  - 0s - loss: 113.1661
# Epoch 43/50
#  - 0s - loss: 109.1059
# Epoch 44/50
#  - 0s - loss: 108.8835
# Epoch 45/50
#  - 0s - loss: 110.5444
# Epoch 46/50
#  - 0s - loss: 109.2750
# Epoch 47/50
#  - 0s - loss: 110.4643
# Epoch 48/50
#  - 0s - loss: 110.8300
# Epoch 49/50
#  - 0s - loss: 111.3855
# Epoch 50/50
#  - 0s - loss: 110.3295
# Duration (seconds): 1.618345022201538
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 111.2650
# Epoch 2/50
#  - 0s - loss: 114.0285
# Epoch 3/50
#  - 0s - loss: 111.3554
# Epoch 4/50
#  - 0s - loss: 108.2837
# Epoch 5/50
#  - 0s - loss: 115.0046
# Epoch 6/50
#  - 0s - loss: 109.2933
# Epoch 7/50
#  - 0s - loss: 110.3983
# Epoch 8/50
#  - 0s - loss: 113.7475
# Epoch 9/50
#  - 0s - loss: 109.8596
# Epoch 10/50
#  - 0s - loss: 112.9680
# Epoch 11/50
#  - 0s - loss: 111.1377
# Epoch 12/50
#  - 0s - loss: 109.6805
# Epoch 13/50
#  - 0s - loss: 111.4863
# Epoch 14/50
#  - 0s - loss: 112.8820
# Epoch 15/50
#  - 0s - loss: 109.6476
# Epoch 16/50
#  - 0s - loss: 108.9591
# Epoch 17/50
#  - 0s - loss: 112.8125
# Epoch 18/50
#  - 0s - loss: 113.7882
# Epoch 19/50
#  - 0s - loss: 110.6381
# Epoch 20/50
#  - 0s - loss: 115.9307
# Epoch 21/50
#  - 0s - loss: 111.4328
# Epoch 22/50
#  - 0s - loss: 110.9397
# Epoch 23/50
#  - 0s - loss: 110.2890
# Epoch 24/50
#  - 0s - loss: 114.3881
# Epoch 25/50
#  - 0s - loss: 110.3484
# Epoch 26/50
#  - 0s - loss: 109.3227
# Epoch 27/50
#  - 0s - loss: 109.4067
# Epoch 28/50
#  - 0s - loss: 110.6922
# Epoch 29/50
#  - 0s - loss: 109.3369
# Epoch 30/50
#  - 0s - loss: 110.0839
# Epoch 31/50
#  - 0s - loss: 108.5213
# Epoch 32/50
#  - 0s - loss: 110.4896
# Epoch 33/50
#  - 0s - loss: 111.0087
# Epoch 34/50
#  - 0s - loss: 110.2763
# Epoch 35/50
#  - 0s - loss: 111.7489
# Epoch 36/50
#  - 0s - loss: 112.1200
# Epoch 37/50
#  - 0s - loss: 116.6680
# Epoch 38/50
#  - 0s - loss: 112.6010
# Epoch 39/50
#  - 0s - loss: 110.7165
# Epoch 40/50
#  - 0s - loss: 111.4201
# Epoch 41/50
#  - 0s - loss: 109.5099
# Epoch 42/50
#  - 0s - loss: 110.4446
# Epoch 43/50
#  - 0s - loss: 112.3066
# Epoch 44/50
#  - 0s - loss: 109.4398
# Epoch 45/50
#  - 0s - loss: 110.2814
# Epoch 46/50
#  - 0s - loss: 113.0705
# Epoch 47/50
#  - 0s - loss: 111.1002
# Epoch 48/50
#  - 0s - loss: 110.2572
# Epoch 49/50
#  - 0s - loss: 109.6263
# Epoch 50/50
#  - 0s - loss: 108.1848
# Duration (seconds): 1.728503704071045
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 109.1140
# Epoch 2/50
#  - 0s - loss: 112.3582
# Epoch 3/50
#  - 0s - loss: 110.5855
# Epoch 4/50
#  - 0s - loss: 108.8184
# Epoch 5/50
#  - 0s - loss: 109.5111
# Epoch 6/50
#  - 0s - loss: 109.7369
# Epoch 7/50
#  - 0s - loss: 108.8691
# Epoch 8/50
#  - 0s - loss: 108.5783
# Epoch 9/50
#  - 0s - loss: 114.8773
# Epoch 10/50
#  - 0s - loss: 108.1981
# Epoch 11/50
#  - 0s - loss: 113.6138
# Epoch 12/50
#  - 0s - loss: 111.8704
# Epoch 13/50
#  - 0s - loss: 108.3620
# Epoch 14/50
#  - 0s - loss: 109.2679
# Epoch 15/50
#  - 0s - loss: 109.2412
# Epoch 16/50
#  - 0s - loss: 113.0512
# Epoch 17/50
#  - 0s - loss: 112.9787
# Epoch 18/50
#  - 0s - loss: 108.8700
# Epoch 19/50
#  - 0s - loss: 108.7083
# Epoch 20/50
#  - 0s - loss: 111.3167
# Epoch 21/50
#  - 0s - loss: 111.4287
# Epoch 22/50
#  - 0s - loss: 110.9788
# Epoch 23/50
#  - 0s - loss: 110.1489
# Epoch 24/50
#  - 0s - loss: 109.8193
# Epoch 25/50
#  - 0s - loss: 111.3887
# Epoch 26/50
#  - 0s - loss: 110.0042
# Epoch 27/50
#  - 0s - loss: 113.8604
# Epoch 28/50
#  - 0s - loss: 114.4100
# Epoch 29/50
#  - 0s - loss: 110.2854
# Epoch 30/50
#  - 0s - loss: 109.5511
# Epoch 31/50
#  - 0s - loss: 111.4845
# Epoch 32/50
#  - 0s - loss: 108.4061
# Epoch 33/50
#  - 0s - loss: 109.7209
# Epoch 34/50
#  - 0s - loss: 108.7789
# Epoch 35/50
#  - 0s - loss: 109.0451
# Epoch 36/50
#  - 0s - loss: 113.1815
# Epoch 37/50
#  - 0s - loss: 112.4625
# Epoch 38/50
#  - 0s - loss: 109.8512
# Epoch 39/50
#  - 0s - loss: 109.7568
# Epoch 40/50
#  - 0s - loss: 109.8476
# Epoch 41/50
#  - 0s - loss: 110.3233
# Epoch 42/50
#  - 0s - loss: 109.8761
# Epoch 43/50
#  - 0s - loss: 109.1389
# Epoch 44/50
#  - 0s - loss: 112.4383
# Epoch 45/50
#  - 0s - loss: 112.2284
# Epoch 46/50
#  - 0s - loss: 109.3938
# Epoch 47/50
#  - 0s - loss: 108.7985
# Epoch 48/50
#  - 0s - loss: 108.0794
# Epoch 49/50
#  - 0s - loss: 109.1291
# Epoch 50/50
#  - 0s - loss: 109.2559
# Duration (seconds): 1.5951170921325684
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 108.8279
# Epoch 2/50
#  - 0s - loss: 112.0079
# Epoch 3/50
#  - 0s - loss: 109.8656
# Epoch 4/50
#  - 0s - loss: 111.4032
# Epoch 5/50
#  - 0s - loss: 109.6933
# Epoch 6/50
#  - 0s - loss: 109.4618
# Epoch 7/50
#  - 0s - loss: 111.8755
# Epoch 8/50
#  - 0s - loss: 118.8254
# Epoch 9/50
#  - 0s - loss: 112.2305
# Epoch 10/50
#  - 0s - loss: 109.6853
# Epoch 11/50
#  - 0s - loss: 107.6118
# Epoch 12/50
#  - 0s - loss: 109.2751
# Epoch 13/50
#  - 0s - loss: 109.1082
# Epoch 14/50
#  - 0s - loss: 112.1877
# Epoch 15/50
#  - 0s - loss: 113.2068
# Epoch 16/50
#  - 0s - loss: 115.0233
# Epoch 17/50
#  - 0s - loss: 110.3027
# Epoch 18/50
#  - 0s - loss: 110.5588
# Epoch 19/50
#  - 0s - loss: 108.2961
# Epoch 20/50
#  - 0s - loss: 109.8980
# Epoch 21/50
#  - 0s - loss: 110.9608
# Epoch 22/50
#  - 0s - loss: 117.1747
# Epoch 23/50
#  - 0s - loss: 117.4275
# Epoch 24/50
#  - 0s - loss: 110.7847
# Epoch 25/50
#  - 0s - loss: 111.3359
# Epoch 26/50
#  - 0s - loss: 109.2615
# Epoch 27/50
#  - 0s - loss: 108.5318
# Epoch 28/50
#  - 0s - loss: 109.3895
# Epoch 29/50
#  - 0s - loss: 111.4079
# Epoch 30/50
#  - 0s - loss: 112.3999
# Epoch 31/50
#  - 0s - loss: 113.3145
# Epoch 32/50
#  - 0s - loss: 108.7988
# Epoch 33/50
#  - 0s - loss: 111.0278
# Epoch 34/50
#  - 0s - loss: 111.0162
# Epoch 35/50
#  - 0s - loss: 107.5076
# Epoch 36/50
#  - 0s - loss: 110.7231
# Epoch 37/50
#  - 0s - loss: 109.8144
# Epoch 38/50
#  - 0s - loss: 109.5096
# Epoch 39/50
#  - 0s - loss: 112.9320
# Epoch 40/50
#  - 0s - loss: 111.2794
# Epoch 41/50
#  - 0s - loss: 114.4152
# Epoch 42/50
#  - 0s - loss: 110.6697
# Epoch 43/50
#  - 0s - loss: 109.1496
# Epoch 44/50
#  - 0s - loss: 108.4945
# Epoch 45/50
#  - 0s - loss: 108.9532
# Epoch 46/50
#  - 0s - loss: 110.6351
# Epoch 47/50
#  - 0s - loss: 109.5964
# Epoch 48/50
#  - 0s - loss: 109.8315
# Epoch 49/50
#  - 0s - loss: 113.2011
# Epoch 50/50
#  - 0s - loss: 112.6939
# Duration (seconds): 1.5668201446533203
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 112.6857
# Epoch 2/50
#  - 0s - loss: 109.1176
# Epoch 3/50
#  - 0s - loss: 112.6386
# Epoch 4/50
#  - 0s - loss: 115.0238
# Epoch 5/50
#  - 0s - loss: 107.9514
# Epoch 6/50
#  - 0s - loss: 109.3057
# Epoch 7/50
#  - 0s - loss: 111.1925
# Epoch 8/50
#  - 0s - loss: 112.1937
# Epoch 9/50
#  - 0s - loss: 109.6371
# Epoch 10/50
#  - 0s - loss: 109.0010
# Epoch 11/50
#  - 0s - loss: 110.0785
# Epoch 12/50
#  - 0s - loss: 111.3026
# Epoch 13/50
#  - 0s - loss: 117.0506
# Epoch 14/50
#  - 0s - loss: 110.3696
# Epoch 15/50
#  - 0s - loss: 109.5243
# Epoch 16/50
#  - 0s - loss: 109.4984
# Epoch 17/50
#  - 0s - loss: 115.1221
# Epoch 18/50
#  - 0s - loss: 109.4899
# Epoch 19/50
#  - 0s - loss: 115.5612
# Epoch 20/50
#  - 0s - loss: 110.3858
# Epoch 21/50
#  - 0s - loss: 108.6817
# Epoch 22/50
#  - 0s - loss: 109.0762
# Epoch 23/50
#  - 0s - loss: 110.1056
# Epoch 24/50
#  - 0s - loss: 110.7899
# Epoch 25/50
#  - 0s - loss: 108.4191
# Epoch 26/50
#  - 0s - loss: 110.2255
# Epoch 27/50
#  - 0s - loss: 111.1170
# Epoch 28/50
#  - 0s - loss: 112.1464
# Epoch 29/50
#  - 0s - loss: 109.2078
# Epoch 30/50
#  - 0s - loss: 108.9346
# Epoch 31/50
#  - 0s - loss: 109.5926
# Epoch 32/50
#  - 0s - loss: 110.6496
# Epoch 33/50
#  - 0s - loss: 114.6090
# Epoch 34/50
#  - 0s - loss: 112.6581
# Epoch 35/50
#  - 0s - loss: 110.5001
# Epoch 36/50
#  - 0s - loss: 110.4460
# Epoch 37/50
#  - 0s - loss: 109.8529
# Epoch 38/50
#  - 0s - loss: 110.7696
# Epoch 39/50
#  - 0s - loss: 108.1486
# Epoch 40/50
#  - 0s - loss: 109.6669
# Epoch 41/50
#  - 0s - loss: 111.3128
# Epoch 42/50
#  - 0s - loss: 111.9610
# Epoch 43/50
#  - 0s - loss: 109.6500
# Epoch 44/50
#  - 0s - loss: 110.6014
# Epoch 45/50
#  - 0s - loss: 109.2706
# Epoch 46/50
#  - 0s - loss: 110.5779
# Epoch 47/50
#  - 0s - loss: 114.0878
# Epoch 48/50
#  - 0s - loss: 110.7601
# Epoch 49/50
#  - 0s - loss: 110.8787
# Epoch 50/50
#  - 0s - loss: 109.8694
# Duration (seconds): 1.8621270656585693
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 111.5371
# Epoch 2/50
#  - 0s - loss: 109.5220
# Epoch 3/50
#  - 0s - loss: 111.8316
# Epoch 4/50
#  - 0s - loss: 109.8244
# Epoch 5/50
#  - 0s - loss: 118.1792
# Epoch 6/50
#  - 0s - loss: 109.0513
# Epoch 7/50
#  - 0s - loss: 110.7627
# Epoch 8/50
#  - 0s - loss: 108.8477
# Epoch 9/50
#  - 0s - loss: 110.7434
# Epoch 10/50
#  - 0s - loss: 118.3606
# Epoch 11/50
#  - 0s - loss: 108.5109
# Epoch 12/50
#  - 0s - loss: 109.6395
# Epoch 13/50
#  - 0s - loss: 112.3284
# Epoch 14/50
#  - 0s - loss: 113.9247
# Epoch 15/50
#  - 0s - loss: 110.3731
# Epoch 16/50
#  - 0s - loss: 109.1016
# Epoch 17/50
#  - 0s - loss: 111.7618
# Epoch 18/50
#  - 0s - loss: 111.4296
# Epoch 19/50
#  - 0s - loss: 109.7833
# Epoch 20/50
#  - 0s - loss: 108.6601
# Epoch 21/50
#  - 0s - loss: 111.3349
# Epoch 22/50
#  - 0s - loss: 109.7380
# Epoch 23/50
#  - 0s - loss: 112.7958
# Epoch 24/50
#  - 0s - loss: 112.0750
# Epoch 25/50
#  - 0s - loss: 111.7445
# Epoch 26/50
#  - 0s - loss: 116.0043
# Epoch 27/50
#  - 0s - loss: 109.1560
# Epoch 28/50
#  - 0s - loss: 108.7744
# Epoch 29/50
#  - 0s - loss: 109.8424
# Epoch 30/50
#  - 0s - loss: 108.0350
# Epoch 31/50
#  - 0s - loss: 108.6040
# Epoch 32/50
#  - 0s - loss: 110.7802
# Epoch 33/50
#  - 0s - loss: 116.0571
# Epoch 34/50
#  - 0s - loss: 116.7730
# Epoch 35/50
#  - 0s - loss: 113.1625
# Epoch 36/50
#  - 0s - loss: 111.0996
# Epoch 37/50
#  - 0s - loss: 108.4625
# Epoch 38/50
#  - 0s - loss: 108.4735
# Epoch 39/50
#  - 0s - loss: 108.6460
# Epoch 40/50
#  - 0s - loss: 112.0186
# Epoch 41/50
#  - 0s - loss: 109.9761
# Epoch 42/50
#  - 0s - loss: 112.6772
# Epoch 43/50
#  - 0s - loss: 112.5851
# Epoch 44/50
#  - 0s - loss: 111.8108
# Epoch 45/50
#  - 0s - loss: 110.4404
# Epoch 46/50
#  - 0s - loss: 113.4050
# Epoch 47/50
#  - 0s - loss: 111.0973
# Epoch 48/50
#  - 0s - loss: 109.5860
# Epoch 49/50
#  - 0s - loss: 108.9159
# Epoch 50/50
#  - 0s - loss: 114.8147
# Duration (seconds): 2.008265256881714
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 111.0458
# Epoch 2/50
#  - 0s - loss: 116.7683
# Epoch 3/50
#  - 0s - loss: 111.5153
# Epoch 4/50
#  - 0s - loss: 110.6500
# Epoch 5/50
#  - 0s - loss: 112.6004
# Epoch 6/50
#  - 0s - loss: 113.7943
# Epoch 7/50
#  - 0s - loss: 110.2774
# Epoch 8/50
#  - 0s - loss: 109.1949
# Epoch 9/50
#  - 0s - loss: 108.8099
# Epoch 10/50
#  - 0s - loss: 109.0798
# Epoch 11/50
#  - 0s - loss: 110.7029
# Epoch 12/50
#  - 0s - loss: 108.2901
# Epoch 13/50
#  - 0s - loss: 110.9851
# Epoch 14/50
#  - 0s - loss: 111.9292
# Epoch 15/50
#  - 0s - loss: 108.9367
# Epoch 16/50
#  - 0s - loss: 108.3153
# Epoch 17/50
#  - 0s - loss: 111.6241
# Epoch 18/50
#  - 0s - loss: 110.1861
# Epoch 19/50
#  - 0s - loss: 107.5806
# Epoch 20/50
#  - 0s - loss: 108.9018
# Epoch 21/50
#  - 0s - loss: 111.2289
# Epoch 22/50
#  - 0s - loss: 106.9747
# Epoch 23/50
#  - 0s - loss: 110.8852
# Epoch 24/50
#  - 0s - loss: 108.5703
# Epoch 25/50
#  - 0s - loss: 107.1622
# Epoch 26/50
#  - 0s - loss: 107.4299
# Epoch 27/50
#  - 0s - loss: 106.1115
# Epoch 28/50
#  - 0s - loss: 105.1559
# Epoch 29/50
#  - 0s - loss: 107.0015
# Epoch 30/50
#  - 0s - loss: 108.6878
# Epoch 31/50
#  - 0s - loss: 106.0388
# Epoch 32/50
#  - 0s - loss: 106.9713
# Epoch 33/50
#  - 0s - loss: 107.2293
# Epoch 34/50
#  - 0s - loss: 101.9946
# Epoch 35/50
#  - 0s - loss: 102.0391
# Epoch 36/50
#  - 0s - loss: 100.3188
# Epoch 37/50
#  - 0s - loss: 101.0911
# Epoch 38/50
#  - 0s - loss: 99.5657
# Epoch 39/50
#  - 0s - loss: 103.0920
# Epoch 40/50
#  - 0s - loss: 99.2099
# Epoch 41/50
#  - 0s - loss: 104.1030
# Epoch 42/50
#  - 0s - loss: 98.8875
# Epoch 43/50
#  - 0s - loss: 95.1052
# Epoch 44/50
#  - 0s - loss: 94.7855
# Epoch 45/50
#  - 0s - loss: 93.0763
# Epoch 46/50
#  - 0s - loss: 91.4682
# Epoch 47/50
#  - 0s - loss: 95.2991
# Epoch 48/50
#  - 0s - loss: 93.1403
# Epoch 49/50
#  - 0s - loss: 89.9598
# Epoch 50/50
#  - 0s - loss: 90.2174
# Duration (seconds): 2.0557589530944824
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 92.4968
# Epoch 2/50
#  - 0s - loss: 88.7735
# Epoch 3/50
#  - 0s - loss: 88.9305
# Epoch 4/50
#  - 0s - loss: 87.1801
# Epoch 5/50
#  - 0s - loss: 87.6763
# Epoch 6/50
#  - 0s - loss: 83.5181
# Epoch 7/50
#  - 0s - loss: 83.5325
# Epoch 8/50
#  - 0s - loss: 82.4195
# Epoch 9/50
#  - 0s - loss: 84.5182
# Epoch 10/50
#  - 0s - loss: 84.0221
# Epoch 11/50
#  - 0s - loss: 81.1750
# Epoch 12/50
#  - 0s - loss: 78.9532
# Epoch 13/50
#  - 0s - loss: 79.5588
# Epoch 14/50
#  - 0s - loss: 78.3605
# Epoch 15/50
#  - 0s - loss: 76.6395
# Epoch 16/50
#  - 0s - loss: 76.4914
# Epoch 17/50
#  - 0s - loss: 77.1180
# Epoch 18/50
#  - 0s - loss: 80.3652
# Epoch 19/50
#  - 0s - loss: 76.5149
# Epoch 20/50
#  - 0s - loss: 80.6290
# Epoch 21/50
#  - 0s - loss: 78.2826
# Epoch 22/50
#  - 0s - loss: 77.2325
# Epoch 23/50
#  - 0s - loss: 77.6333
# Epoch 24/50
#  - 0s - loss: 73.2490
# Epoch 25/50
#  - 0s - loss: 73.5160
# Epoch 26/50
#  - 0s - loss: 73.8964
# Epoch 27/50
#  - 0s - loss: 73.1844
# Epoch 28/50
#  - 0s - loss: 71.9048
# Epoch 29/50
#  - 0s - loss: 72.8126
# Epoch 30/50
#  - 0s - loss: 73.2933
# Epoch 31/50
#  - 0s - loss: 71.9982
# Epoch 32/50
#  - 0s - loss: 71.7435
# Epoch 33/50
#  - 0s - loss: 73.1640
# Epoch 34/50
#  - 0s - loss: 72.7347
# Epoch 35/50
#  - 0s - loss: 74.3217
# Epoch 36/50
#  - 0s - loss: 70.9032
# Epoch 37/50
#  - 0s - loss: 73.8517
# Epoch 38/50
#  - 0s - loss: 72.4812
# Epoch 39/50
#  - 0s - loss: 72.1978
# Epoch 40/50
#  - 0s - loss: 75.9486
# Epoch 41/50
#  - 0s - loss: 72.2879
# Epoch 42/50
#  - 0s - loss: 70.2904
# Epoch 43/50
#  - 0s - loss: 70.2876
# Epoch 44/50
#  - 0s - loss: 69.4118
# Epoch 45/50
#  - 0s - loss: 69.3082
# Epoch 46/50
#  - 0s - loss: 68.6949
# Epoch 47/50
#  - 0s - loss: 73.1744
# Epoch 48/50
#  - 0s - loss: 68.9091
# Epoch 49/50
#  - 0s - loss: 68.9415
# Epoch 50/50
#  - 0s - loss: 69.4363
# Duration (seconds): 2.176454782485962
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 68.0070
# Epoch 2/50
#  - 0s - loss: 70.0159
# Epoch 3/50
#  - 0s - loss: 69.1469
# Epoch 4/50
#  - 0s - loss: 67.7544
# Epoch 5/50
#  - 0s - loss: 69.5409
# Epoch 6/50
#  - 0s - loss: 68.2765
# Epoch 7/50
#  - 0s - loss: 69.3738
# Epoch 8/50
#  - 0s - loss: 70.9286
# Epoch 9/50
#  - 0s - loss: 74.1426
# Epoch 10/50
#  - 0s - loss: 69.1908
# Epoch 11/50
#  - 0s - loss: 71.9449
# Epoch 12/50
#  - 0s - loss: 69.2201
# Epoch 13/50
#  - 0s - loss: 68.3238
# Epoch 14/50
#  - 0s - loss: 68.5944
# Epoch 15/50
#  - 0s - loss: 69.1530
# Epoch 16/50
#  - 0s - loss: 67.9868
# Epoch 17/50
#  - 0s - loss: 68.2019
# Epoch 18/50
#  - 0s - loss: 68.0158
# Epoch 19/50
#  - 0s - loss: 67.8655
# Epoch 20/50
#  - 0s - loss: 68.0395
# Epoch 21/50
#  - 0s - loss: 67.0187
# Epoch 22/50
#  - 0s - loss: 67.7580
# Epoch 23/50
#  - 0s - loss: 67.4400
# Epoch 24/50
#  - 0s - loss: 71.5928
# Epoch 25/50
#  - 0s - loss: 74.5128
# Epoch 26/50
#  - 0s - loss: 67.4264
# Epoch 27/50
#  - 0s - loss: 66.7127
# Epoch 28/50
#  - 0s - loss: 67.5228
# Epoch 29/50
#  - 0s - loss: 68.9889
# Epoch 30/50
#  - 0s - loss: 66.5846
# Epoch 31/50
#  - 0s - loss: 73.5811
# Epoch 32/50
#  - 0s - loss: 67.8068
# Epoch 33/50
#  - 0s - loss: 66.4883
# Epoch 34/50
#  - 0s - loss: 67.0021
# Epoch 35/50
#  - 0s - loss: 70.6748
# Epoch 36/50
#  - 0s - loss: 69.5347
# Epoch 37/50
#  - 0s - loss: 66.0738
# Epoch 38/50
#  - 0s - loss: 67.2808
# Epoch 39/50
#  - 0s - loss: 68.7743
# Epoch 40/50
#  - 0s - loss: 66.0646
# Epoch 41/50
#  - 0s - loss: 65.7191
# Epoch 42/50
#  - 0s - loss: 64.4729
# Epoch 43/50
#  - 0s - loss: 63.4014
# Epoch 44/50
#  - 0s - loss: 65.7209
# Epoch 45/50
#  - 0s - loss: 64.2396
# Epoch 46/50
#  - 0s - loss: 63.9184
# Epoch 47/50
#  - 0s - loss: 63.7278
# Epoch 48/50
#  - 0s - loss: 66.9138
# Epoch 49/50
#  - 0s - loss: 64.1629
# Epoch 50/50
#  - 0s - loss: 64.1886
# Duration (seconds): 1.7030179500579834
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 67.3761
# Epoch 2/50
#  - 0s - loss: 63.4819
# Epoch 3/50
#  - 0s - loss: 62.1883
# Epoch 4/50
#  - 0s - loss: 66.1348
# Epoch 5/50
#  - 0s - loss: 62.3774
# Epoch 6/50
#  - 0s - loss: 67.5713
# Epoch 7/50
#  - 0s - loss: 64.1019
# Epoch 8/50
#  - 0s - loss: 63.5296
# Epoch 9/50
#  - 0s - loss: 62.7087
# Epoch 10/50
#  - 0s - loss: 60.9505
# Epoch 11/50
#  - 0s - loss: 62.3479
# Epoch 12/50
#  - 0s - loss: 61.8136
# Epoch 13/50
#  - 0s - loss: 63.5971
# Epoch 14/50
#  - 0s - loss: 67.7394
# Epoch 15/50
#  - 0s - loss: 62.2583
# Epoch 16/50
#  - 0s - loss: 61.5165
# Epoch 17/50
#  - 0s - loss: 62.8351
# Epoch 18/50
#  - 0s - loss: 61.0061
# Epoch 19/50
#  - 0s - loss: 61.8652
# Epoch 20/50
#  - 0s - loss: 62.1491
# Epoch 21/50
#  - 0s - loss: 61.4215
# Epoch 22/50
#  - 0s - loss: 60.6853
# Epoch 23/50
#  - 0s - loss: 59.3327
# Epoch 24/50
#  - 0s - loss: 61.0407
# Epoch 25/50
#  - 0s - loss: 60.6015
# Epoch 26/50
#  - 0s - loss: 61.6379
# Epoch 27/50
#  - 0s - loss: 59.6506
# Epoch 28/50
#  - 0s - loss: 58.8590
# Epoch 29/50
#  - 0s - loss: 59.1563
# Epoch 30/50
#  - 0s - loss: 60.0170
# Epoch 31/50
#  - 0s - loss: 60.9035
# Epoch 32/50
#  - 0s - loss: 62.0863
# Epoch 33/50
#  - 0s - loss: 58.4096
# Epoch 34/50
#  - 0s - loss: 57.3384
# Epoch 35/50
#  - 0s - loss: 57.9406
# Epoch 36/50
#  - 0s - loss: 57.5931
# Epoch 37/50
#  - 0s - loss: 58.1782
# Epoch 38/50
#  - 0s - loss: 59.5763
# Epoch 39/50
#  - 0s - loss: 58.6903
# Epoch 40/50
#  - 0s - loss: 58.2278
# Epoch 41/50
#  - 0s - loss: 60.4534
# Epoch 42/50
#  - 0s - loss: 57.3257
# Epoch 43/50
#  - 0s - loss: 58.8185
# Epoch 44/50
#  - 0s - loss: 55.6337
# Epoch 45/50
#  - 0s - loss: 58.7784
# Epoch 46/50
#  - 0s - loss: 58.8360
# Epoch 47/50
#  - 0s - loss: 56.2726
# Epoch 48/50
#  - 0s - loss: 57.6363
# Epoch 49/50
#  - 0s - loss: 60.7985
# Epoch 50/50
#  - 0s - loss: 56.0319
# Duration (seconds): 1.9513731002807617
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 55.9722
# Epoch 2/50
#  - 0s - loss: 55.6039
# Epoch 3/50
#  - 0s - loss: 65.8763
# Epoch 4/50
#  - 0s - loss: 57.3567
# Epoch 5/50
#  - 0s - loss: 55.7504
# Epoch 6/50
#  - 0s - loss: 57.2066
# Epoch 7/50
#  - 0s - loss: 61.3712
# Epoch 8/50
#  - 0s - loss: 55.6992
# Epoch 9/50
#  - 0s - loss: 55.1927
# Epoch 10/50
#  - 0s - loss: 56.9949
# Epoch 11/50
#  - 0s - loss: 56.2763
# Epoch 12/50
#  - 0s - loss: 61.5378
# Epoch 13/50
#  - 0s - loss: 55.9698
# Epoch 14/50
#  - 0s - loss: 54.2988
# Epoch 15/50
#  - 0s - loss: 54.2642
# Epoch 16/50
#  - 0s - loss: 55.5502
# Epoch 17/50
#  - 0s - loss: 54.4666
# Epoch 18/50
#  - 0s - loss: 55.0965
# Epoch 19/50
#  - 0s - loss: 53.1912
# Epoch 20/50
#  - 0s - loss: 54.4242
# Epoch 21/50
#  - 0s - loss: 55.8169
# Epoch 22/50
#  - 0s - loss: 54.8714
# Epoch 23/50
#  - 0s - loss: 56.4754
# Epoch 24/50
#  - 0s - loss: 54.4500
# Epoch 25/50
#  - 0s - loss: 53.4795
# Epoch 26/50
#  - 0s - loss: 53.2031
# Epoch 27/50
#  - 0s - loss: 54.6963
# Epoch 28/50
#  - 0s - loss: 53.4054
# Epoch 29/50
#  - 0s - loss: 57.2215
# Epoch 30/50
#  - 0s - loss: 56.5163
# Epoch 31/50
#  - 0s - loss: 54.4112
# Epoch 32/50
#  - 0s - loss: 54.0056
# Epoch 33/50
#  - 0s - loss: 53.4201
# Epoch 34/50
#  - 0s - loss: 55.0127
# Epoch 35/50
#  - 0s - loss: 53.5713
# Epoch 36/50
#  - 0s - loss: 53.7825
# Epoch 37/50
#  - 0s - loss: 53.0595
# Epoch 38/50
#  - 0s - loss: 53.8116
# Epoch 39/50
#  - 0s - loss: 53.0681
# Epoch 40/50
#  - 0s - loss: 53.5099
# Epoch 41/50
#  - 0s - loss: 52.5889
# Epoch 42/50
#  - 0s - loss: 52.4818
# Epoch 43/50
#  - 0s - loss: 53.0340
# Epoch 44/50
#  - 0s - loss: 56.4648
# Epoch 45/50
#  - 0s - loss: 54.0082
# Epoch 46/50
#  - 0s - loss: 53.6236
# Epoch 47/50
#  - 0s - loss: 52.2600
# Epoch 48/50
#  - 0s - loss: 53.8475
# Epoch 49/50
#  - 0s - loss: 58.8009
# Epoch 50/50
#  - 0s - loss: 51.2773
# Duration (seconds): 2.55287504196167
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 52.0824
# Epoch 2/50
#  - 0s - loss: 51.6249
# Epoch 3/50
#  - 0s - loss: 53.5777
# Epoch 4/50
#  - 0s - loss: 52.6199
# Epoch 5/50
#  - 0s - loss: 53.0852
# Epoch 6/50
#  - 0s - loss: 51.3759
# Epoch 7/50
#  - 0s - loss: 57.9929
# Epoch 8/50
#  - 0s - loss: 55.6704
# Epoch 9/50
#  - 0s - loss: 52.6282
# Epoch 10/50
#  - 0s - loss: 51.5876
# Epoch 11/50
#  - 0s - loss: 55.3577
# Epoch 12/50
#  - 0s - loss: 52.3489
# Epoch 13/50
#  - 0s - loss: 52.8613
# Epoch 14/50
#  - 0s - loss: 52.0921
# Epoch 15/50
#  - 0s - loss: 50.7435
# Epoch 16/50
#  - 0s - loss: 57.0583
# Epoch 17/50
#  - 0s - loss: 55.3450
# Epoch 18/50
#  - 0s - loss: 54.5429
# Epoch 19/50
#  - 0s - loss: 51.8143
# Epoch 20/50
#  - 0s - loss: 51.8881
# Epoch 21/50
#  - 0s - loss: 51.5243
# Epoch 22/50
#  - 0s - loss: 52.5668
# Epoch 23/50
#  - 0s - loss: 51.2995
# Epoch 24/50
#  - 0s - loss: 53.4127
# Epoch 25/50
#  - 0s - loss: 50.7588
# Epoch 26/50
#  - 0s - loss: 51.0861
# Epoch 27/50
#  - 0s - loss: 50.9230
# Epoch 28/50
#  - 0s - loss: 51.8327
# Epoch 29/50
#  - 0s - loss: 54.8691
# Epoch 30/50
#  - 0s - loss: 52.1078
# Epoch 31/50
#  - 0s - loss: 50.8707
# Epoch 32/50
#  - 0s - loss: 50.9939
# Epoch 33/50
#  - 0s - loss: 52.0612
# Epoch 34/50
#  - 0s - loss: 51.0246
# Epoch 35/50
#  - 0s - loss: 52.8969
# Epoch 36/50
#  - 0s - loss: 50.8021
# Epoch 37/50
#  - 0s - loss: 50.4587
# Epoch 38/50
#  - 0s - loss: 50.0160
# Epoch 39/50
#  - 0s - loss: 52.3033
# Epoch 40/50
#  - 0s - loss: 51.0394
# Epoch 41/50
#  - 0s - loss: 50.3116
# Epoch 42/50
#  - 0s - loss: 51.9847
# Epoch 43/50
#  - 0s - loss: 50.2381
# Epoch 44/50
#  - 0s - loss: 50.0000
# Epoch 45/50
#  - 0s - loss: 53.8060
# Epoch 46/50
#  - 0s - loss: 50.3184
# Epoch 47/50
#  - 0s - loss: 51.7048
# Epoch 48/50
#  - 0s - loss: 53.4440
# Epoch 49/50
#  - 0s - loss: 52.3960
# Epoch 50/50
#  - 0s - loss: 49.8886
# Duration (seconds): 2.391474962234497
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 51.9025
# Epoch 2/50
#  - 0s - loss: 52.0984
# Epoch 3/50
#  - 0s - loss: 50.4736
# Epoch 4/50
#  - 0s - loss: 49.9738
# Epoch 5/50
#  - 0s - loss: 49.9979
# Epoch 6/50
#  - 0s - loss: 51.2828
# Epoch 7/50
#  - 0s - loss: 50.2846
# Epoch 8/50
#  - 0s - loss: 52.2395
# Epoch 9/50
#  - 0s - loss: 56.6162
# Epoch 10/50
#  - 0s - loss: 50.2109
# Epoch 11/50
#  - 0s - loss: 50.9603
# Epoch 12/50
#  - 0s - loss: 49.9791
# Epoch 13/50
#  - 0s - loss: 50.6739
# Epoch 14/50
#  - 0s - loss: 50.7736
# Epoch 15/50
#  - 0s - loss: 50.9066
# Epoch 16/50
#  - 0s - loss: 51.2649
# Epoch 17/50
#  - 0s - loss: 50.0274
# Epoch 18/50
#  - 0s - loss: 54.2539
# Epoch 19/50
#  - 0s - loss: 49.5815
# Epoch 20/50
#  - 0s - loss: 51.7475
# Epoch 21/50
#  - 0s - loss: 56.7067
# Epoch 22/50
#  - 0s - loss: 54.6796
# Epoch 23/50
#  - 0s - loss: 50.5871
# Epoch 24/50
#  - 0s - loss: 51.8316
# Epoch 25/50
#  - 0s - loss: 53.7615
# Epoch 26/50
#  - 0s - loss: 50.8407
# Epoch 27/50
#  - 0s - loss: 50.2255
# Epoch 28/50
#  - 0s - loss: 50.2359
# Epoch 29/50
#  - 0s - loss: 49.0809
# Epoch 30/50
#  - 0s - loss: 51.2106
# Epoch 31/50
#  - 0s - loss: 48.9368
# Epoch 32/50
#  - 0s - loss: 50.8044
# Epoch 33/50
#  - 0s - loss: 52.3917
# Epoch 34/50
#  - 0s - loss: 52.0619
# Epoch 35/50
#  - 0s - loss: 49.8629
# Epoch 36/50
#  - 0s - loss: 54.5657
# Epoch 37/50
#  - 0s - loss: 51.4427
# Epoch 38/50
#  - 0s - loss: 49.7805
# Epoch 39/50
#  - 0s - loss: 50.3889
# Epoch 40/50
#  - 0s - loss: 50.4570
# Epoch 41/50
#  - 0s - loss: 51.9638
# Epoch 42/50
#  - 0s - loss: 49.0240
# Epoch 43/50
#  - 0s - loss: 50.2373
# Epoch 44/50
#  - 0s - loss: 49.8689
# Epoch 45/50
#  - 0s - loss: 52.8989
# Epoch 46/50
#  - 0s - loss: 50.0100
# Epoch 47/50
#  - 0s - loss: 50.7883
# Epoch 48/50
#  - 0s - loss: 56.6824
# Epoch 49/50
#  - 0s - loss: 53.2366
# Epoch 50/50
#  - 0s - loss: 50.5193
# Duration (seconds): 2.463871955871582
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 51.7294
# Epoch 2/50
#  - 0s - loss: 50.4097
# Epoch 3/50
#  - 0s - loss: 57.2758
# Epoch 4/50
#  - 0s - loss: 53.4514
# Epoch 5/50
#  - 0s - loss: 49.2662
# Epoch 6/50
#  - 0s - loss: 49.6238
# Epoch 7/50
#  - 0s - loss: 49.1047
# Epoch 8/50
#  - 0s - loss: 50.4329
# Epoch 9/50
#  - 0s - loss: 49.1577
# Epoch 10/50
#  - 0s - loss: 49.2694
# Epoch 11/50
#  - 0s - loss: 57.2907
# Epoch 12/50
#  - 0s - loss: 53.7100
# Epoch 13/50
#  - 0s - loss: 51.7911
# Epoch 14/50
#  - 0s - loss: 49.7592
# Epoch 15/50
#  - 0s - loss: 49.4524
# Epoch 16/50
#  - 0s - loss: 50.8164
# Epoch 17/50
#  - 0s - loss: 50.8165
# Epoch 18/50
#  - 0s - loss: 49.2196
# Epoch 19/50
#  - 0s - loss: 51.5514
# Epoch 20/50
#  - 0s - loss: 49.9114
# Epoch 21/50
#  - 0s - loss: 50.0086
# Epoch 22/50
#  - 0s - loss: 50.7250
# Epoch 23/50
#  - 0s - loss: 50.8126
# Epoch 24/50
#  - 0s - loss: 53.5152
# Epoch 25/50
#  - 0s - loss: 50.5966
# Epoch 26/50
#  - 0s - loss: 48.8101
# Epoch 27/50
#  - 0s - loss: 49.3034
# Epoch 28/50
#  - 0s - loss: 52.5905
# Epoch 29/50
#  - 0s - loss: 51.1019
# Epoch 30/50
#  - 0s - loss: 51.8213
# Epoch 31/50
#  - 0s - loss: 51.3873
# Epoch 32/50
#  - 0s - loss: 49.5154
# Epoch 33/50
#  - 0s - loss: 49.9687
# Epoch 34/50
#  - 0s - loss: 48.5109
# Epoch 35/50
#  - 0s - loss: 49.7734
# Epoch 36/50
#  - 0s - loss: 48.7268
# Epoch 37/50
#  - 0s - loss: 50.6873
# Epoch 38/50
#  - 0s - loss: 49.4365
# Epoch 39/50
#  - 0s - loss: 50.2199
# Epoch 40/50
#  - 0s - loss: 50.1673
# Epoch 41/50
#  - 0s - loss: 49.1106
# Epoch 42/50
#  - 0s - loss: 51.0921
# Epoch 43/50
#  - 0s - loss: 50.3832
# Epoch 44/50
#  - 0s - loss: 49.5707
# Epoch 45/50
#  - 0s - loss: 48.8936
# Epoch 46/50
#  - 0s - loss: 49.5031
# Epoch 47/50
#  - 0s - loss: 50.0988
# Epoch 48/50
#  - 0s - loss: 49.4295
# Epoch 49/50
#  - 0s - loss: 49.6068
# Epoch 50/50
#  - 0s - loss: 49.3371
# Duration (seconds): 2.3014540672302246
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 51.6940
# Epoch 2/50
#  - 0s - loss: 49.4582
# Epoch 3/50
#  - 0s - loss: 51.2447
# Epoch 4/50
#  - 0s - loss: 52.7105
# Epoch 5/50
#  - 0s - loss: 50.6644
# Epoch 6/50
#  - 0s - loss: 51.9027
# Epoch 7/50
#  - 0s - loss: 49.5349
# Epoch 8/50
#  - 0s - loss: 49.2691
# Epoch 9/50
#  - 0s - loss: 55.0350
# Epoch 10/50
#  - 0s - loss: 49.5265
# Epoch 11/50
#  - 0s - loss: 55.7484
# Epoch 12/50
#  - 0s - loss: 52.7126
# Epoch 13/50
#  - 0s - loss: 51.6841
# Epoch 14/50
#  - 0s - loss: 49.9109
# Epoch 15/50
#  - 0s - loss: 50.8057
# Epoch 16/50
#  - 0s - loss: 49.9733
# Epoch 17/50
#  - 0s - loss: 49.0134
# Epoch 18/50
#  - 0s - loss: 48.6780
# Epoch 19/50
#  - 0s - loss: 48.9841
# Epoch 20/50
#  - 0s - loss: 50.2689
# Epoch 21/50
#  - 0s - loss: 49.6679
# Epoch 22/50
#  - 0s - loss: 49.2649
# Epoch 23/50
#  - 0s - loss: 48.8368
# Epoch 24/50
#  - 0s - loss: 49.8683
# Epoch 25/50
#  - 0s - loss: 49.3620
# Epoch 26/50
#  - 0s - loss: 49.0388
# Epoch 27/50
#  - 0s - loss: 49.9299
# Epoch 28/50
#  - 0s - loss: 51.4754
# Epoch 29/50
#  - 0s - loss: 48.8543
# Epoch 30/50
#  - 0s - loss: 48.6956
# Epoch 31/50
#  - 0s - loss: 49.9805
# Epoch 32/50
#  - 0s - loss: 50.9296
# Epoch 33/50
#  - 0s - loss: 51.4352
# Epoch 34/50
#  - 0s - loss: 49.7056
# Epoch 35/50
#  - 0s - loss: 49.2481
# Epoch 36/50
#  - 0s - loss: 53.5532
# Epoch 37/50
#  - 0s - loss: 51.9167
# Epoch 38/50
#  - 0s - loss: 49.5708
# Epoch 39/50
#  - 0s - loss: 49.4311
# Epoch 40/50
#  - 0s - loss: 51.0908
# Epoch 41/50
#  - 0s - loss: 49.1856
# Epoch 42/50
#  - 0s - loss: 50.9573
# Epoch 43/50
#  - 0s - loss: 56.4544
# Epoch 44/50
#  - 0s - loss: 53.9475
# Epoch 45/50
#  - 0s - loss: 49.3506
# Epoch 46/50
#  - 0s - loss: 49.8310
# Epoch 47/50
#  - 0s - loss: 49.1461
# Epoch 48/50
#  - 0s - loss: 49.2267
# Epoch 49/50
#  - 0s - loss: 50.4354
# Epoch 50/50
#  - 0s - loss: 49.0040
# Duration (seconds): 2.391732931137085
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.8558
# Epoch 2/50
#  - 0s - loss: 49.6538
# Epoch 3/50
#  - 0s - loss: 48.6564
# Epoch 4/50
#  - 0s - loss: 51.5295
# Epoch 5/50
#  - 0s - loss: 51.3511
# Epoch 6/50
#  - 0s - loss: 52.6693
# Epoch 7/50
#  - 0s - loss: 53.7798
# Epoch 8/50
#  - 0s - loss: 53.5530
# Epoch 9/50
#  - 0s - loss: 49.3681
# Epoch 10/50
#  - 0s - loss: 49.0311
# Epoch 11/50
#  - 0s - loss: 48.8420
# Epoch 12/50
#  - 0s - loss: 50.4288
# Epoch 13/50
#  - 0s - loss: 50.4063
# Epoch 14/50
#  - 0s - loss: 50.7532
# Epoch 15/50
#  - 0s - loss: 52.1907
# Epoch 16/50
#  - 0s - loss: 50.0972
# Epoch 17/50
#  - 0s - loss: 49.2253
# Epoch 18/50
#  - 0s - loss: 53.2035
# Epoch 19/50
#  - 0s - loss: 52.8941
# Epoch 20/50
#  - 0s - loss: 49.7095
# Epoch 21/50
#  - 0s - loss: 49.3417
# Epoch 22/50
#  - 0s - loss: 49.6593
# Epoch 23/50
#  - 0s - loss: 49.7580
# Epoch 24/50
#  - 0s - loss: 49.6978
# Epoch 25/50
#  - 0s - loss: 50.0414
# Epoch 26/50
#  - 0s - loss: 49.0236
# Epoch 27/50
#  - 0s - loss: 50.6683
# Epoch 28/50
#  - 0s - loss: 49.0604
# Epoch 29/50
#  - 0s - loss: 48.2049
# Epoch 30/50
#  - 0s - loss: 48.9387
# Epoch 31/50
#  - 0s - loss: 49.9233
# Epoch 32/50
#  - 0s - loss: 49.8526
# Epoch 33/50
#  - 0s - loss: 48.9550
# Epoch 34/50
#  - 0s - loss: 50.3598
# Epoch 35/50
#  - 0s - loss: 48.7676
# Epoch 36/50
#  - 0s - loss: 50.7044
# Epoch 37/50
#  - 0s - loss: 52.1785
# Epoch 38/50
#  - 0s - loss: 49.1024
# Epoch 39/50
#  - 0s - loss: 50.3693
# Epoch 40/50
#  - 0s - loss: 49.0255
# Epoch 41/50
#  - 0s - loss: 51.6034
# Epoch 42/50
#  - 0s - loss: 53.9002
# Epoch 43/50
#  - 0s - loss: 50.4795
# Epoch 44/50
#  - 0s - loss: 49.7676
# Epoch 45/50
#  - 0s - loss: 50.0303
# Epoch 46/50
#  - 0s - loss: 51.0821
# Epoch 47/50
#  - 0s - loss: 49.7353
# Epoch 48/50
#  - 0s - loss: 49.8957
# Epoch 49/50
#  - 0s - loss: 51.5880
# Epoch 50/50
#  - 0s - loss: 50.6591
# Duration (seconds): 1.820268154144287
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.5277
# Epoch 2/50
#  - 0s - loss: 50.6728
# Epoch 3/50
#  - 0s - loss: 48.3482
# Epoch 4/50
#  - 0s - loss: 48.1466
# Epoch 5/50
#  - 0s - loss: 51.3823
# Epoch 6/50
#  - 0s - loss: 49.7560
# Epoch 7/50
#  - 0s - loss: 49.2247
# Epoch 8/50
#  - 0s - loss: 49.5755
# Epoch 9/50
#  - 0s - loss: 50.0832
# Epoch 10/50
#  - 0s - loss: 48.6644
# Epoch 11/50
#  - 0s - loss: 50.2450
# Epoch 12/50
#  - 0s - loss: 49.9091
# Epoch 13/50
#  - 0s - loss: 50.0433
# Epoch 14/50
#  - 0s - loss: 48.3887
# Epoch 15/50
#  - 0s - loss: 48.2958
# Epoch 16/50
#  - 0s - loss: 49.5173
# Epoch 17/50
#  - 0s - loss: 49.2262
# Epoch 18/50
#  - 0s - loss: 48.5216
# Epoch 19/50
#  - 0s - loss: 48.9673
# Epoch 20/50
#  - 0s - loss: 50.3881
# Epoch 21/50
#  - 0s - loss: 48.6701
# Epoch 22/50
#  - 0s - loss: 48.6747
# Epoch 23/50
#  - 0s - loss: 48.6488
# Epoch 24/50
#  - 0s - loss: 49.4040
# Epoch 25/50
#  - 0s - loss: 48.8074
# Epoch 26/50
#  - 0s - loss: 51.7332
# Epoch 27/50
#  - 0s - loss: 50.8666
# Epoch 28/50
#  - 0s - loss: 51.4994
# Epoch 29/50
#  - 0s - loss: 47.9482
# Epoch 30/50
#  - 0s - loss: 49.5135
# Epoch 31/50
#  - 0s - loss: 50.6608
# Epoch 32/50
#  - 0s - loss: 49.4510
# Epoch 33/50
#  - 0s - loss: 49.3765
# Epoch 34/50
#  - 0s - loss: 49.7813
# Epoch 35/50
#  - 0s - loss: 52.1509
# Epoch 36/50
#  - 0s - loss: 50.5973
# Epoch 37/50
#  - 0s - loss: 51.7581
# Epoch 38/50
#  - 0s - loss: 50.2060
# Epoch 39/50
#  - 0s - loss: 49.4876
# Epoch 40/50
#  - 0s - loss: 49.5079
# Epoch 41/50
#  - 0s - loss: 50.4021
# Epoch 42/50
#  - 0s - loss: 52.2551
# Epoch 43/50
#  - 0s - loss: 53.7931
# Epoch 44/50
#  - 0s - loss: 49.8245
# Epoch 45/50
#  - 0s - loss: 50.9166
# Epoch 46/50
#  - 0s - loss: 65.4162
# Epoch 47/50
#  - 0s - loss: 54.8135
# Epoch 48/50
#  - 0s - loss: 48.5455
# Epoch 49/50
#  - 0s - loss: 48.4236
# Epoch 50/50
#  - 0s - loss: 48.5749
# Duration (seconds): 1.8641479015350342
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 50.6351
# Epoch 2/50
#  - 0s - loss: 52.9305
# Epoch 3/50
#  - 0s - loss: 53.1666
# Epoch 4/50
#  - 0s - loss: 50.2375
# Epoch 5/50
#  - 0s - loss: 53.6338
# Epoch 6/50
#  - 0s - loss: 48.4946
# Epoch 7/50
#  - 0s - loss: 48.2951
# Epoch 8/50
#  - 0s - loss: 49.0888
# Epoch 9/50
#  - 0s - loss: 49.5513
# Epoch 10/50
#  - 0s - loss: 52.5749
# Epoch 11/50
#  - 0s - loss: 49.2318
# Epoch 12/50
#  - 0s - loss: 50.5752
# Epoch 13/50
#  - 0s - loss: 49.5304
# Epoch 14/50
#  - 0s - loss: 51.8500
# Epoch 15/50
#  - 0s - loss: 50.4529
# Epoch 16/50
#  - 0s - loss: 48.3948
# Epoch 17/50
#  - 0s - loss: 52.0247
# Epoch 18/50
#  - 0s - loss: 48.8288
# Epoch 19/50
#  - 0s - loss: 49.3221
# Epoch 20/50
#  - 0s - loss: 49.7030
# Epoch 21/50
#  - 0s - loss: 49.1117
# Epoch 22/50
#  - 0s - loss: 49.4026
# Epoch 23/50
#  - 0s - loss: 49.8504
# Epoch 24/50
#  - 0s - loss: 49.6538
# Epoch 25/50
#  - 0s - loss: 49.5367
# Epoch 26/50
#  - 0s - loss: 49.5334
# Epoch 27/50
#  - 0s - loss: 50.1017
# Epoch 28/50
#  - 0s - loss: 50.1068
# Epoch 29/50
#  - 0s - loss: 49.1872
# Epoch 30/50
#  - 0s - loss: 50.5701
# Epoch 31/50
#  - 0s - loss: 51.0324
# Epoch 32/50
#  - 0s - loss: 49.8884
# Epoch 33/50
#  - 0s - loss: 49.4363
# Epoch 34/50
#  - 0s - loss: 48.5276
# Epoch 35/50
#  - 0s - loss: 48.6525
# Epoch 36/50
#  - 0s - loss: 48.9072
# Epoch 37/50
#  - 0s - loss: 49.5415
# Epoch 38/50
#  - 0s - loss: 49.2589
# Epoch 39/50
#  - 0s - loss: 48.4332
# Epoch 40/50
#  - 0s - loss: 49.1891
# Epoch 41/50
#  - 0s - loss: 48.7632
# Epoch 42/50
#  - 0s - loss: 48.9305
# Epoch 43/50
#  - 0s - loss: 52.0935
# Epoch 44/50
#  - 0s - loss: 50.3407
# Epoch 45/50
#  - 0s - loss: 48.9932
# Epoch 46/50
#  - 0s - loss: 49.1177
# Epoch 47/50
#  - 0s - loss: 48.3494
# Epoch 48/50
#  - 0s - loss: 48.5870
# Epoch 49/50
#  - 0s - loss: 48.0851
# Epoch 50/50
#  - 0s - loss: 49.2740
# Duration (seconds): 2.213239908218384
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 52.3964
# Epoch 2/50
#  - 0s - loss: 49.2340
# Epoch 3/50
#  - 0s - loss: 49.4001
# Epoch 4/50
#  - 0s - loss: 53.0691
# Epoch 5/50
#  - 0s - loss: 49.9688
# Epoch 6/50
#  - 0s - loss: 50.4944
# Epoch 7/50
#  - 0s - loss: 51.6901
# Epoch 8/50
#  - 0s - loss: 50.4334
# Epoch 9/50
#  - 0s - loss: 49.1246
# Epoch 10/50
#  - 0s - loss: 49.5120
# Epoch 11/50
#  - 0s - loss: 50.1018
# Epoch 12/50
#  - 0s - loss: 49.7298
# Epoch 13/50
#  - 0s - loss: 49.3092
# Epoch 14/50
#  - 0s - loss: 49.0580
# Epoch 15/50
#  - 0s - loss: 51.2244
# Epoch 16/50
#  - 0s - loss: 49.9159
# Epoch 17/50
#  - 0s - loss: 49.1087
# Epoch 18/50
#  - 0s - loss: 48.6793
# Epoch 19/50
#  - 0s - loss: 50.2862
# Epoch 20/50
#  - 0s - loss: 50.3429
# Epoch 21/50
#  - 0s - loss: 50.2252
# Epoch 22/50
#  - 0s - loss: 49.7302
# Epoch 23/50
#  - 0s - loss: 49.4495
# Epoch 24/50
#  - 0s - loss: 51.0720
# Epoch 25/50
#  - 0s - loss: 55.6264
# Epoch 26/50
#  - 0s - loss: 51.0600
# Epoch 27/50
#  - 0s - loss: 49.1084
# Epoch 28/50
#  - 0s - loss: 48.5831
# Epoch 29/50
#  - 0s - loss: 49.6642
# Epoch 30/50
#  - 0s - loss: 48.2022
# Epoch 31/50
#  - 0s - loss: 51.4303
# Epoch 32/50
#  - 0s - loss: 50.3583
# Epoch 33/50
#  - 0s - loss: 48.0343
# Epoch 34/50
#  - 0s - loss: 49.8070
# Epoch 35/50
#  - 0s - loss: 48.6666
# Epoch 36/50
#  - 0s - loss: 50.3353
# Epoch 37/50
#  - 0s - loss: 48.4484
# Epoch 38/50
#  - 0s - loss: 48.6505
# Epoch 39/50
#  - 0s - loss: 48.6054
# Epoch 40/50
#  - 0s - loss: 49.5230
# Epoch 41/50
#  - 0s - loss: 52.5401
# Epoch 42/50
#  - 0s - loss: 49.0689
# Epoch 43/50
#  - 0s - loss: 49.0231
# Epoch 44/50
#  - 0s - loss: 50.7136
# Epoch 45/50
#  - 0s - loss: 48.6100
# Epoch 46/50
#  - 0s - loss: 50.3041
# Epoch 47/50
#  - 0s - loss: 48.7416
# Epoch 48/50
#  - 0s - loss: 50.3650
# Epoch 49/50
#  - 0s - loss: 49.2826
# Epoch 50/50
#  - 0s - loss: 50.0192
# Duration (seconds): 2.570923089981079
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.7202
# Epoch 2/50
#  - 0s - loss: 51.4014
# Epoch 3/50
#  - 0s - loss: 49.5849
# Epoch 4/50
#  - 0s - loss: 50.9239
# Epoch 5/50
#  - 0s - loss: 48.7052
# Epoch 6/50
#  - 0s - loss: 48.2981
# Epoch 7/50
#  - 0s - loss: 49.1078
# Epoch 8/50
#  - 0s - loss: 48.0972
# Epoch 9/50
#  - 0s - loss: 50.6058
# Epoch 10/50
#  - 0s - loss: 48.9962
# Epoch 11/50
#  - 0s - loss: 49.6606
# Epoch 12/50
#  - 0s - loss: 48.4153
# Epoch 13/50
#  - 0s - loss: 52.2138
# Epoch 14/50
#  - 0s - loss: 50.1700
# Epoch 15/50
#  - 0s - loss: 49.8423
# Epoch 16/50
#  - 0s - loss: 49.1345
# Epoch 17/50
#  - 0s - loss: 48.6524
# Epoch 18/50
#  - 0s - loss: 49.7595
# Epoch 19/50
#  - 0s - loss: 49.9567
# Epoch 20/50
#  - 0s - loss: 49.4797
# Epoch 21/50
#  - 0s - loss: 51.2961
# Epoch 22/50
#  - 0s - loss: 50.8861
# Epoch 23/50
#  - 0s - loss: 49.2945
# Epoch 24/50
#  - 0s - loss: 49.9723
# Epoch 25/50
#  - 0s - loss: 48.6701
# Epoch 26/50
#  - 0s - loss: 52.1813
# Epoch 27/50
#  - 0s - loss: 48.2094
# Epoch 28/50
#  - 0s - loss: 48.5478
# Epoch 29/50
#  - 0s - loss: 48.1633
# Epoch 30/50
#  - 0s - loss: 49.6688
# Epoch 31/50
#  - 0s - loss: 51.4092
# Epoch 32/50
#  - 0s - loss: 48.4165
# Epoch 33/50
#  - 0s - loss: 49.2963
# Epoch 34/50
#  - 0s - loss: 49.5538
# Epoch 35/50
#  - 0s - loss: 50.5866
# Epoch 36/50
#  - 0s - loss: 48.3629
# Epoch 37/50
#  - 0s - loss: 49.1490
# Epoch 38/50
#  - 0s - loss: 48.7223
# Epoch 39/50
#  - 0s - loss: 52.7677
# Epoch 40/50
#  - 0s - loss: 48.7287
# Epoch 41/50
#  - 0s - loss: 48.7824
# Epoch 42/50
#  - 0s - loss: 49.7517
# Epoch 43/50
#  - 0s - loss: 50.8006
# Epoch 44/50
#  - 0s - loss: 50.7005
# Epoch 45/50
#  - 0s - loss: 50.8674
# Epoch 46/50
#  - 0s - loss: 49.1353
# Epoch 47/50
#  - 0s - loss: 50.4443
# Epoch 48/50
#  - 0s - loss: 48.1267
# Epoch 49/50
#  - 0s - loss: 49.7205
# Epoch 50/50
#  - 0s - loss: 50.6686
# Duration (seconds): 2.8243510723114014
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.7013
# Epoch 2/50
#  - 0s - loss: 49.7161
# Epoch 3/50
#  - 0s - loss: 51.5797
# Epoch 4/50
#  - 0s - loss: 49.3352
# Epoch 5/50
#  - 0s - loss: 49.7590
# Epoch 6/50
#  - 0s - loss: 49.8360
# Epoch 7/50
#  - 0s - loss: 48.2407
# Epoch 8/50
#  - 0s - loss: 53.5428
# Epoch 9/50
#  - 0s - loss: 58.2366
# Epoch 10/50
#  - 0s - loss: 48.8035
# Epoch 11/50
#  - 0s - loss: 48.6997
# Epoch 12/50
#  - 0s - loss: 52.4254
# Epoch 13/50
#  - 0s - loss: 51.9911
# Epoch 14/50
# ...
# Epoch 2/50
#  - 0s - loss: 49.1735
# Epoch 3/50
#  - 0s - loss: 49.9218
# Epoch 4/50
#  - 0s - loss: 52.4159
# Epoch 5/50
#  - 0s - loss: 49.1725
# Epoch 6/50
#  - 0s - loss: 50.8711
# Epoch 7/50
#  - 0s - loss: 49.7606
# Epoch 8/50
#  - 0s - loss: 51.2414
# Epoch 9/50
#  - 0s - loss: 48.4109
# Epoch 10/50
#  - 0s - loss: 48.6161
# Epoch 11/50
#  - 0s - loss: 52.8070
# Epoch 12/50
#  - 0s - loss: 49.1429
# Epoch 13/50
#  - 0s - loss: 49.2881
# Epoch 14/50
#  - 0s - loss: 48.8519
# Epoch 15/50
#  - 0s - loss: 48.0032
# Epoch 16/50
#  - 0s - loss: 48.0263
# Epoch 17/50
#  - 0s - loss: 49.1926
# Epoch 18/50
#  - 0s - loss: 48.9934
# Epoch 19/50
#  - 0s - loss: 48.8702
# Epoch 20/50
#  - 0s - loss: 50.1251
# Epoch 21/50
#  - 0s - loss: 49.5497
# Epoch 22/50
#  - 0s - loss: 49.7264
# Epoch 23/50
#  - 0s - loss: 48.4183
# Epoch 24/50
#  - 0s - loss: 47.9311
# Epoch 25/50
#  - 0s - loss: 50.9832
# Epoch 26/50
#  - 0s - loss: 51.8622
# Epoch 27/50
#  - 0s - loss: 48.5395
# Epoch 28/50
#  - 0s - loss: 47.2397
# Epoch 29/50
#  - 0s - loss: 50.0029
# Epoch 30/50
#  - 0s - loss: 48.7216
# Epoch 31/50
#  - 0s - loss: 53.8899
# Epoch 32/50
#  - 0s - loss: 49.2070
# Epoch 33/50
#  - 0s - loss: 49.0388
# Epoch 34/50
#  - 0s - loss: 48.0389
# Epoch 35/50
#  - 0s - loss: 47.9470
# Epoch 36/50
#  - 0s - loss: 50.1978
# Epoch 37/50
#  - 0s - loss: 49.0892
# Epoch 38/50
#  - 0s - loss: 49.5541
# Epoch 39/50
#  - 0s - loss: 53.8812
# Epoch 40/50
#  - 0s - loss: 48.5365
# Epoch 41/50
#  - 0s - loss: 48.5392
# Epoch 42/50
#  - 0s - loss: 51.1949
# Epoch 43/50
#  - 0s - loss: 51.0968
# Epoch 44/50
#  - 0s - loss: 47.9932
# Epoch 45/50
#  - 0s - loss: 49.3948
# Epoch 46/50
#  - 0s - loss: 52.5793
# Epoch 47/50
#  - 0s - loss: 51.5789
# Epoch 48/50
#  - 0s - loss: 48.4354
# Epoch 49/50
#  - 0s - loss: 47.9807
# Epoch 50/50
#  - 0s - loss: 48.1166
# Duration (seconds): 2.069836139678955
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.9791
# Epoch 2/50
#  - 0s - loss: 49.6450
# Epoch 3/50
#  - 0s - loss: 51.2167
# Epoch 4/50
#  - 0s - loss: 50.6475
# Epoch 5/50
#  - 0s - loss: 53.1422
# Epoch 6/50
#  - 0s - loss: 48.7504
# Epoch 7/50
#  - 0s - loss: 49.1076
# Epoch 8/50
#  - 0s - loss: 48.1107
# Epoch 9/50
#  - 0s - loss: 48.4873
# Epoch 10/50
#  - 0s - loss: 49.6914
# Epoch 11/50
#  - 0s - loss: 48.3184
# Epoch 12/50
#  - 0s - loss: 50.0075
# Epoch 13/50
#  - 0s - loss: 49.5653
# Epoch 14/50
#  - 0s - loss: 50.4868
# Epoch 15/50
#  - 0s - loss: 52.4030
# Epoch 16/50
#  - 0s - loss: 52.0987
# Epoch 17/50
#  - 0s - loss: 51.1937
# Epoch 18/50
#  - 0s - loss: 49.8177
# Epoch 19/50
#  - 0s - loss: 52.8382
# Epoch 20/50
#  - 0s - loss: 49.1678
# Epoch 21/50
#  - 0s - loss: 48.4240
# Epoch 22/50
#  - 0s - loss: 48.2735
# Epoch 23/50
#  - 0s - loss: 50.8289
# Epoch 24/50
#  - 0s - loss: 48.6123
# Epoch 25/50
#  - 0s - loss: 47.7218
# Epoch 26/50
#  - 0s - loss: 49.0996
# Epoch 27/50
#  - 0s - loss: 48.3371
# Epoch 28/50
#  - 0s - loss: 48.5556
# Epoch 29/50
#  - 0s - loss: 49.1247
# Epoch 30/50
#  - 0s - loss: 53.0069
# Epoch 31/50
#  - 0s - loss: 49.6972
# Epoch 32/50
#  - 0s - loss: 48.3937
# Epoch 33/50
#  - 0s - loss: 48.9998
# Epoch 34/50
#  - 0s - loss: 49.8854
# Epoch 35/50
#  - 0s - loss: 51.5064
# Epoch 36/50
#  - 0s - loss: 48.5030
# Epoch 37/50
#  - 0s - loss: 48.4774
# Epoch 38/50
#  - 0s - loss: 48.4302
# Epoch 39/50
#  - 0s - loss: 47.9428
# Epoch 40/50
#  - 0s - loss: 48.0470
# Epoch 41/50
#  - 0s - loss: 48.1617
# Epoch 42/50
#  - 0s - loss: 51.0870
# Epoch 43/50
#  - 0s - loss: 48.7074
# Epoch 44/50
#  - 0s - loss: 49.0775
# Epoch 45/50
#  - 0s - loss: 48.2171
# Epoch 46/50
#  - 0s - loss: 53.4847
# Epoch 47/50
#  - 0s - loss: 49.7637
# Epoch 48/50
#  - 0s - loss: 49.8890
# Epoch 49/50
#  - 0s - loss: 48.2923
# Epoch 50/50
#  - 0s - loss: 49.4303
# Duration (seconds): 2.09260892868042
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 49.3828
# Epoch 2/50
#  - 0s - loss: 49.3686
# Epoch 3/50
#  - 0s - loss: 50.4552
# Epoch 4/50
#  - 0s - loss: 47.7898
# Epoch 5/50
#  - 0s - loss: 50.6813
# Epoch 6/50
#  - 0s - loss: 49.1146
# Epoch 7/50
#  - 0s - loss: 52.2238
# Epoch 8/50
#  - 0s - loss: 49.0679
# Epoch 9/50
#  - 0s - loss: 48.9555
# Epoch 10/50
#  - 0s - loss: 51.8670
# Epoch 11/50
#  - 0s - loss: 54.3315
# Epoch 12/50
#  - 0s - loss: 47.3449
# Epoch 13/50
#  - 0s - loss: 47.7868
# Epoch 14/50
#  - 0s - loss: 48.4820
# Epoch 15/50
#  - 0s - loss: 48.0182
# Epoch 16/50
#  - 0s - loss: 48.0134
# Epoch 17/50
#  - 0s - loss: 49.2220
# Epoch 18/50
#  - 0s - loss: 50.7133
# Epoch 19/50
#  - 0s - loss: 48.5925
# Epoch 20/50
#  - 0s - loss: 48.3298
# Epoch 21/50
#  - 0s - loss: 48.8127
# Epoch 22/50
#  - 0s - loss: 50.4889
# Epoch 23/50
#  - 0s - loss: 52.9925
# Epoch 24/50
#  - 0s - loss: 49.1314
# Epoch 25/50
#  - 0s - loss: 52.6755
# Epoch 26/50
#  - 0s - loss: 50.2106
# Epoch 27/50
#  - 0s - loss: 49.9173
# Epoch 28/50
#  - 0s - loss: 48.5814
# Epoch 29/50
#  - 0s - loss: 49.7613
# Epoch 30/50
#  - 0s - loss: 47.5831
# Epoch 31/50
#  - 0s - loss: 49.5551
# Epoch 32/50
#  - 0s - loss: 47.8790
# Epoch 33/50
#  - 0s - loss: 48.1912
# Epoch 34/50
#  - 0s - loss: 50.7573
# Epoch 35/50
#  - 0s - loss: 52.2351
# Epoch 36/50
#  - 0s - loss: 51.6450
# Epoch 37/50
#  - 0s - loss: 52.5652
# Epoch 38/50
#  - 0s - loss: 48.6675
# Epoch 39/50
#  - 0s - loss: 50.0040
# Epoch 40/50
#  - 0s - loss: 48.5836
# Epoch 41/50
#  - 0s - loss: 47.6766
# Epoch 42/50
#  - 0s - loss: 47.4625
# Epoch 43/50
#  - 0s - loss: 49.6175
# Epoch 44/50
#  - 0s - loss: 50.1791
# Epoch 45/50
#  - 0s - loss: 49.2299
# Epoch 46/50
#  - 0s - loss: 48.8971
# Epoch 47/50
#  - 0s - loss: 47.6182
# Epoch 48/50
#  - 0s - loss: 51.4980
# Epoch 49/50
#  - 0s - loss: 52.0448
# Epoch 50/50
#  - 0s - loss: 48.4726
# Duration (seconds): 2.0063557624816895
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.5325
# Epoch 2/50
#  - 0s - loss: 48.3162
# Epoch 3/50
#  - 0s - loss: 48.0944
# Epoch 4/50
#  - 0s - loss: 48.4047
# Epoch 5/50
#  - 0s - loss: 47.8962
# Epoch 6/50
#  - 0s - loss: 48.2779
# Epoch 7/50
#  - 0s - loss: 47.9314
# Epoch 8/50
#  - 0s - loss: 48.8778
# Epoch 9/50
#  - 0s - loss: 47.2817
# Epoch 10/50
#  - 0s - loss: 48.2879
# Epoch 11/50
#  - 0s - loss: 47.9158
# Epoch 12/50
#  - 0s - loss: 47.7649
# Epoch 13/50
#  - 0s - loss: 53.9358
# Epoch 14/50
#  - 0s - loss: 49.2425
# Epoch 15/50
#  - 0s - loss: 49.8703
# Epoch 16/50
#  - 0s - loss: 49.6256
# Epoch 17/50
#  - 0s - loss: 48.7436
# Epoch 18/50
#  - 0s - loss: 48.9453
# Epoch 19/50
#  - 0s - loss: 49.2406
# Epoch 20/50
#  - 0s - loss: 48.7659
# Epoch 21/50
#  - 0s - loss: 47.9824
# Epoch 22/50
#  - 0s - loss: 48.2283
# Epoch 23/50
#  - 0s - loss: 48.1641
# Epoch 24/50
#  - 0s - loss: 48.2039
# Epoch 25/50
#  - 0s - loss: 47.7636
# Epoch 26/50
#  - 0s - loss: 47.7190
# Epoch 27/50
#  - 0s - loss: 49.1490
# Epoch 28/50
#  - 0s - loss: 48.0736
# Epoch 29/50
#  - 0s - loss: 50.2763
# Epoch 30/50
#  - 0s - loss: 48.1347
# Epoch 31/50
#  - 0s - loss: 47.5539
# Epoch 32/50
#  - 0s - loss: 49.1073
# Epoch 33/50
#  - 0s - loss: 50.7517
# Epoch 34/50
#  - 0s - loss: 47.4124
# Epoch 35/50
#  - 0s - loss: 53.7697
# Epoch 36/50
#  - 0s - loss: 51.2200
# Epoch 37/50
#  - 0s - loss: 50.0801
# Epoch 38/50
#  - 0s - loss: 49.0015
# Epoch 39/50
#  - 0s - loss: 51.8398
# Epoch 40/50
#  - 0s - loss: 48.3127
# Epoch 41/50
#  - 0s - loss: 47.9247
# Epoch 42/50
#  - 0s - loss: 50.7938
# Epoch 43/50
#  - 0s - loss: 51.8538
# Epoch 44/50
#  - 0s - loss: 49.6545
# Epoch 45/50
#  - 0s - loss: 48.1879
# Epoch 46/50
#  - 0s - loss: 48.2147
# Epoch 47/50
#  - 0s - loss: 47.9890
# Epoch 48/50
#  - 0s - loss: 49.6187
# Epoch 49/50
#  - 0s - loss: 49.4000
# Epoch 50/50
#  - 0s - loss: 49.6404
# Duration (seconds): 1.9960529804229736
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 50.7434
# Epoch 2/50
#  - 0s - loss: 48.6515
# Epoch 3/50
#  - 0s - loss: 48.1704
# Epoch 4/50
#  - 0s - loss: 48.6197
# Epoch 5/50
#  - 0s - loss: 48.0736
# Epoch 6/50
#  - 0s - loss: 48.6354
# Epoch 7/50
#  - 0s - loss: 48.8876
# Epoch 8/50
#  - 0s - loss: 50.4859
# Epoch 9/50
#  - 0s - loss: 48.9744
# Epoch 10/50
#  - 0s - loss: 50.1846
# Epoch 11/50
#  - 0s - loss: 49.3421
# Epoch 12/50
#  - 0s - loss: 48.5100
# Epoch 13/50
#  - 0s - loss: 53.1706
# Epoch 14/50
#  - 0s - loss: 48.0997
# Epoch 15/50
#  - 0s - loss: 48.0712
# Epoch 16/50
#  - 0s - loss: 49.2221
# Epoch 17/50
#  - 0s - loss: 49.3037
# Epoch 18/50
#  - 0s - loss: 48.3661
# Epoch 19/50
#  - 0s - loss: 58.6239
# Epoch 20/50
#  - 0s - loss: 56.2959
# Epoch 21/50
#  - 0s - loss: 54.6881
# Epoch 22/50
#  - 0s - loss: 50.1816
# Epoch 23/50
#  - 0s - loss: 49.1064
# Epoch 24/50
#  - 0s - loss: 49.7936
# Epoch 25/50
#  - 0s - loss: 48.5083
# Epoch 26/50
#  - 0s - loss: 50.0238
# Epoch 27/50
#  - 0s - loss: 50.5205
# Epoch 28/50
#  - 0s - loss: 49.9282
# Epoch 29/50
#  - 0s - loss: 48.3223
# Epoch 30/50
#  - 0s - loss: 49.6832
# Epoch 31/50
#  - 0s - loss: 48.3836
# Epoch 32/50
#  - 0s - loss: 48.7296
# Epoch 33/50
#  - 0s - loss: 48.3666
# Epoch 34/50
#  - 0s - loss: 48.4971
# Epoch 35/50
#  - 0s - loss: 48.7304
# Epoch 36/50
#  - 0s - loss: 47.6653
# Epoch 37/50
#  - 0s - loss: 48.0211
# Epoch 38/50
#  - 0s - loss: 49.9707
# Epoch 39/50
#  - 0s - loss: 48.3154
# Epoch 40/50
#  - 0s - loss: 49.3352
# Epoch 41/50
#  - 0s - loss: 48.7460
# Epoch 42/50
#  - 0s - loss: 49.7380
# Epoch 43/50
#  - 0s - loss: 48.1981
# Epoch 44/50
#  - 0s - loss: 48.9866
# Epoch 45/50
#  - 0s - loss: 48.4281
# Epoch 46/50
#  - 0s - loss: 53.1243
# Epoch 47/50
#  - 0s - loss: 52.0616
# Epoch 48/50
#  - 0s - loss: 50.2173
# Epoch 49/50
#  - 0s - loss: 49.4675
# Epoch 50/50
#  - 0s - loss: 49.1577
# Duration (seconds): 2.0708730220794678
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.0543
# Epoch 2/50
#  - 0s - loss: 47.9626
# Epoch 3/50
#  - 0s - loss: 47.2736
# Epoch 4/50
#  - 0s - loss: 49.2876
# Epoch 5/50
#  - 0s - loss: 48.5922
# Epoch 6/50
#  - 0s - loss: 47.8976
# Epoch 7/50
#  - 0s - loss: 49.1210
# Epoch 8/50
#  - 0s - loss: 47.4235
# Epoch 9/50
#  - 0s - loss: 49.7245
# Epoch 10/50
#  - 0s - loss: 48.0174
# Epoch 11/50
#  - 0s - loss: 49.1020
# Epoch 12/50
#  - 0s - loss: 48.8155
# Epoch 13/50
#  - 0s - loss: 49.6101
# Epoch 14/50
#  - 0s - loss: 48.6893
# Epoch 15/50
#  - 0s - loss: 49.2514
# Epoch 16/50
#  - 0s - loss: 48.7337
# Epoch 17/50
#  - 0s - loss: 51.1386
# Epoch 18/50
#  - 0s - loss: 51.4258
# Epoch 19/50
#  - 0s - loss: 50.2075
# Epoch 20/50
#  - 0s - loss: 47.5394
# Epoch 21/50
#  - 0s - loss: 50.8702
# Epoch 22/50
#  - 0s - loss: 48.0707
# Epoch 23/50
#  - 0s - loss: 50.0380
# Epoch 24/50
#  - 0s - loss: 49.3838
# Epoch 25/50
#  - 0s - loss: 47.6634
# Epoch 26/50
#  - 0s - loss: 48.6858
# Epoch 27/50
#  - 0s - loss: 49.8944
# Epoch 28/50
#  - 0s - loss: 48.7781
# Epoch 29/50
#  - 0s - loss: 48.5593
# Epoch 30/50
#  - 0s - loss: 47.3131
# Epoch 31/50
#  - 0s - loss: 48.8659
# Epoch 32/50
#  - 0s - loss: 49.9454
# Epoch 33/50
#  - 0s - loss: 56.3758
# Epoch 34/50
#  - 0s - loss: 49.4490
# Epoch 35/50
#  - 0s - loss: 51.9703
# Epoch 36/50
#  - 0s - loss: 49.6386
# Epoch 37/50
#  - 0s - loss: 48.9879
# Epoch 38/50
#  - 0s - loss: 52.3365
# Epoch 39/50
#  - 0s - loss: 49.2367
# Epoch 40/50
#  - 0s - loss: 49.0206
# Epoch 41/50
#  - 0s - loss: 48.4043
# Epoch 42/50
#  - 0s - loss: 48.1386
# Epoch 43/50
#  - 0s - loss: 48.9379
# Epoch 44/50
#  - 0s - loss: 51.0505
# Epoch 45/50
#  - 0s - loss: 48.0068
# Epoch 46/50
#  - 0s - loss: 49.1885
# Epoch 47/50
#  - 0s - loss: 47.7290
# Epoch 48/50
#  - 0s - loss: 48.0937
# Epoch 49/50
#  - 0s - loss: 49.5414
# Epoch 50/50
#  - 0s - loss: 49.6171
# Duration (seconds): 1.9987711906433105
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 52.1366
# Epoch 2/50
#  - 0s - loss: 50.4557
# Epoch 3/50
#  - 0s - loss: 49.8456
# Epoch 4/50
#  - 0s - loss: 48.9883
# Epoch 5/50
#  - 0s - loss: 50.4300
# Epoch 6/50
#  - 0s - loss: 51.1300
# Epoch 7/50
#  - 0s - loss: 48.5869
# Epoch 8/50
#  - 0s - loss: 48.2245
# Epoch 9/50
#  - 0s - loss: 51.1222
# Epoch 10/50
#  - 0s - loss: 52.6178
# Epoch 11/50
#  - 0s - loss: 50.1787
# Epoch 12/50
#  - 0s - loss: 52.0159
# Epoch 13/50
#  - 0s - loss: 50.2058
# Epoch 14/50
#  - 0s - loss: 48.7331
# Epoch 15/50
#  - 0s - loss: 48.0748
# Epoch 16/50
#  - 0s - loss: 47.8966
# Epoch 17/50
#  - 0s - loss: 48.3948
# Epoch 18/50
#  - 0s - loss: 48.8272
# Epoch 19/50
#  - 0s - loss: 47.9143
# Epoch 20/50
#  - 0s - loss: 50.2976
# Epoch 21/50
#  - 0s - loss: 48.2700
# Epoch 22/50
#  - 0s - loss: 49.4793
# Epoch 23/50
#  - 0s - loss: 50.2777
# Epoch 24/50
#  - 0s - loss: 48.9088
# Epoch 25/50
#  - 0s - loss: 48.4898
# Epoch 26/50
#  - 0s - loss: 49.7073
# Epoch 27/50
#  - 0s - loss: 48.0647
# Epoch 28/50
#  - 0s - loss: 47.7944
# Epoch 29/50
#  - 0s - loss: 48.0632
# Epoch 30/50
#  - 0s - loss: 47.4799
# Epoch 31/50
#  - 0s - loss: 48.1246
# Epoch 32/50
#  - 0s - loss: 47.8505
# Epoch 33/50
#  - 0s - loss: 48.4016
# Epoch 34/50
#  - 0s - loss: 49.0127
# Epoch 35/50
#  - 0s - loss: 48.2424
# Epoch 36/50
#  - 0s - loss: 47.1404
# Epoch 37/50
#  - 0s - loss: 48.2223
# Epoch 38/50
#  - 0s - loss: 48.4868
# Epoch 39/50
#  - 0s - loss: 47.7942
# Epoch 40/50
#  - 0s - loss: 47.7522
# Epoch 41/50
#  - 0s - loss: 50.5930
# Epoch 42/50
#  - 0s - loss: 51.9042
# Epoch 43/50
#  - 0s - loss: 49.8204
# Epoch 44/50
#  - 0s - loss: 49.2518
# Epoch 45/50
#  - 0s - loss: 48.7796
# Epoch 46/50
#  - 0s - loss: 48.0420
# Epoch 47/50
#  - 0s - loss: 50.1395
# Epoch 48/50
#  - 0s - loss: 49.1641
# Epoch 49/50
#  - 0s - loss: 48.3297
# Epoch 50/50
#  - 0s - loss: 47.5271
# Duration (seconds): 1.9566051959991455
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 48.7980
# Epoch 2/50
#  - 0s - loss: 50.0597
# Epoch 3/50
#  - 0s - loss: 48.7360
# Epoch 4/50
#  - 0s - loss: 48.1567
# Epoch 5/50
#  - 0s - loss: 47.6488
# Epoch 6/50
#  - 0s - loss: 48.6948
# Epoch 7/50
#  - 0s - loss: 47.8217
# Epoch 8/50
#  - 0s - loss: 50.6058
# Epoch 9/50
#  - 0s - loss: 47.9062
# Epoch 10/50
#  - 0s - loss: 47.9320
# Epoch 11/50
#  - 0s - loss: 50.3791
# Epoch 12/50
#  - 0s - loss: 49.6475
# Epoch 13/50
#  - 0s - loss: 47.8862
# Epoch 14/50
#  - 0s - loss: 48.0601
# Epoch 15/50
#  - 0s - loss: 49.1844
# Epoch 16/50
#  - 0s - loss: 52.2526
# Epoch 17/50
#  - 0s - loss: 49.1427
# Epoch 18/50
#  - 0s - loss: 48.3335
# Epoch 19/50
#  - 0s - loss: 47.0269
# Epoch 20/50
#  - 0s - loss: 50.0516
# Epoch 21/50
#  - 0s - loss: 51.3483
# Epoch 22/50
#  - 0s - loss: 48.2947
# Epoch 23/50
#  - 0s - loss: 50.3878
# Epoch 24/50
#  - 0s - loss: 50.0806
# Epoch 25/50
#  - 0s - loss: 49.1245
# Epoch 26/50
#  - 0s - loss: 51.4109
# Epoch 27/50
#  - 0s - loss: 48.0637
# Epoch 28/50
#  - 0s - loss: 49.5231
# Epoch 29/50
#  - 0s - loss: 49.6764
# Epoch 30/50
#  - 0s - loss: 48.7391
# Epoch 31/50
#  - 0s - loss: 48.8714
# Epoch 32/50
#  - 0s - loss: 47.5902
# Epoch 33/50
#  - 0s - loss: 48.3786
# Epoch 34/50
#  - 0s - loss: 48.2990
# Epoch 35/50
#  - 0s - loss: 49.3408
# Epoch 36/50
#  - 0s - loss: 48.5750
# Epoch 37/50
#  - 0s - loss: 48.5219
# Epoch 38/50
#  - 0s - loss: 47.9594
# Epoch 39/50
#  - 0s - loss: 48.7406
# Epoch 40/50
#  - 0s - loss: 47.8540
# Epoch 41/50
#  - 0s - loss: 48.5557
# Epoch 42/50
#  - 0s - loss: 49.0092
# Epoch 43/50
#  - 0s - loss: 53.2994
# Epoch 44/50
#  - 0s - loss: 48.2182
# Epoch 45/50
#  - 0s - loss: 47.6604
# Epoch 46/50
#  - 0s - loss: 48.1530
# Epoch 47/50
#  - 0s - loss: 48.1934
# Epoch 48/50
#  - 0s - loss: 48.9989
# Epoch 49/50
#  - 0s - loss: 51.7877
# Epoch 50/50
#  - 0s - loss: 48.7313
# Duration (seconds): 2.0047192573547363
# Finished - 50 times.
# And the list of mean squared errors : [754.9860532449675, 243.57483284907894, 154.62513822894869, 121.7080081569582, 110.7063865322131, 107.9162563599382, 114.08818939690457, 107.81814062226509, 107.89945472643483, 108.96398113593307, 110.6988281743998, 102.6054722514721, 65.36797141411364, 58.89002830961426, 50.84542850591122, 47.98945113414472, 52.80534084745285, 51.6105307554072, 51.010241083833286, 48.64935641686742, 48.16727504960567, 48.22351228491355, 47.865958285656355, 48.708255508666404, 54.830449363560184, 51.86489859556999, 48.091600936479594, 67.02169204435403, 51.205020665389874, 52.05395260748444, 48.41083521398826, 52.311043708995015, 52.56617425095577, 51.57496907424535, 57.30661011148139, 56.52916665299651, 48.18943445995541, 48.39529912811813, 48.49789014218582, 48.722769687649944, 51.28933131523144, 48.76146046261785, 51.68820222509309, 52.87918244137772, 49.65655692588171, 50.75499072303797, 50.005986516798814, 52.13690363639781, 50.01723210937953, 56.068381957384005]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 82.33 and 102.66, respectively

# %% [markdown]
# ### Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of not normalized data is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline-not normalized (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline = get_report(name_of_case, mean_mse, std_mse)
df_baseline
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     82.33             102.66

# %% [markdown]
# ## Part B: Normalized data

# %% [markdown]
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
# How does the mean of the mean squared errors compare to that from Step A?

# %% [markdown]
# ### Data before normalization

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %% [markdown]
# ### Data after normalization

# %% [markdown]
# We will normalize the data by substracting the mean and dividing by the standard deviation

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_colsnorm = predictors_norm.shape[1] #number of predictors

# %% [markdown]
# Defining the regression model as above

# %%
#define the regression model with one hidden layer
def regression_model():
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(n_colsnorm,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Creating the regression model

# %%
model = regression_model()

# %% [markdown]
# Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=24)   
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)

# %% [markdown]
# Train the model on the training data using 50 epochs

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
#  - 0s - loss: 1623.5850
# Epoch 2/50
#  - 0s - loss: 1608.4249
# Epoch 3/50
#  - 0s - loss: 1593.4508
# Epoch 4/50
#  - 0s - loss: 1579.0658
# Epoch 5/50
#  - 0s - loss: 1564.2792
# Epoch 6/50
#  - 0s - loss: 1549.4693
# Epoch 7/50
#  - 0s - loss: 1534.1506
# Epoch 8/50
#  - 0s - loss: 1518.3228
# Epoch 9/50
#  - 0s - loss: 1501.7177
# Epoch 10/50
#  - 0s - loss: 1484.3600
# Epoch 11/50
#  - 0s - loss: 1466.2228
# Epoch 12/50
#  - 0s - loss: 1447.0411
# Epoch 13/50
#  - 0s - loss: 1426.6101
# Epoch 14/50
#  - 0s - loss: 1405.6983
# Epoch 15/50
#  - 0s - loss: 1383.4877
# Epoch 16/50
#  - 0s - loss: 1360.5316
# Epoch 17/50
#  - 0s - loss: 1336.9053
# Epoch 18/50
#  - 0s - loss: 1312.4215
# Epoch 19/50
#  - 0s - loss: 1287.4737
# Epoch 20/50
#  - 0s - loss: 1261.4789
# Epoch 21/50
#  - 0s - loss: 1235.5406
# Epoch 22/50
#  - 0s - loss: 1208.8780
# Epoch 23/50
#  - 0s - loss: 1181.5878
# Epoch 24/50
#  - 0s - loss: 1154.1139
# Epoch 25/50
#  - 0s - loss: 1126.2791
# Epoch 26/50
#  - 0s - loss: 1098.2967
# Epoch 27/50
#  - 0s - loss: 1070.0182
# Epoch 28/50
#  - 0s - loss: 1041.7842
# Epoch 29/50
#  - 0s - loss: 1013.2821
# Epoch 30/50
#  - 0s - loss: 984.2040
# Epoch 31/50
#  - 0s - loss: 955.6306
# Epoch 32/50
#  - 0s - loss: 926.5653
# Epoch 33/50
#  - 0s - loss: 897.3094
# Epoch 34/50
#  - 0s - loss: 868.5509
# Epoch 35/50
#  - 0s - loss: 839.7577
# Epoch 36/50
#  - 0s - loss: 811.0418
# Epoch 37/50
#  - 0s - loss: 782.4805
# Epoch 38/50
#  - 0s - loss: 754.6412
# Epoch 39/50
#  - 0s - loss: 727.0740
# Epoch 40/50
#  - 0s - loss: 699.4863
# Epoch 41/50
#  - 0s - loss: 672.8155
# Epoch 42/50
#  - 0s - loss: 646.0385
# Epoch 43/50
#  - 0s - loss: 620.5256
# Epoch 44/50
#  - 0s - loss: 594.5103
# Epoch 45/50
#  - 0s - loss: 569.8972
# Epoch 46/50
#  - 0s - loss: 545.5193
# Epoch 47/50
#  - 0s - loss: 522.2429
# Epoch 48/50
#  - 0s - loss: 499.4517
# Epoch 49/50
#  - 0s - loss: 478.0076
# Epoch 50/50
#  - 0s - loss: 457.1124

# %% [markdown]
# Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.

# %%
y_hat = model.predict(X_test)   
mse = mean_squared_error(y_test, y_hat)

# %%
print(mse)
# Out:
# 430.8369270906882

# %% [markdown]
# For the case of not normalized data that we ran in Part A mse = 425.59, for this case with normalized data mse=281.52

# %% [markdown]
# Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors

# %%
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
    """Get report (dataframe) of two metrics: 
    The mean and the standard deviation of the mean squared errors
    """   
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn. 
    X = predictors_norm
    y = target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse

# %%
#Function to round the calculation of the mean and std deviation to 2 decimal places
def get_round(score, num_of_digits=2):
    """Get round with given number of decimal digits 
    """
    return round(score, num_of_digits)

#Function to calculate the mean of the list of mean squared errors
def get_mean(list_of_mse_scores):
    """Get mean
    """
    if list_of_mse_scores:
        return get_round(np.mean(list_of_mse_scores))
    return None

#Function to calculate the standard deviation of the list of mean squared errors
def get_standard_deviation(list_of_mse_scores):
    """Get standard deviation
    """
    if list_of_mse_scores:
        return get_round(np.std(list_of_mse_scores))
    return None




#Function to iterate and calculate the mean squared error
def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
    """Generate the mean and the standard deviation of the mean squared errors 
    """
    # Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.    
    list_of_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        list_of_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))
    # end for

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  list_of_mean_squared_errors))
    
    mean_mse = get_mean(list_of_mean_squared_errors)
    std_mse = get_standard_deviation(list_of_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse

# %%
max_iteration = 50
epochs = 50
verbose = 2

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors_norm, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 1607.7804
# Epoch 2/50
#  - 0s - loss: 1588.5265
# Epoch 3/50
#  - 0s - loss: 1570.0454
# Epoch 4/50
#  - 0s - loss: 1551.8686
# Epoch 5/50
#  - 0s - loss: 1534.1607
# Epoch 6/50
#  - 0s - loss: 1516.8524
# Epoch 7/50
#  - 0s - loss: 1499.7577
# Epoch 8/50
#  - 0s - loss: 1482.3267
# Epoch 9/50
#  - 0s - loss: 1465.2797
# Epoch 10/50
#  - 0s - loss: 1447.5409
# Epoch 11/50
#  - 0s - loss: 1429.9501
# Epoch 12/50
#  - 0s - loss: 1411.9260
# Epoch 13/50
#  - 0s - loss: 1393.5068
# Epoch 14/50
#  - 0s - loss: 1374.7789
# Epoch 15/50
#  - 0s - loss: 1355.7026
# Epoch 16/50
#  - 0s - loss: 1336.2381
# Epoch 17/50
#  - 0s - loss: 1316.2639
# Epoch 18/50
#  - 0s - loss: 1295.7872
# Epoch 19/50
#  - 0s - loss: 1274.8553
# Epoch 20/50
#  - 0s - loss: 1253.7118
# Epoch 21/50
#  - 0s - loss: 1231.5125
# Epoch 22/50
#  - 0s - loss: 1208.9604
# Epoch 23/50
#  - 0s - loss: 1186.4615
# Epoch 24/50
#  - 0s - loss: 1162.2975
# Epoch 25/50
#  - 0s - loss: 1138.0692
# Epoch 26/50
#  - 0s - loss: 1113.3395
# Epoch 27/50
#  - 0s - loss: 1087.6593
# Epoch 28/50
#  - 0s - loss: 1061.9829
# Epoch 29/50
#  - 0s - loss: 1035.4826
# Epoch 30/50
#  - 0s - loss: 1009.1830
# Epoch 31/50
#  - 0s - loss: 981.8154
# Epoch 32/50
#  - 0s - loss: 953.7092
# Epoch 33/50
#  - 0s - loss: 925.8274
# Epoch 34/50
#  - 0s - loss: 896.6868
# Epoch 35/50
#  - 0s - loss: 867.3989
# Epoch 36/50
#  - 0s - loss: 837.9206
# Epoch 37/50
#  - 0s - loss: 808.4691
# Epoch 38/50
#  - 0s - loss: 778.8427
# Epoch 39/50
#  - 0s - loss: 749.4285
# Epoch 40/50
#  - 0s - loss: 720.7274
# Epoch 41/50
#  - 0s - loss: 692.1819
# Epoch 42/50
#  - 0s - loss: 664.2529
# Epoch 43/50
#  - 0s - loss: 637.1691
# Epoch 44/50
#  - 0s - loss: 610.5461
# Epoch 45/50
#  - 0s - loss: 584.7031
# Epoch 46/50
#  - 0s - loss: 559.6658
# Epoch 47/50
#  - 0s - loss: 535.7599
# Epoch 48/50
#  - 0s - loss: 512.0053
# Epoch 49/50
#  - 0s - loss: 489.3383
# Epoch 50/50
#  - 0s - loss: 467.4927
# Duration (seconds): 3.0622198581695557
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 447.2423
# Epoch 2/50
#  - 0s - loss: 427.1487
# Epoch 3/50
#  - 0s - loss: 408.3937
# Epoch 4/50
#  - 0s - loss: 390.3760
# Epoch 5/50
#  - 0s - loss: 373.5508
# Epoch 6/50
#  - 0s - loss: 357.2727
# Epoch 7/50
#  - 0s - loss: 342.1035
# Epoch 8/50
#  - 0s - loss: 327.9462
# Epoch 9/50
#  - 0s - loss: 314.6247
# Epoch 10/50
#  - 0s - loss: 301.9159
# Epoch 11/50
#  - 0s - loss: 290.1894
# Epoch 12/50
#  - 0s - loss: 279.1008
# Epoch 13/50
#  - 0s - loss: 269.0347
# Epoch 14/50
#  - 0s - loss: 259.4030
# Epoch 15/50
#  - 0s - loss: 250.4650
# Epoch 16/50
#  - 0s - loss: 242.4041
# Epoch 17/50
#  - 0s - loss: 234.7190
# Epoch 18/50
#  - 0s - loss: 227.6621
# Epoch 19/50
#  - 0s - loss: 221.4417
# Epoch 20/50
#  - 0s - loss: 215.5084
# Epoch 21/50
#  - 0s - loss: 210.2058
# Epoch 22/50
#  - 0s - loss: 205.3138
# Epoch 23/50
#  - 0s - loss: 200.7938
# Epoch 24/50
#  - 0s - loss: 196.6701
# Epoch 25/50
#  - 0s - loss: 192.9349
# Epoch 26/50
#  - 0s - loss: 189.5469
# Epoch 27/50
#  - 0s - loss: 186.3943
# Epoch 28/50
#  - 0s - loss: 183.5312
# Epoch 29/50
#  - 0s - loss: 180.8397
# Epoch 30/50
#  - 0s - loss: 178.4127
# Epoch 31/50
#  - 0s - loss: 176.2330
# Epoch 32/50
#  - 0s - loss: 174.0196
# Epoch 33/50
#  - 0s - loss: 172.1041
# Epoch 34/50
#  - 0s - loss: 170.1556
# Epoch 35/50
#  - 0s - loss: 168.4297
# Epoch 36/50
#  - 0s - loss: 166.7878
# Epoch 37/50
#  - 0s - loss: 165.1625
# Epoch 38/50
#  - 0s - loss: 163.7481
# Epoch 39/50
#  - 0s - loss: 162.3451
# Epoch 40/50
#  - 0s - loss: 160.9894
# Epoch 41/50
#  - 0s - loss: 159.7525
# Epoch 42/50
#  - 0s - loss: 158.5325
# Epoch 43/50
#  - 0s - loss: 157.2994
# Epoch 44/50
#  - 0s - loss: 156.1997
# Epoch 45/50
#  - 0s - loss: 155.0181
# Epoch 46/50
#  - 0s - loss: 153.9732
# Epoch 47/50
#  - 0s - loss: 152.8601
# Epoch 48/50
#  - 0s - loss: 151.8157
# Epoch 49/50
#  - 0s - loss: 150.7567
# Epoch 50/50
#  - 0s - loss: 149.8454
# Duration (seconds): 2.1614620685577393
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 148.7621
# Epoch 2/50
#  - 0s - loss: 147.8095
# Epoch 3/50
#  - 0s - loss: 146.9387
# Epoch 4/50
#  - 0s - loss: 146.0052
# Epoch 5/50
#  - 0s - loss: 145.0939
# Epoch 6/50
#  - 0s - loss: 144.2600
# Epoch 7/50
#  - 0s - loss: 143.2396
# Epoch 8/50
#  - 0s - loss: 142.4083
# Epoch 9/50
#  - 0s - loss: 141.5121
# Epoch 10/50
#  - 0s - loss: 140.7925
# Epoch 11/50
#  - 0s - loss: 139.7776
# Epoch 12/50
#  - 0s - loss: 138.9551
# Epoch 13/50
#  - 0s - loss: 138.0900
# Epoch 14/50
#  - 0s - loss: 137.2452
# Epoch 15/50
#  - 0s - loss: 136.4436
# Epoch 16/50
#  - 0s - loss: 135.6553
# Epoch 17/50
#  - 0s - loss: 134.7923
# Epoch 18/50
#  - 0s - loss: 134.0515
# Epoch 19/50
#  - 0s - loss: 133.1580
# Epoch 20/50
#  - 0s - loss: 132.4131
# Epoch 21/50
#  - 0s - loss: 131.6121
# Epoch 22/50
#  - 0s - loss: 130.8626
# Epoch 23/50
#  - 0s - loss: 130.0853
# Epoch 24/50
#  - 0s - loss: 129.4259
# Epoch 25/50
#  - 0s - loss: 128.6225
# Epoch 26/50
#  - 0s - loss: 127.9303
# Epoch 27/50
#  - 0s - loss: 127.2934
# Epoch 28/50
#  - 0s - loss: 126.5869
# Epoch 29/50
#  - 0s - loss: 125.8407
# Epoch 30/50
#  - 0s - loss: 125.1498
# Epoch 31/50
#  - 0s - loss: 124.4751
# Epoch 32/50
#  - 0s - loss: 123.7812
# Epoch 33/50
#  - 0s - loss: 123.0904
# Epoch 34/50
#  - 0s - loss: 122.3463
# Epoch 35/50
#  - 0s - loss: 121.6852
# Epoch 36/50
#  - 0s - loss: 121.0017
# Epoch 37/50
#  - 0s - loss: 120.3362
# Epoch 38/50
#  - 0s - loss: 119.6512
# Epoch 39/50
#  - 0s - loss: 118.8895
# Epoch 40/50
#  - 0s - loss: 118.2173
# Epoch 41/50
#  - 0s - loss: 117.5088
# Epoch 42/50
#  - 0s - loss: 116.9026
# Epoch 43/50
#  - 0s - loss: 116.1214
# Epoch 44/50
#  - 0s - loss: 115.4301
# Epoch 45/50
#  - 0s - loss: 114.7348
# Epoch 46/50
#  - 0s - loss: 114.1282
# Epoch 47/50
#  - 0s - loss: 113.4611
# Epoch 48/50
#  - 0s - loss: 112.8126
# Epoch 49/50
#  - 0s - loss: 112.0376
# Epoch 50/50
#  - 0s - loss: 111.3308
# Duration (seconds): 2.062309741973877
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 110.6485
# Epoch 2/50
#  - 0s - loss: 109.9763
# Epoch 3/50
#  - 0s - loss: 109.2351
# Epoch 4/50
#  - 0s - loss: 108.5462
# Epoch 5/50
#  - 0s - loss: 107.8782
# Epoch 6/50
#  - 0s - loss: 107.1682
# Epoch 7/50
#  - 0s - loss: 106.4902
# Epoch 8/50
#  - 0s - loss: 105.8338
# Epoch 9/50
#  - 0s - loss: 105.2487
# Epoch 10/50
#  - 0s - loss: 104.4957
# Epoch 11/50
#  - 0s - loss: 103.8496
# Epoch 12/50
#  - 0s - loss: 103.2010
# Epoch 13/50
#  - 0s - loss: 102.4845
# Epoch 14/50
#  - 0s - loss: 101.8694
# Epoch 15/50
#  - 0s - loss: 101.2544
# Epoch 16/50
#  - 0s - loss: 100.5770
# Epoch 17/50
#  - 0s - loss: 99.9215
# Epoch 18/50
#  - 0s - loss: 99.2349
# Epoch 19/50
#  - 0s - loss: 98.7130
# Epoch 20/50
#  - 0s - loss: 98.0209
# Epoch 21/50
#  - 0s - loss: 97.3983
# Epoch 22/50
#  - 0s - loss: 96.7816
# Epoch 23/50
#  - 0s - loss: 96.1937
# Epoch 24/50
#  - 0s - loss: 95.5662
# Epoch 25/50
#  - 0s - loss: 95.0164
# Epoch 26/50
#  - 0s - loss: 94.3602
# Epoch 27/50
#  - 0s - loss: 93.8501
# Epoch 28/50
#  - 0s - loss: 93.2100
# Epoch 29/50
#  - 0s - loss: 92.6700
# Epoch 30/50
#  - 0s - loss: 92.0418
# Epoch 31/50
#  - 0s - loss: 91.4335
# Epoch 32/50
#  - 0s - loss: 90.9282
# Epoch 33/50
#  - 0s - loss: 90.2737
# Epoch 34/50
#  - 0s - loss: 89.6858
# Epoch 35/50
#  - 0s - loss: 89.1454
# Epoch 36/50
#  - 0s - loss: 88.5485
# Epoch 37/50
#  - 0s - loss: 87.9257
# Epoch 38/50
#  - 0s - loss: 87.3609
# Epoch 39/50
#  - 0s - loss: 86.7723
# Epoch 40/50
#  - 0s - loss: 86.2281
# Epoch 41/50
#  - 0s - loss: 85.7056
# Epoch 42/50
#  - 0s - loss: 85.2003
# Epoch 43/50
#  - 0s - loss: 84.5536
# Epoch 44/50
#  - 0s - loss: 84.0174
# Epoch 45/50
#  - 0s - loss: 83.4861
# Epoch 46/50
#  - 0s - loss: 82.9249
# Epoch 47/50
#  - 0s - loss: 82.4925
# Epoch 48/50
#  - 0s - loss: 81.9677
# Epoch 49/50
#  - 0s - loss: 81.4545
# Epoch 50/50
#  - 0s - loss: 80.9485
# Duration (seconds): 2.0838441848754883
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 80.4106
# Epoch 2/50
#  - 0s - loss: 79.8557
# Epoch 3/50
#  - 0s - loss: 79.3863
# Epoch 4/50
#  - 0s - loss: 78.9186
# Epoch 5/50
#  - 0s - loss: 78.3993
# Epoch 6/50
#  - 0s - loss: 77.8657
# Epoch 7/50
#  - 0s - loss: 77.4388
# Epoch 8/50
#  - 0s - loss: 76.8881
# Epoch 9/50
#  - 0s - loss: 76.5049
# Epoch 10/50
#  - 0s - loss: 75.9106
# Epoch 11/50
#  - 0s - loss: 75.4933
# Epoch 12/50
#  - 0s - loss: 74.9665
# Epoch 13/50
#  - 0s - loss: 74.5346
# Epoch 14/50
#  - 0s - loss: 74.0438
# Epoch 15/50
#  - 0s - loss: 73.5741
# Epoch 16/50
#  - 0s - loss: 73.1469
# Epoch 17/50
#  - 0s - loss: 72.7445
# Epoch 18/50
#  - 0s - loss: 72.2663
# Epoch 19/50
#  - 0s - loss: 71.8294
# Epoch 20/50
#  - 0s - loss: 71.4484
# Epoch 21/50
#  - 0s - loss: 71.0142
# Epoch 22/50
#  - 0s - loss: 70.5512
# Epoch 23/50
#  - 0s - loss: 70.1826
# Epoch 24/50
#  - 0s - loss: 69.7323
# Epoch 25/50
#  - 0s - loss: 69.4172
# Epoch 26/50
#  - 0s - loss: 68.9537
# Epoch 27/50
#  - 0s - loss: 68.5778
# Epoch 28/50
#  - 0s - loss: 68.1745
# Epoch 29/50
#  - 0s - loss: 67.7989
# Epoch 30/50
#  - 0s - loss: 67.3760
# Epoch 31/50
#  - 0s - loss: 67.0377
# Epoch 32/50
#  - 0s - loss: 66.7268
# Epoch 33/50
#  - 0s - loss: 66.3065
# Epoch 34/50
#  - 0s - loss: 66.0251
# Epoch 35/50
#  - 0s - loss: 65.6389
# Epoch 36/50
#  - 0s - loss: 65.2643
# Epoch 37/50
#  - 0s - loss: 64.9231
# Epoch 38/50
#  - 0s - loss: 64.5847
# Epoch 39/50
#  - 0s - loss: 64.2570
# Epoch 40/50
#  - 0s - loss: 63.9709
# Epoch 41/50
#  - 0s - loss: 63.7415
# Epoch 42/50
#  - 0s - loss: 63.3617
# Epoch 43/50
#  - 0s - loss: 63.0509
# Epoch 44/50
#  - 0s - loss: 62.6632
# Epoch 45/50
#  - 0s - loss: 62.3976
# Epoch 46/50
#  - 0s - loss: 62.1504
# Epoch 47/50
#  - 0s - loss: 61.8601
# Epoch 48/50
#  - 0s - loss: 61.4980
# Epoch 49/50
#  - 0s - loss: 61.2576
# Epoch 50/50
#  - 0s - loss: 60.9118
# Duration (seconds): 2.1039562225341797
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 60.6368
# Epoch 2/50
#  - 0s - loss: 60.3503
# Epoch 3/50
#  - 0s - loss: 60.0746
# Epoch 4/50
#  - 0s - loss: 59.7941
# Epoch 5/50
#  - 0s - loss: 59.5031
# Epoch 6/50
#  - 0s - loss: 59.2844
# Epoch 7/50
#  - 0s - loss: 59.0716
# Epoch 8/50
#  - 0s - loss: 58.7575
# Epoch 9/50
#  - 0s - loss: 58.5181
# Epoch 10/50
#  - 0s - loss: 58.2208
# Epoch 11/50
#  - 0s - loss: 57.9957
# Epoch 12/50
#  - 0s - loss: 57.7737
# Epoch 13/50
#  - 0s - loss: 57.5307
# Epoch 14/50
#  - 0s - loss: 57.2505
# Epoch 15/50
#  - 0s - loss: 57.0571
# Epoch 16/50
#  - 0s - loss: 56.7392
# Epoch 17/50
#  - 0s - loss: 56.5707
# Epoch 18/50
#  - 0s - loss: 56.3787
# Epoch 19/50
#  - 0s - loss: 56.0594
# Epoch 20/50
#  - 0s - loss: 55.8549
# Epoch 21/50
#  - 0s - loss: 55.6458
# Epoch 22/50
#  - 0s - loss: 55.4203
# Epoch 23/50
#  - 0s - loss: 55.2273
# Epoch 24/50
#  - 0s - loss: 55.0100
# Epoch 25/50
#  - 0s - loss: 54.7627
# Epoch 26/50
#  - 0s - loss: 54.5719
# Epoch 27/50
#  - 0s - loss: 54.3957
# Epoch 28/50
#  - 0s - loss: 54.2142
# Epoch 29/50
#  - 0s - loss: 54.0539
# Epoch 30/50
#  - 0s - loss: 53.7511
# Epoch 31/50
#  - 0s - loss: 53.6189
# Epoch 32/50
#  - 0s - loss: 53.3976
# Epoch 33/50
#  - 0s - loss: 53.2178
# Epoch 34/50
#  - 0s - loss: 52.9928
# Epoch 35/50
#  - 0s - loss: 52.8246
# Epoch 36/50
#  - 0s - loss: 52.6318
# Epoch 37/50
#  - 0s - loss: 52.4924
# Epoch 38/50
#  - 0s - loss: 52.3250
# Epoch 39/50
#  - 0s - loss: 52.1425
# Epoch 40/50
#  - 0s - loss: 51.9314
# Epoch 41/50
#  - 0s - loss: 51.7733
# Epoch 42/50
#  - 0s - loss: 51.5851
# Epoch 43/50
#  - 0s - loss: 51.4686
# Epoch 44/50
#  - 0s - loss: 51.2212
# Epoch 45/50
#  - 0s - loss: 51.0578
# Epoch 46/50
#  - 0s - loss: 50.8798
# Epoch 47/50
#  - 0s - loss: 50.7419
# Epoch 48/50
#  - 0s - loss: 50.6705
# Epoch 49/50
#  - 0s - loss: 50.4898
# Epoch 50/50
#  - 0s - loss: 50.2623
# Duration (seconds): 2.004456043243408
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 50.1556
# Epoch 2/50
#  - 0s - loss: 49.9759
# Epoch 3/50
#  - 0s - loss: 49.8364
# Epoch 4/50
#  - 0s - loss: 49.6596
# Epoch 5/50
#  - 0s - loss: 49.5827
# Epoch 6/50
#  - 0s - loss: 49.4784
# Epoch 7/50
#  - 0s - loss: 49.2986
# Epoch 8/50
#  - 0s - loss: 49.1278
# Epoch 9/50
#  - 0s - loss: 49.0283
# Epoch 10/50
#  - 0s - loss: 48.7978
# Epoch 11/50
#  - 0s - loss: 48.6878
# Epoch 12/50
#  - 0s - loss: 48.5879
# Epoch 13/50
#  - 0s - loss: 48.4816
# Epoch 14/50
#  - 0s - loss: 48.2705
# Epoch 15/50
#  - 0s - loss: 48.1118
# Epoch 16/50
#  - 0s - loss: 48.0006
# Epoch 17/50
#  - 0s - loss: 47.8423
# Epoch 18/50
#  - 0s - loss: 47.6916
# Epoch 19/50
#  - 0s - loss: 47.6501
# Epoch 20/50
#  - 0s - loss: 47.4541
# Epoch 21/50
#  - 0s - loss: 47.4459
# Epoch 22/50
#  - 0s - loss: 47.2363
# Epoch 23/50
#  - 0s - loss: 47.1057
# Epoch 24/50
#  - 0s - loss: 46.9824
# Epoch 25/50
#  - 0s - loss: 46.8426
# Epoch 26/50
#  - 0s - loss: 46.7527
# Epoch 27/50
#  - 0s - loss: 46.6235
# Epoch 28/50
#  - 0s - loss: 46.5294
# Epoch 29/50
#  - 0s - loss: 46.3940
# Epoch 30/50
#  - 0s - loss: 46.4057
# Epoch 31/50
#  - 0s - loss: 46.2237
# Epoch 32/50
#  - 0s - loss: 46.0331
# Epoch 33/50
#  - 0s - loss: 45.9581
# Epoch 34/50
#  - 0s - loss: 45.8341
# Epoch 35/50
#  - 0s - loss: 45.7277
# Epoch 36/50
#  - 0s - loss: 45.6304
# Epoch 37/50
#  - 0s - loss: 45.5526
# Epoch 38/50
#  - 0s - loss: 45.4721
# Epoch 39/50
#  - 0s - loss: 45.4158
# Epoch 40/50
#  - 0s - loss: 45.2328
# Epoch 41/50
#  - 0s - loss: 45.1994
# Epoch 42/50
#  - 0s - loss: 45.0820
# Epoch 43/50
#  - 0s - loss: 44.9981
# Epoch 44/50
#  - 0s - loss: 44.9014
# Epoch 45/50
#  - 0s - loss: 44.7984
# Epoch 46/50
#  - 0s - loss: 44.8019
# Epoch 47/50
#  - 0s - loss: 44.6696
# Epoch 48/50
#  - 0s - loss: 44.5960
# Epoch 49/50
#  - 0s - loss: 44.4912
# Epoch 50/50
#  - 0s - loss: 44.3941
# Duration (seconds): 2.091603994369507
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 44.3131
# Epoch 2/50
#  - 0s - loss: 44.2734
# Epoch 3/50
#  - 0s - loss: 44.1917
# Epoch 4/50
#  - 0s - loss: 44.0719
# Epoch 5/50
#  - 0s - loss: 44.0226
# Epoch 6/50
#  - 0s - loss: 43.9764
# Epoch 7/50
#  - 0s - loss: 43.8341
# Epoch 8/50
#  - 0s - loss: 43.7799
# Epoch 9/50
#  - 0s - loss: 43.7480
# Epoch 10/50
#  - 0s - loss: 43.6096
# Epoch 11/50
#  - 0s - loss: 43.5604
# Epoch 12/50
#  - 0s - loss: 43.4338
# Epoch 13/50
#  - 0s - loss: 43.4164
# Epoch 14/50
#  - 0s - loss: 43.3473
# Epoch 15/50
#  - 0s - loss: 43.3430
# Epoch 16/50
#  - 0s - loss: 43.1880
# Epoch 17/50
#  - 0s - loss: 43.1275
# Epoch 18/50
#  - 0s - loss: 43.1253
# Epoch 19/50
#  - 0s - loss: 43.0006
# Epoch 20/50
#  - 0s - loss: 42.8715
# Epoch 21/50
#  - 0s - loss: 42.8105
# Epoch 22/50
#  - 0s - loss: 42.7360
# Epoch 23/50
#  - 0s - loss: 42.6474
# Epoch 24/50
#  - 0s - loss: 42.6067
# Epoch 25/50
#  - 0s - loss: 42.5430
# Epoch 26/50
#  - 0s - loss: 42.5079
# Epoch 27/50
#  - 0s - loss: 42.4216
# Epoch 28/50
#  - 0s - loss: 42.3086
# Epoch 29/50
#  - 0s - loss: 42.2427
# Epoch 30/50
#  - 0s - loss: 42.2431
# Epoch 31/50
#  - 0s - loss: 42.1517
# Epoch 32/50
#  - 0s - loss: 42.0571
# Epoch 33/50
#  - 0s - loss: 42.0463
# Epoch 34/50
#  - 0s - loss: 41.9411
# Epoch 35/50
#  - 0s - loss: 41.8602
# Epoch 36/50
#  - 0s - loss: 41.7753
# Epoch 37/50
#  - 0s - loss: 41.7449
# Epoch 38/50
#  - 0s - loss: 41.6573
# Epoch 39/50
#  - 0s - loss: 41.6019
# Epoch 40/50
#  - 0s - loss: 41.5597
# Epoch 41/50
#  - 0s - loss: 41.5592
# Epoch 42/50
#  - 0s - loss: 41.4612
# Epoch 43/50
#  - 0s - loss: 41.3685
# Epoch 44/50
#  - 0s - loss: 41.3453
# Epoch 45/50
#  - 0s - loss: 41.2432
# Epoch 46/50
#  - 0s - loss: 41.2480
# Epoch 47/50
#  - 0s - loss: 41.1199
# Epoch 48/50
#  - 0s - loss: 41.1482
# Epoch 49/50
#  - 0s - loss: 41.0544
# Epoch 50/50
#  - 0s - loss: 41.0187
# Duration (seconds): 2.093729019165039
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 40.9352
# Epoch 2/50
#  - 0s - loss: 40.9010
# Epoch 3/50
#  - 0s - loss: 40.8383
# Epoch 4/50
#  - 0s - loss: 40.8340
# Epoch 5/50
#  - 0s - loss: 40.7760
# Epoch 6/50
#  - 0s - loss: 40.7436
# Epoch 7/50
#  - 0s - loss: 40.6243
# Epoch 8/50
#  - 0s - loss: 40.6309
# Epoch 9/50
#  - 0s - loss: 40.4929
# Epoch 10/50
#  - 0s - loss: 40.4567
# Epoch 11/50
#  - 0s - loss: 40.4048
# Epoch 12/50
#  - 0s - loss: 40.3258
# Epoch 13/50
#  - 0s - loss: 40.3271
# Epoch 14/50
#  - 0s - loss: 40.2705
# Epoch 15/50
#  - 0s - loss: 40.1862
# Epoch 16/50
#  - 0s - loss: 40.2358
# Epoch 17/50
#  - 0s - loss: 40.1561
# Epoch 18/50
#  - 0s - loss: 40.0812
# Epoch 19/50
#  - 0s - loss: 40.0605
# Epoch 20/50
#  - 0s - loss: 40.0305
# Epoch 21/50
#  - 0s - loss: 39.9452
# Epoch 22/50
#  - 0s - loss: 39.8429
# Epoch 23/50
#  - 0s - loss: 39.8422
# Epoch 24/50
#  - 0s - loss: 39.7663
# Epoch 25/50
#  - 0s - loss: 39.7631
# Epoch 26/50
#  - 0s - loss: 39.6637
# Epoch 27/50
#  - 0s - loss: 39.6820
# Epoch 28/50
#  - 0s - loss: 39.5768
# Epoch 29/50
#  - 0s - loss: 39.6159
# Epoch 30/50
#  - 0s - loss: 39.5054
# Epoch 31/50
#  - 0s - loss: 39.4761
# Epoch 32/50
#  - 0s - loss: 39.4033
# Epoch 33/50
#  - 0s - loss: 39.3690
# Epoch 34/50
#  - 0s - loss: 39.3343
# Epoch 35/50
#  - 0s - loss: 39.3182
# Epoch 36/50
#  - 0s - loss: 39.2869
# Epoch 37/50
#  - 0s - loss: 39.2509
# Epoch 38/50
#  - 0s - loss: 39.1790
# Epoch 39/50
#  - 0s - loss: 39.1183
# Epoch 40/50
#  - 0s - loss: 39.0708
# Epoch 41/50
#  - 0s - loss: 39.0772
# Epoch 42/50
#  - 0s - loss: 39.1038
# Epoch 43/50
#  - 0s - loss: 38.9404
# Epoch 44/50
#  - 0s - loss: 38.9083
# Epoch 45/50
#  - 0s - loss: 38.8815
# Epoch 46/50
#  - 0s - loss: 38.8341
# Epoch 47/50
#  - 0s - loss: 38.7644
# Epoch 48/50
#  - 0s - loss: 38.8219
# Epoch 49/50
#  - 0s - loss: 38.7545
# Epoch 50/50
#  - 0s - loss: 38.7517
# Duration (seconds): 1.6398608684539795
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 38.6285
# Epoch 2/50
#  - 0s - loss: 38.5945
# Epoch 3/50
#  - 0s - loss: 38.5860
# Epoch 4/50
#  - 0s - loss: 38.5953
# Epoch 5/50
#  - 0s - loss: 38.5006
# Epoch 6/50
#  - 0s - loss: 38.4663
# Epoch 7/50
#  - 0s - loss: 38.4234
# Epoch 8/50
#  - 0s - loss: 38.3623
# Epoch 9/50
#  - 0s - loss: 38.3324
# Epoch 10/50
#  - 0s - loss: 38.3051
# Epoch 11/50
#  - 0s - loss: 38.2672
# Epoch 12/50
#  - 0s - loss: 38.1836
# Epoch 13/50
#  - 0s - loss: 38.2454
# Epoch 14/50
#  - 0s - loss: 38.1132
# Epoch 15/50
#  - 0s - loss: 38.1666
# Epoch 16/50
#  - 0s - loss: 38.0837
# Epoch 17/50
#  - 0s - loss: 38.0560
# Epoch 18/50
#  - 0s - loss: 38.0460
# Epoch 19/50
#  - 0s - loss: 37.9625
# Epoch 20/50
#  - 0s - loss: 37.9353
# Epoch 21/50
#  - 0s - loss: 37.8734
# Epoch 22/50
#  - 0s - loss: 37.8622
# Epoch 23/50
#  - 0s - loss: 37.7760
# Epoch 24/50
#  - 0s - loss: 37.7948
# Epoch 25/50
#  - 0s - loss: 37.7206
# Epoch 26/50
#  - 0s - loss: 37.7108
# Epoch 27/50
#  - 0s - loss: 37.6619
# Epoch 28/50
#  - 0s - loss: 37.6176
# Epoch 29/50
#  - 0s - loss: 37.6179
# Epoch 30/50
#  - 0s - loss: 37.5318
# Epoch 31/50
#  - 0s - loss: 37.5633
# Epoch 32/50
#  - 0s - loss: 37.4969
# Epoch 33/50
#  - 0s - loss: 37.5064
# Epoch 34/50
#  - 0s - loss: 37.4333
# Epoch 35/50
#  - 0s - loss: 37.4265
# Epoch 36/50
#  - 0s - loss: 37.3332
# Epoch 37/50
#  - 0s - loss: 37.3678
# Epoch 38/50
#  - 0s - loss: 37.3292
# Epoch 39/50
#  - 0s - loss: 37.2701
# Epoch 40/50
#  - 0s - loss: 37.1881
# Epoch 41/50
#  - 0s - loss: 37.1953
# Epoch 42/50
#  - 0s - loss: 37.1757
# Epoch 43/50
#  - 0s - loss: 37.1477
# Epoch 44/50
#  - 0s - loss: 37.1036
# Epoch 45/50
#  - 0s - loss: 37.0832
# Epoch 46/50
#  - 0s - loss: 37.0920
# Epoch 47/50
#  - 0s - loss: 37.0195
# Epoch 48/50
#  - 0s - loss: 36.9746
# Epoch 49/50
#  - 0s - loss: 36.9850
# Epoch 50/50
#  - 0s - loss: 36.9668
# Duration (seconds): 1.5989727973937988
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 36.9985
# Epoch 2/50
#  - 0s - loss: 36.8599
# Epoch 3/50
#  - 0s - loss: 36.8300
# Epoch 4/50
#  - 0s - loss: 36.8034
# Epoch 5/50
#  - 0s - loss: 36.7560
# Epoch 6/50
#  - 0s - loss: 36.8560
# Epoch 7/50
#  - 0s - loss: 36.7204
# Epoch 8/50
#  - 0s - loss: 36.7527
# Epoch 9/50
#  - 0s - loss: 36.6976
# Epoch 10/50
#  - 0s - loss: 36.6172
# Epoch 11/50
#  - 0s - loss: 36.6184
# Epoch 12/50
#  - 0s - loss: 36.5797
# Epoch 13/50
#  - 0s - loss: 36.5438
# Epoch 14/50
#  - 0s - loss: 36.5500
# Epoch 15/50
#  - 0s - loss: 36.5155
# Epoch 16/50
#  - 0s - loss: 36.4917
# Epoch 17/50
#  - 0s - loss: 36.4887
# Epoch 18/50
#  - 0s - loss: 36.4125
# Epoch 19/50
#  - 0s - loss: 36.3963
# Epoch 20/50
#  - 0s - loss: 36.3085
# Epoch 21/50
#  - 0s - loss: 36.3551
# Epoch 22/50
#  - 0s - loss: 36.2567
# Epoch 23/50
#  - 0s - loss: 36.2430
# Epoch 24/50
#  - 0s - loss: 36.1725
# Epoch 25/50
#  - 0s - loss: 36.1513
# Epoch 26/50
#  - 0s - loss: 36.1653
# Epoch 27/50
#  - 0s - loss: 36.1244
# Epoch 28/50
#  - 0s - loss: 36.0618
# Epoch 29/50
#  - 0s - loss: 36.0309
# Epoch 30/50
#  - 0s - loss: 36.0210
# Epoch 31/50
#  - 0s - loss: 36.0295
# Epoch 32/50
#  - 0s - loss: 35.9225
# Epoch 33/50
#  - 0s - loss: 36.0021
# Epoch 34/50
#  - 0s - loss: 35.9129
# Epoch 35/50
#  - 0s - loss: 35.8810
# Epoch 36/50
#  - 0s - loss: 35.9001
# Epoch 37/50
#  - 0s - loss: 35.8937
# Epoch 38/50
#  - 0s - loss: 35.8092
# Epoch 39/50
#  - 0s - loss: 35.7939
# Epoch 40/50
#  - 0s - loss: 35.7039
# Epoch 41/50
#  - 0s - loss: 35.7134
# Epoch 42/50
#  - 0s - loss: 35.6684
# Epoch 43/50
#  - 0s - loss: 35.6842
# Epoch 44/50
#  - 0s - loss: 35.6230
# Epoch 45/50
#  - 0s - loss: 35.5904
# Epoch 46/50
#  - 0s - loss: 35.5783
# Epoch 47/50
#  - 0s - loss: 35.5803
# Epoch 48/50
#  - 0s - loss: 35.5351
# Epoch 49/50
#  - 0s - loss: 35.5025
# Epoch 50/50
#  - 0s - loss: 35.5160
# Duration (seconds): 1.6340680122375488
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 35.4316
# Epoch 2/50
#  - 0s - loss: 35.4385
# Epoch 3/50
#  - 0s - loss: 35.4131
# Epoch 4/50
#  - 0s - loss: 35.4335
# Epoch 5/50
#  - 0s - loss: 35.3039
# Epoch 6/50
#  - 0s - loss: 35.3767
# Epoch 7/50
#  - 0s - loss: 35.2895
# Epoch 8/50
#  - 0s - loss: 35.2939
# Epoch 9/50
#  - 0s - loss: 35.2228
# Epoch 10/50
#  - 0s - loss: 35.2618
# Epoch 11/50
#  - 0s - loss: 35.1538
# Epoch 12/50
#  - 0s - loss: 35.1834
# Epoch 13/50
#  - 0s - loss: 35.1587
# Epoch 14/50
#  - 0s - loss: 35.1108
# Epoch 15/50
#  - 0s - loss: 35.1422
# Epoch 16/50
#  - 0s - loss: 35.0256
# Epoch 17/50
#  - 0s - loss: 35.0578
# Epoch 18/50
#  - 0s - loss: 35.0526
# Epoch 19/50
#  - 0s - loss: 35.0670
# Epoch 20/50
#  - 0s - loss: 34.9559
# Epoch 21/50
#  - 0s - loss: 34.9362
# Epoch 22/50
#  - 0s - loss: 34.8929
# Epoch 23/50
#  - 0s - loss: 35.0342
# Epoch 24/50
#  - 0s - loss: 34.8825
# Epoch 25/50
#  - 0s - loss: 34.8333
# Epoch 26/50
#  - 0s - loss: 34.7893
# Epoch 27/50
#  - 0s - loss: 34.8022
# Epoch 28/50
#  - 0s - loss: 34.6972
# Epoch 29/50
#  - 0s - loss: 34.7320
# Epoch 30/50
#  - 0s - loss: 34.6739
# Epoch 31/50
#  - 0s - loss: 34.6932
# Epoch 32/50
#  - 0s - loss: 34.6519
# Epoch 33/50
#  - 0s - loss: 34.6025
# Epoch 34/50
#  - 0s - loss: 34.5871
# Epoch 35/50
#  - 0s - loss: 34.5589
# Epoch 36/50
#  - 0s - loss: 34.5492
# Epoch 37/50
#  - 0s - loss: 34.5651
# Epoch 38/50
#  - 0s - loss: 34.4886
# Epoch 39/50
#  - 0s - loss: 34.4062
# Epoch 40/50
#  - 0s - loss: 34.4736
# Epoch 41/50
#  - 0s - loss: 34.3572
# Epoch 42/50
#  - 0s - loss: 34.3899
# Epoch 43/50
#  - 0s - loss: 34.2994
# Epoch 44/50
#  - 0s - loss: 34.3220
# Epoch 45/50
#  - 0s - loss: 34.3177
# Epoch 46/50
#  - 0s - loss: 34.2660
# Epoch 47/50
#  - 0s - loss: 34.2348
# Epoch 48/50
#  - 0s - loss: 34.1268
# Epoch 49/50
#  - 0s - loss: 34.0910
# Epoch 50/50
#  - 0s - loss: 34.1913
# Duration (seconds): 1.6440072059631348
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 34.0547
# Epoch 2/50
#  - 0s - loss: 34.1606
# Epoch 3/50
#  - 0s - loss: 34.0866
# Epoch 4/50
#  - 0s - loss: 33.9940
# Epoch 5/50
#  - 0s - loss: 33.9492
# Epoch 6/50
#  - 0s - loss: 33.8807
# Epoch 7/50
#  - 0s - loss: 33.9257
# Epoch 8/50
#  - 0s - loss: 33.8285
# Epoch 9/50
#  - 0s - loss: 33.7795
# Epoch 10/50
#  - 0s - loss: 33.8209
# Epoch 11/50
#  - 0s - loss: 33.8273
# Epoch 12/50
#  - 0s - loss: 33.7433
# Epoch 13/50
#  - 0s - loss: 33.7133
# Epoch 14/50
#  - 0s - loss: 33.7289
# Epoch 15/50
#  - 0s - loss: 33.6215
# Epoch 16/50
#  - 0s - loss: 33.5834
# Epoch 17/50
#  - 0s - loss: 33.5829
# Epoch 18/50
#  - 0s - loss: 33.4919
# Epoch 19/50
#  - 0s - loss: 33.5130
# Epoch 20/50
#  - 0s - loss: 33.4963
# Epoch 21/50
#  - 0s - loss: 33.4945
# Epoch 22/50
#  - 0s - loss: 33.4327
# Epoch 23/50
#  - 0s - loss: 33.3784
# Epoch 24/50
#  - 0s - loss: 33.3586
# Epoch 25/50
#  - 0s - loss: 33.3590
# Epoch 26/50
#  - 0s - loss: 33.3434
# Epoch 27/50
#  - 0s - loss: 33.2726
# Epoch 28/50
#  - 0s - loss: 33.2474
# Epoch 29/50
#  - 0s - loss: 33.2436
# Epoch 30/50
#  - 0s - loss: 33.2376
# Epoch 31/50
#  - 0s - loss: 33.1871
# Epoch 32/50
#  - 0s - loss: 33.2105
# Epoch 33/50
#  - 0s - loss: 33.1420
# Epoch 34/50
#  - 0s - loss: 33.1517
# Epoch 35/50
#  - 0s - loss: 33.0985
# Epoch 36/50
#  - 0s - loss: 33.0965
# Epoch 37/50
#  - 0s - loss: 33.1632
# Epoch 38/50
#  - 0s - loss: 33.0208
# Epoch 39/50
#  - 0s - loss: 32.9922
# Epoch 40/50
#  - 0s - loss: 32.9753
# Epoch 41/50
#  - 0s - loss: 32.9672
# Epoch 42/50
#  - 0s - loss: 32.9372
# Epoch 43/50
#  - 0s - loss: 32.9046
# Epoch 44/50
#  - 0s - loss: 32.8281
# Epoch 45/50
#  - 0s - loss: 32.8845
# Epoch 46/50
#  - 0s - loss: 32.9095
# Epoch 47/50
#  - 0s - loss: 32.8298
# Epoch 48/50
#  - 0s - loss: 32.7684
# Epoch 49/50
#  - 0s - loss: 32.7465
# Epoch 50/50
#  - 0s - loss: 32.6923
# Duration (seconds): 1.640333890914917
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 32.6693
# Epoch 2/50
#  - 0s - loss: 32.6668
# Epoch 3/50
#  - 0s - loss: 32.6979
# Epoch 4/50
#  - 0s - loss: 32.6233
# Epoch 5/50
#  - 0s - loss: 32.5885
# Epoch 6/50
#  - 0s - loss: 32.5705
# Epoch 7/50
#  - 0s - loss: 32.5784
# Epoch 8/50
#  - 0s - loss: 32.5381
# Epoch 9/50
#  - 0s - loss: 32.5414
# Epoch 10/50
#  - 0s - loss: 32.4594
# Epoch 11/50
#  - 0s - loss: 32.4412
# Epoch 12/50
#  - 0s - loss: 32.4443
# Epoch 13/50
#  - 0s - loss: 32.4814
# Epoch 14/50
#  - 0s - loss: 32.3953
# Epoch 15/50
#  - 0s - loss: 32.3856
# Epoch 16/50
#  - 0s - loss: 32.4123
# Epoch 17/50
#  - 0s - loss: 32.3458
# Epoch 18/50
#  - 0s - loss: 32.3728
# Epoch 19/50
#  - 0s - loss: 32.4044
# Epoch 20/50
#  - 0s - loss: 32.3761
# Epoch 21/50
#  - 0s - loss: 32.2962
# Epoch 22/50
#  - 0s - loss: 32.2757
# Epoch 23/50
#  - 0s - loss: 32.2949
# Epoch 24/50
#  - 0s - loss: 32.2654
# Epoch 25/50
#  - 0s - loss: 32.1988
# Epoch 26/50
#  - 0s - loss: 32.1786
# Epoch 27/50
#  - 0s - loss: 32.1655
# Epoch 28/50
#  - 0s - loss: 32.1435
# Epoch 29/50
#  - 0s - loss: 32.1638
# Epoch 30/50
#  - 0s - loss: 32.1504
# Epoch 31/50
#  - 0s - loss: 32.1108
# Epoch 32/50
#  - 0s - loss: 32.0918
# Epoch 33/50
#  - 0s - loss: 32.1001
# Epoch 34/50
#  - 0s - loss: 32.0741
# Epoch 35/50
#  - 0s - loss: 32.0353
# Epoch 36/50
#  - 0s - loss: 31.9921
# Epoch 37/50
#  - 0s - loss: 32.0121
# Epoch 38/50
#  - 0s - loss: 32.1015
# Epoch 39/50
#  - 0s - loss: 31.9769
# Epoch 40/50
#  - 0s - loss: 31.9974
# Epoch 41/50
#  - 0s - loss: 31.9165
# Epoch 42/50
#  - 0s - loss: 31.9413
# Epoch 43/50
#  - 0s - loss: 31.8913
# Epoch 44/50
#  - 0s - loss: 31.8607
# Epoch 45/50
#  - 0s - loss: 31.8359
# Epoch 46/50
#  - 0s - loss: 31.8518
# Epoch 47/50
#  - 0s - loss: 31.8274
# Epoch 48/50
#  - 0s - loss: 31.7932
# Epoch 49/50
#  - 0s - loss: 31.8135
# Epoch 50/50
#  - 0s - loss: 31.8022
# Duration (seconds): 1.6088740825653076
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.7624
# Epoch 2/50
#  - 0s - loss: 31.7833
# Epoch 3/50
#  - 0s - loss: 31.7205
# Epoch 4/50
#  - 0s - loss: 31.7555
# Epoch 5/50
#  - 0s - loss: 31.7090
# Epoch 6/50
#  - 0s - loss: 31.6987
# Epoch 7/50
#  - 0s - loss: 31.6533
# Epoch 8/50
#  - 0s - loss: 31.6805
# Epoch 9/50
#  - 0s - loss: 31.7695
# Epoch 10/50
#  - 0s - loss: 31.6261
# Epoch 11/50
#  - 0s - loss: 31.6502
# Epoch 12/50
#  - 0s - loss: 31.6014
# Epoch 13/50
#  - 0s - loss: 31.6134
# Epoch 14/50
#  - 0s - loss: 31.5977
# Epoch 15/50
#  - 0s - loss: 31.5945
# Epoch 16/50
#  - 0s - loss: 31.5644
# Epoch 17/50
#  - 0s - loss: 31.6023
# Epoch 18/50
#  - 0s - loss: 31.5003
# Epoch 19/50
#  - 0s - loss: 31.5301
# Epoch 20/50
#  - 0s - loss: 31.4946
# Epoch 21/50
#  - 0s - loss: 31.4714
# Epoch 22/50
#  - 0s - loss: 31.4480
# Epoch 23/50
#  - 0s - loss: 31.4864
# Epoch 24/50
#  - 0s - loss: 31.4253
# Epoch 25/50
#  - 0s - loss: 31.4146
# Epoch 26/50
#  - 0s - loss: 31.4566
# Epoch 27/50
#  - 0s - loss: 31.4483
# Epoch 28/50
#  - 0s - loss: 31.3878
# Epoch 29/50
#  - 0s - loss: 31.4047
# Epoch 30/50
#  - 0s - loss: 31.4092
# Epoch 31/50
#  - 0s - loss: 31.3707
# Epoch 32/50
#  - 0s - loss: 31.3503
# Epoch 33/50
#  - 0s - loss: 31.3581
# Epoch 34/50
#  - 0s - loss: 31.3799
# Epoch 35/50
#  - 0s - loss: 31.3215
# Epoch 36/50
#  - 0s - loss: 31.3599
# Epoch 37/50
#  - 0s - loss: 31.3394
# Epoch 38/50
#  - 0s - loss: 31.3016
# Epoch 39/50
#  - 0s - loss: 31.2530
# Epoch 40/50
#  - 0s - loss: 31.2826
# Epoch 41/50
#  - 0s - loss: 31.2329
# Epoch 42/50
#  - 0s - loss: 31.2565
# Epoch 43/50
#  - 0s - loss: 31.2574
# Epoch 44/50
#  - 0s - loss: 31.1868
# Epoch 45/50
#  - 0s - loss: 31.2788
# Epoch 46/50
#  - 0s - loss: 31.1913
# Epoch 47/50
#  - 0s - loss: 31.2045
# Epoch 48/50
#  - 0s - loss: 31.1666
# Epoch 49/50
#  - 0s - loss: 31.1966
# Epoch 50/50
#  - 0s - loss: 31.1616
# Duration (seconds): 1.977616786956787
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 31.1118
# Epoch 2/50
#  - 0s - loss: 31.1504
# Epoch 3/50
#  - 0s - loss: 31.1396
# Epoch 4/50
#  - 0s - loss: 31.1108
# Epoch 5/50
#  - 0s - loss: 31.1325
# Epoch 6/50
#  - 0s - loss: 31.0843
# Epoch 7/50
#  - 0s - loss: 31.1140
# Epoch 8/50
#  - 0s - loss: 31.0600
# Epoch 9/50
#  - 0s - loss: 31.0604
# Epoch 10/50
#  - 0s - loss: 31.0449
# Epoch 11/50
#  - 0s - loss: 31.0215
# Epoch 12/50
#  - 0s - loss: 31.0312
# Epoch 13/50
#  - 0s - loss: 31.0864
# Epoch 14/50
#  - 0s - loss: 30.9925
# Epoch 15/50
#  - 0s - loss: 30.9808
# Epoch 16/50
#  - 0s - loss: 30.9714
# Epoch 17/50
#  - 0s - loss: 30.9527
# Epoch 18/50
#  - 0s - loss: 30.9316
# Epoch 19/50
#  - 0s - loss: 30.9366
# Epoch 20/50
#  - 0s - loss: 30.9011
# Epoch 21/50
#  - 0s - loss: 30.9132
# Epoch 22/50
#  - 0s - loss: 30.9622
# Epoch 23/50
#  - 0s - loss: 30.9742
# Epoch 24/50
#  - 0s - loss: 30.9247
# Epoch 25/50
#  - 0s - loss: 30.9050
# Epoch 26/50
#  - 0s - loss: 30.8801
# Epoch 27/50
#  - 0s - loss: 30.8463
# Epoch 28/50
#  - 0s - loss: 30.8147
# Epoch 29/50
#  - 0s - loss: 30.8570
# Epoch 30/50
#  - 0s - loss: 30.8733
# Epoch 31/50
#  - 0s - loss: 30.8278
# Epoch 32/50
#  - 0s - loss: 30.8093
# Epoch 33/50
#  - 0s - loss: 30.7802
# Epoch 34/50
#  - 0s - loss: 30.8280
# Epoch 35/50
#  - 0s - loss: 30.8552
# Epoch 36/50
#  - 0s - loss: 30.7702
# Epoch 37/50
#  - 0s - loss: 30.7711
# Epoch 38/50
#  - 0s - loss: 30.7805
# Epoch 39/50
#  - 0s - loss: 30.7567
# Epoch 40/50
#  - 0s - loss: 30.7478
# Epoch 41/50
#  - 0s - loss: 30.7266
# Epoch 42/50
#  - 0s - loss: 30.7340
# Epoch 43/50
#  - 0s - loss: 30.6766
# Epoch 44/50
#  - 0s - loss: 30.7217
# Epoch 45/50
#  - 0s - loss: 30.6974
# Epoch 46/50
#  - 0s - loss: 30.6717
# Epoch 47/50
#  - 0s - loss: 30.6933
# Epoch 48/50
#  - 0s - loss: 30.6793
# Epoch 49/50
#  - 0s - loss: 30.6789
# Epoch 50/50
#  - 0s - loss: 30.6488
# Duration (seconds): 2.309058904647827
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.6312
# Epoch 2/50
#  - 0s - loss: 30.5824
# Epoch 3/50
#  - 0s - loss: 30.6008
# Epoch 4/50
#  - 0s - loss: 30.6283
# Epoch 5/50
#  - 0s - loss: 30.5994
# Epoch 6/50
#  - 0s - loss: 30.6097
# Epoch 7/50
#  - 0s - loss: 30.5917
# Epoch 8/50
#  - 0s - loss: 30.5182
# Epoch 9/50
#  - 0s - loss: 30.5572
# Epoch 10/50
#  - 0s - loss: 30.5405
# Epoch 11/50
#  - 0s - loss: 30.5856
# Epoch 12/50
#  - 0s - loss: 30.4813
# Epoch 13/50
#  - 0s - loss: 30.5772
# Epoch 14/50
#  - 0s - loss: 30.5669
# Epoch 15/50
#  - 0s - loss: 30.5309
# Epoch 16/50
#  - 0s - loss: 30.5019
# Epoch 17/50
#  - 0s - loss: 30.4571
# Epoch 18/50
#  - 0s - loss: 30.4578
# Epoch 19/50
#  - 0s - loss: 30.4323
# Epoch 20/50
#  - 0s - loss: 30.4720
# Epoch 21/50
#  - 0s - loss: 30.4232
# Epoch 22/50
#  - 0s - loss: 30.4074
# Epoch 23/50
#  - 0s - loss: 30.4012
# Epoch 24/50
#  - 0s - loss: 30.4258
# Epoch 25/50
#  - 0s - loss: 30.3857
# Epoch 26/50
#  - 0s - loss: 30.4437
# Epoch 27/50
#  - 0s - loss: 30.3740
# Epoch 28/50
#  - 0s - loss: 30.3753
# Epoch 29/50
#  - 0s - loss: 30.3370
# Epoch 30/50
#  - 0s - loss: 30.3114
# Epoch 31/50
#  - 0s - loss: 30.3332
# Epoch 32/50
#  - 0s - loss: 30.3346
# Epoch 33/50
#  - 0s - loss: 30.3152
# Epoch 34/50
#  - 0s - loss: 30.2986
# Epoch 35/50
#  - 0s - loss: 30.2955
# Epoch 36/50
#  - 0s - loss: 30.3209
# Epoch 37/50
#  - 0s - loss: 30.3279
# Epoch 38/50
#  - 0s - loss: 30.2289
# Epoch 39/50
#  - 0s - loss: 30.2650
# Epoch 40/50
#  - 0s - loss: 30.2806
# Epoch 41/50
#  - 0s - loss: 30.2062
# Epoch 42/50
#  - 0s - loss: 30.2511
# Epoch 43/50
#  - 0s - loss: 30.1821
# Epoch 44/50
#  - 0s - loss: 30.2478
# Epoch 45/50
#  - 0s - loss: 30.2641
# Epoch 46/50
#  - 0s - loss: 30.1882
# Epoch 47/50
#  - 0s - loss: 30.1615
# Epoch 48/50
#  - 0s - loss: 30.1634
# Epoch 49/50
#  - 0s - loss: 30.1919
# Epoch 50/50
#  - 0s - loss: 30.1995
# Duration (seconds): 2.2823679447174072
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 30.1234
# Epoch 2/50
#  - 0s - loss: 30.1358
# Epoch 3/50
#  - 0s - loss: 30.1059
# Epoch 4/50
#  - 0s - loss: 30.1282
# Epoch 5/50
#  - 0s - loss: 30.0861
# Epoch 6/50
#  - 0s - loss: 30.0782
# Epoch 7/50
#  - 0s - loss: 30.0976
# Epoch 8/50
#  - 0s - loss: 30.0889
# Epoch 9/50
#  - 0s - loss: 30.1080
# Epoch 10/50
#  - 0s - loss: 30.1463
# Epoch 11/50
#  - 0s - loss: 30.0992
# Epoch 12/50
#  - 0s - loss: 30.0734
# Epoch 13/50
#  - 0s - loss: 30.1083
# Epoch 14/50
#  - 0s - loss: 30.1250
# Epoch 15/50
#  - 0s - loss: 30.0093
# Epoch 16/50
#  - 0s - loss: 30.0508
# Epoch 17/50
#  - 0s - loss: 30.0413
# Epoch 18/50
#  - 0s - loss: 30.0277
# Epoch 19/50
#  - 0s - loss: 30.0004
# Epoch 20/50
#  - 0s - loss: 30.0291
# Epoch 21/50
#  - 0s - loss: 30.0083
# Epoch 22/50
#  - 0s - loss: 30.0108
# Epoch 23/50
#  - 0s - loss: 29.9651
# Epoch 24/50
#  - 0s - loss: 29.9804
# Epoch 25/50
#  - 0s - loss: 29.9417
# Epoch 26/50
#  - 0s - loss: 29.9697
# Epoch 27/50
#  - 0s - loss: 29.9591
# Epoch 28/50
#  - 0s - loss: 29.9454
# Epoch 29/50
#  - 0s - loss: 29.9449
# Epoch 30/50
#  - 0s - loss: 29.9245
# Epoch 31/50
#  - 0s - loss: 29.9974
# Epoch 32/50
#  - 0s - loss: 29.9795
# Epoch 33/50
#  - 0s - loss: 29.9162
# Epoch 34/50
#  - 0s - loss: 29.9464
# Epoch 35/50
#  - 0s - loss: 29.9227
# Epoch 36/50
#  - 0s - loss: 29.8656
# Epoch 37/50
#  - 0s - loss: 29.9165
# Epoch 38/50
#  - 0s - loss: 29.9214
# Epoch 39/50
#  - 0s - loss: 29.8791
# Epoch 40/50
#  - 0s - loss: 29.9232
# Epoch 41/50
#  - 0s - loss: 29.8376
# Epoch 42/50
#  - 0s - loss: 29.8902
# Epoch 43/50
#  - 0s - loss: 29.7974
# Epoch 44/50
#  - 0s - loss: 29.8711
# Epoch 45/50
#  - 0s - loss: 29.8333
# Epoch 46/50
#  - 0s - loss: 29.8302
# Epoch 47/50
#  - 0s - loss: 29.8527
# Epoch 48/50
#  - 0s - loss: 29.8071
# Epoch 49/50
#  - 0s - loss: 29.8227
# Epoch 50/50
#  - 0s - loss: 29.8387
# Duration (seconds): 2.2348992824554443
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 29.7867
# Epoch 2/50
#  - 0s - loss: 29.8080
# Epoch 3/50
#  - 0s - loss: 29.7745
# Epoch 4/50
#  - 0s - loss: 29.7773
# Epoch 5/50
#  - 0s - loss: 29.7837
# Epoch 6/50
#  - 0s - loss: 29.7532
# Epoch 7/50
#  - 0s - loss: 29.7580
# Epoch 8/50
#  - 0s - loss: 29.7698
# Epoch 9/50
#  - 0s - loss: 29.7763
# Epoch 10/50
#  - 0s - loss: 29.7086
# Epoch 11/50
#  - 0s - loss: 29.8125
# Epoch 12/50
#  - 0s - loss: 29.7383
# Epoch 13/50
#  - 0s - loss: 29.7277
# Epoch 14/50
#  - 0s - loss: 29.7600
# Epoch 15/50
#  - 0s - loss: 29.7194
# Epoch 16/50
#  - 0s - loss: 29.8049
# Epoch 17/50
#  - 0s - loss: 29.6974
# Epoch 18/50
#  - 0s - loss: 29.7056
# Epoch 19/50
#  - 0s - loss: 29.7263
# Epoch 20/50
#  - 0s - loss: 29.6717
# Epoch 21/50
#  - 0s - loss: 29.7121
# Epoch 22/50
#  - 0s - loss: 29.7200
# Epoch 23/50
#  - 0s - loss: 29.6774
# Epoch 24/50
#  - 0s - loss: 29.6494
# Epoch 25/50
#  - 0s - loss: 29.6640
# Epoch 26/50
#  - 0s - loss: 29.7011
# Epoch 27/50
#  - 0s - loss: 29.6501
# Epoch 28/50
#  - 0s - loss: 29.6403
# Epoch 29/50
#  - 0s - loss: 29.6693
# Epoch 30/50
#  - 0s - loss: 29.6224
# Epoch 31/50
#  - 0s - loss: 29.6691
# Epoch 32/50
#  - 0s - loss: 29.6064
# Epoch 33/50
#  - 0s - loss: 29.6109
# Epoch 34/50
#  - 0s - loss: 29.6190
# Epoch 35/50
#  - 0s - loss: 29.6307
# Epoch 36/50
#  - 0s - loss: 29.5977
# Epoch 37/50
#  - 0s - loss: 29.6168
# Epoch 38/50
#  - 0s - loss: 29.6453
# Epoch 39/50
#  - 0s - loss: 29.5986
# Epoch 40/50
#  - 0s - loss: 29.5905
# Epoch 41/50
#  - 0s - loss: 29.5937
# Epoch 42/50
#  - 0s - loss: 29.6317
# Epoch 43/50
#  - 0s - loss: 29.6301
# Epoch 44/50
#  - 0s - loss: 29.6528
# Epoch 45/50
#  - 0s - loss: 29.5683
# Epoch 46/50
#  - 0s - loss: 29.5734
# Epoch 47/50
#  - 0s - loss: 29.5487
# Epoch 48/50
#  - 0s - loss: 29.5612
# Epoch 49/50
#  - 0s - loss: 29.5737
# Epoch 50/50
#  - 0s - loss: 29.6102
# Duration (seconds): 2.3159351348876953
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 29.5489
# Epoch 2/50
#  - 0s - loss: 29.5274
# Epoch 3/50
#  - 0s - loss: 29.5829
# Epoch 4/50
#  - 0s - loss: 29.5536
# Epoch 5/50
#  - 0s - loss: 29.5340
# Epoch 6/50
#  - 0s - loss: 29.5137
# Epoch 7/50
#  - 0s - loss: 29.4854
# Epoch 8/50
#  - 0s - loss: 29.5578
# Epoch 9/50
#  - 0s - loss: 29.4997
# Epoch 10/50
#  - 0s - loss: 29.5059
# Epoch 11/50
#  - 0s - loss: 29.4809
# Epoch 12/50
#  - 0s - loss: 29.4924
# Epoch 13/50
#  - 0s - loss: 29.5057
# Epoch 14/50
#  - 0s - loss: 29.4902
# Epoch 15/50
#  - 0s - loss: 29.5047
# Epoch 16/50
#  - 0s - loss: 29.4721
# Epoch 17/50
#  - 0s - loss: 29.4430
# Epoch 18/50
#  - 0s - loss: 29.4939
# Epoch 19/50
#  - 0s - loss: 29.4538
# Epoch 20/50
#  - 0s - loss: 29.4454
# Epoch 21/50
#  - 0s - loss: 29.4707
# Epoch 22/50
#  - 0s - loss: 29.4364
# Epoch 23/50
#  - 0s - loss: 29.4573
# Epoch 24/50
#  - 0s - loss: 29.4512
# Epoch 25/50
#  - 0s - loss: 29.4476
# Epoch 26/50
#  - 0s - loss: 29.4585
# Epoch 27/50
#  - 0s - loss: 29.3926
# Epoch 28/50
#  - 0s - loss: 29.4698
# Epoch 29/50
#  - 0s - loss: 29.4431
# Epoch 30/50
#  - 0s - loss: 29.4088
# Epoch 31/50
#  - 0s - loss: 29.3685
# Epoch 32/50
#  - 0s - loss: 29.3496
# Epoch 33/50
#  - 0s - loss: 29.4019
# Epoch 34/50
#  - 0s - loss: 29.3316
# Epoch 35/50
#  - 0s - loss: 29.3372
# Epoch 36/50
#  - 0s - loss: 29.2822
# Epoch 37/50
#  - 0s - loss: 29.3071
# Epoch 38/50
#  - 0s - loss: 29.2756
# Epoch 39/50
#  - 0s - loss: 29.2759
# Epoch 40/50
#  - 0s - loss: 29.2739
# Epoch 41/50
#  - 0s - loss: 29.2375
# Epoch 42/50
#  - 0s - loss: 29.2394
# Epoch 43/50
#  - 0s - loss: 29.2220
# Epoch 44/50
#  - 0s - loss: 29.2225
# Epoch 45/50
#  - 0s - loss: 29.2183
# Epoch 46/50
#  - 0s - loss: 29.2073
# Epoch 47/50
#  - 0s - loss: 29.1815
# Epoch 48/50
#  - 0s - loss: 29.2250
# Epoch 49/50
#  - 0s - loss: 29.1658
# Epoch 50/50
#  - 0s - loss: 29.1815
# Duration (seconds): 2.341986894607544
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 29.2029
# Epoch 2/50
#  - 0s - loss: 29.1672
# Epoch 3/50
#  - 0s - loss: 29.2753
# Epoch 4/50
#  - 0s - loss: 29.1732
# Epoch 5/50
#  - 0s - loss: 29.1796
# Epoch 6/50
#  - 0s - loss: 29.1076
# Epoch 7/50
#  - 0s - loss: 29.0986
# Epoch 8/50
#  - 0s - loss: 29.0836
# Epoch 9/50
#  - 0s - loss: 29.1171
# Epoch 10/50
#  - 0s - loss: 29.1619
# Epoch 11/50
#  - 0s - loss: 29.0594
# Epoch 12/50
#  - 0s - loss: 29.1051
# Epoch 13/50
#  - 0s - loss: 29.0572
# Epoch 14/50
#  - 0s - loss: 29.0717
# Epoch 15/50
#  - 0s - loss: 29.0616
# Epoch 16/50
#  - 0s - loss: 29.0200
# Epoch 17/50
#  - 0s - loss: 29.0156
# Epoch 18/50
#  - 0s - loss: 29.0904
# Epoch 19/50
#  - 0s - loss: 29.0414
# Epoch 20/50
#  - 0s - loss: 29.0520
# Epoch 21/50
#  - 0s - loss: 28.9678
# Epoch 22/50
#  - 0s - loss: 28.9876
# Epoch 23/50
#  - 0s - loss: 29.0815
# Epoch 24/50
#  - 0s - loss: 28.9557
# Epoch 25/50
#  - 0s - loss: 28.9635
# Epoch 26/50
#  - 0s - loss: 29.0100
# Epoch 27/50
#  - 0s - loss: 28.9774
# Epoch 28/50
#  - 0s - loss: 28.9721
# Epoch 29/50
#  - 0s - loss: 28.9489
# Epoch 30/50
#  - 0s - loss: 28.9117
# Epoch 31/50
#  - 0s - loss: 28.9074
# Epoch 32/50
#  - 0s - loss: 28.9978
# Epoch 33/50
#  - 0s - loss: 28.8784
# Epoch 34/50
#  - 0s - loss: 28.9493
# Epoch 35/50
#  - 0s - loss: 28.8976
# Epoch 36/50
#  - 0s - loss: 28.9724
# Epoch 37/50
#  - 0s - loss: 28.8928
# Epoch 38/50
#  - 0s - loss: 28.9533
# Epoch 39/50
#  - 0s - loss: 28.8934
# Epoch 40/50
#  - 0s - loss: 28.8717
# Epoch 41/50
#  - 0s - loss: 28.9160
# Epoch 42/50
#  - 0s - loss: 28.8876
# Epoch 43/50
#  - 0s - loss: 28.8696
# Epoch 44/50
#  - 0s - loss: 28.9751
# Epoch 45/50
#  - 0s - loss: 28.8121
# Epoch 46/50
#  - 0s - loss: 28.8416
# Epoch 47/50
#  - 0s - loss: 28.8684
# Epoch 48/50
#  - 0s - loss: 28.8919
# Epoch 49/50
#  - 0s - loss: 28.8027
# Epoch 50/50
#  - 0s - loss: 28.8090
# Duration (seconds): 2.180493116378784
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 28.8036
# Epoch 2/50
#  - 0s - loss: 28.8300
# Epoch 3/50
#  - 0s - loss: 28.8217
# Epoch 4/50
#  - 0s - loss: 28.7934
# Epoch 5/50
#  - 0s - loss: 28.7942
# Epoch 6/50
#  - 0s - loss: 28.7982
# Epoch 7/50
#  - 0s - loss: 28.8408
# Epoch 8/50
#  - 0s - loss: 28.7807
# Epoch 9/50
#  - 0s - loss: 28.7531
# Epoch 10/50
#  - 0s - loss: 28.8920
# Epoch 11/50
#  - 0s - loss: 28.7430
# Epoch 12/50
#  - 0s - loss: 28.7955
# Epoch 13/50
#  - 0s - loss: 28.7711
# Epoch 14/50
#  - 0s - loss: 28.7584
# Epoch 15/50
#  - 0s - loss: 28.7310
# Epoch 16/50
#  - 0s - loss: 28.6972
# Epoch 17/50
#  - 0s - loss: 28.6733
# Epoch 18/50
#  - 0s - loss: 28.7115
# Epoch 19/50
#  - 0s - loss: 28.6909
# Epoch 20/50
#  - 0s - loss: 28.6985
# Epoch 21/50
#  - 0s - loss: 28.6466
# Epoch 22/50
#  - 0s - loss: 28.6951
# Epoch 23/50
#  - 0s - loss: 28.6780
# Epoch 24/50
#  - 0s - loss: 28.6708
# Epoch 25/50
#  - 0s - loss: 28.6519
# Epoch 26/50
#  - 0s - loss: 28.6507
# Epoch 27/50
#  - 0s - loss: 28.6593
# Epoch 28/50
#  - 0s - loss: 28.6814
# Epoch 29/50
#  - 0s - loss: 28.6496
# Epoch 30/50
#  - 0s - loss: 28.6510
# Epoch 31/50
#  - 0s - loss: 28.6380
# Epoch 32/50
#  - 0s - loss: 28.6375
# Epoch 33/50
#  - 0s - loss: 28.6566
# Epoch 34/50
#  - 0s - loss: 28.6007
# Epoch 35/50
#  - 0s - loss: 28.6064
# Epoch 36/50
#  - 0s - loss: 28.5878
# Epoch 37/50
#  - 0s - loss: 28.7000
# Epoch 38/50
#  - 0s - loss: 28.6027
# Epoch 39/50
#  - 0s - loss: 28.5659
# Epoch 40/50
#  - 0s - loss: 28.5785
# Epoch 41/50
#  - 0s - loss: 28.5840
# Epoch 42/50
#  - 0s - loss: 28.5605
# Epoch 43/50
#  - 0s - loss: 28.5511
# Epoch 44/50
#  - 0s - loss: 28.5951
# Epoch 45/50
#  - 0s - loss: 28.5394
# Epoch 46/50
#  - 0s - loss: 28.6140
# Epoch 47/50
#  - 0s - loss: 28.5659
# Epoch 48/50
#  - 0s - loss: 28.5247
# Epoch 49/50
#  - 0s - loss: 28.5155
# Epoch 50/50
#  - 0s - loss: 28.5768
# Duration (seconds): 1.8331730365753174
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 28.5652
# Epoch 2/50
#  - 0s - loss: 28.5441
# Epoch 3/50
#  - 0s - loss: 28.5220
# Epoch 4/50
#  - 0s - loss: 28.4758
# Epoch 5/50
#  - 0s - loss: 28.5099
# Epoch 6/50
#  - 0s - loss: 28.5515
# Epoch 7/50
#  - 0s - loss: 28.5419
# Epoch 8/50
#  - 0s - loss: 28.4806
# Epoch 9/50
#  - 0s - loss: 28.5013
# Epoch 10/50
#  - 0s - loss: 28.5051
# Epoch 11/50
#  - 0s - loss: 28.4749
# Epoch 12/50
#  - 0s - loss: 28.4756
# Epoch 13/50
#  - 0s - loss: 28.5105
# Epoch 14/50
#  - 0s - loss: 28.5086
# Epoch 15/50
#  - 0s - loss: 28.4704
# Epoch 16/50
#  - 0s - loss: 28.4801
# Epoch 17/50
#  - 0s - loss: 28.5214
# Epoch 18/50
#  - 0s - loss: 28.4545
# Epoch 19/50
#  - 0s - loss: 28.4485
# Epoch 20/50
#  - 0s - loss: 28.4607
# Epoch 21/50
#  - 0s - loss: 28.5026
# Epoch 22/50
#  - 0s - loss: 28.4555
# Epoch 23/50
#  - 0s - loss: 28.4107
# Epoch 24/50
#  - 0s - loss: 28.4453
# Epoch 25/50
#  - 0s - loss: 28.4271
# Epoch 26/50
#  - 0s - loss: 28.4209
# Epoch 27/50
#  - 0s - loss: 28.4390
# Epoch 28/50
#  - 0s - loss: 28.3952
# Epoch 29/50
#  - 0s - loss: 28.4418
# Epoch 30/50
#  - 0s - loss: 28.4190
# Epoch 31/50
#  - 0s - loss: 28.4094
# Epoch 32/50
#  - 0s - loss: 28.3876
# Epoch 33/50
#  - 0s - loss: 28.4069
# Epoch 34/50
#  - 0s - loss: 28.4954
# Epoch 35/50
#  - 0s - loss: 28.3712
# Epoch 36/50
#  - 0s - loss: 28.4158
# Epoch 37/50
#  - 0s - loss: 28.3659
# Epoch 38/50
#  - 0s - loss: 28.3724
# Epoch 39/50
#  - 0s - loss: 28.4176
# Epoch 40/50
#  - 0s - loss: 28.3743
# Epoch 41/50
#  - 0s - loss: 28.3727
# Epoch 42/50
#  - 0s - loss: 28.3918
# Epoch 43/50
#  - 0s - loss: 28.3492
# Epoch 44/50
#  - 0s - loss: 28.4350
# Epoch 45/50
#  - 0s - loss: 28.3574
# Epoch 46/50
#  - 0s - loss: 28.3680
# Epoch 47/50
#  - 0s - loss: 28.3080
# Epoch 48/50
#  - 0s - loss: 28.3260
# Epoch 49/50
#  - 0s - loss: 28.3311
# Epoch 50/50
#  - 0s - loss: 28.3543
# Duration (seconds): 1.9057738780975342
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 28.3093
# Epoch 2/50
#  - 0s - loss: 28.3071
# Epoch 3/50
#  - 0s - loss: 28.3536
# Epoch 4/50
#  - 0s - loss: 28.3027
# Epoch 5/50
#  - 0s - loss: 28.3156
# Epoch 6/50
#  - 0s - loss: 28.3080
# Epoch 7/50
#  - 0s - loss: 28.3075
# Epoch 8/50
#  - 0s - loss: 28.2869
# Epoch 9/50
#  - 0s - loss: 28.3002
# Epoch 10/50
#  - 0s - loss: 28.3322
# Epoch 11/50
#  - 0s - loss: 28.3830
# Epoch 12/50
#  - 0s - loss: 28.2767
# Epoch 13/50
#  - 0s - loss: 28.2832
# Epoch 14/50
#  - 0s - loss: 28.2519
# Epoch 15/50
#  - 0s - loss: 28.2698
# Epoch 16/50
#  - 0s - loss: 28.3039
# Epoch 17/50
#  - 0s - loss: 28.2480
# Epoch 18/50
#  - 0s - loss: 28.2315
# Epoch 19/50
#  - 0s - loss: 28.2961
# Epoch 20/50
#  - 0s - loss: 28.2569
# Epoch 21/50
#  - 0s - loss: 28.2916
# Epoch 22/50
#  - 0s - loss: 28.2791
# Epoch 23/50
#  - 0s - loss: 28.2014
# Epoch 24/50
#  - 0s - loss: 28.2312
# Epoch 25/50
#  - 0s - loss: 28.2395
# Epoch 26/50
#  - 0s - loss: 28.2577
# Epoch 27/50
#  - 0s - loss: 28.2763
# Epoch 28/50
#  - 0s - loss: 28.3020
# Epoch 29/50
#  - 0s - loss: 28.2239
# Epoch 30/50
#  - 0s - loss: 28.2335
# Epoch 31/50
#  - 0s - loss: 28.2523
# Epoch 32/50
#  - 0s - loss: 28.1962
# Epoch 33/50
#  - 0s - loss: 28.2075
# Epoch 34/50
#  - 0s - loss: 28.2449
# Epoch 35/50
#  - 0s - loss: 28.2160
# Epoch 36/50
#  - 0s - loss: 28.2095
# Epoch 37/50
#  - 0s - loss: 28.2113
# Epoch 38/50
#  - 0s - loss: 28.1667
# Epoch 39/50
#  - 0s - loss: 28.1897
# Epoch 40/50
#  - 0s - loss: 28.2353
# Epoch 41/50
#  - 0s - loss: 28.2443
# Epoch 42/50
#  - 0s - loss: 28.1526
# Epoch 43/50
#  - 0s - loss: 28.1837
# Epoch 44/50
#  - 0s - loss: 28.1413
# Epoch 45/50
#  - 0s - loss: 28.1850
# Epoch 46/50
#  - 0s - loss: 28.2493
# Epoch 47/50
#  - 0s - loss: 28.1482
# Epoch 48/50
#  - 0s - loss: 28.1656
# Epoch 49/50
#  - 0s - loss: 28.1865
# Epoch 50/50
#  - 0s - loss: 28.1642
# Duration (seconds): 2.4623749256134033
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 28.1217
# Epoch 2/50
#  - 0s - loss: 28.1509
# Epoch 3/50
#  - 0s - loss: 28.1206
# Epoch 4/50
#  - 0s - loss: 28.1399
# Epoch 5/50
#  - 0s - loss: 28.1700
# Epoch 6/50
#  - 0s - loss: 28.1428
# Epoch 7/50
#  - 0s - loss: 28.1475
# Epoch 8/50
#  - 0s - loss: 28.1567
# Epoch 9/50
#  - 0s - loss: 28.1291
# Epoch 10/50
#  - 0s - loss: 28.2067
# Epoch 11/50
#  - 0s - loss: 28.1241
# Epoch 12/50
#  - 0s - loss: 28.1172
# Epoch 13/50
#  - 0s - loss: 28.1371
# Epoch 14/50
#  - 0s - loss: 28.1512
# Epoch 15/50
#  - 0s - loss: 28.1037
# Epoch 16/50
#  - 0s - loss: 28.1298
# Epoch 17/50
#  - 0s - loss: 28.0888
# Epoch 18/50
#  - 0s - loss: 28.0969
# Epoch 19/50
#  - 0s - loss: 28.1926
# Epoch 20/50
#  - 0s - loss: 28.1814
# Epoch 21/50
#  - 0s - loss: 28.0818
# Epoch 22/50
#  - 0s - loss: 28.1148
# Epoch 23/50
#  - 0s - loss: 28.0798
# Epoch 24/50
#  - 0s - loss: 28.1179
# Epoch 25/50
#  - 0s - loss: 28.1065
# Epoch 26/50
#  - 0s - loss: 28.0836
# Epoch 27/50
#  - 0s - loss: 28.1320
# Epoch 28/50
#  - 0s - loss: 28.0258
# Epoch 29/50
#  - 0s - loss: 28.1190
# Epoch 30/50
#  - 0s - loss: 28.0634
# Epoch 31/50
#  - 0s - loss: 28.0345
# Epoch 32/50
#  - 0s - loss: 28.0552
# Epoch 33/50
#  - 0s - loss: 28.0632
# Epoch 34/50
#  - 0s - loss: 28.0768
# Epoch 35/50
#  - 0s - loss: 28.0283
# Epoch 36/50
#  - 0s - loss: 28.0376
# Epoch 37/50
#  - 0s - loss: 28.0601
# Epoch 38/50
#  - 0s - loss: 28.0301
# Epoch 39/50
#  - 0s - loss: 28.0228
# Epoch 40/50
#  - 0s - loss: 28.0513
# Epoch 41/50
#  - 0s - loss: 28.0052
# Epoch 42/50
#  - 0s - loss: 28.0255
# Epoch 43/50
#  - 0s - loss: 28.0345
# Epoch 44/50
#  - 0s - loss: 28.0382
# Epoch 45/50
#  - 0s - loss: 28.0460
# Epoch 46/50
#  - 0s - loss: 28.0217
# Epoch 47/50
#  - 0s - loss: 28.0563
# Epoch 48/50
#  - 0s - loss: 28.0612
# Epoch 49/50
#  - 0s - loss: 28.0425
# Epoch 50/50
#  - 0s - loss: 28.0160
# Duration (seconds): 1.732856035232544
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 28.0306
# Epoch 2/50
#  - 0s - loss: 28.0151
# Epoch 3/50
#  - 0s - loss: 27.9891
# Epoch 4/50
#  - 0s - loss: 28.0082
# Epoch 5/50
#  - 0s - loss: 28.0268
# Epoch 6/50
#  - 0s - loss: 27.9962
# Epoch 7/50
#  - 0s - loss: 28.0639
# Epoch 8/50
#  - 0s - loss: 28.0329
# Epoch 9/50
#  - 0s - loss: 27.9837
# Epoch 10/50
#  - 0s - loss: 28.0141
# Epoch 11/50
#  - 0s - loss: 28.0675
# Epoch 12/50
#  - 0s - loss: 27.9821
# Epoch 13/50
#  - 0s - loss: 27.9750
# Epoch 14/50
#  - 0s - loss: 28.0039
# Epoch 15/50
#  - 0s - loss: 27.9610
# Epoch 16/50
#  - 0s - loss: 28.0345
# Epoch 17/50
#  - 0s - loss: 28.0455
# Epoch 18/50
#  - 0s - loss: 27.9561
# Epoch 19/50
#  - 0s - loss: 27.9572
# Epoch 20/50
#  - 0s - loss: 27.9664
# Epoch 21/50
#  - 0s - loss: 27.9905
# Epoch 22/50
#  - 0s - loss: 27.9255
# Epoch 23/50
#  - 0s - loss: 27.9966
# Epoch 24/50
#  - 0s - loss: 27.9776
# Epoch 25/50
#  - 0s - loss: 27.9568
# Epoch 26/50
#  - 0s - loss: 27.9814
# ...
# Epoch 2/50
#  - 0s - loss: 25.9368
# Epoch 3/50
#  - 0s - loss: 25.9029
# Epoch 4/50
#  - 0s - loss: 25.9262
# Epoch 5/50
#  - 0s - loss: 25.9795
# Epoch 6/50
#  - 0s - loss: 25.9745
# Epoch 7/50
#  - 0s - loss: 25.9123
# Epoch 8/50
#  - 0s - loss: 25.9624
# Epoch 9/50
#  - 0s - loss: 25.9323
# Epoch 10/50
#  - 0s - loss: 25.9266
# Epoch 11/50
#  - 0s - loss: 25.8906
# Epoch 12/50
#  - 0s - loss: 25.9716
# Epoch 13/50
#  - 0s - loss: 25.9709
# Epoch 14/50
#  - 0s - loss: 25.9662
# Epoch 15/50
#  - 0s - loss: 25.9092
# Epoch 16/50
#  - 0s - loss: 25.9529
# Epoch 17/50
#  - 0s - loss: 25.9068
# Epoch 18/50
#  - 0s - loss: 25.8905
# Epoch 19/50
#  - 0s - loss: 25.9207
# Epoch 20/50
#  - 0s - loss: 25.9025
# Epoch 21/50
#  - 0s - loss: 25.9372
# Epoch 22/50
#  - 0s - loss: 25.8567
# Epoch 23/50
#  - 0s - loss: 25.9213
# Epoch 24/50
#  - 0s - loss: 25.9177
# Epoch 25/50
#  - 0s - loss: 25.8509
# Epoch 26/50
#  - 0s - loss: 25.8614
# Epoch 27/50
#  - 0s - loss: 25.9226
# Epoch 28/50
#  - 0s - loss: 25.8611
# Epoch 29/50
#  - 0s - loss: 25.8875
# Epoch 30/50
#  - 0s - loss: 25.8950
# Epoch 31/50
#  - 0s - loss: 25.8794
# Epoch 32/50
#  - 0s - loss: 25.8732
# Epoch 33/50
#  - 0s - loss: 25.8629
# Epoch 34/50
#  - 0s - loss: 25.8709
# Epoch 35/50
#  - 0s - loss: 25.9023
# Epoch 36/50
#  - 0s - loss: 25.8935
# Epoch 37/50
#  - 0s - loss: 25.8561
# Epoch 38/50
#  - 0s - loss: 25.8793
# Epoch 39/50
#  - 0s - loss: 25.8710
# Epoch 40/50
#  - 0s - loss: 25.8560
# Epoch 41/50
#  - 0s - loss: 25.9184
# Epoch 42/50
#  - 0s - loss: 25.9529
# Epoch 43/50
#  - 0s - loss: 25.8526
# Epoch 44/50
#  - 0s - loss: 25.8623
# Epoch 45/50
#  - 0s - loss: 25.8412
# Epoch 46/50
#  - 0s - loss: 25.8890
# Epoch 47/50
#  - 0s - loss: 25.8266
# Epoch 48/50
#  - 0s - loss: 25.8115
# Epoch 49/50
#  - 0s - loss: 25.8379
# Epoch 50/50
#  - 0s - loss: 25.8750
# Duration (seconds): 1.74922513961792
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 25.8496
# Epoch 2/50
#  - 0s - loss: 25.8532
# Epoch 3/50
#  - 0s - loss: 25.8770
# Epoch 4/50
#  - 0s - loss: 25.8370
# Epoch 5/50
#  - 0s - loss: 25.8492
# Epoch 6/50
#  - 0s - loss: 25.8297
# Epoch 7/50
#  - 0s - loss: 25.8298
# Epoch 8/50
#  - 0s - loss: 25.8586
# Epoch 9/50
#  - 0s - loss: 25.8267
# Epoch 10/50
#  - 0s - loss: 25.8457
# Epoch 11/50
#  - 0s - loss: 25.8256
# Epoch 12/50
#  - 0s - loss: 25.8784
# Epoch 13/50
#  - 0s - loss: 25.8362
# Epoch 14/50
#  - 0s - loss: 25.8384
# Epoch 15/50
#  - 0s - loss: 25.8531
# Epoch 16/50
#  - 0s - loss: 25.8359
# Epoch 17/50
#  - 0s - loss: 25.8353
# Epoch 18/50
#  - 0s - loss: 25.8461
# Epoch 19/50
#  - 0s - loss: 25.7865
# Epoch 20/50
#  - 0s - loss: 25.8592
# Epoch 21/50
#  - 0s - loss: 25.7955
# Epoch 22/50
#  - 0s - loss: 25.7962
# Epoch 23/50
#  - 0s - loss: 25.8014
# Epoch 24/50
#  - 0s - loss: 25.7841
# Epoch 25/50
#  - 0s - loss: 25.8320
# Epoch 26/50
#  - 0s - loss: 25.8470
# Epoch 27/50
#  - 0s - loss: 25.7806
# Epoch 28/50
#  - 0s - loss: 25.7689
# Epoch 29/50
#  - 0s - loss: 25.8268
# Epoch 30/50
#  - 0s - loss: 25.8227
# Epoch 31/50
#  - 0s - loss: 25.8750
# Epoch 32/50
#  - 0s - loss: 25.7794
# Epoch 33/50
#  - 0s - loss: 25.8495
# Epoch 34/50
#  - 0s - loss: 25.7958
# Epoch 35/50
#  - 0s - loss: 25.8156
# Epoch 36/50
#  - 0s - loss: 25.8012
# Epoch 37/50
#  - 0s - loss: 25.8179
# Epoch 38/50
#  - 0s - loss: 25.7905
# Epoch 39/50
#  - 0s - loss: 25.7873
# Epoch 40/50
#  - 0s - loss: 25.7661
# Epoch 41/50
#  - 0s - loss: 25.7790
# Epoch 42/50
#  - 0s - loss: 25.7802
# Epoch 43/50
#  - 0s - loss: 25.7509
# Epoch 44/50
#  - 0s - loss: 25.7601
# Epoch 45/50
#  - 0s - loss: 25.7916
# Epoch 46/50
#  - 0s - loss: 25.7555
# Epoch 47/50
#  - 0s - loss: 25.8263
# Epoch 48/50
#  - 0s - loss: 25.7677
# Epoch 49/50
#  - 0s - loss: 25.7573
# Epoch 50/50
#  - 0s - loss: 25.7758
# Duration (seconds): 1.8446738719940186
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 25.7633
# Epoch 2/50
#  - 0s - loss: 25.8008
# Epoch 3/50
#  - 0s - loss: 25.7448
# Epoch 4/50
#  - 0s - loss: 25.7793
# Epoch 5/50
#  - 0s - loss: 25.8140
# Epoch 6/50
#  - 0s - loss: 25.7969
# Epoch 7/50
#  - 0s - loss: 25.8120
# Epoch 8/50
#  - 0s - loss: 25.7750
# Epoch 9/50
#  - 0s - loss: 25.7651
# Epoch 10/50
#  - 0s - loss: 25.8014
# Epoch 11/50
#  - 0s - loss: 25.8635
# Epoch 12/50
#  - 0s - loss: 25.8256
# Epoch 13/50
#  - 0s - loss: 25.7703
# Epoch 14/50
#  - 0s - loss: 25.7784
# Epoch 15/50
#  - 0s - loss: 25.7937
# Epoch 16/50
#  - 0s - loss: 25.7235
# Epoch 17/50
#  - 0s - loss: 25.7429
# Epoch 18/50
#  - 0s - loss: 25.7563
# Epoch 19/50
#  - 0s - loss: 25.7437
# Epoch 20/50
#  - 0s - loss: 25.7654
# Epoch 21/50
#  - 0s - loss: 25.7490
# Epoch 22/50
#  - 0s - loss: 25.8131
# Epoch 23/50
#  - 0s - loss: 25.7378
# Epoch 24/50
#  - 0s - loss: 25.7451
# Epoch 25/50
#  - 0s - loss: 25.7819
# Epoch 26/50
#  - 0s - loss: 25.7545
# Epoch 27/50
#  - 0s - loss: 25.7491
# Epoch 28/50
#  - 0s - loss: 25.7430
# Epoch 29/50
#  - 0s - loss: 25.7086
# Epoch 30/50
#  - 0s - loss: 25.7850
# Epoch 31/50
#  - 0s - loss: 25.8362
# Epoch 32/50
#  - 0s - loss: 25.8387
# Epoch 33/50
#  - 0s - loss: 25.7179
# Epoch 34/50
#  - 0s - loss: 25.7797
# Epoch 35/50
#  - 0s - loss: 25.7413
# Epoch 36/50
#  - 0s - loss: 25.7029
# Epoch 37/50
#  - 0s - loss: 25.7652
# Epoch 38/50
#  - 0s - loss: 25.7418
# Epoch 39/50
#  - 0s - loss: 25.7060
# Epoch 40/50
#  - 0s - loss: 25.7283
# Epoch 41/50
#  - 0s - loss: 25.7453
# Epoch 42/50
#  - 0s - loss: 25.7242
# Epoch 43/50
#  - 0s - loss: 25.7171
# Epoch 44/50
#  - 0s - loss: 25.7520
# Epoch 45/50
#  - 0s - loss: 25.6938
# Epoch 46/50
#  - 0s - loss: 25.6753
# Epoch 47/50
#  - 0s - loss: 25.6989
# Epoch 48/50
#  - 0s - loss: 25.7032
# Epoch 49/50
#  - 0s - loss: 25.7651
# Epoch 50/50
#  - 0s - loss: 25.7380
# Duration (seconds): 1.7119052410125732
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 25.7075
# Epoch 2/50
#  - 0s - loss: 25.7206
# Epoch 3/50
#  - 0s - loss: 25.6864
# Epoch 4/50
#  - 0s - loss: 25.7231
# Epoch 5/50
#  - 0s - loss: 25.6699
# Epoch 6/50
#  - 0s - loss: 25.7247
# Epoch 7/50
#  - 0s - loss: 25.6922
# Epoch 8/50
#  - 0s - loss: 25.6825
# Epoch 9/50
#  - 0s - loss: 25.6857
# Epoch 10/50
#  - 0s - loss: 25.7217
# Epoch 11/50
#  - 0s - loss: 25.6887
# Epoch 12/50
#  - 0s - loss: 25.7141
# Epoch 13/50
#  - 0s - loss: 25.7094
# Epoch 14/50
#  - 0s - loss: 25.7013
# Epoch 15/50
#  - 0s - loss: 25.6649
# Epoch 16/50
#  - 0s - loss: 25.7312
# Epoch 17/50
#  - 0s - loss: 25.7236
# Epoch 18/50
#  - 0s - loss: 25.6847
# Epoch 19/50
#  - 0s - loss: 25.6665
# Epoch 20/50
#  - 0s - loss: 25.6523
# Epoch 21/50
#  - 0s - loss: 25.6545
# Epoch 22/50
#  - 0s - loss: 25.7221
# Epoch 23/50
#  - 0s - loss: 25.7104
# Epoch 24/50
#  - 0s - loss: 25.6829
# Epoch 25/50
#  - 0s - loss: 25.6603
# Epoch 26/50
#  - 0s - loss: 25.7623
# Epoch 27/50
#  - 0s - loss: 25.6318
# Epoch 28/50
#  - 0s - loss: 25.7035
# Epoch 29/50
#  - 0s - loss: 25.6563
# Epoch 30/50
#  - 0s - loss: 25.6962
# Epoch 31/50
#  - 0s - loss: 25.6998
# Epoch 32/50
#  - 0s - loss: 25.7230
# Epoch 33/50
#  - 0s - loss: 25.6159
# Epoch 34/50
#  - 0s - loss: 25.6666
# Epoch 35/50
#  - 0s - loss: 25.6383
# Epoch 36/50
#  - 0s - loss: 25.6443
# Epoch 37/50
#  - 0s - loss: 25.6865
# Epoch 38/50
#  - 0s - loss: 25.6407
# Epoch 39/50
#  - 0s - loss: 25.6865
# Epoch 40/50
#  - 0s - loss: 25.6759
# Epoch 41/50
#  - 0s - loss: 25.6598
# Epoch 42/50
#  - 0s - loss: 25.6646
# Epoch 43/50
#  - 0s - loss: 25.6536
# Epoch 44/50
#  - 0s - loss: 25.6586
# Epoch 45/50
#  - 0s - loss: 25.6319
# Epoch 46/50
#  - 0s - loss: 25.6659
# Epoch 47/50
#  - 0s - loss: 25.6518
# Epoch 48/50
#  - 0s - loss: 25.6921
# Epoch 49/50
#  - 0s - loss: 25.6179
# Epoch 50/50
#  - 0s - loss: 25.6660
# Duration (seconds): 1.6954760551452637
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 25.6277
# Epoch 2/50
#  - 0s - loss: 25.6306
# Epoch 3/50
#  - 0s - loss: 25.6154
# Epoch 4/50
#  - 0s - loss: 25.7329
# Epoch 5/50
#  - 0s - loss: 25.6725
# Epoch 6/50
#  - 0s - loss: 25.6085
# Epoch 7/50
#  - 0s - loss: 25.6549
# Epoch 8/50
#  - 0s - loss: 25.6218
# Epoch 9/50
#  - 0s - loss: 25.6954
# Epoch 10/50
#  - 0s - loss: 25.6516
# Epoch 11/50
#  - 0s - loss: 25.6107
# Epoch 12/50
#  - 0s - loss: 25.6203
# Epoch 13/50
#  - 0s - loss: 25.6255
# Epoch 14/50
#  - 0s - loss: 25.6111
# Epoch 15/50
#  - 0s - loss: 25.5882
# Epoch 16/50
#  - 0s - loss: 25.6343
# Epoch 17/50
#  - 0s - loss: 25.6016
# Epoch 18/50
#  - 0s - loss: 25.6242
# Epoch 19/50
#  - 0s - loss: 25.5925
# Epoch 20/50
#  - 0s - loss: 25.6162
# Epoch 21/50
#  - 0s - loss: 25.6337
# Epoch 22/50
#  - 0s - loss: 25.6398
# Epoch 23/50
#  - 0s - loss: 25.5895
# Epoch 24/50
#  - 0s - loss: 25.5986
# Epoch 25/50
#  - 0s - loss: 25.5908
# Epoch 26/50
#  - 0s - loss: 25.6130
# Epoch 27/50
#  - 0s - loss: 25.6161
# Epoch 28/50
#  - 0s - loss: 25.5836
# Epoch 29/50
#  - 0s - loss: 25.5964
# Epoch 30/50
#  - 0s - loss: 25.5637
# Epoch 31/50
#  - 0s - loss: 25.5906
# Epoch 32/50
#  - 0s - loss: 25.5823
# Epoch 33/50
#  - 0s - loss: 25.5479
# Epoch 34/50
#  - 0s - loss: 25.5792
# Epoch 35/50
#  - 0s - loss: 25.5575
# Epoch 36/50
#  - 0s - loss: 25.6241
# Epoch 37/50
#  - 0s - loss: 25.5872
# Epoch 38/50
#  - 0s - loss: 25.6096
# Epoch 39/50
#  - 0s - loss: 25.5557
# Epoch 40/50
#  - 0s - loss: 25.5579
# Epoch 41/50
#  - 0s - loss: 25.6122
# Epoch 42/50
#  - 0s - loss: 25.6054
# Epoch 43/50
#  - 0s - loss: 25.5754
# Epoch 44/50
#  - 0s - loss: 25.5711
# Epoch 45/50
#  - 0s - loss: 25.5838
# Epoch 46/50
#  - 0s - loss: 25.5640
# Epoch 47/50
#  - 0s - loss: 25.5576
# Epoch 48/50
#  - 0s - loss: 25.5943
# Epoch 49/50
#  - 0s - loss: 25.5463
# Epoch 50/50
#  - 0s - loss: 25.5647
# Duration (seconds): 1.6859440803527832
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 25.5511
# Epoch 2/50
#  - 0s - loss: 25.5433
# Epoch 3/50
#  - 0s - loss: 25.5413
# Epoch 4/50
#  - 0s - loss: 25.5903
# Epoch 5/50
#  - 0s - loss: 25.5562
# Epoch 6/50
#  - 0s - loss: 25.5838
# Epoch 7/50
#  - 0s - loss: 25.5697
# Epoch 8/50
#  - 0s - loss: 25.5623
# Epoch 9/50
#  - 0s - loss: 25.5517
# Epoch 10/50
#  - 0s - loss: 25.5195
# Epoch 11/50
#  - 0s - loss: 25.5692
# Epoch 12/50
#  - 0s - loss: 25.5580
# Epoch 13/50
#  - 0s - loss: 25.5319
# Epoch 14/50
#  - 0s - loss: 25.5226
# Epoch 15/50
#  - 0s - loss: 25.5137
# Epoch 16/50
#  - 0s - loss: 25.5945
# Epoch 17/50
#  - 0s - loss: 25.5292
# Epoch 18/50
#  - 0s - loss: 25.5764
# Epoch 19/50
#  - 0s - loss: 25.5147
# Epoch 20/50
#  - 0s - loss: 25.5702
# Epoch 21/50
#  - 0s - loss: 25.5720
# Epoch 22/50
#  - 0s - loss: 25.5041
# Epoch 23/50
#  - 0s - loss: 25.5296
# Epoch 24/50
#  - 0s - loss: 25.5333
# Epoch 25/50
#  - 0s - loss: 25.4979
# Epoch 26/50
#  - 0s - loss: 25.4697
# Epoch 27/50
#  - 0s - loss: 25.5120
# Epoch 28/50
#  - 0s - loss: 25.5454
# Epoch 29/50
#  - 0s - loss: 25.5222
# Epoch 30/50
#  - 0s - loss: 25.4807
# Epoch 31/50
#  - 0s - loss: 25.4805
# Epoch 32/50
#  - 0s - loss: 25.5698
# Epoch 33/50
#  - 0s - loss: 25.4808
# Epoch 34/50
#  - 0s - loss: 25.4997
# Epoch 35/50
#  - 0s - loss: 25.4812
# Epoch 36/50
#  - 0s - loss: 25.4833
# Epoch 37/50
#  - 0s - loss: 25.5010
# Epoch 38/50
#  - 0s - loss: 25.4855
# Epoch 39/50
#  - 0s - loss: 25.5544
# Epoch 40/50
#  - 0s - loss: 25.4638
# Epoch 41/50
#  - 0s - loss: 25.4570
# Epoch 42/50
#  - 0s - loss: 25.4727
# Epoch 43/50
#  - 0s - loss: 25.5291
# Epoch 44/50
#  - 0s - loss: 25.4566
# Epoch 45/50
#  - 0s - loss: 25.4821
# Epoch 46/50
#  - 0s - loss: 25.5010
# Epoch 47/50
#  - 0s - loss: 25.5562
# Epoch 48/50
#  - 0s - loss: 25.5259
# Epoch 49/50
#  - 0s - loss: 25.4644
# Epoch 50/50
#  - 0s - loss: 25.4972
# Duration (seconds): 1.5874650478363037
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 25.4953
# Epoch 2/50
#  - 0s - loss: 25.4649
# Epoch 3/50
#  - 0s - loss: 25.4686
# Epoch 4/50
#  - 0s - loss: 25.4653
# Epoch 5/50
#  - 0s - loss: 25.4625
# Epoch 6/50
#  - 0s - loss: 25.4185
# Epoch 7/50
#  - 0s - loss: 25.4603
# Epoch 8/50
#  - 0s - loss: 25.5437
# Epoch 9/50
#  - 0s - loss: 25.4369
# Epoch 10/50
#  - 0s - loss: 25.4568
# Epoch 11/50
#  - 0s - loss: 25.4612
# Epoch 12/50
#  - 0s - loss: 25.4715
# Epoch 13/50
#  - 0s - loss: 25.4181
# Epoch 14/50
#  - 0s - loss: 25.4415
# Epoch 15/50
#  - 0s - loss: 25.4345
# Epoch 16/50
#  - 0s - loss: 25.4291
# Epoch 17/50
#  - 0s - loss: 25.4748
# Epoch 18/50
#  - 0s - loss: 25.4608
# Epoch 19/50
#  - 0s - loss: 25.4171
# Epoch 20/50
#  - 0s - loss: 25.4841
# Epoch 21/50
#  - 0s - loss: 25.4981
# Epoch 22/50
#  - 0s - loss: 25.4283
# Epoch 23/50
#  - 0s - loss: 25.4215
# Epoch 24/50
#  - 0s - loss: 25.4408
# Epoch 25/50
#  - 0s - loss: 25.5045
# Epoch 26/50
#  - 0s - loss: 25.4233
# Epoch 27/50
#  - 0s - loss: 25.4499
# Epoch 28/50
#  - 0s - loss: 25.4790
# Epoch 29/50
#  - 0s - loss: 25.3791
# Epoch 30/50
#  - 0s - loss: 25.4118
# Epoch 31/50
#  - 0s - loss: 25.4249
# Epoch 32/50
#  - 0s - loss: 25.4211
# Epoch 33/50
#  - 0s - loss: 25.4141
# Epoch 34/50
#  - 0s - loss: 25.4304
# Epoch 35/50
#  - 0s - loss: 25.3998
# Epoch 36/50
#  - 0s - loss: 25.4081
# Epoch 37/50
#  - 0s - loss: 25.3984
# Epoch 38/50
#  - 0s - loss: 25.3951
# Epoch 39/50
#  - 0s - loss: 25.3804
# Epoch 40/50
#  - 0s - loss: 25.4445
# Epoch 41/50
#  - 0s - loss: 25.4245
# Epoch 42/50
#  - 0s - loss: 25.4091
# Epoch 43/50
#  - 0s - loss: 25.3529
# Epoch 44/50
#  - 0s - loss: 25.3954
# Epoch 45/50
#  - 0s - loss: 25.4061
# Epoch 46/50
#  - 0s - loss: 25.4140
# Epoch 47/50
#  - 0s - loss: 25.4105
# Epoch 48/50
#  - 0s - loss: 25.3892
# Epoch 49/50
#  - 0s - loss: 25.3761
# Epoch 50/50
#  - 0s - loss: 25.3684
# Duration (seconds): 1.8357789516448975
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Epoch 1/50
#  - 0s - loss: 25.4527
# Epoch 2/50
#  - 0s - loss: 25.3805
# Epoch 3/50
#  - 0s - loss: 25.3355
# Epoch 4/50
#  - 0s - loss: 25.3628
# Epoch 5/50
#  - 0s - loss: 25.4129
# Epoch 6/50
#  - 0s - loss: 25.3943
# Epoch 7/50
#  - 0s - loss: 25.3408
# Epoch 8/50
#  - 0s - loss: 25.3662
# Epoch 9/50
#  - 0s - loss: 25.3496
# Epoch 10/50
#  - 0s - loss: 25.4006
# Epoch 11/50
#  - 0s - loss: 25.4106
# Epoch 12/50
#  - 0s - loss: 25.3764
# Epoch 13/50
#  - 0s - loss: 25.3955
# Epoch 14/50
#  - 0s - loss: 25.3720
# Epoch 15/50
#  - 0s - loss: 25.3836
# Epoch 16/50
#  - 0s - loss: 25.4288
# Epoch 17/50
#  - 0s - loss: 25.3750
# Epoch 18/50
#  - 0s - loss: 25.3454
# Epoch 19/50
#  - 0s - loss: 25.3750
# Epoch 20/50
#  - 0s - loss: 25.3299
# Epoch 21/50
#  - 0s - loss: 25.3083
# Epoch 22/50
#  - 0s - loss: 25.3561
# Epoch 23/50
#  - 0s - loss: 25.3752
# Epoch 24/50
#  - 0s - loss: 25.3783
# Epoch 25/50
#  - 0s - loss: 25.2685
# Epoch 26/50
#  - 0s - loss: 25.3397
# Epoch 27/50
#  - 0s - loss: 25.2852
# Epoch 28/50
#  - 0s - loss: 25.3181
# Epoch 29/50
#  - 0s - loss: 25.3035
# Epoch 30/50
#  - 0s - loss: 25.2732
# Epoch 31/50
#  - 0s - loss: 25.3133
# Epoch 32/50
#  - 0s - loss: 25.3065
# Epoch 33/50
#  - 0s - loss: 25.3057
# Epoch 34/50
#  - 0s - loss: 25.3510
# Epoch 35/50
#  - 0s - loss: 25.2949
# Epoch 36/50
#  - 0s - loss: 25.2704
# Epoch 37/50
#  - 0s - loss: 25.2559
# Epoch 38/50
#  - 0s - loss: 25.2930
# Epoch 39/50
#  - 0s - loss: 25.2757
# Epoch 40/50
#  - 0s - loss: 25.3012
# Epoch 41/50
#  - 0s - loss: 25.2441
# Epoch 42/50
#  - 0s - loss: 25.2976
# Epoch 43/50
#  - 0s - loss: 25.2478
# Epoch 44/50
#  - 0s - loss: 25.2660
# Epoch 45/50
#  - 0s - loss: 25.2375
# Epoch 46/50
#  - 0s - loss: 25.2961
# Epoch 47/50
#  - 0s - loss: 25.2768
# Epoch 48/50
#  - 0s - loss: 25.2564
# Epoch 49/50
#  - 0s - loss: 25.2525
# Epoch 50/50
#  - 0s - loss: 25.2668
# Duration (seconds): 1.6956758499145508
# Finished - 50 times.
# And the list of mean squared errors : [387.40506257376853, 143.55756456374903, 105.34210409206756, 75.85276646435972, 57.02588890907949, 48.95750767251898, 45.55146423707127, 44.015574645973565, 42.913590006172925, 41.820183218345335, 41.32622819777992, 40.91871524368536, 40.04712586185913, 39.314843924561046, 38.738817656462025, 38.724277206056726, 38.27253037569424, 38.03261005345562, 37.91219328727823, 37.66306807472248, 37.793088326298445, 37.547577272773076, 37.379488565664715, 37.395337022072376, 37.22488475991616, 37.23269672090452, 36.94449909118022, 36.784526940812306, 36.582759793473876, 36.43286311128502, 36.39636644629278, 36.37006982537689, 36.37184534335573, 36.19979392683852, 36.150897540367296, 35.98169216927659, 35.88960132875956, 35.90701613373687, 35.845843873060375, 35.794814713539516, 35.675968284699394, 35.76106729949934, 35.59275233997868, 35.65887386273183, 35.46432348528708, 35.51193390519029, 35.41076405815385, 35.21237731704936, 35.18896385305155, 35.12005129855931]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 49.4 and 51.66, respectively

# %% [markdown]
# ###  Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of not normalized data is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline  normalized (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline_norm = get_report(name_of_case, mean_mse, std_mse)
df_baseline_norm
# Out:
#                          Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline  normalized (50 epochs)      49.4              51.66

# %% [markdown]
# Comparing the case of not normalized data with the case of normalized data:

# %%
# Create a data frame with the summary
df_summary = pd.concat([df_baseline, df_baseline_norm], axis=0)

# Review the result dataframe
df_summary.reset_index(drop=True)
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     82.33             102.66
# 1     Baseline  normalized (50 epochs)     49.40              51.66

# %% [markdown]
# ### Part C: Normalized data with 100 epochs

# %% [markdown]
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# #### Building the model with normalized data and increasing to 100 epochs

# %%
max_iteration = 50
epochs = 100
verbose = 0

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors_norm, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.3392791748046875
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.5032520294189453
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.5578949451446533
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.26336407661438
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.420630693435669
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.501801013946533
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.423687219619751
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.6835126876831055
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.5102038383483887
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.422060012817383
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4317409992218018
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.449518918991089
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4251599311828613
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4551987648010254
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4213922023773193
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4110422134399414
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4014151096343994
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.3964271545410156
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.748289108276367
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.6656832695007324
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4423086643218994
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.42226505279541
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4115397930145264
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.3923141956329346
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.408827066421509
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.394725799560547
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4048991203308105
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4105467796325684
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4224600791931152
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.3957388401031494
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.403345823287964
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.416067123413086
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.409839153289795
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.41157603263855
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.403099298477173
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.389224052429199
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.39442777633667
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4821066856384277
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.671278715133667
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.544092893600464
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.401477336883545
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4437339305877686
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4328231811523438
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4077799320220947
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 3.1092238426208496
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.522908926010132
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.4601147174835205
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.548436403274536
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.6960299015045166
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.431798219680786
# Finished - 50 times.
# And the list of mean squared errors : [139.60106811950504, 81.6738164914522, 64.60005627639525, 49.44872718186771, 43.713622868472136, 41.59217671529869, 40.17882242450102, 39.29546235490267, 39.325368193564636, 38.749096539512706, 38.30695076890661, 37.853853376700386, 37.71732991962208, 37.29036693922695, 37.02008421714114, 36.900964743520845, 36.83183086451208, 37.034784424614564, 36.89826955675039, 36.77125156574228, 36.54130519132979, 36.59421081532841, 36.62724128346498, 36.770023631050016, 36.70957176736551, 36.70261663085939, 36.649556755449034, 36.63056704845231, 36.424815274395115, 36.41921889401032, 36.46219186902232, 36.415714092937336, 36.23735064696323, 35.91769094437633, 36.040724587334324, 35.91585138437851, 35.95638666315349, 36.177182658835974, 36.196153413021605, 36.060079983573914, 36.018995248134495, 36.01466510516838, 36.086684785887655, 36.05105019209863, 36.017417362942595, 36.03081118502329, 36.07096573914223, 35.96455955686088, 36.04966587502667, 36.04227726701035]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 40.77 and 16.02, respectively

# %% [markdown]
# ### Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of  normalized data running 100 epochs is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline  normalized (100 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline_norm100 = get_report(name_of_case, mean_mse, std_mse)
df_baseline_norm100
# Out:
#                           Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline  normalized (100 epochs)     40.77              16.02

# %% [markdown]
# Comparing the normalized cases ran with 50 epochs and 100 epochs

# %%
# Create a data frame with the summary
df_summary = pd.concat([df_baseline, df_baseline_norm, df_baseline_norm100], axis=0)

# Review the result dataframe
df_summary.reset_index(drop=True)
# Out:
#                             Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline-not normalized (50 epochs)     82.33             102.66
# 1     Baseline  normalized (50 epochs)     49.40              51.66
# 2    Baseline  normalized (100 epochs)     40.77              16.02

# %% [markdown]
# We can see from the result, that both the Mean of the  MSE (mean squared error) and the Std Deviation  of the MSE reduced when the number of epochs was increased from 50 to 100

# %% [markdown]
# ### Part D: Increase the number of hidden layers

# %% [markdown]
# Repeat part B but use a neural network with the following instead:
#
# Three hidden layers, each of 10 nodes and ReLU activation function.
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# Define the neural network with three hidden layers

# %%
#define the regression model with one hidden layer
def regression_model():
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(n_colsnorm,)))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Create the regression model

# %%
model = regression_model()

# %% [markdown]
# #### Buildling the normalized model with 3 hidden layers and running 50 epochs

# %%
max_iteration = 50
epochs = 50
verbose = 0

# Get the compiled model
model = regression_model()

mean_mse, std_mse = get_mean_and_std_of_mse(predictors_norm, target, model, max_iteration=max_iteration, epochs=epochs, verbose=verbose)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 4.236215114593506
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7553222179412842
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7203178405761719
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7975847721099854
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.246209144592285
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 2.1708202362060547
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7789859771728516
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.8049380779266357
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7386267185211182
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6603589057922363
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7347676753997803
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6969010829925537
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6884899139404297
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.9285480976104736
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7097022533416748
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6588470935821533
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7634251117706299
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6809461116790771
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7488951683044434
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7294301986694336
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7705328464508057
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7900018692016602
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7131037712097168
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.744565725326538
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6554601192474365
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.638277292251587
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6610918045043945
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6629769802093506
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6449470520019531
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7261621952056885
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6816928386688232
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7453749179840088
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.8468260765075684
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.8084650039672852
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6252059936523438
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6641638278961182
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6260569095611572
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6192419528961182
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6749696731567383
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6888649463653564
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6458649635314941
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.699275016784668
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6376070976257324
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6154968738555908
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.7157800197601318
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6378121376037598
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.5840649604797363
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6436221599578857
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6195659637451172
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721,)
# Testing set:  (309, 8) (309,)
# Duration (seconds): 1.6233408451080322
# Finished - 50 times.
# And the list of mean squared errors : [124.4256623817944, 85.60856394543744, 53.77393378377813, 50.444003858469394, 48.13310026475869, 45.85717797030075, 46.430194096527885, 46.23238232192936, 47.121267833973675, 45.27615966751855, 45.80931827870984, 44.502166048053, 42.7413699867304, 41.2305856012512, 39.65532630763131, 38.47797876189112, 37.98042591139066, 37.14593460961616, 36.952760578194976, 36.656573950818284, 36.88035021378409, 36.74404043703137, 36.529048817905476, 36.397897181084836, 36.451171147499146, 36.39233939017146, 35.95239431937787, 36.37308699807666, 35.63843413811714, 35.00331351215293, 35.61173364395892, 35.49993611072359, 35.268407903695504, 35.422479398001876, 35.911235189066936, 35.9161080038642, 35.34040952193619, 35.708580339285305, 35.396051403143474, 35.79871769468032, 35.473675934804135, 36.17902393398049, 37.10441272718067, 36.08185095945803, 37.98282065934636, 37.6399887443536, 37.73126878476833, 37.87822047275361, 36.47640317550187, 37.97583373392612]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 41.66 and 14.25, respectively

# %% [markdown]
# ### Report the mean and standard deviation of the mean squared error

# %% [markdown]
# The mean and standard deviation of the mean squared error after 50 iterations, for the case of  normalized data with a model of 3 hidden layers is:

# %%
def get_report(name_of_case, mean_mse, std_mse):
    """Get report of mse and std: 
    The mean and the standard deviation of the mean squared errors
    """
    COL_NAME_EXPERIMENT = "Experiment"
    COL_NAME_MSE = "Mean MSE"
    COL_NAME_RMSE = "Std Deviation MSE"
    header_of_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
    values = [[name_of_case, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_mse_and_rmse, data=values)

# %%
name_of_case = "Baseline  normalized 3 hidden layers (50 epochs)"

# Report the mean and the standard deviation of the mean squared errors
df_baseline_norm3hid = get_report(name_of_case, mean_mse, std_mse)
df_baseline_norm3hid
# Out:
#                                          Experiment  Mean MSE  \
# 0  Baseline  normalized 3 hidden layers (50 epochs)     41.66
#
#    Std Deviation MSE
# 0              14.25

# %% [markdown]
# Comparing the normalized cases with one and three hidden layers

# %%
# Create a data frame with the summary
df_summary = pd.concat([df_baseline, df_baseline_norm, df_baseline_norm100, df_baseline_norm3hid], axis=0)

# Review the result dataframe
df_summary.reset_index(drop=True)
# Out:
#                                          Experiment  Mean MSE  \
# 0               Baseline-not normalized (50 epochs)     82.33
# 1                  Baseline  normalized (50 epochs)     49.40
# 2                 Baseline  normalized (100 epochs)     40.77
# 3  Baseline  normalized 3 hidden layers (50 epochs)     41.66
#
#    Std Deviation MSE
# 0             102.66
# 1              51.66
# 2              16.02
# 3              14.25

# %% [markdown]
# We can observe that increasing the number of hidden layers from one to three, resulted in a decrease in mean MSE and a more significant decrease in the std deviation of the mse
